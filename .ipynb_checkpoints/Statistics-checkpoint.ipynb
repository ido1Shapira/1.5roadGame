# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import seaborn as sns

path = 'road-game-default-rtdb-export.json'

branchs = ['all-games','complete-games']
childs = ['additional_comments',
          'log',
         'aggressively_value',
         'behavior',
         'birthYear',
         'computer_value',
         'drivinglicense',
         'education',
         'gender',
         'generously_value',
         'redScore',
          'blueScore',
         'steps',
         'win',
         'wisely_value']

# with open(path) as json_file:
#     data = json.load(json_file)
#     num_of_games = len(data[branchs[1]])
#     print("number of %s is %d" % (branchs[1], num_of_games))
#     for game_id in data[branchs[1]].values():
#         for child in childs:
#             print(child, game_id[child])
#         print()

# %%
#load data from the json file
with open(path) as train_file:
    data = json.load(train_file)

# %%
branch = branchs[1]
df = pd.DataFrame.from_dict(data[branch], orient='index')
df.reset_index(level=0, inplace=True)
df
# Out:
#                    index additional_comments aggressively_value  \
# 0   -MZiWIwdnrn8TJ034z2w                                      5
# 1   -MZiWUxZs8BvWglGhc9r                                      2
# 2   -MZiWYgxyToIiCSDQY8S                                      5
# 3   -MZiWYz_z_BcQlpReXf_                                      6
# 4   -MZiWaNZ6n3K3AZDfr-q                                      6
# ..                   ...                 ...                ...
# 95  -MZj55Ev79aO0EAwzM9U                                      2
# 96  -MZj9IqoiqXvW2JHstPR                                      2
# 97  -MZj9QsFKzqjSmi0lyc3                                      2
# 98  -MZjCIu-JGJGnQs73IMe                                      6
# 99  -MZjJAN58QB0S4683T6o                                      2
#
#                   behavior birthYear  blueScore computer_value drivinglicense  \
# 0          carefulBehavior      1961        -10              5          valid
# 1          carefulBehavior      1982        -11              6          valid
# 2       aggressiveBehavior      1953        -94              7          valid
# 3       aggressiveBehavior      1990          6              7          valid
# 4       aggressiveBehavior      1953        -94              6          valid
# ..                     ...       ...        ...            ...            ...
# 95         carefulBehavior      1984        -10              4          valid
# 96      aggressiveBehavior      1972          6              7          valid
# 97         carefulBehavior      1978        -12              4          valid
# 98  semiAggressiveBehavior      1984       -106              6          valid
# 99  semiAggressiveBehavior      1975          5              7          valid
#
#           education  gender generously_value  \
# 0                BA    male                6
# 1                BA  female                4
# 2                BA  female                2
# 3   Master's degree    male                2
# 4                BA  female                2
# ..              ...     ...              ...
# 95               BA  female                6
# 96      High School  female                6
# 97      High School    male                5
# 98               BA    male                6
# 99               BA  female                4
#
#                                                   log  \
# 0   [None, {'blue': 'from: a6, action: left', 'red...
# 1   [None, {'blue': 'from: a6, action: left', 'red...
# 2   [None, {'blue': 'from: a6, action: left', 'red...
# 3   [None, {'blue': 'from: a6, action: left', 'red...
# 4   [None, {'blue': 'from: a6, action: left', 'red...
# ..                                                ...
# 95  [None, {'blue': 'from: a6, action: left', 'red...
# 96  [None, {'blue': 'from: a6, action: left', 'red...
# 97  [None, {'blue': 'from: a6, action: left', 'red...
# 98  [None, {'blue': 'from: a6, action: left', 'red...
# 99  [None, {'blue': 'from: a6, action: left', 'red...
#
#     press-the-read-instructions-button  redScore  steps    win wisely_value
# 0                                 True         3      7   True            1
# 1                                 True         2      8   True            4
# 2                                 True      -105      5  False            6
# 3                                 True         1      9   True            2
# 4                                 True      -105      5  False            1
# ..                                 ...       ...    ...    ...          ...
# 95                                True         3      7   True            4
# 96                                True         2      8   True            4
# 97                                True         1      9   True            2
# 98                                True      -104      4  False            6
# 99                                True         1      9   True            6
#
# [100 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['index', 'additional_comments', 'aggressively_value', 'behavior',
#        'birthYear', 'blueScore', 'computer_value', 'drivinglicense',
#        'education', 'gender', 'generously_value', 'log',
#        'press-the-read-instructions-button', 'redScore', 'steps', 'win',
#        'wisely_value'],
#       dtype='object')

# %% [markdown]
# ## Survay results:

# %%
df['additional_comments']
# Out:
# 0
# 1
# 2
# 3
# 4
#      ..
# 95
# 96
# 97
# 98
# 99
# Name: additional_comments, Length: 100, dtype: object

# %%
df.groupby('behavior')[['blueScore','redScore','steps','win']].mean()
# Out:
#                         blueScore   redScore     steps       win
# behavior
# aggressiveBehavior     -35.548387 -38.967742  6.387097  0.612903
# carefulBehavior         -9.428571   2.285714  7.714286  1.000000
# semiAggressiveBehavior -72.000000 -74.121951  6.317073  0.292683

# %%
# Sort the dataframe by target
target_0 = df.loc[df['behavior'] == 'carefulBehavior']
target_1 = df.loc[df['behavior'] == 'semiAggressiveBehavior']
target_2 = df.loc[df['behavior'] == 'aggressiveBehavior']

sns.distplot(target_0[['aggressively_value']], bins = 10)
sns.distplot(target_1[['aggressively_value']], bins = 10)
sns.distplot(target_2[['aggressively_value']], bins = 10)

# %%
target_0[target_0['aggressively_value'] == '3'].count()
# Out:
# index                                 2
# additional_comments                   2
# aggressively_value                    2
# behavior                              2
# birthYear                             2
# blueScore                             2
# computer_value                        2
# drivinglicense                        2
# education                             2
# gender                                2
# generously_value                      2
# log                                   2
# press-the-read-instructions-button    2
# redScore                              2
# steps                                 2
# win                                   2
# wisely_value                          2
# dtype: int64

# %%
target_0.count()
# Out:
# index                                 28
# additional_comments                   28
# aggressively_value                    28
# behavior                              28
# birthYear                             28
# blueScore                             28
# computer_value                        28
# drivinglicense                        28
# education                             28
# gender                                28
# generously_value                      28
# log                                   28
# press-the-read-instructions-button    28
# redScore                              28
# steps                                 28
# win                                   28
# wisely_value                          28
# dtype: int64

# %%
fig,(ax1) = plt.subplots(ncols=1, figsize=(8,5))
sns.kdeplot(df.aggressively_value[df['behavior'] == 'carefulBehavior'], label='carefulBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'semiAggressiveBehavior'], label='semiAggressiveBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'aggressiveBehavior'], label='aggressiveBehavior', shade=True)
ax1.set_ylabel('Distribution')
ax1.set_xlabel('aggressively_value')
# Out:
# Text(0.5, 0, 'aggressively_value')

# %%
def count_plot_by_behavior(feature):
    sns.countplot(x=df[feature],hue=df['behavior'])
    plt.show()
    
for value in ['aggressively_value', 'computer_value', 'generously_value', 'wisely_value']:
    count_plot_by_behavior(value)

# %%
def pie_count_plot(feature):
    list_gen=df[feature].value_counts().plot.pie(figsize=(6, 6))
    title = 'Distribution by: ', feature
    plt.title(title)
    plt.show()
    
for value in ['birthYear', 'drivinglicense', 'education', 'gender', 'redScore', 'steps', 'win']:
    pie_count_plot(value)

# %%
df.groupby('win')['gender'].value_counts().plot.pie(figsize=(6, 6))

# %%
df.groupby('gender')['redScore'].mean().plot()
sns.barplot(y='redScore',x='gender', data=df)

# %%
df.groupby('gender').describe()
# Out:
#        blueScore                                                     redScore  \
#            count       mean        std    min    25%   50%  75%  max    count
# gender
# female      43.0 -47.720930  51.784041 -106.0 -105.0 -10.0  5.5  6.0     43.0
# male        57.0 -39.754386  49.997957 -106.0 -105.0 -10.0  5.0  6.0     57.0
#
#                    ...           steps                                     \
#              mean  ...  75%  max count      mean       std  min  25%  50%
# gender             ...
# female -47.744186  ...  2.0  3.0  43.0  6.581395  2.701257  3.0  4.5  7.0
# male   -37.368421  ...  3.0  5.0  57.0  6.842105  2.763212  3.0  4.0  7.0
#
#
#         75%   max
# gender
# female  8.0  18.0
# male    9.0  14.0
#
# [2 rows x 24 columns]

# %%
df.describe()
# Out:
#         blueScore    redScore       steps
# count  100.000000  100.000000  100.000000
# mean   -43.180000  -41.830000    6.730000
# std     50.669334   52.701763    2.726062
# min   -106.000000 -114.000000    3.000000
# 25%   -105.000000 -104.000000    4.000000
# 50%    -10.000000    1.000000    7.000000
# 75%      5.000000    3.000000    8.000000
# max      6.000000    5.000000   18.000000

# %% [markdown]
# # Statistics of the red agent movements:

# %%
new_df = pd.concat([pd.DataFrame(pd.json_normalize(x)) for x in df['log']],ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-19983f417162> in <module>
# ----> 1 new_df = pd.concat([pd.DataFrame(pd.json_normalize(x)) for x in df['log']],ignore_index=True)
#
# <ipython-input-17-19983f417162> in <listcomp>(.0)
# ----> 1 new_df = pd.concat([pd.DataFrame(pd.json_normalize(x)) for x in df['log']],ignore_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     272
#     273     if record_path is None:
# --> 274         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     275             # naive normalization, this is idempotent for flat records
#     276             # and potentially will inflate the data considerably for
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in <genexpr>(.0)
#     272
#     273     if record_path is None:
# --> 274         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     275             # naive normalization, this is idempotent for flat records
#     276             # and potentially will inflate the data considerably for
#
# AttributeError: 'NoneType' object has no attribute 'values'

# %%
statistics_raw = pd.DataFrame.from_dict(data['all-games'], orient='index')
log_red = flat_table.normalize(statistics_raw).iloc[:,-2:]
log_red = log_red.dropna()
log_red['log.red'] = log_red['log.red'] + ' ' + log_red['log.blue']
log_red = log_red.drop('log.blue', axis=1)
log_red['log.red'] = log_red.apply(lambda x: x['log.red'].rsplit(' ', 1)[0], axis = 1)
log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace('from: ', '', 2), axis = 1)
log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(', action:', '', 2), axis = 1)
log_red['log.red'] = log_red['log.red'].str.split().apply(reversed).apply(' '.join)
log_red['value']=1

log_red['action'] = log_red['log.red'].str.split().str[1]
log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(x['action'], '', 2), axis = 1)


log_red = log_red.groupby(['log.red', 'action']).count()

log_red.reset_index(inplace=True)
log_red = log_red.set_index('log.red')

# log_red.rename(columns = {'value': 'ido'}, inplace = False)
# log_red.replace(to_replace =["from: a1, action: right"], 
#                             value ="ido")
log_red
# Out:
#         action  value
# log.red
# a1  a2   right      5
# a1  a3   right     24
# a1  a4   right     32
# a1  a5   right     34
# a1  b1    stay     19
# ...        ...    ...
# b4  a4   right     26
# b4  a4    stay      2
# b4  a5   right     26
# b4  b3    stay      6
# b4  b3      up     21
#
# [77 rows x 2 columns]

# %%
idx = log_red.index.drop_duplicates()
result = pd.DataFrame('x', index=log_red.index.drop_duplicates(), columns=['right', 'stay', 'up', 'down'])
# result.reset_index(level=0, inplace=True)
result
# Out:
#         right stay up down
# log.red
# a1  a2      x    x  x    x
# a1  a3      x    x  x    x
# a1  a4      x    x  x    x
# a1  a5      x    x  x    x
# a1  b1      x    x  x    x
# a1  b2      x    x  x    x
# a1  b3      x    x  x    x
# a2  a1      x    x  x    x
# a2  a3      x    x  x    x
# a2  a4      x    x  x    x
# a2  b1      x    x  x    x
# a2  b2      x    x  x    x
# a2  b3      x    x  x    x
# a3  a1      x    x  x    x
# a3  a2      x    x  x    x
# a3  a5      x    x  x    x
# a3  b1      x    x  x    x
# a3  b2      x    x  x    x
# a3  b3      x    x  x    x
# a4  a1      x    x  x    x
# a4  a2      x    x  x    x
# a4  a3      x    x  x    x
# a4  b1      x    x  x    x
# a4  b2      x    x  x    x
# a4  b3      x    x  x    x
# a5  a1      x    x  x    x
# a5  a2      x    x  x    x
# a5  b1      x    x  x    x
# a6  a1      x    x  x    x
# b2  a1      x    x  x    x
# b2  a2      x    x  x    x
# b2  a3      x    x  x    x
# b2  b1      x    x  x    x
# b3  a2      x    x  x    x
# b3  a3      x    x  x    x
# b3  a4      x    x  x    x
# b3  b2      x    x  x    x
# b4  a3      x    x  x    x
# b4  a4      x    x  x    x
# b4  a5      x    x  x    x
# b4  b3      x    x  x    x

# %%
def flatten(js):
    return pd.DataFrame(js).squeeze()

a = df.log.apply(flatten).drop(0, axis=1)
# a = a.fillna()
a
# Out:
#                                                    1   \
# 0   {'blue': 'from: a6, action: left', 'red': 'fro...
# 1   {'blue': 'from: a6, action: left', 'red': 'fro...
# 2   {'blue': 'from: a6, action: left', 'red': 'fro...
# 3   {'blue': 'from: a6, action: left', 'red': 'fro...
# 4   {'blue': 'from: a6, action: left', 'red': 'fro...
# ..                                                ...
# 95  {'blue': 'from: a6, action: left', 'red': 'fro...
# 96  {'blue': 'from: a6, action: left', 'red': 'fro...
# 97  {'blue': 'from: a6, action: left', 'red': 'fro...
# 98  {'blue': 'from: a6, action: left', 'red': 'fro...
# 99  {'blue': 'from: a6, action: left', 'red': 'fro...
#
#                                                    2   \
# 0   {'blue': 'from: a5, action: left', 'red': 'fro...
# 1   {'blue': 'from: a5, action: left', 'red': 'fro...
# 2   {'blue': 'from: a5, action: left', 'red': 'fro...
# 3   {'blue': 'from: a5, action: left', 'red': 'fro...
# 4   {'blue': 'from: a5, action: left', 'red': 'fro...
# ..                                                ...
# 95  {'blue': 'from: a5, action: left', 'red': 'fro...
# 96  {'blue': 'from: a5, action: left', 'red': 'fro...
# 97  {'blue': 'from: a5, action: left', 'red': 'fro...
# 98  {'blue': 'from: a5, action: left', 'red': 'fro...
# 99  {'blue': 'from: a5, action: left', 'red': 'fro...
#
#                                                    3   \
# 0   {'blue': 'from: a4, action: down', 'red': 'fro...
# 1   {'blue': 'from: a4, action: down', 'red': 'fro...
# 2   {'blue': 'from: a4, action: left', 'red': 'fro...
# 3   {'blue': 'from: a4, action: left', 'red': 'fro...
# 4   {'blue': 'from: a4, action: left', 'red': 'fro...
# ..                                                ...
# 95  {'blue': 'from: a4, action: down', 'red': 'fro...
# 96  {'blue': 'from: a4, action: left', 'red': 'fro...
# 97  {'blue': 'from: a4, action: down', 'red': 'fro...
# 98  {'blue': 'from: a4, action: stay', 'red': 'fro...
# 99  {'blue': 'from: a4, action: stay', 'red': 'fro...
#
#                                                    4   \
# 0   {'blue': 'from: b4, action: stay', 'red': 'fro...
# 1   {'blue': 'from: b4, action: stay', 'red': 'fro...
# 2   {'blue': 'from: a3, action: left', 'red': 'fro...
# 3   {'blue': 'from: a3, action: left', 'red': 'fro...
# 4   {'blue': 'from: a3, action: left', 'red': 'fro...
# ..                                                ...
# 95  {'blue': 'from: b4, action: stay', 'red': 'fro...
# 96  {'blue': 'from: a3, action: left', 'red': 'fro...
# 97  {'blue': 'from: b4, action: stay', 'red': 'fro...
# 98  {'blue': 'from: a4, action: left', 'red': 'fro...
# 99  {'blue': 'from: a4, action: left', 'red': 'fro...
#
#                                                    5   \
# 0   {'blue': 'from: b4, action: stay', 'red': 'fro...
# 1   {'blue': 'from: b4, action: stay', 'red': 'fro...
# 2   {'blue': 'from: a2, action: left', 'red': 'fro...
# 3   {'blue': 'from: a2, action: left', 'red': 'fro...
# 4   {'blue': 'from: a2, action: left', 'red': 'fro...
# ..                                                ...
# 95  {'blue': 'from: b4, action: stay', 'red': 'fro...
# 96  {'blue': 'from: a2, action: left', 'red': 'fro...
# 97  {'blue': 'from: b4, action: stay', 'red': 'fro...
# 98                                                NaN
# 99  {'blue': 'from: a3, action: left', 'red': 'fro...
#
#                                                    6   \
# 0   {'blue': 'from: b4, action: stay', 'red': 'fro...
# 1   {'blue': 'from: b4, action: stay', 'red': 'fro...
# 2                                                 NaN
# 3   {'blue': 'from: a1, action: stay', 'red': 'fro...
# 4                                                 NaN
# ..                                                ...
# 95  {'blue': 'from: b4, action: stay', 'red': 'fro...
# 96  {'blue': 'from: a1, action: stay', 'red': 'fro...
# 97  {'blue': 'from: b4, action: stay', 'red': 'fro...
# 98                                                NaN
# 99  {'blue': 'from: a2, action: left', 'red': 'fro...
#
#                                                    7   \
# 0   {'blue': 'from: b4, action: up', 'red': 'from:...
# 1   {'blue': 'from: b4, action: stay', 'red': 'fro...
# 2                                                 NaN
# 3   {'blue': 'from: a1, action: stay', 'red': 'fro...
# 4                                                 NaN
# ..                                                ...
# 95  {'blue': 'from: b4, action: up', 'red': 'from:...
# 96  {'blue': 'from: a1, action: stay', 'red': 'fro...
# 97  {'blue': 'from: b4, action: stay', 'red': 'fro...
# 98                                                NaN
# 99  {'blue': 'from: a1, action: stay', 'red': 'fro...
#
#                                                    8   \
# 0                                                 NaN
# 1   {'blue': 'from: b4, action: up', 'red': 'from:...
# 2                                                 NaN
# 3   {'blue': 'from: a1, action: stay', 'red': 'fro...
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96  {'blue': 'from: a1, action: stay', 'red': 'fro...
# 97  {'blue': 'from: b4, action: stay', 'red': 'fro...
# 98                                                NaN
# 99  {'blue': 'from: a1, action: stay', 'red': 'fro...
#
#                                                    9    10   11   12   13  \
# 0                                                 NaN  NaN  NaN  NaN  NaN
# 1                                                 NaN  NaN  NaN  NaN  NaN
# 2                                                 NaN  NaN  NaN  NaN  NaN
# 3   {'blue': 'from: a1, action: stay', 'red': 'fro...  NaN  NaN  NaN  NaN
# 4                                                 NaN  NaN  NaN  NaN  NaN
# ..                                                ...  ...  ...  ...  ...
# 95                                                NaN  NaN  NaN  NaN  NaN
# 96                                                NaN  NaN  NaN  NaN  NaN
# 97  {'blue': 'from: b4, action: up', 'red': 'from:...  NaN  NaN  NaN  NaN
# 98                                                NaN  NaN  NaN  NaN  NaN
# 99  {'blue': 'from: a1, action: stay', 'red': 'fro...  NaN  NaN  NaN  NaN
#
#      14   15   16   17   18
# 0   NaN  NaN  NaN  NaN  NaN
# 1   NaN  NaN  NaN  NaN  NaN
# 2   NaN  NaN  NaN  NaN  NaN
# 3   NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN  NaN
# ..  ...  ...  ...  ...  ...
# 95  NaN  NaN  NaN  NaN  NaN
# 96  NaN  NaN  NaN  NaN  NaN
# 97  NaN  NaN  NaN  NaN  NaN
# 98  NaN  NaN  NaN  NaN  NaN
# 99  NaN  NaN  NaN  NaN  NaN
#
# [100 rows x 18 columns]

# %%
# pd.concat([pd.json_normalize(a[4]).add_prefix(f'{2}.') for i in a.columns], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-401e7a1cfacd> in <module>
# ----> 1 pd.concat([pd.json_normalize(a[4]).add_prefix(f'{2}.') for i in a.columns], axis=1)
#
# <ipython-input-37-401e7a1cfacd> in <listcomp>(.0)
# ----> 1 pd.concat([pd.json_normalize(a[4]).add_prefix(f'{2}.') for i in a.columns], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     280             # TODO: handle record value which are lists, at least error
#     281             #       reasonably
# --> 282             data = nested_to_record(data, sep=sep, max_level=max_level)
#     283         return DataFrame(data)
#     284     elif not isinstance(record_path, list):
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in nested_to_record(ds, prefix, sep, level, max_level)
#      82     for d in ds:
#      83         new_d = copy.deepcopy(d)
# ---> 84         for k, v in d.items():
#      85             # each key gets renamed with prefix
#      86             if not isinstance(k, str):
#
# AttributeError: 'float' object has no attribute 'items'

# %%
red_moves.columns
# Out:
# Index(['right', 'stay', 'up', 'down'], dtype='object')

# %%
red_moves = pd.DataFrame.from_dict(data['statistics'], orient='index')
# red_moves.reset_index(level=0, inplace=True)
red_moves = red_moves.fillna(0)
red_moves
# Out:
#        right  stay    up  down
# a1 a2   5.00  0.00  0.00  0.00
# a1 a3  24.00  0.00  0.00  0.00
# a1 a4  32.00  0.00  0.00  0.00
# a1 a5  34.00  0.00  0.00  0.00
# a2 a1   2.00  4.00  0.00  4.00
# a2 a3   8.00  0.00  0.00  0.00
# a2 a4   2.00  0.00  0.00  0.00
# a3 a1   3.00  5.00  0.00  2.00
# a3 a2   4.00  1.00  0.00 13.00
# a3 a5   3.00  0.00  0.00  0.00
# a4 a1  10.00  6.00  0.00  2.00
# a4 a2   3.00  1.00  0.00  0.00
# a4 a3  11.00  1.00  0.00 60.00
# a5 a1  28.00  9.00  0.00  2.00
# a5 a2  71.00  2.00  0.00  8.00
# a6 a1  81.00 12.00  0.00 19.00
# b2 a1   2.00  2.00  0.00  2.00
# b2 a2   2.00  0.00  0.00  0.00
# b2 a3   2.00  0.00  0.00  0.00
# b3 a2   2.00  0.00  0.00  0.00
# b3 a3   3.00  0.00  0.00  0.00
# b3 a4   3.00  0.00  0.00  0.00
# b4 a1  68.00  0.00  0.00  0.00
# b4 a2  58.00  0.00  0.00  0.00
# b4 a3  14.00  1.00  0.00  2.00
# b4 a4  26.00  2.00  0.00  0.00
# b4 a5  26.00  0.00  0.00  0.00
# a1 b1   0.00 17.00  5.00  0.00
# a1 b3   0.00  3.00  2.00  0.00
# a2 b1   0.00  7.00  4.00  0.00
# a2 b2   0.00  4.00  2.00  0.00
# a2 b3   0.00 16.00 17.00  0.00
# a3 b1   0.00  5.00  3.00  0.00
# a3 b2   0.00  4.00  6.00  0.00
# a3 b3   0.00 18.00  8.00  0.00
# a4 b1   0.00  5.00  4.00  0.00
# a4 b2   0.00  1.00  7.00  0.00
# a4 b3   0.00  9.00 14.00  0.00
# a5 b1   0.00  9.00 10.00  0.00
# b2 b1   0.00 14.00  3.00  0.00
# b4 b3   0.00  6.00 21.00  0.00
# a1 b2   0.00  0.00  3.00  0.00
# b3 b2   0.00  0.00  2.00  0.00

# %% [markdown]
# ## Distribution of red agent movements:

# %%
pd.options.display.float_format = "{:,.2f}".format
red_moves.div(red_moves.sum(axis=1), axis=0)
# Out:
#        right  stay   up  down
# a1 a2   1.00  0.00 0.00  0.00
# a1 a3   1.00  0.00 0.00  0.00
# a1 a4   1.00  0.00 0.00  0.00
# a1 a5   1.00  0.00 0.00  0.00
# a2 a1   0.20  0.40 0.00  0.40
# a2 a3   1.00  0.00 0.00  0.00
# a2 a4   1.00  0.00 0.00  0.00
# a3 a1   0.30  0.50 0.00  0.20
# a3 a2   0.22  0.06 0.00  0.72
# a3 a5   1.00  0.00 0.00  0.00
# a4 a1   0.56  0.33 0.00  0.11
# a4 a2   0.75  0.25 0.00  0.00
# a4 a3   0.15  0.01 0.00  0.83
# a5 a1   0.72  0.23 0.00  0.05
# a5 a2   0.88  0.02 0.00  0.10
# a6 a1   0.72  0.11 0.00  0.17
# b2 a1   0.33  0.33 0.00  0.33
# b2 a2   1.00  0.00 0.00  0.00
# b2 a3   1.00  0.00 0.00  0.00
# b3 a2   1.00  0.00 0.00  0.00
# b3 a3   1.00  0.00 0.00  0.00
# b3 a4   1.00  0.00 0.00  0.00
# b4 a1   1.00  0.00 0.00  0.00
# b4 a2   1.00  0.00 0.00  0.00
# b4 a3   0.82  0.06 0.00  0.12
# b4 a4   0.93  0.07 0.00  0.00
# b4 a5   1.00  0.00 0.00  0.00
# a1 b1   0.00  0.77 0.23  0.00
# a1 b3   0.00  0.60 0.40  0.00
# a2 b1   0.00  0.64 0.36  0.00
# a2 b2   0.00  0.67 0.33  0.00
# a2 b3   0.00  0.48 0.52  0.00
# a3 b1   0.00  0.62 0.38  0.00
# a3 b2   0.00  0.40 0.60  0.00
# a3 b3   0.00  0.69 0.31  0.00
# a4 b1   0.00  0.56 0.44  0.00
# a4 b2   0.00  0.12 0.88  0.00
# a4 b3   0.00  0.39 0.61  0.00
# a5 b1   0.00  0.47 0.53  0.00
# b2 b1   0.00  0.82 0.18  0.00
# b4 b3   0.00  0.22 0.78  0.00
# a1 b2   0.00  0.00 1.00  0.00
# b3 b2   0.00  0.00 1.00  0.00
