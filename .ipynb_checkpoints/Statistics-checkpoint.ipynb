# %%
import json
import glob
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import seaborn as sns
import numpy as np
import pprint
pp = pprint.PrettyPrinter(depth=4)


path = './data/road-game-default-rtdb-export.json'

branchs = ['all-games','complete-games']

# %%
#load data from the json file
with open(path) as train_file:
    data = json.load(train_file)

# %%
branch = branchs[0]
df = pd.DataFrame.from_dict(data[branch], orient='index')
df.reset_index(level=0, inplace=True)
df
# Out:
#                     index additional_comments aggressively_value  \
# 0    -MZiWIwdnrn8TJ034z2w                                      5
# 1    -MZiWUxZs8BvWglGhc9r                                      2
# 2    -MZiWYgxyToIiCSDQY8S                                      5
# 3    -MZiWYz_z_BcQlpReXf_                                      6
# 4    -MZiWaNZ6n3K3AZDfr-q                                      6
# ..                    ...                 ...                ...
# 673  -MbcURCQaLlJFHGxAvyW                 NaN                NaN
# 674  -MbcbjkKh8M10JRrqfwb                 NaN                NaN
# 675  -MbcfQpUktm_lYEmxpz2                 NaN                NaN
# 676  -Mbcz6inzp9NEdJCbK17                 NaN                NaN
# 677             undefined                 NaN                NaN
#
#                            behavior birthYear  blueScore computer_value  \
# 0                   carefulBehavior      1961       20.0              5
# 1                   carefulBehavior      1982       19.0              6
# 2                aggressiveBehavior      1953     -105.0              7
# 3                aggressiveBehavior      1990       34.0              7
# 4                aggressiveBehavior      1953     -105.0              6
# ..                              ...       ...        ...            ...
# 673  valueIterationBasedBehavior_v2       NaN        NaN            NaN
# 674  valueIterationBasedBehavior_v2       NaN        NaN            NaN
# 675  valueIterationBasedBehavior_v2       NaN        NaN            NaN
# 676  valueIterationBasedBehavior_v2       NaN        NaN            NaN
# 677                             NaN       NaN        NaN            NaN
#
#     drivinglicense        education  gender generously_value  \
# 0            valid               BA    male                6
# 1            valid               BA  female                4
# 2            valid               BA  female                2
# 3            valid  Master's degree    male                2
# 4            valid               BA  female                2
# ..             ...              ...     ...              ...
# 673            NaN              NaN     NaN              NaN
# 674            NaN              NaN     NaN              NaN
# 675            NaN              NaN     NaN              NaN
# 676            NaN              NaN     NaN              NaN
# 677            NaN              NaN     NaN              NaN
#
#                                                    log  \
# 0    [None, {'blue': 'from: a6, action: left', 'red...
# 1    [None, {'blue': 'from: a6, action: left', 'red...
# 2    [None, {'blue': 'from: a6, action: left', 'red...
# 3    [None, {'blue': 'from: a6, action: left', 'red...
# 4    [None, {'blue': 'from: a6, action: left', 'red...
# ..                                                 ...
# 673                                                NaN
# 674                                                NaN
# 675                                                NaN
# 676                                                NaN
# 677                                                NaN
#
#     press-the-read-instructions-button  redScore  steps    win wisely_value  \
# 0                                 True      23.0    7.0   True            1
# 1                                 True      22.0    8.0   True            4
# 2                                 True    -105.0    5.0  False            6
# 3                                 True      21.0    9.0   True            2
# 4                                 True    -105.0    5.0  False            1
# ..                                 ...       ...    ...    ...          ...
# 673                                NaN       NaN    NaN    NaN          NaN
# 674                                NaN       NaN    NaN    NaN          NaN
# 675                                NaN       NaN    NaN    NaN          NaN
# 676                                NaN       NaN    NaN    NaN          NaN
# 677                               True       NaN    NaN    NaN          NaN
#
#     predictable_value answer-the-quiz
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# ..                ...             ...
# 673               NaN             NaN
# 674               NaN             NaN
# 675               NaN             NaN
# 676               NaN             NaN
# 677               NaN            True
#
# [678 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['index', 'additional_comments', 'aggressively_value', 'behavior',
#        'birthYear', 'blueScore', 'computer_value', 'drivinglicense',
#        'education', 'gender', 'generously_value', 'log',
#        'press-the-read-instructions-button', 'redScore', 'steps', 'win',
#        'wisely_value', 'predictable_value', 'answer-the-quiz'],
#       dtype='object')

# %%
# df = df[df['answer-the-quiz'].notnull()]

# %% [markdown]
# number of people that start to play:

# %%
df['press-the-read-instructions-button'].count()
# Out:
# 559

# %%
len(df)
# Out:
# 678

# %%
# df[['blueScore']]

# %%
# df.loc[df['win'] == True, ['redScore']] += 20
# df[df['answer-the-quiz'].notnull()].loc[df['win'] == True, ['blueScore']] += 30

# %%
# df.loc[(df['win'] == True) & (df['answer-the-quiz'].notnull()), ['blueScore']] += 30

# %%
# df.loc[(df['win'] == True) & (df['answer-the-quiz'].notnull()) & (), ['blueScore', 'behavior']].groupby('behavior').mean()

# %%
# df.loc[df['win'] == False, ['blueScore']] = df.loc[df['win'] == False, ['redScore']].to_numpy()

# %%
# df.loc[df['win'] == False, ['blueScore', 'redScore']]

# %%
# df.loc[(df['win'] == True) & (df['answer-the-quiz'].notnull()), ['blueScore', 'behavior']].groupby('behavior').min()

# %%
# df.to_json('data/test.json', orient = "index", indent=2)

# %% [markdown]
# ## Survay results:

# %% [markdown]
# upload Id workers and search for duplicate workers

# %%
path = './data/workers' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    fromOne = pd.read_csv(filename, index_col=None, header=0)
    fromOne['filename'] = filename
    li.append(fromOne)

workers = pd.concat(li, axis=0, ignore_index=True)

# %%
df['WorkerId'] = workers['WorkerId']

# %%
pd.concat(g for _, g in df.groupby('WorkerId') if len(g) > 1).groupby('WorkerId')['index'].count()
# Out:
# WorkerId
# A17AF42SNQNH9C    5
# A1AZLJ3R5FQ9B7    2
# A1BQI9JKLVCIL0    2
# A1K1E4KCVW1HOZ    3
# A1KZ21TSAYUHO4    2
# A1OW27AZS122X2    2
# A1QKW8E5J7NAF2    2
# A209KMZQTLEZZC    2
# A244IQQR0CTZ3I    2
# A2DCKE7398C0XV    2
# A2I6ZALE49CVSC    2
# A2IFXO71MXB9GK    2
# A2OU4N4VBIE91I    2
# A2YR29YNFLZSUG    2
# A2ZRL1ZWWXJ0L7    3
# A30YR5TPOKQYXJ    2
# A33XAJW8WGY3O9    2
# A34CPKFZXBX1PO    2
# A36UD0YBRIWTVL    2
# A37XBH865833FE    2
# A39ICPRR4OS3OX    2
# A3ADHMAWDD7M6V    2
# A3GWRDHAURRNK6    2
# A3H073G4EPBYOM    2
# A3H3BTRV6I3LYU    2
# A3KK1BNF5H0N1Z    3
# A3L7TVDAMZM0FG    2
# A3P35II1RN3FYV    2
# A3UWHJTAUTF6TO    2
# A6JUD4NCQCDWG     2
# ACXP8KHFX06KR     3
# AD1ILDUXZHASF     3
# ASNMT3I94HZ44     2
# ATJ92FYQX176Z     4
# Name: index, dtype: int64

# %% [markdown]
# We will keep the first one of any 'WorkerId' instance to keep samples unique

# %%
df = df.drop_duplicates(subset=['WorkerId'])

# %% [markdown]
# number of people that answer the survay:

# %%
df['birthYear'].count()
# Out:
# 403

# %%
df['additional_comments'][df['additional_comments'].notna()][df['additional_comments'] != ""]
# Out:
# 8                                    Thankyouandstaysafe
# 11     Icouldn'tmovetotherightusingtherightarrowasins...
# 12                                                  none
# 24                                           GodBlessYou
# 34                                                  none
#                              ...
# 370                                               Thanks
# 398                                            Thankyou.
# 406                                                 None
# 426                                                 Good
# 429                                                  N/A
# Name: additional_comments, Length: 64, dtype: object

# %%
df.loc[:, ['aggressively_value', 'computer_value', 'generously_value', 'wisely_value', 'predictable_value']] = df.loc[:, ['aggressively_value', 'computer_value', 'generously_value', 'wisely_value', 'predictable_value']].apply(pd.to_numeric)
# Out:
# /home/ido/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1786: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)

# %%
df.groupby('behavior').mean().drop('carefulBehavior')
# Out:
#                                 aggressively_value  blueScore  computer_value  \
# behavior
# aggressiveBehavior                            5.05     -13.43            5.89
# randomBehavior                                3.49     -58.26            5.68
# semiAggressiveBehavior                        4.59     -55.68            5.73
# semiCarefulBehavior                           4.01     -11.35            5.76
# valueIterationBasedBehavior_v2                4.77      -1.39            6.04
#
#                                 generously_value  redScore  steps  \
# behavior
# aggressiveBehavior                          3.27    -18.68   6.89
# randomBehavior                              4.03    -45.41  10.56
# semiAggressiveBehavior                      3.17    -58.41   6.56
# semiCarefulBehavior                         4.16     -1.61  14.28
# valueIterationBasedBehavior_v2              3.64     -6.28   8.92
#
#                                 wisely_value  predictable_value
# behavior
# aggressiveBehavior                      4.48               4.85
# randomBehavior                          3.74               3.44
# semiAggressiveBehavior                  4.30               4.51
# semiCarefulBehavior                     5.00               4.36
# valueIterationBasedBehavior_v2          4.78               4.90

# %%
df.groupby('behavior')['blueScore', 'redScore'].describe()
# Out:
# <ipython-input-24-c4d30ac448c8>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('behavior')['blueScore', 'redScore'].describe()
#                                blueScore                                       \
#                                    count       mean        std    min     25%
# behavior
# aggressiveBehavior                  56.0 -13.428571  63.107659 -108.0 -103.00
# carefulBehavior                     28.0  20.571429   2.658718   15.0   20.00
# randomBehavior                      68.0 -58.264706  51.619335 -152.0 -103.25
# semiAggressiveBehavior              81.0 -55.679012  64.622331 -114.0 -105.00
# semiCarefulBehavior                 75.0 -11.346667  43.917150 -136.0  -14.50
# valueIterationBasedBehavior_v2      95.0  -1.389474  54.662464 -124.0   15.00
#
#                                                   redScore             \
#                                   50%   75%   max    count       mean
# behavior
# aggressiveBehavior               25.0  34.0  35.0     56.0 -18.678571
# carefulBehavior                  20.0  20.5  31.0     28.0  22.285714
# randomBehavior                  -85.0 -14.5  34.0     68.0 -45.411765
# semiAggressiveBehavior         -104.0  24.0  34.0     81.0 -58.407407
# semiCarefulBehavior              -8.0  18.5  32.0     75.0  -1.613333
# valueIterationBasedBehavior_v2   25.0  25.0  35.0     95.0  -6.284211
#
#
#                                       std    min     25%    50%   75%   max
# behavior
# aggressiveBehavior              59.360258 -108.0 -103.00   22.0  22.0  23.0
# carefulBehavior                  2.536506   12.0   21.75   23.0  23.0  25.0
# randomBehavior                  59.172461 -152.0 -101.50  -75.0  20.0  25.0
# semiAggressiveBehavior          60.975359 -114.0 -105.00 -104.0  20.0  22.0
# semiCarefulBehavior             50.300151 -171.0   14.00   19.0  22.0  25.0
# valueIterationBasedBehavior_v2  52.605853 -134.0   13.00   21.0  22.0  23.0

# %%
fig,(ax1) = plt.subplots(ncols=1, figsize=(8,5))
sns.kdeplot(df.aggressively_value[df['behavior'] == 'carefulBehavior'], label='carefulBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'semiAggressiveBehavior'], label='semiAggressiveBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'aggressiveBehavior'], label='aggressiveBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'randomBehavior'], label='randomBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'valueIterationBasedBehavior_v2'], label='valueIterationBasedBehavior_v2', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'semiCarefulBehavior'], label='semiCarefulBehavior', shade=True)
ax1.set_ylabel('Distribution')
ax1.set_xlabel('aggressively_value')
# Out:
# Text(0.5, 0, 'aggressively_value')

# %%
df_temp = df[df.behavior != 'carefulBehavior']

def count_plot_by_behavior(feature):
    sns.countplot(x=df_temp[feature],hue=df_temp['behavior'])
    plt.show()
    
for value in ['aggressively_value', 'computer_value', 'generously_value', 'wisely_value', 'predictable_value']:
    count_plot_by_behavior(value)

# %%
def pie_count_plot(feature):
    list_gen=df[feature].value_counts().plot.pie(figsize=(6, 6))
    title = 'Distribution by: ', feature
    plt.title(title)
    plt.show()
    
for value in ['birthYear', 'drivinglicense', 'education', 'gender', 'redScore', 'steps', 'win']:
    pie_count_plot(value)

# %%
df.groupby('win')['gender'].value_counts().plot.pie(figsize=(6, 6))
# Out:
# <AxesSubplot:ylabel='gender'>

# %%
df.groupby('gender').mean()
# Out:
#         aggressively_value  blueScore  computer_value  generously_value  \
# gender
# female            4.251572 -21.213836        5.811321          3.685535
# male              4.315574 -25.647541        5.770492          3.803279
#
#          redScore     steps  wisely_value  predictable_value
# gender
# female -20.006289  9.000000      4.544218           4.595960
# male   -23.680328  9.581967      4.310811           4.328571

# %% [markdown]
# # Statistics of the red agent movements:

# %% [markdown]
# ### Create the statistics table from the log column:

# %%
import flat_table

# %%
statistics_raw = pd.DataFrame.from_dict(data[branch], orient='index')
log_red = flat_table.normalize(statistics_raw).iloc[:,-2:]
log_red = log_red.dropna()
log_red['log.red'] = log_red['log.red'] + ' ' + log_red['log.blue']
log_red = log_red.drop('log.blue', axis=1)
log_red['log.red'] = log_red.apply(lambda x: x['log.red'].rsplit(' ', 1)[0], axis = 1)
for substr in ['from: ', ', action:']:
    log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(substr, '', 2), axis = 1)
log_red['log.red'] = log_red['log.red'].str.split().apply(reversed).apply(' '.join)
log_red['value']=1
log_red['action'] = log_red['log.red'].str.split().str[1]
log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(str(x['action'])+' ', '', 2), axis = 1)

log_red = log_red.groupby(['log.red', 'action']).count()
log_red.reset_index(inplace=True)
log_red = log_red.set_index('log.red')

# s_r = df['log'].apply(pd.Series).iloc[:,1:]
# s_r.columns = s_r.columns.astype(str)
# s_r = flat_table.normalize(s_r).drop('index', axis=1)
# log_red = pd.concat([s_r.melt(id_vars=[str(i)+'.blue' for i in range(1,int(len(s_r.columns)/2))],var_name='red', value_name="log.red").iloc[:,-2:].dropna(),
#            s_r.melt(id_vars=[str(i)+'.red' for i in range(1,int(len(s_r.columns)/2))],var_name='blue', value_name="log.blue").iloc[:,-2:].dropna()
#           ], axis=1)
# log_red = log_red.drop(['red','blue'],axis=1)
# log_red['log.red'] = log_red['log.red'] + ' ' + log_red['log.blue']
# log_red = log_red.drop('log.blue', axis=1)
# log_red['log.red'] = log_red.apply(lambda x: x['log.red'].rsplit(' ', 1)[0], axis = 1)
# for substr in ['from: ', ', action:']:
#     log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(substr, '', 2), axis = 1)
# log_red['log.red'] = log_red['log.red'].str.split().apply(reversed).apply(' '.join)
# log_red['value']=1
# log_red['action'] = log_red['log.red'].str.split().str[1]
# log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(str(x['action'])+' ', '', 2), axis = 1)

# log_red = log_red.groupby(['log.red', 'action']).count()
# log_red.reset_index(inplace=True)
# log_red = log_red.set_index('log.red')

log_red.sort_index()
# Out:
#         action  value
# log.red
# a1 a2     down      2
# a1 a2    right     32
# a1 a2     stay      1
# a1 a3     down      5
# a1 a3    right    106
# ...        ...    ...
# b6 b1     stay     11
# b6 b1       up      3
# b6 b4       up      1
# b6 b5     stay      6
# b6 b5       up     34
#
# [198 rows x 2 columns]

# %%
len(log_red.index)
log_red[log_red.index == 'a1 a5']
# Out:
#         action  value
# log.red
# a1 a5     down      6
# a1 a5    right    175
# a1 a5     stay      8

# %%
result = pd.DataFrame(index=log_red.index.drop_duplicates(), columns=['right', 'stay', 'up', 'down'])
# result.reset_index(level=0, inplace=True)
for action in ['right', 'stay', 'up', 'down']:
    result[action] = log_red[log_red['action'] == action]['value']
result = result.fillna(0)
result.reset_index(inplace=True)
result.sort_index()
# Out:
#    log.red  right   stay    up  down
# 0    a1 a2   32.0    1.0   0.0   2.0
# 1    a1 a3  106.0   10.0   0.0   5.0
# 2    a1 a4  162.0  170.0   0.0   2.0
# 3    a1 a5  175.0    8.0   0.0   6.0
# 4    a1 b1    0.0   46.0  13.0   0.0
# ..     ...    ...    ...   ...   ...
# 88   b6 a4   11.0    1.0   0.0   0.0
# 89   b6 a5   36.0    5.0   0.0   5.0
# 90   b6 b1    0.0   11.0   3.0   0.0
# 91   b6 b4    0.0    0.0   1.0   0.0
# 92   b6 b5    0.0    6.0  34.0   0.0
#
# [93 rows x 5 columns]

# %% [markdown]
# #### After Laplace's Smoothing:

# %%
for i in range(1,7):
    result.loc[result['log.red'].str.endswith('a'+str(i)), ['stay', 'right', 'down']] += 1
    
for i in range(1,7):
    result.loc[result['log.red'].str.endswith('b'+str(i)), ['stay', 'up']] += 1

result = result.set_index('log.red')
result
# Out:
#          right   stay    up  down
# log.red
# a1 a2     33.0    2.0   0.0   3.0
# a1 a3    107.0   11.0   0.0   6.0
# a1 a4    163.0  171.0   0.0   3.0
# a1 a5    176.0    9.0   0.0   7.0
# a1 b1      0.0   47.0  14.0   0.0
# ...        ...    ...   ...   ...
# b6 a4     12.0    2.0   0.0   1.0
# b6 a5     37.0    6.0   0.0   6.0
# b6 b1      0.0   12.0   4.0   0.0
# b6 b4      0.0    1.0   2.0   0.0
# b6 b5      0.0    7.0  35.0   0.0
#
# [93 rows x 4 columns]

# %% [markdown]
# #### Convert it to Probability table:

# %%
pd.options.display.float_format = "{:,.2f}".format
result_probs = result.div(result.sum(axis=1), axis=0)
# Out:
#                   right  stay   up  down
# state
# a1 a2 nxt: a1 a2   0.50  0.25 0.00  0.25
# a1 a2 nxt: a1 a3   0.86  0.07 0.00  0.07
# a1 a2 nxt: a1 b2   0.00  0.50 0.50  0.00
# a1 a3 nxt: a1 a3   0.15  0.54 0.00  0.31
# a1 a3 nxt: a1 a4   0.98  0.01 0.00  0.01
# ...                 ...   ...  ...   ...
# b6 b1 nxt: b6 a1   0.60  0.20 0.00  0.20
# b6 b1 nxt: b6 b1   0.00  0.75 0.25  0.00
# b6 b4 nxt: a6 a4   0.50  0.25 0.00  0.25
# b6 b5 nxt: b6 a5   0.74  0.11 0.00  0.14
# b6 b5 nxt: b6 b5   0.00  0.38 0.62  0.00
#
# [260 rows x 4 columns]

# %% [markdown]
# #### Save data on computer for the policy iteration:

# %%
result_probs.to_json('data/probs1.json' , orient='index', indent=4)

# %%
#To calculate the score:
crushing = -100;
richToDestination = 30;
step = -1;

# %%
'''==================================================
Initial set up                              version 1
=================================================='''
#Define all states
all_states=[]
for i in range(12):
    for j in range(12):
            all_states.append((i,j))

#Define rewards for all states
rewards = {}
for (i,j) in all_states:
    if(i == j): # crushed
        rewards[(i,j)] = crushing
    elif(i == 0): # blue agent in a1
        rewards[(i,j)] = richToDestination
    else:
        rewards[(i,j)] = step

#Dictionnary of possible actions. We have two "end" states (1,2 and 2,2)
actions = {}
for (i,j) in all_states:
    if i != 0 and i != j: #if s=(i, j) is not an "end" state
        actions[(i,j)] = ("stay", "left", "down") if (i < 6) else ("up", "stay")

#Define an initial policy
Policy={}
for s in actions.keys():
    Policy[s] = np.random.choice(actions[s])

probs = json.load(open('data/probs1.json',))
    
#Define initial value function 
V={}
for (i,j) in all_states:
    if (i,j) in actions.keys():
        V[(i,j)] = step
    if(i == 0): # blue agent in a1
        V[(i,j)] = richToDestination
    if(i == j): # crushed
        V[(i,j)] = crushing

# %%
# print('all_states: ', all_states)

# %%
# print('rewards: ', rewards)

# %%
# print('actions: ', actions)

# %%
# print('V: ', V)

# %%
def adapt_state(s):
    # takes (i,j) format state and convert it to "a|b[1-6] a|b[1-6]" format
    i = s[0]
    j = s[1]
    if i < 6:
        blueState = 'a' + str(i+1)
    else:
        blueState = 'b' + str(i-5)
    if j < 6:
        redState = 'a' + str(j+1)
    else:
        redState = 'b' + str(j-5)
    return blueState + ' ' + redState

# %%
print(adapt_state((0,1)))
print(adapt_state((0,7)))
print(adapt_state((6,8)))
print(adapt_state((10,11)))
# Out:
# a1 a2
# a1 b2
# b1 b3
# b5 b6

# %%
def newPosGivenAction(s, a, agent_i):
    # assert check
    if s[agent_i] == 5 and agent_i == 1:
        actions=["stay"]
    elif s[agent_i] == 0 and agent_i == 0:
        actions=["stay"]
    elif s[agent_i] < 6 and agent_i == 1:
        actions=["right","stay", "down"]
    elif s[agent_i] < 6 and agent_i == 0:
        actions=["left","stay", "down"]
    else:
        actions=["stay", "up"]
    assert a in actions , "action: " + str(a) + " is not vallid at state: " + str(s) + " for agent: " + str(agent_i)
    # agent_i = 0 for blue and 1 for red
    newPos = -1
    if a == "up":
        newPos = s[agent_i]-6
    if a == "down":
        newPos = s[agent_i]+6
    if a == "left":
        newPos = s[agent_i]-1
    if a == "right":
        newPos = s[agent_i]+1
    if a == "stay":
        newPos = s[agent_i]
    assert newPos > -1 and newPos < 12 , "Got out from board!\naction: " + str(a) + " ,state: " + str(s) + " for agent: " + str(agent_i)
    return newPos

# %%
def randomProbForAction(s):
    # if aX return 1/3 else (it is bX) return 1/2
    if s[1] == 5: # a6
        return 1
    if s[1] < 6:
        return 1.0/3
    else:
        return 1.0/2

# %%
def nextStateDistibution(s, a):
    # given state s and action a, return distibution of possibles new states by probs
    nxt = {}
#     print('s: ', s)
#     print('a: ', a)
    bluePossition = newPosGivenAction(s, a, 0)
#     print('bluePossition: ', bluePossition)
    
    # red possible action given state
    if s[1] == 5:
        actions=["stay"]
    elif s[1] < 6:
        actions=["right","stay", "down"]
    else:
        actions=["stay", "up"]
    for r_a in actions:
        redPossition = newPosGivenAction(s, r_a, 1)
#         print('redPossition: '+ str(redPossition))
        newState = (bluePossition, redPossition)
        try:
            nxt[newState] = probs[adapt_state(s)][r_a]
#                 nxt[newState] = {probs[adapt_state(s)][r_a], r_a, adapt_state(newState)}
        except KeyError:
#                 print("Warning! State not found: assume random behavior. ", s)
            nxt[newState] = randomProbForAction(s)
    assert abs(sum(nxt.values()) - 1.0) < 0.0001, "probs not sum to 1.0. \nstate: " + str(s) + " action: " + str(a) + " nxt: " + str(nxt) + "\nsum of probs: " + str(sum(nxt.values()))
    return nxt

# %%
pp.pprint(nextStateDistibution((10, 11), "up"))
pp.pprint(nextStateDistibution((1, 5), "stay"))
# Out:
# {(4, 5): 0.5, (4, 11): 0.5}
# {(1, 5): 1}

# %%
pp.pprint(nextStateDistibution((6, 7), "stay"))
# Out:
# {(6, 1): 0.5, (6, 7): 0.5}

# %%
adapt_state((0,2))
# Out:
# 'a1 a3'

# %%
'''==================================================
Value Iteration
=================================================='''

#Hyperparameters
SMALL_ENOUGH = 0.0001
GAMMA = 0.99

iteration = 1
while True:
    biggest_change = 0
    for s in all_states:
        if s in Policy:
            
            old_v = V[s]
            new_v = np.NINF
            
            for a in actions[s]:
                nxt = nextStateDistibution(s, a)
                v=0
                #Calculate the value
                for next_state, prob in nxt.items():
                    v += prob * (rewards[s] + GAMMA * V[next_state])
                if v > new_v: #Is this the best action so far? If so, keep it
                    new_v = v
                    Policy[s] = a

       #Save the best of all actions for the state                                
            V[s] = new_v
            biggest_change = max(biggest_change, np.abs(old_v - V[s]))

            
   #See if the loop should stop now         
    if biggest_change < SMALL_ENOUGH:
        print('converge after: ' + str(iteration) + ' iterations')
        break
    iteration += 1
    
#     #Print every 100 iterations
    if(iteration % 100 == 0):
        print(iteration, ') ', V[(5,0)]) #V[(a6, a1)]
# Out:
# 100 )  12.636804464340221
# 200 )  12.636804464340221
# 300 )  12.636804464340221
# 400 )  12.636804464340221
# 500 )  12.636804464340221
# 600 )  12.636804464340221
# 700 )  12.636804464340221
# 800 )  12.636804464340221
# 900 )  12.636804464340221
# converge after: 917 iterations

# %% [markdown]
# ## Results:

# %%
def convertStates():
    P_convert= {}
    V_convert = {}
    for s,v in V.items():
        V_convert[adapt_state(s)] = v
    
#     print()
    for s,p in Policy.items():
        P_convert[adapt_state(s)] = p
    
    pp.pprint(V_convert)
    pp.pprint(P_convert)
    return P_convert, V_convert

# %%
# print the results:
print("iterations: ", iteration)
optimal_policy, optimal_V = convertStates()
# Out:
# iterations:  917
# {'a1 a1': -100,
#  'a1 a2': 30,
#  'a1 a3': 30,
#  'a1 a4': 30,
#  'a1 a5': 30,
#  'a1 a6': 30,
#  'a1 b1': 30,
#  'a1 b2': 30,
#  'a1 b3': 30,
#  'a1 b4': 30,
#  'a1 b5': 30,
#  'a1 b6': 30,
#  'a2 a1': 2.0575029370921283,
#  'a2 a2': -100,
#  'a2 a3': 28.7,
#  'a2 a4': 28.7,
#  'a2 a5': 28.7,
#  'a2 a6': 28.7,
#  'a2 b1': 0.2404624999045077,
#  'a2 b2': 28.7,
#  'a2 b3': 28.700000000000003,
#  'a2 b4': 28.699999999999996,
#  'a2 b5': 28.699999999999996,
#  'a2 b6': 28.7,
#  'a3 a1': 15.490315172871911,
#  'a3 a2': 18.130088546583607,
#  'a3 a3': -100,
#  'a3 a4': 27.413,
#  'a3 a5': 27.4129999972587,
#  'a3 a6': 27.413,
#  'a3 b1': 14.459494839562439,
#  'a3 b2': 18.275992865311377,
#  'a3 b3': 27.413000000000004,
#  'a3 b4': 27.413,
#  'a3 b5': 27.412999999999997,
#  'a3 b6': 27.413,
#  'a4 a1': 15.553577899843516,
#  'a4 a2': 12.909328461770176,
#  'a4 a3': 13.281739994405413,
#  'a4 a4': -100,
#  'a4 a5': 26.138869996481482,
#  'a4 a6': 26.13887,
#  'a4 b1': 13.504423572433561,
#  'a4 b2': 16.979942524468225,
#  'a4 b3': 10.747626100706697,
#  'a4 b4': 26.13887,
#  'a4 b5': 26.138869997889202,
#  'a4 b6': 26.13887,
#  'a5 a1': 13.188447427047354,
#  'a5 a2': 12.62657336774991,
#  'a5 a3': 10.728588257971662,
#  'a5 a4': 12.389733168954999,
#  'a5 a5': -100,
#  'a5 a6': 24.8774813,
#  'a5 b1': 13.564036309611769,
#  'a5 b2': 13.795189138188007,
#  'a5 b3': 11.312665009624409,
#  'a5 b4': 10.712274465023366,
#  'a5 b5': 24.87748129787934,
#  'a5 b6': 24.8774813,
#  'a6 a1': 12.636804464340221,
#  'a6 a2': 14.265795065871002,
#  'a6 a3': 15.493154873261947,
#  'a6 a4': 16.39908832273456,
#  'a6 a5': 18.780521914166734,
#  'a6 a6': -100,
#  'a6 b1': 12.360789947660818,
#  'a6 b2': 12.747312739414244,
#  'a6 b3': 13.99146221136408,
#  'a6 b4': 14.843029407247444,
#  'a6 b5': 15.286977151646276,
#  'a6 b6': 23.628706487,
#  'b1 a1': -14.199999999999996,
#  'b1 a2': 28.7,
#  'b1 a3': 28.7,
#  'b1 a4': 28.7,
#  'b1 a5': 28.7,
#  'b1 a6': 28.7,
#  'b1 b1': -100,
#  'b1 b2': 28.7,
#  'b1 b3': 28.7,
#  'b1 b4': 28.7,
#  'b1 b5': 28.7,
#  'b1 b6': 28.7,
#  'b2 a1': 2.642949025545728,
#  'b2 a2': 10.424600001505798,
#  'b2 a3': 27.413000000000004,
#  'b2 a4': 27.413,
#  'b2 a5': 27.412999999999997,
#  'b2 a6': 27.413,
#  'b2 b1': 0.5580141235503339,
#  'b2 b2': -100,
#  'b2 b3': 27.413000000000004,
#  'b2 b4': 27.412999999999997,
#  'b2 b5': 27.412999999999997,
#  'b2 b6': 27.413,
#  'b3 a1': 16.72429458525515,
#  'b3 a2': 20.05609011517826,
#  'b3 a3': 21.78925379571322,
#  'b3 a4': 26.138869997937448,
#  'b3 a5': 26.138869999457224,
#  'b3 a6': 26.13887,
#  'b3 b1': 14.982140934814762,
#  'b3 b2': 18.75226637370152,
#  'b3 b3': -100,
#  'b3 b4': 26.13887,
#  'b3 b5': 26.138869999224603,
#  'b3 b6': 26.13887,
#  'b4 a1': 12.849218876950673,
#  'b4 a2': 11.900274262148079,
#  'b4 a3': 11.568512077001644,
#  'b4 a4': 13.164197028238902,
#  'b4 a5': 24.87748129965978,
#  'b4 a6': 24.8774813,
#  'b4 b1': 13.045600264686888,
#  'b4 b2': 13.123537817708499,
#  'b4 b3': 11.521729405770927,
#  'b4 b4': -100,
#  'b4 b5': 24.87748129721349,
#  'b4 b6': 24.8774813,
#  'b5 a1': 11.914010008065627,
#  'b5 a2': 10.604290401410875,
#  'b5 a3': 10.814030681699872,
#  'b5 a4': 8.990334920497155,
#  'b5 a5': 9.892183544907104,
#  'b5 a6': 23.628706487,
#  'b5 b1': 12.304451615281788,
#  'b5 b2': 12.07877244043927,
#  'b5 b3': 9.814047703418076,
#  'b5 b4': 10.989055151061374,
#  'b5 b5': -100,
#  'b5 b6': 23.628706487,
#  'b6 a1': 12.340408731599421,
#  'b6 a2': 14.292901243606877,
#  'b6 a3': 15.65889301115668,
#  'b6 a4': 17.018492955447996,
#  'b6 a5': -71.62528684604857,
#  'b6 a6': -99.99015742709012,
#  'b6 b1': 11.305495641062361,
#  'b6 b2': 12.371488363616196,
#  'b6 b3': 13.594885456889884,
#  'b6 b4': 15.271948284557183,
#  'b6 b5': 17.016281809093904,
#  'b6 b6': -100}
# {'a2 a1': 'down',
#  'a2 a3': 'left',
#  'a2 a4': 'left',
#  'a2 a5': 'left',
#  'a2 a6': 'left',
#  'a2 b1': 'down',
#  'a2 b2': 'left',
#  'a2 b3': 'left',
#  'a2 b4': 'left',
#  'a2 b5': 'left',
#  'a2 b6': 'left',
#  'a3 a1': 'down',
#  'a3 a2': 'down',
#  'a3 a4': 'left',
#  'a3 a5': 'left',
#  'a3 a6': 'left',
#  'a3 b1': 'down',
#  'a3 b2': 'down',
#  'a3 b3': 'left',
#  'a3 b4': 'left',
#  'a3 b5': 'left',
#  'a3 b6': 'left',
#  'a4 a1': 'left',
#  'a4 a2': 'stay',
#  'a4 a3': 'left',
#  'a4 a5': 'left',
#  'a4 a6': 'left',
#  'a4 b1': 'left',
#  'a4 b2': 'left',
#  'a4 b3': 'stay',
#  'a4 b4': 'left',
#  'a4 b5': 'left',
#  'a4 b6': 'left',
#  'a5 a1': 'left',
#  'a5 a2': 'left',
#  'a5 a3': 'stay',
#  'a5 a4': 'left',
#  'a5 a6': 'left',
#  'a5 b1': 'left',
#  'a5 b2': 'left',
#  'a5 b3': 'left',
#  'a5 b4': 'stay',
#  'a5 b5': 'left',
#  'a5 b6': 'left',
#  'a6 a1': 'stay',
#  'a6 a2': 'down',
#  'a6 a3': 'down',
#  'a6 a4': 'stay',
#  'a6 a5': 'left',
#  'a6 b1': 'left',
#  'a6 b2': 'stay',
#  'a6 b3': 'down',
#  'a6 b4': 'down',
#  'a6 b5': 'stay',
#  'a6 b6': 'left',
#  'b1 a1': 'up',
#  'b1 a2': 'up',
#  'b1 a3': 'up',
#  'b1 a4': 'up',
#  'b1 a5': 'up',
#  'b1 a6': 'up',
#  'b1 b2': 'up',
#  'b1 b3': 'up',
#  'b1 b4': 'up',
#  'b1 b5': 'up',
#  'b1 b6': 'up',
#  'b2 a1': 'stay',
#  'b2 a2': 'up',
#  'b2 a3': 'up',
#  'b2 a4': 'up',
#  'b2 a5': 'up',
#  'b2 a6': 'up',
#  'b2 b1': 'stay',
#  'b2 b3': 'up',
#  'b2 b4': 'up',
#  'b2 b5': 'up',
#  'b2 b6': 'up',
#  'b3 a1': 'stay',
#  'b3 a2': 'stay',
#  'b3 a3': 'up',
#  'b3 a4': 'up',
#  'b3 a5': 'up',
#  'b3 a6': 'up',
#  'b3 b1': 'stay',
#  'b3 b2': 'stay',
#  'b3 b4': 'up',
#  'b3 b5': 'up',
#  'b3 b6': 'up',
#  'b4 a1': 'up',
#  'b4 a2': 'up',
#  'b4 a3': 'stay',
#  'b4 a4': 'stay',
#  'b4 a5': 'up',
#  'b4 a6': 'up',
#  'b4 b1': 'up',
#  'b4 b2': 'up',
#  'b4 b3': 'up',
#  'b4 b5': 'up',
#  'b4 b6': 'up',
#  'b5 a1': 'up',
#  'b5 a2': 'up',
#  'b5 a3': 'up',
#  'b5 a4': 'stay',
#  'b5 a5': 'up',
#  'b5 a6': 'up',
#  'b5 b1': 'up',
#  'b5 b2': 'up',
#  'b5 b3': 'up',
#  'b5 b4': 'up',
#  'b5 b6': 'up',
#  'b6 a1': 'up',
#  'b6 a2': 'stay',
#  'b6 a3': 'stay',
#  'b6 a4': 'up',
#  'b6 a5': 'up',
#  'b6 a6': 'stay',
#  'b6 b1': 'up',
#  'b6 b2': 'up',
#  'b6 b3': 'up',
#  'b6 b4': 'stay',
#  'b6 b5': 'up'}

# %%
import seaborn as sns
intensity = np.array(list(optimal_V.values())).reshape(12,12)
f, ax = plt.subplots(figsize=(20, 10))
sns.heatmap(intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
ax.set_title('Value Iteration results:')
# Out:
# Text(0.5, 1.0, 'Value Iteration results:')

# %% [markdown]
# # Policy evaluation:

# %%
def policy_eval(policy):
    V={}
    for (i,j) in all_states:
        if (i,j) in actions.keys():
            V[(i,j)] = step
        if(i == 0): # blue agent in a1
            V[(i,j)] = richToDestination
        if(i == j): # crushed
            V[(i,j)] = crushing
    while True:
        biggest_change = 0
        for s in all_states:
            if s in Policy:  
                old_v = V[s]
                nxt = nextStateDistibution(s, policy[s])
                v=0
                #Calculate the value
                for next_state, prob in nxt.items():
                    v += prob * (rewards[s] + GAMMA * V[next_state])
        
                #Save the best of all actions for the state                                
                V[s] = v
                biggest_change = max(biggest_change, np.abs(old_v - V[s]))
        #See if the loop should stop now         
        if biggest_change < SMALL_ENOUGH:
            return V

# %%
valueIteration_policy = Policy

# %% [markdown]
# # evaluate other behaviors:

# %%
def randomBehavior():
    Policy={}
    for s in actions.keys():
        Policy[s] = np.random.choice(actions[s])
    return Policy

random_policy = randomBehavior()

# %%
randomBehavior_intensity = np.array(list(policy_eval(random_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(randomBehavior_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: randomBehavior')

# %%
def carefulBehavior():
    Policy={}
    for s in actions.keys():
        blueState = s[0]
        redState = s[1]
        if redState + 1 == blueState or redState == blueState + 5 or redState + 6 == blueState or redState + 7 == blueState:
            if blueState < 6:
                Policy[s] = "down"
            else:
                Policy[s] = "stay"
        elif redState + 2 == blueState:
            if blueState < 6:
                Policy[s] = "down"
            else:
                Policy[s] = "up"
        else:
            if blueState < 6:
                Policy[s] = "left"
            else:
                Policy[s] = "up"
    return Policy

careful_policy = carefulBehavior()

# %%
careful_intensity = np.array(list(policy_eval(careful_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(careful_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: carefulBehavior')

# %%
def semiCarefulBehavior():
    Policy={}
    for s in actions.keys():
        blueState = s[0]
        redState = s[1]
        if redState + 1 == blueState:
            if blueState < 6:
                Policy[s] = "down"
            else:
                Policy[s] = "up"
        elif redState + 2 == blueState:
            if blueState < 6:
                Policy[s] = "stay"
            else:
                Policy[s] = "up"
        elif redState == blueState + 5 or redState + 6 == blueState or redState + 7 == blueState:
            if redState == 11 and blueState == 6:
                Policy[s] = "up"
            else:
                Policy[s] = "stay"
        else:
            if blueState < 6:
                Policy[s] = "left"
            else:
                Policy[s] = "up"
    return Policy

semiCareful_policy = semiCarefulBehavior()

# %%
semiCareful_intensity = np.array(list(policy_eval(semiCareful_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(semiCareful_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: carefulBehavior')

# %%
def semiAggressiveBehavior():
    Policy={}
    for s in actions.keys():
        blueState = s[0]
        redState = s[1]
        if redState + 1 == blueState:
            if blueState < 6:
                Policy[s] = "stay"
            else:
                Policy[s] = "up"
        elif redState == blueState + 5 or redState + 6 == blueState or redState + 7 == blueState:
            if blueState < 6:
                Policy[s] = "left"
            else:
                Policy[s] = "stay"
        else:
            if blueState < 6:
                Policy[s] = "left"
            else:
                Policy[s] = "up"
    return Policy

semiAggressive_policy = semiAggressiveBehavior()

# %%
semiAggressive_intensity = np.array(list(policy_eval(semiAggressive_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(semiAggressive_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: semiAggressiveBehavior')

# %%
def aggressiveBehavior():
    Policy={}
    for s in actions.keys():
        blueState = s[0]
        redState = s[1]
        if blueState > 5: #blue is in bX
            Policy[s] = "up"
        else:
            Policy[s] = "left"
    return Policy

aggressive_policy = aggressiveBehavior()

# %%
aggressive_intensity = np.array(list(policy_eval(aggressive_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(aggressive_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: aggressiveBehavior')

# %%
# diff = pd.DataFrame({'Real': df.groupby(['behavior']).mean()['blueScore'],
#                       'Prediction': [aggressive_intensity[5][0], careful_intensity[5][0], randomBehavior_intensity[5][0] , semiAggressive_intensity[5][0]]},
#                      index= df.groupby(['behavior']).mean()['blueScore'].index)
# diff['different'] = abs(diff['Real']-diff['Prediction'])
# diff

# %% [markdown]
# ## Value iteration with taking into account the previous state:

# %%
class OutOfBoard(Exception):
    pass

# %%
def get_pos_after_action(s, a):
    if a == 'U' or a == "up":
        if(s[0] == 'a'):
            raise OutOfBoard("An error occurred, state: "+ s + " action: " + a)
        return "a" + s[1]
    if a == 'D' or a == "down":
        if(s[0] == 'b'):
            raise OutOfBoard("An error occurred, state: "+ s + " action: " + a)
        return "b" + s[1]
    if a == 'L' or a == "left":
        if(s[0] == 'b' or s[1] == '1'):
            raise OutOfBoard("An error occurred, state: "+ s + " action: " + a)
        return "a" + str(int(s[1])-1)
    if a == 'R' or a == "right":
        if(s[0] == 'b' or s[1] == '6'):
            raise OutOfBoard("An error occurred, state: "+ s + " action: " + a)
        return "a" + str(int(s[1])+1)
    if a == 'S' or a == "stay":
        return s

# %%
def get_next_state(c_s):
    n_s = c_s.split()
    blueAction = n_s[3]
    blueState = n_s[2]
    redAction = n_s[1]
    redState = n_s[0]
    
    newPosBlue = get_pos_after_action(blueState, blueAction)
    newPosRed = get_pos_after_action(redState, redAction)
    
    return newPosBlue + ' ' + newPosRed

# %%
# s_r = df['log'].apply(pd.Series).iloc[:,1:]
# s_r.columns = s_r.columns.astype(str)
# log_red = flat_table.normalize(s_r).drop('index', axis=1)
# log_red = log_red.dropna(how='all')

# log_len = int(len(log_red.columns)/2)+1
# for i in range(1,log_len):
#     log_red[str(i)] = log_red[str(i)+'.red'] + ' ' + log_red[str(i)+'.blue']
#     log_red = log_red.drop([str(i)+'.red', str(i)+'.blue'],axis=1)
#     for substr in ['from: ', ', action:']:
#         log_red[str(i)] = log_red[str(i)].apply(lambda x: x.replace(substr, '', 2) if type(x) != float else x)
    
# log_len = len(log_red.columns)
# for i in range(1,log_len):
#     log_red[str(i) + '&' + str(i+1)] = log_red[str(i)] + '&' + log_red[str(i+1)]
#     log_red[str(i) + '&' + str(i+1)] = log_red[str(i) + '&' + str(i+1)].apply(lambda x: x.rsplit(' ', 2)[0] if type(x) != float else x)
# log_red = log_red.drop([str(i) for i in range(1,log_len+1)],axis=1)

# log_red = pd.DataFrame(log_red.to_numpy().flatten(), columns=['state'])
# log_red = log_red.dropna()

# log_red['action'] = log_red['state'].apply(lambda x: x.rsplit('&', 1)[1].rsplit(' ', 1)[1])
# log_red['state'] = log_red['state'].apply(lambda x: x.rsplit('&', 1)[0])

# log_red['nxt'] = log_red['state'].apply(get_next_state)
# log_red['state'] = log_red['state'].str.split().apply(reversed).apply(' '.join)

# log_red['value']=1

# for a in ['right', 'stay', 'up', 'down', 'left']:
#     log_red['state'] = log_red['state'].apply(lambda x: x.replace(a+' ', '', 2))

# log_red['state'] = log_red['state'] + ' nxt: ' + log_red['nxt']
# log_red = log_red.drop('nxt',axis=1)

# log_red = log_red.groupby(['state', 'action']).count()
# log_red.reset_index(inplace=True)
# log_red = log_red.set_index('state')

# log_red

s_r = df['log'].apply(pd.Series).iloc[:,1:]
s_r.columns = s_r.columns.astype(str)
s_r.set_index( df['index'], inplace=True)
log_red = flat_table.normalize(s_r)
log_red = log_red.dropna(how='all')
log_red.set_index(log_red['index'], inplace=True)
log_red = log_red.drop('index', axis=1)

log_len = int(len(log_red.columns)/2)+1
for i in range(1,log_len):
    log_red[str(i)] = log_red[str(i)+'.red'] + ' ' + log_red[str(i)+'.blue']
    log_red = log_red.drop([str(i)+'.red', str(i)+'.blue'],axis=1)
    for substr in ['from: ', ', action:']:
        log_red[str(i)] = log_red[str(i)].apply(lambda x: x.replace(substr, '', 2) if type(x) != float else x)
    
log_len = len(log_red.columns)
for i in range(1,log_len):
    log_red[str(i) + '&' + str(i+1)] = log_red[str(i)] + '&' + log_red[str(i+1)]
    log_red[str(i) + '&' + str(i+1)] = log_red[str(i) + '&' + str(i+1)].apply(lambda x: x.rsplit(' ', 2)[0] if type(x) != float else x)
log_red = log_red.drop([str(i) for i in range(1,log_len+1)],axis=1)

log_red_copy = log_red.copy(deep=True)

log_red = pd.DataFrame(log_red.to_numpy().flatten(), columns=['state'])
log_red = log_red.dropna()

log_red['action'] = log_red['state'].apply(lambda x: x.rsplit('&', 1)[1].rsplit(' ', 1)[1])
log_red['state'] = log_red['state'].apply(lambda x: x.rsplit('&', 1)[0])

log_red['nxt'] = log_red['state'].apply(get_next_state)
log_red['state'] = log_red['state'].str.split().apply(reversed).apply(' '.join)

log_red['value']=1

for a in ['right', 'stay', 'up', 'down', 'left']:
    log_red['state'] = log_red['state'].apply(lambda x: x.replace(a+' ', '', 2))

log_red['state'] = log_red['state'] + ' nxt: ' + log_red['nxt']
log_red = log_red.drop('nxt',axis=1)

log_red = log_red.groupby(['state', 'action']).count()
log_red.reset_index(inplace=True)
log_red = log_red.set_index('state')

log_red
# Out:
#                  action  value
# state
# a1 a2 nxt: a1 a2  right      1
# a1 a2 nxt: a1 a3   down      1
# a1 a2 nxt: a1 a3  right     24
# a1 a2 nxt: a1 a3   stay      1
# a1 a2 nxt: a1 b2   stay      1
# ...                 ...    ...
# b6 b5 nxt: b6 a5   down      4
# b6 b5 nxt: b6 a5  right     25
# b6 b5 nxt: b6 a5   stay      3
# b6 b5 nxt: b6 b5   stay      2
# b6 b5 nxt: b6 b5     up      4
#
# [444 rows x 2 columns]

# %%
log_red[log_red.index == 'a4 b3 nxt: a4 b3']
# Out:
#                  action  value
# state
# a4 b3 nxt: a4 b3   stay     23
# a4 b3 nxt: a4 b3     up     11

# %%
a = df[['index','win']]
a.set_index('index', inplace=True)

b = df[['index','behavior']]
b.set_index('index', inplace=True)

# %%
# log_red_copy['1&2'].apply(lambda x: x.rsplit(' ', 3)[0] if type(x) != float else x)

# %%
log_red_copy = pd.concat([log_red_copy,a],axis=1)
log_red_copy = pd.concat([log_red_copy,b],axis=1)
c = log_red_copy[log_red_copy['win'] == True][log_red_copy['behavior'] == 'semiCarefulBehavior']
# log_red_copy['win'].isnull().count()
# c = log_red_copy.tail(103)[['8&9','9&10','10&11','11&12','12&13', '13&14','14&15','15&16']]
c
# Out:
# <ipython-input-75-40e30856b5f5>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c = log_red_copy[log_red_copy['win'] == True][log_red_copy['behavior'] == 'semiCarefulBehavior']
#                                             1&2                       2&3  \
# index
# -Majseg4QUg1TtH_ew7v    a1 stay a6 left&a1 stay   a1 stay a5 left&a1 stay
# -MajsfplbkG3tJ8GXddD  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MajsjC_8D-KybolDJW2  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -Majss9mdL3S7KqSmMk9  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -Majt477IWiowI-hlOpE  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# ...                                         ...                       ...
# -MbMcUaa5BcFWRlgsd0v   a1 stay a6 left&a1 right  a1 right a5 left&a2 stay
# -MbTT8AhnwoNxhvSev2B  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbTTrtKDNBfKgUF94l_  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbTVbO-0yOiOsU7WriY   a1 right a6 left&a2 down     a2 down a5 left&b2 up
# -MbTh1pjBTQfj_0DpBKo   a1 stay a6 left&a1 right  a1 right a5 left&a2 down
#
#                                           3&4                      4&5  \
# index
# -Majseg4QUg1TtH_ew7v  a1 stay a4 left&a1 stay  a1 stay a3 stay&a1 stay
# -MajsfplbkG3tJ8GXddD    a3 down a4 down&b3 up     b3 up b4 up&a3 right
# -MajsjC_8D-KybolDJW2    a3 down a4 down&b3 up      b3 up b4 up&a3 down
# -Majss9mdL3S7KqSmMk9    a3 down a4 down&b3 up      b3 up b4 up&a3 down
# -Majt477IWiowI-hlOpE    a3 down a4 down&b3 up      b3 up b4 up&a3 stay
# ...                                       ...                      ...
# -MbMcUaa5BcFWRlgsd0v  a2 stay a4 stay&a2 stay  a2 stay a4 stay&a2 stay
# -MbTT8AhnwoNxhvSev2B    a3 down a4 down&b3 up      b3 up b4 up&a3 stay
# -MbTTrtKDNBfKgUF94l_    a3 down a4 down&b3 up      b3 up b4 up&a3 down
# -MbTVbO-0yOiOsU7WriY    b2 up a4 left&a2 down    a2 down a3 down&b2 up
# -MbTh1pjBTQfj_0DpBKo  a2 down a4 stay&b2 stay    b2 stay a4 left&b2 up
#
#                                             5&6                        6&7  \
# index
# -Majseg4QUg1TtH_ew7v    a1 stay a3 stay&a1 stay    a1 stay a3 stay&a1 stay
# -MajsfplbkG3tJ8GXddD  a3 right a4 down&a4 right  a4 right b4 stay&a5 right
# -MajsjC_8D-KybolDJW2      a3 down a4 down&b3 up       b3 up b4 up&a3 right
# -Majss9mdL3S7KqSmMk9    a3 down a4 down&b3 stay      b3 stay b4 up&b3 stay
# -Majt477IWiowI-hlOpE   a3 stay a4 down&a3 right  a3 right b4 stay&a4 right
# ...                                         ...                        ...
# -MbMcUaa5BcFWRlgsd0v   a2 stay a4 stay&a2 right   a2 right a4 stay&a3 stay
# -MbTT8AhnwoNxhvSev2B   a3 stay a4 down&a3 right  a3 right b4 stay&a4 right
# -MbTTrtKDNBfKgUF94l_      a3 down a4 down&b3 up        b3 up b4 up&a3 stay
# -MbTVbO-0yOiOsU7WriY        b2 up b3 up&a2 down      a2 down a3 down&b2 up
# -MbTh1pjBTQfj_0DpBKo     b2 up a3 stay&a2 right  a2 right a3 down&a3 right
#
#                                             7&8                        8&9  \
# index
# -Majseg4QUg1TtH_ew7v    a1 stay a3 stay&a1 stay    a1 stay a3 stay&a1 stay
# -MajsfplbkG3tJ8GXddD                        NaN                        NaN
# -MajsjC_8D-KybolDJW2  a3 right a4 down&a4 right  a4 right b4 stay&a5 right
# -Majss9mdL3S7KqSmMk9    b3 stay a4 stay&b3 stay    b3 stay a4 stay&b3 stay
# -Majt477IWiowI-hlOpE  a4 right b4 stay&a5 right                        NaN
# ...                                         ...                        ...
# -MbMcUaa5BcFWRlgsd0v    a3 stay a4 down&a3 down    a3 down b4 stay&b3 stay
# -MbTT8AhnwoNxhvSev2B  a4 right b4 stay&a5 right                        NaN
# -MbTTrtKDNBfKgUF94l_   a3 stay a4 down&a3 right  a3 right b4 stay&a4 right
# -MbTVbO-0yOiOsU7WriY       b2 up b3 up&a2 right  a2 right a3 down&a3 right
# -MbTh1pjBTQfj_0DpBKo   a3 right b3 stay&a4 stay      a4 stay b3 up&a4 down
#
#                                            9&10                    10&11  ...  \
# index                                                                     ...
# -Majseg4QUg1TtH_ew7v    a1 stay a3 stay&a1 stay  a1 stay a3 stay&a1 stay  ...
# -MajsfplbkG3tJ8GXddD                        NaN                      NaN  ...
# -MajsjC_8D-KybolDJW2                        NaN                      NaN  ...
# -Majss9mdL3S7KqSmMk9    b3 stay a4 stay&b3 stay  b3 stay a4 stay&b3 stay  ...
# -Majt477IWiowI-hlOpE                        NaN                      NaN  ...
# ...                                         ...                      ...  ...
# -MbMcUaa5BcFWRlgsd0v        b3 stay b4 up&b3 up    b3 up a4 stay&a3 down  ...
# -MbTT8AhnwoNxhvSev2B                        NaN                      NaN  ...
# -MbTTrtKDNBfKgUF94l_  a4 right b4 stay&a5 right                      NaN  ...
# -MbTVbO-0yOiOsU7WriY  a3 right b3 stay&a4 right  a4 right b3 up&a5 right  ...
# -MbTh1pjBTQfj_0DpBKo    a4 down a3 left&b4 stay    b4 stay a2 left&b4 up  ...
#
#                      193&194 194&195 195&196 196&197 197&198 198&199 199&200  \
# index
# -Majseg4QUg1TtH_ew7v     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -MajsfplbkG3tJ8GXddD     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -MajsjC_8D-KybolDJW2     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -Majss9mdL3S7KqSmMk9     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -Majt477IWiowI-hlOpE     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...                      ...     ...     ...     ...     ...     ...     ...
# -MbMcUaa5BcFWRlgsd0v     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -MbTT8AhnwoNxhvSev2B     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -MbTTrtKDNBfKgUF94l_     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -MbTVbO-0yOiOsU7WriY     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -MbTh1pjBTQfj_0DpBKo     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                      200&201   win             behavior
# index
# -Majseg4QUg1TtH_ew7v     NaN  True  semiCarefulBehavior
# -MajsfplbkG3tJ8GXddD     NaN  True  semiCarefulBehavior
# -MajsjC_8D-KybolDJW2     NaN  True  semiCarefulBehavior
# -Majss9mdL3S7KqSmMk9     NaN  True  semiCarefulBehavior
# -Majt477IWiowI-hlOpE     NaN  True  semiCarefulBehavior
# ...                      ...   ...                  ...
# -MbMcUaa5BcFWRlgsd0v     NaN  True  semiCarefulBehavior
# -MbTT8AhnwoNxhvSev2B     NaN  True  semiCarefulBehavior
# -MbTTrtKDNBfKgUF94l_     NaN  True  semiCarefulBehavior
# -MbTVbO-0yOiOsU7WriY     NaN  True  semiCarefulBehavior
# -MbTh1pjBTQfj_0DpBKo     NaN  True  semiCarefulBehavior
#
# [65 rows x 202 columns]

# %%
# aaaaaa

# %%
# mask = np.column_stack([log_red_copy[col].str.contains("b3 stay a3 left", na=False) for col in log_red_copy])
# find_result = np.where(mask==True)[0].tolist()
# first_filter = np.array(log_red_copy.index.tolist())[find_result]
# first_filter_log_red = log_red_copy.loc[first_filter,:] #[['3&4','4&5','5&6','6&7','7&8']]

# # mask = np.column_stack([first_filter_log_red[col].str.endswith(" right") for col in first_filter_log_red])
# # find_result = np.where(mask==True)[0].tolist()
# # second_filter = np.array(first_filter_log_red.index.tolist())[find_result]

# # second_filter_log_red = first_filter_log_red.loc[second_filter,:]
# first_filter_log_red

# %%
result = pd.DataFrame(index=log_red.index.drop_duplicates(), columns=['right', 'stay', 'up', 'down'])
# result.reset_index(level=0, inplace=True)
for action in ['right', 'stay', 'up', 'down']:
    result[action] = log_red[log_red['action'] == action]['value']
result = result.fillna(0)
result.reset_index(inplace=True)
result.sort_index()
# Out:
#                 state  right  stay   up  down
# 0    a1 a2 nxt: a1 a2   1.00  0.00 0.00  0.00
# 1    a1 a2 nxt: a1 a3  24.00  1.00 0.00  1.00
# 2    a1 a2 nxt: a1 b2   0.00  1.00 1.00  0.00
# 3    a1 a3 nxt: a1 a3   1.00  6.00 0.00  3.00
# 4    a1 a3 nxt: a1 a4  93.00  0.00 0.00  0.00
# ..                ...    ...   ...  ...   ...
# 255  b6 b1 nxt: b6 a1   2.00  0.00 0.00  0.00
# 256  b6 b1 nxt: b6 b1   0.00  2.00 0.00  0.00
# 257  b6 b4 nxt: a6 a4   1.00  0.00 0.00  0.00
# 258  b6 b5 nxt: b6 a5  25.00  3.00 0.00  4.00
# 259  b6 b5 nxt: b6 b5   0.00  2.00 4.00  0.00
#
# [260 rows x 5 columns]

# %%
# laplace smoving:
for i in range(1,7):
    result.loc[result['state'].str.endswith('a'+str(i)), ['stay', 'right', 'down']] += 1
    
for i in range(1,7):
    result.loc[result['state'].str.endswith('b'+str(i)), ['stay', 'up']] += 1

result = result.set_index('state')
result
# Out:
#                   right  stay   up  down
# state
# a1 a2 nxt: a1 a2   2.00  1.00 0.00  1.00
# a1 a2 nxt: a1 a3  25.00  2.00 0.00  2.00
# a1 a2 nxt: a1 b2   0.00  2.00 2.00  0.00
# a1 a3 nxt: a1 a3   2.00  7.00 0.00  4.00
# a1 a3 nxt: a1 a4  94.00  1.00 0.00  1.00
# ...                 ...   ...  ...   ...
# b6 b1 nxt: b6 a1   3.00  1.00 0.00  1.00
# b6 b1 nxt: b6 b1   0.00  3.00 1.00  0.00
# b6 b4 nxt: a6 a4   2.00  1.00 0.00  1.00
# b6 b5 nxt: b6 a5  26.00  4.00 0.00  5.00
# b6 b5 nxt: b6 b5   0.00  3.00 5.00  0.00
#
# [260 rows x 4 columns]

# %% [markdown]
# #### Convert it to Probability table:

# %%
pd.options.display.float_format = "{:,.2f}".format
result_probs = result.div(result.sum(axis=1), axis=0)

# %% [markdown]
# #### Save data on computer for the policy iteration:

# %%
result_probs.to_json('data/probs2.json' , orient='index', indent=4)

# %%
def possibleFutureStates(s):
    n_l = []
    for a in actions[s]:
#         print('s: ', adapt_state((3,2)))
#         print(a)
        n = nextStateDistibution(s, a)
        n_l.extend([elm for elm in n])
#         print('n: ', n)
#         print('n_l: ', n_l)
    return n_l

possibleStatesForState = {}
for s in all_states:
    if s in Policy:
        poss_states = possibleFutureStates(s)
        possibleStatesForState[s] = [s for s in poss_states]

# %%
possibleStatesForState
# Out:
# {(1, 0): [(1, 1),
#   (1, 0),
#   (1, 6),
#   (0, 1),
#   (0, 0),
#   (0, 6),
#   (7, 1),
#   (7, 0),
#   (7, 6)],
#  (1, 2): [(1, 3),
#   (1, 2),
#   (1, 8),
#   (0, 3),
#   (0, 2),
#   (0, 8),
#   (7, 3),
#   (7, 2),
#   (7, 8)],
#  (1, 3): [(1, 4),
#   (1, 3),
#   (1, 9),
#   (0, 4),
#   (0, 3),
#   (0, 9),
#   (7, 4),
#   (7, 3),
#   (7, 9)],
#  (1, 4): [(1, 5),
#   (1, 4),
#   (1, 10),
#   (0, 5),
#   (0, 4),
#   (0, 10),
#   (7, 5),
#   (7, 4),
#   (7, 10)],
#  (1, 5): [(1, 5), (0, 5), (7, 5)],
#  (1, 6): [(1, 6), (1, 0), (0, 6), (0, 0), (7, 6), (7, 0)],
#  (1, 7): [(1, 7), (1, 1), (0, 7), (0, 1), (7, 7), (7, 1)],
#  (1, 8): [(1, 8), (1, 2), (0, 8), (0, 2), (7, 8), (7, 2)],
#  (1, 9): [(1, 9), (1, 3), (0, 9), (0, 3), (7, 9), (7, 3)],
#  (1, 10): [(1, 10), (1, 4), (0, 10), (0, 4), (7, 10), (7, 4)],
#  (1, 11): [(1, 11), (1, 5), (0, 11), (0, 5), (7, 11), (7, 5)],
#  (2, 0): [(2, 1),
#   (2, 0),
#   (2, 6),
#   (1, 1),
#   (1, 0),
#   (1, 6),
#   (8, 1),
#   (8, 0),
#   (8, 6)],
#  (2, 1): [(2, 2),
#   (2, 1),
#   (2, 7),
#   (1, 2),
#   (1, 1),
#   (1, 7),
#   (8, 2),
#   (8, 1),
#   (8, 7)],
#  (2, 3): [(2, 4),
#   (2, 3),
#   (2, 9),
#   (1, 4),
#   (1, 3),
#   (1, 9),
#   (8, 4),
#   (8, 3),
#   (8, 9)],
#  (2, 4): [(2, 5),
#   (2, 4),
#   (2, 10),
#   (1, 5),
#   (1, 4),
#   (1, 10),
#   (8, 5),
#   (8, 4),
#   (8, 10)],
#  (2, 5): [(2, 5), (1, 5), (8, 5)],
#  (2, 6): [(2, 6), (2, 0), (1, 6), (1, 0), (8, 6), (8, 0)],
#  (2, 7): [(2, 7), (2, 1), (1, 7), (1, 1), (8, 7), (8, 1)],
#  (2, 8): [(2, 8), (2, 2), (1, 8), (1, 2), (8, 8), (8, 2)],
#  (2, 9): [(2, 9), (2, 3), (1, 9), (1, 3), (8, 9), (8, 3)],
#  (2, 10): [(2, 10), (2, 4), (1, 10), (1, 4), (8, 10), (8, 4)],
#  (2, 11): [(2, 11), (2, 5), (1, 11), (1, 5), (8, 11), (8, 5)],
#  (3, 0): [(3, 1),
#   (3, 0),
#   (3, 6),
#   (2, 1),
#   (2, 0),
#   (2, 6),
#   (9, 1),
#   (9, 0),
#   (9, 6)],
#  (3, 1): [(3, 2),
#   (3, 1),
#   (3, 7),
#   (2, 2),
#   (2, 1),
#   (2, 7),
#   (9, 2),
#   (9, 1),
#   (9, 7)],
#  (3, 2): [(3, 3),
#   (3, 2),
#   (3, 8),
#   (2, 3),
#   (2, 2),
#   (2, 8),
#   (9, 3),
#   (9, 2),
#   (9, 8)],
#  (3, 4): [(3, 5),
#   (3, 4),
#   (3, 10),
#   (2, 5),
#   (2, 4),
#   (2, 10),
#   (9, 5),
#   (9, 4),
#   (9, 10)],
#  (3, 5): [(3, 5), (2, 5), (9, 5)],
#  (3, 6): [(3, 6), (3, 0), (2, 6), (2, 0), (9, 6), (9, 0)],
#  (3, 7): [(3, 7), (3, 1), (2, 7), (2, 1), (9, 7), (9, 1)],
#  (3, 8): [(3, 8), (3, 2), (2, 8), (2, 2), (9, 8), (9, 2)],
#  (3, 9): [(3, 9), (3, 3), (2, 9), (2, 3), (9, 9), (9, 3)],
#  (3, 10): [(3, 10), (3, 4), (2, 10), (2, 4), (9, 10), (9, 4)],
#  (3, 11): [(3, 11), (3, 5), (2, 11), (2, 5), (9, 11), (9, 5)],
#  (4, 0): [(4, 1),
#   (4, 0),
#   (4, 6),
#   (3, 1),
#   (3, 0),
#   (3, 6),
#   (10, 1),
#   (10, 0),
#   (10, 6)],
#  (4, 1): [(4, 2),
#   (4, 1),
#   (4, 7),
#   (3, 2),
#   (3, 1),
#   (3, 7),
#   (10, 2),
#   (10, 1),
#   (10, 7)],
#  (4, 2): [(4, 3),
#   (4, 2),
#   (4, 8),
#   (3, 3),
#   (3, 2),
#   (3, 8),
#   (10, 3),
#   (10, 2),
#   (10, 8)],
#  (4, 3): [(4, 4),
#   (4, 3),
#   (4, 9),
#   (3, 4),
#   (3, 3),
#   (3, 9),
#   (10, 4),
#   (10, 3),
#   (10, 9)],
#  (4, 5): [(4, 5), (3, 5), (10, 5)],
#  (4, 6): [(4, 6), (4, 0), (3, 6), (3, 0), (10, 6), (10, 0)],
#  (4, 7): [(4, 7), (4, 1), (3, 7), (3, 1), (10, 7), (10, 1)],
#  (4, 8): [(4, 8), (4, 2), (3, 8), (3, 2), (10, 8), (10, 2)],
#  (4, 9): [(4, 9), (4, 3), (3, 9), (3, 3), (10, 9), (10, 3)],
#  (4, 10): [(4, 10), (4, 4), (3, 10), (3, 4), (10, 10), (10, 4)],
#  (4, 11): [(4, 11), (4, 5), (3, 11), (3, 5), (10, 11), (10, 5)],
#  (5, 0): [(5, 1),
#   (5, 0),
#   (5, 6),
#   (4, 1),
#   (4, 0),
#   (4, 6),
#   (11, 1),
#   (11, 0),
#   (11, 6)],
#  (5, 1): [(5, 2),
#   (5, 1),
#   (5, 7),
#   (4, 2),
#   (4, 1),
#   (4, 7),
#   (11, 2),
#   (11, 1),
#   (11, 7)],
#  (5, 2): [(5, 3),
#   (5, 2),
#   (5, 8),
#   (4, 3),
#   (4, 2),
#   (4, 8),
#   (11, 3),
#   (11, 2),
#   (11, 8)],
#  (5, 3): [(5, 4),
#   (5, 3),
#   (5, 9),
#   (4, 4),
#   (4, 3),
#   (4, 9),
#   (11, 4),
#   (11, 3),
#   (11, 9)],
#  (5, 4): [(5, 5),
#   (5, 4),
#   (5, 10),
#   (4, 5),
#   (4, 4),
#   (4, 10),
#   (11, 5),
#   (11, 4),
#   (11, 10)],
#  (5, 6): [(5, 6), (5, 0), (4, 6), (4, 0), (11, 6), (11, 0)],
#  (5, 7): [(5, 7), (5, 1), (4, 7), (4, 1), (11, 7), (11, 1)],
#  (5, 8): [(5, 8), (5, 2), (4, 8), (4, 2), (11, 8), (11, 2)],
#  (5, 9): [(5, 9), (5, 3), (4, 9), (4, 3), (11, 9), (11, 3)],
#  (5, 10): [(5, 10), (5, 4), (4, 10), (4, 4), (11, 10), (11, 4)],
#  (5, 11): [(5, 11), (5, 5), (4, 11), (4, 5), (11, 11), (11, 5)],
#  (6, 0): [(0, 1), (0, 0), (0, 6), (6, 1), (6, 0), (6, 6)],
#  (6, 1): [(0, 2), (0, 1), (0, 7), (6, 2), (6, 1), (6, 7)],
#  (6, 2): [(0, 3), (0, 2), (0, 8), (6, 3), (6, 2), (6, 8)],
#  (6, 3): [(0, 4), (0, 3), (0, 9), (6, 4), (6, 3), (6, 9)],
#  (6, 4): [(0, 5), (0, 4), (0, 10), (6, 5), (6, 4), (6, 10)],
#  (6, 5): [(0, 5), (6, 5)],
#  (6, 7): [(0, 7), (0, 1), (6, 7), (6, 1)],
#  (6, 8): [(0, 8), (0, 2), (6, 8), (6, 2)],
#  (6, 9): [(0, 9), (0, 3), (6, 9), (6, 3)],
#  (6, 10): [(0, 10), (0, 4), (6, 10), (6, 4)],
#  (6, 11): [(0, 11), (0, 5), (6, 11), (6, 5)],
#  (7, 0): [(1, 1), (1, 0), (1, 6), (7, 1), (7, 0), (7, 6)],
#  (7, 1): [(1, 2), (1, 1), (1, 7), (7, 2), (7, 1), (7, 7)],
#  (7, 2): [(1, 3), (1, 2), (1, 8), (7, 3), (7, 2), (7, 8)],
#  (7, 3): [(1, 4), (1, 3), (1, 9), (7, 4), (7, 3), (7, 9)],
#  (7, 4): [(1, 5), (1, 4), (1, 10), (7, 5), (7, 4), (7, 10)],
#  (7, 5): [(1, 5), (7, 5)],
#  (7, 6): [(1, 6), (1, 0), (7, 6), (7, 0)],
#  (7, 8): [(1, 8), (1, 2), (7, 8), (7, 2)],
#  (7, 9): [(1, 9), (1, 3), (7, 9), (7, 3)],
#  (7, 10): [(1, 10), (1, 4), (7, 10), (7, 4)],
#  (7, 11): [(1, 11), (1, 5), (7, 11), (7, 5)],
#  (8, 0): [(2, 1), (2, 0), (2, 6), (8, 1), (8, 0), (8, 6)],
#  (8, 1): [(2, 2), (2, 1), (2, 7), (8, 2), (8, 1), (8, 7)],
#  (8, 2): [(2, 3), (2, 2), (2, 8), (8, 3), (8, 2), (8, 8)],
#  (8, 3): [(2, 4), (2, 3), (2, 9), (8, 4), (8, 3), (8, 9)],
#  (8, 4): [(2, 5), (2, 4), (2, 10), (8, 5), (8, 4), (8, 10)],
#  (8, 5): [(2, 5), (8, 5)],
#  (8, 6): [(2, 6), (2, 0), (8, 6), (8, 0)],
#  (8, 7): [(2, 7), (2, 1), (8, 7), (8, 1)],
#  (8, 9): [(2, 9), (2, 3), (8, 9), (8, 3)],
#  (8, 10): [(2, 10), (2, 4), (8, 10), (8, 4)],
#  (8, 11): [(2, 11), (2, 5), (8, 11), (8, 5)],
#  (9, 0): [(3, 1), (3, 0), (3, 6), (9, 1), (9, 0), (9, 6)],
#  (9, 1): [(3, 2), (3, 1), (3, 7), (9, 2), (9, 1), (9, 7)],
#  (9, 2): [(3, 3), (3, 2), (3, 8), (9, 3), (9, 2), (9, 8)],
#  (9, 3): [(3, 4), (3, 3), (3, 9), (9, 4), (9, 3), (9, 9)],
#  (9, 4): [(3, 5), (3, 4), (3, 10), (9, 5), (9, 4), (9, 10)],
#  (9, 5): [(3, 5), (9, 5)],
#  (9, 6): [(3, 6), (3, 0), (9, 6), (9, 0)],
#  (9, 7): [(3, 7), (3, 1), (9, 7), (9, 1)],
#  (9, 8): [(3, 8), (3, 2), (9, 8), (9, 2)],
#  (9, 10): [(3, 10), (3, 4), (9, 10), (9, 4)],
#  (9, 11): [(3, 11), (3, 5), (9, 11), (9, 5)],
#  (10, 0): [(4, 1), (4, 0), (4, 6), (10, 1), (10, 0), (10, 6)],
#  (10, 1): [(4, 2), (4, 1), (4, 7), (10, 2), (10, 1), (10, 7)],
#  (10, 2): [(4, 3), (4, 2), (4, 8), (10, 3), (10, 2), (10, 8)],
#  (10, 3): [(4, 4), (4, 3), (4, 9), (10, 4), (10, 3), (10, 9)],
#  (10, 4): [(4, 5), (4, 4), (4, 10), (10, 5), (10, 4), (10, 10)],
#  (10, 5): [(4, 5), (10, 5)],
#  (10, 6): [(4, 6), (4, 0), (10, 6), (10, 0)],
#  (10, 7): [(4, 7), (4, 1), (10, 7), (10, 1)],
#  (10, 8): [(4, 8), (4, 2), (10, 8), (10, 2)],
#  (10, 9): [(4, 9), (4, 3), (10, 9), (10, 3)],
#  (10, 11): [(4, 11), (4, 5), (10, 11), (10, 5)],
#  (11, 0): [(5, 1), (5, 0), (5, 6), (11, 1), (11, 0), (11, 6)],
#  (11, 1): [(5, 2), (5, 1), (5, 7), (11, 2), (11, 1), (11, 7)],
#  (11, 2): [(5, 3), (5, 2), (5, 8), (11, 3), (11, 2), (11, 8)],
#  (11, 3): [(5, 4), (5, 3), (5, 9), (11, 4), (11, 3), (11, 9)],
#  (11, 4): [(5, 5), (5, 4), (5, 10), (11, 5), (11, 4), (11, 10)],
#  (11, 5): [(5, 5), (11, 5)],
#  (11, 6): [(5, 6), (5, 0), (11, 6), (11, 0)],
#  (11, 7): [(5, 7), (5, 1), (11, 7), (11, 1)],
#  (11, 8): [(5, 8), (5, 2), (11, 8), (11, 2)],
#  (11, 9): [(5, 9), (5, 3), (11, 9), (11, 3)],
#  (11, 10): [(5, 10), (5, 4), (11, 10), (11, 4)]}

# %%
'''==================================================
Initial set up                              version 2
=================================================='''

#Hyperparameters
SMALL_ENOUGH = 0.0001
GAMMA = 0.99

#Define all states
all_states=[]
for prev_state in possibleStatesForState:
    poss_states = possibleStatesForState[prev_state]
    for curr_state in poss_states:
        # current state: (i,j), previous state: (l,k)
        all_states.append((curr_state,prev_state))
all_states.append(((5,0),(-10, -10)))

#Define rewards for all states
rewards = {}
for ((i,j),(l,k)) in all_states:
    if(i == 0): # blue agent in a1
        rewards[((i,j),(l,k))] = richToDestination
    elif(i == j): # crushed
        rewards[((i,j),(l,k))] = crushing
    else:
        rewards[((i,j),(l,k))] = step

#Dictionnary of possible actions. We have two "end" states (1,2 and 2,2)
actions = {}
for ((i,j),(l,k)) in all_states:
    if i != 0 and i != j: #if s=((i, j),(l, k)) is not an "end" state
        actions[((i,j),(l,k))] = ("stay", "left", "down") if (i < 6) else ("up", "stay")

probs = json.load(open('data/probs2.json',))

#Define an initial policy
Policy={}
for s in actions.keys():
    Policy[s] = np.random.choice(actions[s])
    
#Define initial value function 
V={}
for ((i,j),(l,k)) in all_states:
    if ((i,j),(l,k)) in actions.keys():
        V[((i,j),(l,k))] = step
    if(i == 0): # blue agent in a1
        V[((i,j),(l,k))] = richToDestination
    if(i == j): # crushed
        V[((i,j),(l,k))] = crushing

# %%
def nextStateDistibution2(s, a):
    # given state s and action a, return distibution of possibles new states by probs
    nxt = {}
#     print('s: ', s)
#     print('a: ', a)
    bluePossition = newPosGivenAction(s[0], a, 0)
#     print('bluePossition: ', bluePossition)
    
    # red possible action given state
    if s[0][1] == 5:
        actions=["stay"]
    elif s[0][1] < 6:
        actions=["right","stay", "down"]
    else:
        actions=["stay", "up"]
#     print('actions: ', actions)
    for r_a in actions:
        redPossition = newPosGivenAction(s[0], r_a, 1)
#         print('r_a: ', r_a)
#         print('redPossition: ', redPossition)
        newState = ((bluePossition, redPossition),s[0])
#         print('newState: ', newState)
        try:
            nxt[newState] = probs[adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0])][r_a]
        except KeyError:
#             print("Warning! State not found: assume random behavior. ", s[0])
            nxt[newState] = randomProbForAction(s[0])
    assert abs(sum(nxt.values()) - 1.0) < 0.0001, "probs not sum to 1.0. \nstate: " + str(s) + " action: " + str(a) + " nxt: " + str(nxt) + "\nsum of probs: " + str(sum(nxt.values()))
    return nxt

# %%
pp.pprint(nextStateDistibution2(((0, 4),(1, 4)), "stay"))
pp.pprint(nextStateDistibution2(((4, 1),(5, 0)), "left"))
# Out:
# {((0, 4), (0, 4)): 0.25, ((0, 5), (0, 4)): 0.5, ((0, 10), (0, 4)): 0.25}
# {((3, 1), (4, 1)): 0.030651341,
#  ((3, 2), (4, 1)): 0.8352490421,
#  ((3, 7), (4, 1)): 0.1340996169}

# %%
(adapt_state((1, 8)), adapt_state((1, 8)))
# Out:
# ('a2 b3', 'a2 b3')

# %%
(adapt_state((1, 2)), adapt_state((1, 8)))
# Out:
# ('a2 a3', 'a2 b3')

# %%
s = ((1, 8), (2, 8))
print((adapt_state((1, 8)), adapt_state((2, 8))))
print(adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0]))
probs[adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0])]
# Out:
# ('a2 b3', 'a3 b3')
# a3 b3 nxt: a2 b3
# {'right': 0.0, 'stay': 0.1212121212, 'up': 0.8787878788, 'down': 0.0}

# %%
pp.pprint(nextStateDistibution2(s, "stay"))
# Out:
# {((1, 2), (1, 8)): 0.8787878788, ((1, 8), (1, 8)): 0.1212121212}

# %%
'''==================================================
Value Iteration
=================================================='''

iteration = 1

while True:
    biggest_change = 0
    for s in all_states:            
        if s in Policy:
            
            old_v = V[s]
            new_v = np.NINF
            
            for a in actions[s]:
#                 print("actions: ", actions[s])
#                 print("action: ", a)
#                 print("state: ", s)
                nxt = nextStateDistibution2(s, a)
#                 print("nxt:", nxt)
                
                v=0
                #Calculate the value
                for next_state, prob in nxt.items():
#                     print("next_state: ", next_state)
#                     print("prob: ", prob)
#                     print('V[next_state]: ', V[next_state])
                    assert rewards[s] == -1, "rewards is not -1"
                    v += prob * (rewards[s] + GAMMA * V[next_state])
#                 print('v: ', v)
#                 print()
                if v > new_v: #Is this the best action so far? If so, keep it
                    new_v = v
                    Policy[s] = a

           #Save the best of all actions for the state                                
            V[s] = new_v
            biggest_change = max(biggest_change, np.abs(old_v - V[s]))

            
   #See if the loop should stop now         
    if biggest_change < SMALL_ENOUGH:
        print('converge after: ' + str(iteration) + ' iterations')
        break
    iteration += 1
    
    #Print every 100 iterations
#     if(iteration % 100 == 0):
#         print(iteration, ') ', V[(5, 0)]) # V([a6,a1])
# Out:
# converge after: 917 iterations

# %%
def convertStates(Policy):
    P_convert= {}
    V_convert = {}
    for s,v in V.items():
        V_convert[adapt_state(s[0]) + ',' + adapt_state(s[1])] = v
    
#     print()
    for s,p in Policy.items():
        P_convert[adapt_state(s[0]) + ',' + adapt_state(s[1])] = p
    
#     pp.pprint(V_convert)
#     pp.pprint(P_convert)
    return P_convert, V_convert

# %%
# print the results:
print("iterations: ", iteration)
optimal_policy_v2, optimal_V_v2 = convertStates(Policy)
# Out:
# iterations:  917

# %%
# intensity = np.array(list(V.values())).reshape(1, 693)
# f, ax = plt.subplots(figsize=(2^16, 2^16))
# sns.heatmap(intensity, annot=True, linewidths=0.1, cmap="YlGnBu")

# %%
optimal_policy_v2
# Out:
# {'a2 a1,a2 a1': 'down',
#  'a2 b1,a2 a1': 'stay',
#  'b2 a2,a2 a1': 'up',
#  'b2 a1,a2 a1': 'stay',
#  'b2 b1,a2 a1': 'up',
#  'a2 a4,a2 a3': 'left',
#  'a2 a3,a2 a3': 'left',
#  'a2 b3,a2 a3': 'left',
#  'b2 a4,a2 a3': 'up',
#  'b2 a3,a2 a3': 'up',
#  'b2 b3,a2 a3': 'up',
#  'a2 a5,a2 a4': 'left',
#  'a2 a4,a2 a4': 'left',
#  'a2 b4,a2 a4': 'left',
#  'b2 a5,a2 a4': 'up',
#  'b2 a4,a2 a4': 'up',
#  'b2 b4,a2 a4': 'up',
#  'a2 a6,a2 a5': 'left',
#  'a2 a5,a2 a5': 'left',
#  'a2 b5,a2 a5': 'left',
#  'b2 a6,a2 a5': 'up',
#  'b2 a5,a2 a5': 'up',
#  'b2 b5,a2 a5': 'up',
#  'a2 a6,a2 a6': 'left',
#  'b2 a6,a2 a6': 'up',
#  'a2 b1,a2 b1': 'stay',
#  'a2 a1,a2 b1': 'left',
#  'b2 b1,a2 b1': 'up',
#  'b2 a1,a2 b1': 'stay',
#  'a2 b2,a2 b2': 'left',
#  'b2 a2,a2 b2': 'up',
#  'a2 b3,a2 b3': 'left',
#  'a2 a3,a2 b3': 'left',
#  'b2 b3,a2 b3': 'up',
#  'b2 a3,a2 b3': 'up',
#  'a2 b4,a2 b4': 'left',
#  'a2 a4,a2 b4': 'left',
#  'b2 b4,a2 b4': 'up',
#  'b2 a4,a2 b4': 'up',
#  'a2 b5,a2 b5': 'left',
#  'a2 a5,a2 b5': 'left',
#  'b2 b5,a2 b5': 'up',
#  'b2 a5,a2 b5': 'up',
#  'a2 b6,a2 b6': 'left',
#  'a2 a6,a2 b6': 'left',
#  'b2 b6,a2 b6': 'up',
#  'b2 a6,a2 b6': 'up',
#  'a3 a2,a3 a1': 'down',
#  'a3 a1,a3 a1': 'down',
#  'a3 b1,a3 a1': 'left',
#  'a2 a1,a3 a1': 'down',
#  'a2 b1,a3 a1': 'stay',
#  'b3 a2,a3 a1': 'stay',
#  'b3 a1,a3 a1': 'up',
#  'b3 b1,a3 a1': 'up',
#  'a3 a2,a3 a2': 'down',
#  'a3 b2,a3 a2': 'stay',
#  'a2 a3,a3 a2': 'left',
#  'a2 b2,a3 a2': 'left',
#  'b3 a3,a3 a2': 'up',
#  'b3 a2,a3 a2': 'stay',
#  'b3 b2,a3 a2': 'up',
#  'a3 a5,a3 a4': 'left',
#  'a3 a4,a3 a4': 'left',
#  'a3 b4,a3 a4': 'left',
#  'a2 a5,a3 a4': 'left',
#  'a2 a4,a3 a4': 'left',
#  'a2 b4,a3 a4': 'left',
#  'b3 a5,a3 a4': 'up',
#  'b3 a4,a3 a4': 'up',
#  'b3 b4,a3 a4': 'up',
#  'a3 a6,a3 a5': 'left',
#  'a3 a5,a3 a5': 'left',
#  'a3 b5,a3 a5': 'left',
#  'a2 a6,a3 a5': 'left',
#  'a2 a5,a3 a5': 'left',
#  'a2 b5,a3 a5': 'left',
#  'b3 a6,a3 a5': 'up',
#  'b3 a5,a3 a5': 'up',
#  'b3 b5,a3 a5': 'up',
#  'a3 a6,a3 a6': 'left',
#  'a2 a6,a3 a6': 'left',
#  'b3 a6,a3 a6': 'up',
#  'a3 b1,a3 b1': 'left',
#  'a3 a1,a3 b1': 'stay',
#  'a2 b1,a3 b1': 'stay',
#  'a2 a1,a3 b1': 'left',
#  'b3 b1,a3 b1': 'up',
#  'b3 a1,a3 b1': 'up',
#  'a3 b2,a3 b2': 'down',
#  'a3 a2,a3 b2': 'down',
#  'a2 b2,a3 b2': 'left',
#  'b3 b2,a3 b2': 'up',
#  'b3 a2,a3 b2': 'stay',
#  'a3 b3,a3 b3': 'left',
#  'a2 b3,a3 b3': 'left',
#  'a2 a3,a3 b3': 'left',
#  'b3 a3,a3 b3': 'up',
#  'a3 b4,a3 b4': 'left',
#  'a3 a4,a3 b4': 'left',
#  'a2 b4,a3 b4': 'left',
#  'a2 a4,a3 b4': 'left',
#  'b3 b4,a3 b4': 'up',
#  'b3 a4,a3 b4': 'up',
#  'a3 b5,a3 b5': 'left',
#  'a3 a5,a3 b5': 'left',
#  'a2 b5,a3 b5': 'left',
#  'a2 a5,a3 b5': 'left',
#  'b3 b5,a3 b5': 'up',
#  'b3 a5,a3 b5': 'up',
#  'a3 b6,a3 b6': 'left',
#  'a3 a6,a3 b6': 'left',
#  'a2 b6,a3 b6': 'left',
#  'a2 a6,a3 b6': 'left',
#  'b3 b6,a3 b6': 'up',
#  'b3 a6,a3 b6': 'up',
#  'a4 a2,a4 a1': 'stay',
#  'a4 a1,a4 a1': 'left',
#  'a4 b1,a4 a1': 'stay',
#  'a3 a2,a4 a1': 'left',
#  'a3 a1,a4 a1': 'down',
#  'a3 b1,a4 a1': 'left',
#  'b4 a2,a4 a1': 'up',
#  'b4 a1,a4 a1': 'up',
#  'b4 b1,a4 a1': 'up',
#  'a4 a3,a4 a2': 'down',
#  'a4 a2,a4 a2': 'down',
#  'a4 b2,a4 a2': 'stay',
#  'a3 a2,a4 a2': 'down',
#  'a3 b2,a4 a2': 'stay',
#  'b4 a3,a4 a2': 'stay',
#  'b4 a2,a4 a2': 'up',
#  'b4 b2,a4 a2': 'up',
#  'a4 a3,a4 a3': 'down',
#  'a4 b3,a4 a3': 'down',
#  'a3 a4,a4 a3': 'left',
#  'a3 b3,a4 a3': 'left',
#  'b4 a4,a4 a3': 'up',
#  'b4 a3,a4 a3': 'stay',
#  'b4 b3,a4 a3': 'stay',
#  'a4 a6,a4 a5': 'left',
#  'a4 a5,a4 a5': 'left',
#  'a4 b5,a4 a5': 'left',
#  'a3 a6,a4 a5': 'left',
#  'a3 a5,a4 a5': 'left',
#  'a3 b5,a4 a5': 'left',
#  'b4 a6,a4 a5': 'up',
#  'b4 a5,a4 a5': 'up',
#  'b4 b5,a4 a5': 'up',
#  'a4 a6,a4 a6': 'left',
#  'a3 a6,a4 a6': 'left',
#  'b4 a6,a4 a6': 'up',
#  'a4 b1,a4 b1': 'left',
#  'a4 a1,a4 b1': 'left',
#  'a3 b1,a4 b1': 'left',
#  'a3 a1,a4 b1': 'stay',
#  'b4 b1,a4 b1': 'up',
#  'b4 a1,a4 b1': 'up',
#  'a4 b2,a4 b2': 'left',
#  'a4 a2,a4 b2': 'down',
#  'a3 b2,a4 b2': 'down',
#  'a3 a2,a4 b2': 'left',
#  'b4 b2,a4 b2': 'up',
#  'b4 a2,a4 b2': 'up',
#  'a4 b3,a4 b3': 'down',
#  'a4 a3,a4 b3': 'down',
#  'a3 b3,a4 b3': 'left',
#  'b4 b3,a4 b3': 'stay',
#  'b4 a3,a4 b3': 'stay',
#  'a4 b4,a4 b4': 'left',
#  'a3 b4,a4 b4': 'left',
#  'a3 a4,a4 b4': 'left',
#  'b4 a4,a4 b4': 'up',
#  'a4 b5,a4 b5': 'left',
#  'a4 a5,a4 b5': 'left',
#  'a3 b5,a4 b5': 'left',
#  'a3 a5,a4 b5': 'left',
#  'b4 b5,a4 b5': 'up',
#  'b4 a5,a4 b5': 'up',
#  'a4 b6,a4 b6': 'left',
#  'a4 a6,a4 b6': 'left',
#  'a3 b6,a4 b6': 'left',
#  'a3 a6,a4 b6': 'left',
#  'b4 b6,a4 b6': 'up',
#  'b4 a6,a4 b6': 'up',
#  'a5 a2,a5 a1': 'left',
#  'a5 a1,a5 a1': 'stay',
#  'a5 b1,a5 a1': 'left',
#  'a4 a2,a5 a1': 'stay',
#  'a4 a1,a5 a1': 'left',
#  'a4 b1,a5 a1': 'stay',
#  'b5 a2,a5 a1': 'up',
#  'b5 a1,a5 a1': 'up',
#  'b5 b1,a5 a1': 'up',
#  'a5 a3,a5 a2': 'stay',
#  'a5 a2,a5 a2': 'left',
#  'a5 b2,a5 a2': 'stay',
#  'a4 a3,a5 a2': 'left',
#  'a4 a2,a5 a2': 'stay',
#  'a4 b2,a5 a2': 'left',
#  'b5 a3,a5 a2': 'up',
#  'b5 a2,a5 a2': 'up',
#  'b5 b2,a5 a2': 'up',
#  'a5 a4,a5 a3': 'left',
#  'a5 a3,a5 a3': 'stay',
#  'a5 b3,a5 a3': 'left',
#  'a4 a3,a5 a3': 'down',
#  'a4 b3,a5 a3': 'down',
#  'b5 a4,a5 a3': 'stay',
#  'b5 a3,a5 a3': 'up',
#  'b5 b3,a5 a3': 'up',
#  'a5 a4,a5 a4': 'down',
#  'a5 b4,a5 a4': 'down',
#  'a4 a5,a5 a4': 'left',
#  'a4 b4,a5 a4': 'left',
#  'b5 a5,a5 a4': 'up',
#  'b5 a4,a5 a4': 'stay',
#  'b5 b4,a5 a4': 'stay',
#  'a5 a6,a5 a6': 'left',
#  'a4 a6,a5 a6': 'left',
#  'b5 a6,a5 a6': 'up',
#  'a5 b1,a5 b1': 'stay',
#  'a5 a1,a5 b1': 'stay',
#  'a4 b1,a5 b1': 'stay',
#  'a4 a1,a5 b1': 'left',
#  'b5 b1,a5 b1': 'up',
#  'b5 a1,a5 b1': 'up',
#  'a5 b2,a5 b2': 'stay',
#  'a5 a2,a5 b2': 'left',
#  'a4 b2,a5 b2': 'left',
#  'a4 a2,a5 b2': 'stay',
#  'b5 b2,a5 b2': 'up',
#  'b5 a2,a5 b2': 'up',
#  'a5 b3,a5 b3': 'left',
#  'a5 a3,a5 b3': 'stay',
#  'a4 b3,a5 b3': 'down',
#  'a4 a3,a5 b3': 'down',
#  'b5 b3,a5 b3': 'up',
#  'b5 a3,a5 b3': 'up',
#  'a5 b4,a5 b4': 'down',
#  'a5 a4,a5 b4': 'down',
#  'a4 b4,a5 b4': 'left',
#  'b5 b4,a5 b4': 'stay',
#  'b5 a4,a5 b4': 'stay',
#  'a5 b5,a5 b5': 'left',
#  'a4 b5,a5 b5': 'left',
#  'a4 a5,a5 b5': 'left',
#  'b5 a5,a5 b5': 'up',
#  'a5 b6,a5 b6': 'left',
#  'a5 a6,a5 b6': 'left',
#  'a4 b6,a5 b6': 'left',
#  'a4 a6,a5 b6': 'left',
#  'b5 b6,a5 b6': 'up',
#  'b5 a6,a5 b6': 'up',
#  'a6 a2,a6 a1': 'stay',
#  'a6 a1,a6 a1': 'left',
#  'a6 b1,a6 a1': 'left',
#  'a5 a2,a6 a1': 'left',
#  'a5 a1,a6 a1': 'stay',
#  'a5 b1,a6 a1': 'left',
#  'b6 a2,a6 a1': 'up',
#  'b6 a1,a6 a1': 'up',
#  'b6 b1,a6 a1': 'up',
#  'a6 a3,a6 a2': 'stay',
#  'a6 a2,a6 a2': 'stay',
#  'a6 b2,a6 a2': 'left',
#  'a5 a3,a6 a2': 'stay',
#  'a5 a2,a6 a2': 'left',
#  'a5 b2,a6 a2': 'stay',
#  'b6 a3,a6 a2': 'up',
#  'b6 a2,a6 a2': 'up',
#  'b6 b2,a6 a2': 'up',
#  'a6 a4,a6 a3': 'stay',
#  'a6 a3,a6 a3': 'stay',
#  'a6 b3,a6 a3': 'stay',
#  'a5 a4,a6 a3': 'down',
#  'a5 a3,a6 a3': 'stay',
#  'a5 b3,a6 a3': 'left',
#  'b6 a4,a6 a3': 'up',
#  'b6 a3,a6 a3': 'up',
#  'b6 b3,a6 a3': 'up',
#  'a6 a5,a6 a4': 'left',
#  'a6 a4,a6 a4': 'stay',
#  'a6 b4,a6 a4': 'stay',
#  'a5 a4,a6 a4': 'down',
#  'a5 b4,a6 a4': 'down',
#  'b6 a5,a6 a4': 'up',
#  'b6 a4,a6 a4': 'up',
#  'b6 b4,a6 a4': 'up',
#  'a6 a5,a6 a5': 'left',
#  'a6 b5,a6 a5': 'stay',
#  'a5 a6,a6 a5': 'left',
#  'a5 b5,a6 a5': 'left',
#  'b6 a6,a6 a5': 'stay',
#  'b6 a5,a6 a5': 'up',
#  'b6 b5,a6 a5': 'up',
#  'a6 b1,a6 b1': 'left',
#  'a6 a1,a6 b1': 'left',
#  'a5 b1,a6 b1': 'stay',
#  'a5 a1,a6 b1': 'stay',
#  'b6 b1,a6 b1': 'up',
#  'b6 a1,a6 b1': 'up',
#  'a6 b2,a6 b2': 'left',
#  'a6 a2,a6 b2': 'stay',
#  'a5 b2,a6 b2': 'stay',
#  'a5 a2,a6 b2': 'left',
#  'b6 b2,a6 b2': 'up',
#  'b6 a2,a6 b2': 'up',
#  'a6 b3,a6 b3': 'stay',
#  'a6 a3,a6 b3': 'stay',
#  'a5 b3,a6 b3': 'left',
#  'a5 a3,a6 b3': 'stay',
#  'b6 b3,a6 b3': 'up',
#  'b6 a3,a6 b3': 'up',
#  'a6 b4,a6 b4': 'stay',
#  'a6 a4,a6 b4': 'stay',
#  'a5 b4,a6 b4': 'down',
#  'a5 a4,a6 b4': 'down',
#  'b6 b4,a6 b4': 'up',
#  'b6 a4,a6 b4': 'up',
#  'a6 b5,a6 b5': 'stay',
#  'a6 a5,a6 b5': 'left',
#  'a5 b5,a6 b5': 'left',
#  'b6 b5,a6 b5': 'up',
#  'b6 a5,a6 b5': 'up',
#  'a6 b6,a6 b6': 'left',
#  'a5 b6,a6 b6': 'left',
#  'a5 a6,a6 b6': 'left',
#  'b6 a6,a6 b6': 'stay',
#  'b1 a2,b1 a1': 'up',
#  'b1 a1,b1 a1': 'up',
#  'b1 a3,b1 a2': 'up',
#  'b1 a2,b1 a2': 'up',
#  'b1 b2,b1 a2': 'up',
#  'b1 a4,b1 a3': 'up',
#  'b1 a3,b1 a3': 'up',
#  'b1 b3,b1 a3': 'up',
#  'b1 a5,b1 a4': 'up',
#  'b1 a4,b1 a4': 'up',
#  'b1 b4,b1 a4': 'up',
#  'b1 a6,b1 a5': 'up',
#  'b1 a5,b1 a5': 'up',
#  'b1 b5,b1 a5': 'up',
#  'b1 a6,b1 a6': 'up',
#  'b1 b2,b1 b2': 'up',
#  'b1 a2,b1 b2': 'up',
#  'b1 b3,b1 b3': 'up',
#  'b1 a3,b1 b3': 'up',
#  'b1 b4,b1 b4': 'up',
#  'b1 a4,b1 b4': 'up',
#  'b1 b5,b1 b5': 'up',
#  'b1 a5,b1 b5': 'up',
#  'b1 b6,b1 b6': 'up',
#  'b1 a6,b1 b6': 'up',
#  'a2 a1,b2 a1': 'down',
#  'a2 b1,b2 a1': 'stay',
#  'b2 a2,b2 a1': 'up',
#  'b2 a1,b2 a1': 'stay',
#  'b2 b1,b2 a1': 'up',
#  'a2 a3,b2 a2': 'left',
#  'a2 b2,b2 a2': 'left',
#  'b2 a3,b2 a2': 'up',
#  'b2 a2,b2 a2': 'up',
#  'a2 a4,b2 a3': 'left',
#  'a2 a3,b2 a3': 'left',
#  'a2 b3,b2 a3': 'left',
#  'b2 a4,b2 a3': 'up',
#  'b2 a3,b2 a3': 'up',
#  'b2 b3,b2 a3': 'up',
#  'a2 a5,b2 a4': 'left',
#  'a2 a4,b2 a4': 'left',
#  'a2 b4,b2 a4': 'left',
#  'b2 a5,b2 a4': 'up',
#  'b2 a4,b2 a4': 'up',
#  'b2 b4,b2 a4': 'up',
#  'a2 a6,b2 a5': 'left',
#  'a2 a5,b2 a5': 'left',
#  'a2 b5,b2 a5': 'left',
#  'b2 a6,b2 a5': 'up',
#  'b2 a5,b2 a5': 'up',
#  'b2 b5,b2 a5': 'up',
#  'a2 a6,b2 a6': 'left',
#  'b2 a6,b2 a6': 'up',
#  'a2 b1,b2 b1': 'stay',
#  'a2 a1,b2 b1': 'left',
#  'b2 b1,b2 b1': 'up',
#  'b2 a1,b2 b1': 'stay',
#  'a2 b3,b2 b3': 'left',
#  'a2 a3,b2 b3': 'left',
#  'b2 b3,b2 b3': 'up',
#  'b2 a3,b2 b3': 'up',
#  'a2 b4,b2 b4': 'left',
#  'a2 a4,b2 b4': 'left',
#  'b2 b4,b2 b4': 'up',
#  'b2 a4,b2 b4': 'up',
#  'a2 b5,b2 b5': 'left',
#  'a2 a5,b2 b5': 'left',
#  'b2 b5,b2 b5': 'up',
#  'b2 a5,b2 b5': 'up',
#  'a2 b6,b2 b6': 'left',
#  'a2 a6,b2 b6': 'left',
#  'b2 b6,b2 b6': 'up',
#  'b2 a6,b2 b6': 'up',
#  'a3 a2,b3 a1': 'down',
#  'a3 a1,b3 a1': 'stay',
#  'a3 b1,b3 a1': 'left',
#  'b3 a2,b3 a1': 'stay',
#  'b3 a1,b3 a1': 'up',
#  'b3 b1,b3 a1': 'up',
#  'a3 a2,b3 a2': 'down',
#  'a3 b2,b3 a2': 'stay',
#  'b3 a3,b3 a2': 'up',
#  'b3 a2,b3 a2': 'stay',
#  'b3 b2,b3 a2': 'up',
#  'a3 a4,b3 a3': 'left',
#  'a3 b3,b3 a3': 'left',
#  'b3 a4,b3 a3': 'up',
#  'b3 a3,b3 a3': 'up',
#  'a3 a5,b3 a4': 'left',
#  'a3 a4,b3 a4': 'left',
#  'a3 b4,b3 a4': 'left',
#  'b3 a5,b3 a4': 'up',
#  'b3 a4,b3 a4': 'up',
#  'b3 b4,b3 a4': 'up',
#  'a3 a6,b3 a5': 'left',
#  'a3 a5,b3 a5': 'left',
#  'a3 b5,b3 a5': 'left',
#  'b3 a6,b3 a5': 'up',
#  'b3 a5,b3 a5': 'up',
#  'b3 b5,b3 a5': 'up',
#  'a3 a6,b3 a6': 'left',
#  'b3 a6,b3 a6': 'up',
#  'a3 b1,b3 b1': 'left',
#  'a3 a1,b3 b1': 'stay',
#  'b3 b1,b3 b1': 'up',
#  'b3 a1,b3 b1': 'up',
#  'a3 b2,b3 b2': 'stay',
#  'a3 a2,b3 b2': 'down',
#  'b3 b2,b3 b2': 'up',
#  'b3 a2,b3 b2': 'stay',
#  'a3 b4,b3 b4': 'left',
#  'a3 a4,b3 b4': 'left',
#  'b3 b4,b3 b4': 'up',
#  'b3 a4,b3 b4': 'up',
#  'a3 b5,b3 b5': 'left',
#  'a3 a5,b3 b5': 'left',
#  'b3 b5,b3 b5': 'up',
#  'b3 a5,b3 b5': 'up',
#  'a3 b6,b3 b6': 'left',
#  'a3 a6,b3 b6': 'left',
#  'b3 b6,b3 b6': 'up',
#  'b3 a6,b3 b6': 'up',
#  'a4 a2,b4 a1': 'stay',
#  'a4 a1,b4 a1': 'left',
#  'a4 b1,b4 a1': 'stay',
#  'b4 a2,b4 a1': 'up',
#  'b4 a1,b4 a1': 'up',
#  'b4 b1,b4 a1': 'up',
#  'a4 a3,b4 a2': 'down',
#  'a4 a2,b4 a2': 'stay',
#  'a4 b2,b4 a2': 'left',
#  'b4 a3,b4 a2': 'stay',
#  'b4 a2,b4 a2': 'up',
#  'b4 b2,b4 a2': 'up',
#  'a4 a3,b4 a3': 'down',
#  'a4 b3,b4 a3': 'down',
#  'b4 a4,b4 a3': 'up',
#  'b4 a3,b4 a3': 'stay',
#  'b4 b3,b4 a3': 'stay',
#  'a4 a5,b4 a4': 'left',
#  'a4 b4,b4 a4': 'left',
#  'b4 a5,b4 a4': 'up',
#  'b4 a4,b4 a4': 'stay',
#  'a4 a6,b4 a5': 'left',
#  'a4 a5,b4 a5': 'left',
#  'a4 b5,b4 a5': 'left',
#  'b4 a6,b4 a5': 'up',
#  'b4 a5,b4 a5': 'up',
#  'b4 b5,b4 a5': 'up',
#  'a4 a6,b4 a6': 'left',
#  'b4 a6,b4 a6': 'up',
#  'a4 b1,b4 b1': 'stay',
#  'a4 a1,b4 b1': 'left',
#  'b4 b1,b4 b1': 'up',
#  'b4 a1,b4 b1': 'up',
#  'a4 b2,b4 b2': 'left',
#  'a4 a2,b4 b2': 'stay',
#  'b4 b2,b4 b2': 'up',
#  'b4 a2,b4 b2': 'up',
#  'a4 b3,b4 b3': 'down',
#  'a4 a3,b4 b3': 'down',
#  'b4 b3,b4 b3': 'stay',
#  'b4 a3,b4 b3': 'stay',
#  'a4 b5,b4 b5': 'left',
#  'a4 a5,b4 b5': 'left',
#  'b4 b5,b4 b5': 'up',
#  'b4 a5,b4 b5': 'up',
#  'a4 b6,b4 b6': 'left',
#  'a4 a6,b4 b6': 'left',
#  'b4 b6,b4 b6': 'up',
#  'b4 a6,b4 b6': 'up',
#  'a5 a2,b5 a1': 'left',
#  'a5 a1,b5 a1': 'stay',
#  'a5 b1,b5 a1': 'stay',
#  'b5 a2,b5 a1': 'up',
#  'b5 a1,b5 a1': 'up',
#  'b5 b1,b5 a1': 'up',
#  'a5 a3,b5 a2': 'stay',
#  'a5 a2,b5 a2': 'left',
#  'a5 b2,b5 a2': 'stay',
#  'b5 a3,b5 a2': 'up',
#  'b5 a2,b5 a2': 'up',
#  'b5 b2,b5 a2': 'up',
#  'a5 a4,b5 a3': 'left',
#  'a5 a3,b5 a3': 'stay',
#  'a5 b3,b5 a3': 'left',
#  'b5 a4,b5 a3': 'stay',
#  'b5 a3,b5 a3': 'up',
#  'b5 b3,b5 a3': 'up',
#  'a5 a4,b5 a4': 'down',
#  'a5 b4,b5 a4': 'down',
#  'b5 a5,b5 a4': 'up',
#  'b5 a4,b5 a4': 'stay',
#  'b5 b4,b5 a4': 'stay',
#  'a5 a6,b5 a5': 'left',
#  'a5 b5,b5 a5': 'left',
#  'b5 a6,b5 a5': 'up',
#  'b5 a5,b5 a5': 'up',
#  'a5 a6,b5 a6': 'left',
#  'b5 a6,b5 a6': 'up',
#  'a5 b1,b5 b1': 'stay',
#  'a5 a1,b5 b1': 'stay',
#  'b5 b1,b5 b1': 'up',
#  'b5 a1,b5 b1': 'up',
#  'a5 b2,b5 b2': 'stay',
#  'a5 a2,b5 b2': 'left',
#  'b5 b2,b5 b2': 'up',
#  'b5 a2,b5 b2': 'up',
#  'a5 b3,b5 b3': 'left',
#  'a5 a3,b5 b3': 'stay',
#  'b5 b3,b5 b3': 'up',
#  'b5 a3,b5 b3': 'up',
#  'a5 b4,b5 b4': 'down',
#  'a5 a4,b5 b4': 'down',
#  'b5 b4,b5 b4': 'stay',
#  'b5 a4,b5 b4': 'stay',
#  'a5 b6,b5 b6': 'left',
#  'a5 a6,b5 b6': 'left',
#  'b5 b6,b5 b6': 'up',
#  'b5 a6,b5 b6': 'up',
#  'a6 a2,b6 a1': 'stay',
#  'a6 a1,b6 a1': 'left',
#  'a6 b1,b6 a1': 'left',
#  'b6 a2,b6 a1': 'up',
#  'b6 a1,b6 a1': 'up',
#  'b6 b1,b6 a1': 'up',
#  'a6 a3,b6 a2': 'stay',
#  'a6 a2,b6 a2': 'stay',
#  'a6 b2,b6 a2': 'left',
#  'b6 a3,b6 a2': 'up',
#  'b6 a2,b6 a2': 'up',
#  'b6 b2,b6 a2': 'up',
#  'a6 a4,b6 a3': 'stay',
#  'a6 a3,b6 a3': 'stay',
#  'a6 b3,b6 a3': 'stay',
#  'b6 a4,b6 a3': 'up',
#  'b6 a3,b6 a3': 'up',
#  'b6 b3,b6 a3': 'up',
#  'a6 a5,b6 a4': 'left',
#  'a6 a4,b6 a4': 'stay',
#  'a6 b4,b6 a4': 'stay',
#  'b6 a5,b6 a4': 'up',
#  'b6 a4,b6 a4': 'up',
#  'b6 b4,b6 a4': 'up',
#  'a6 a5,b6 a5': 'left',
#  'a6 b5,b6 a5': 'stay',
#  'b6 a6,b6 a5': 'stay',
#  'b6 a5,b6 a5': 'up',
#  'b6 b5,b6 a5': 'up',
#  'b6 a6,b6 a6': 'stay',
#  'a6 b1,b6 b1': 'left',
#  'a6 a1,b6 b1': 'left',
#  'b6 b1,b6 b1': 'up',
#  'b6 a1,b6 b1': 'up',
#  'a6 b2,b6 b2': 'left',
#  'a6 a2,b6 b2': 'stay',
#  'b6 b2,b6 b2': 'up',
#  'b6 a2,b6 b2': 'up',
#  'a6 b3,b6 b3': 'stay',
#  'a6 a3,b6 b3': 'stay',
#  'b6 b3,b6 b3': 'up',
#  'b6 a3,b6 b3': 'up',
#  'a6 b4,b6 b4': 'stay',
#  'a6 a4,b6 b4': 'stay',
#  'b6 b4,b6 b4': 'up',
#  'b6 a4,b6 b4': 'up',
#  'a6 b5,b6 b5': 'stay',
#  'a6 a5,b6 b5': 'left',
#  'b6 b5,b6 b5': 'up',
#  'b6 a5,b6 b5': 'up',
#  'a6 a1,a-9 a-9': 'left'}

# %%
def policy_eval2(policy):
    V={}
    for ((i,j),(l,k)) in all_states:
        if ((i,j),(l,k)) in actions.keys():
            V[((i,j),(l,k))] = step
        if(i == 0): # blue agent in a1
            V[((i,j),(l,k))] = richToDestination
        if(i == j): # crashed
            V[((i,j),(l,k))] = crushing
    while True:
        biggest_change = 0
        for s in all_states:
            if s in Policy:
                old_v = V[s]
                nxt = nextStateDistibution2(s, policy[s])
                v=0
                #Calculate the value
                for next_state, prob in nxt.items():
                    assert rewards[s] == -1, "rewards[s] is not -1"
                    v += prob * (rewards[s] + GAMMA * V[next_state])
        
                #Save the best of all actions for the state                                
                V[s] = v
                biggest_change = max(biggest_change, np.abs(old_v - V[s]))
        #See if the loop should stop now         
        if biggest_change < SMALL_ENOUGH:
            return V

# %%
a = policy_eval2(Policy)
a
# Out:
# {((1, 1), (1, 0)): -100,
#  ((1, 0), (1, 0)): 4.891475049933639,
#  ((1, 6), (1, 0)): 9.547481521549456,
#  ((0, 1), (1, 0)): 30,
#  ((0, 0), (1, 0)): -100,
#  ((0, 6), (1, 0)): 30,
#  ((7, 1), (1, 0)): -4.440249999999999,
#  ((7, 0), (1, 0)): 6.879724389758994,
#  ((7, 6), (1, 0)): 11.69852234150672,
#  ((1, 3), (1, 2)): 28.7,
#  ((1, 2), (1, 2)): 28.7,
#  ((1, 8), (1, 2)): 28.7,
#  ((0, 3), (1, 2)): 30,
#  ((0, 2), (1, 2)): 30,
#  ((0, 8), (1, 2)): 30,
#  ((7, 3), (1, 2)): 27.413,
#  ((7, 2), (1, 2)): 27.4130000009471,
#  ((7, 8), (1, 2)): 27.413,
#  ((1, 4), (1, 3)): 28.7,
#  ((1, 3), (1, 3)): 28.7,
#  ((1, 9), (1, 3)): 28.7,
#  ((0, 4), (1, 3)): 30,
#  ((0, 3), (1, 3)): 30,
#  ((0, 9), (1, 3)): 30,
#  ((7, 4), (1, 3)): 27.412999999999997,
#  ((7, 3), (1, 3)): 27.412999999999997,
#  ((7, 9), (1, 3)): 27.413,
#  ((1, 5), (1, 4)): 28.7,
#  ((1, 4), (1, 4)): 28.7,
#  ((1, 10), (1, 4)): 28.7,
#  ((0, 5), (1, 4)): 30,
#  ((0, 4), (1, 4)): 30,
#  ((0, 10), (1, 4)): 30,
#  ((7, 5), (1, 4)): 27.413,
#  ((7, 4), (1, 4)): 27.412999999999997,
#  ((7, 10), (1, 4)): 27.413,
#  ((1, 5), (1, 5)): 28.7,
#  ((0, 5), (1, 5)): 30,
#  ((7, 5), (1, 5)): 27.413,
#  ((1, 6), (1, 6)): 10.164402173673555,
#  ((1, 0), (1, 6)): 12.6125,
#  ((0, 6), (1, 6)): 30,
#  ((0, 0), (1, 6)): -100,
#  ((7, 6), (1, 6)): 11.103222415667059,
#  ((7, 0), (1, 6)): 7.08664397019354,
#  ((1, 7), (1, 7)): 28.7,
#  ((1, 1), (1, 7)): -100,
#  ((0, 7), (1, 7)): 30,
#  ((0, 1), (1, 7)): 30,
#  ((7, 7), (1, 7)): -100,
#  ((7, 1), (1, 7)): -15.057999999999995,
#  ((1, 8), (1, 8)): 28.7,
#  ((1, 2), (1, 8)): 28.7,
#  ((0, 8), (1, 8)): 30,
#  ((0, 2), (1, 8)): 30,
#  ((7, 8), (1, 8)): 27.413,
#  ((7, 2), (1, 8)): 27.41300000142065,
#  ((1, 9), (1, 9)): 28.7,
#  ((1, 3), (1, 9)): 28.7,
#  ((0, 9), (1, 9)): 30,
#  ((0, 3), (1, 9)): 30,
#  ((7, 9), (1, 9)): 27.413,
#  ((7, 3), (1, 9)): 27.412999999999997,
#  ((1, 10), (1, 10)): 28.7,
#  ((1, 4), (1, 10)): 28.7,
#  ((0, 10), (1, 10)): 30,
#  ((0, 4), (1, 10)): 30,
#  ((7, 10), (1, 10)): 27.413,
#  ((7, 4), (1, 10)): 27.412999999999997,
#  ((1, 11), (1, 11)): 28.7,
#  ((1, 5), (1, 11)): 28.7,
#  ((0, 11), (1, 11)): 30,
#  ((0, 5), (1, 11)): 30,
#  ((7, 11), (1, 11)): 27.413,
#  ((7, 5), (1, 11)): 27.413,
#  ((2, 1), (2, 0)): 14.489569665012537,
#  ((2, 0), (2, 0)): 9.194197316247058,
#  ((2, 6), (2, 0)): 12.006117159679706,
#  ((1, 1), (2, 0)): -100,
#  ((1, 0), (2, 0)): 4.201885977453616,
#  ((1, 6), (2, 0)): 10.880470787984205,
#  ((8, 1), (2, 0)): 11.350944894597603,
#  ((8, 0), (2, 0)): 10.308983106692803,
#  ((8, 6), (2, 0)): 10.058059984240089,
#  ((2, 2), (2, 1)): -100,
#  ((2, 1), (2, 1)): 12.86056423992011,
#  ((2, 7), (2, 1)): 11.354780619111017,
#  ((1, 2), (2, 1)): 28.7,
#  ((1, 1), (2, 1)): -100,
#  ((1, 7), (2, 1)): 28.7,
#  ((8, 2), (2, 1)): 19.13115499408128,
#  ((8, 1), (2, 1)): 12.549314892697733,
#  ((8, 7), (2, 1)): 11.772494977776221,
#  ((2, 4), (2, 3)): 27.413,
#  ((2, 3), (2, 3)): 27.413,
#  ((2, 9), (2, 3)): 27.413,
#  ((1, 4), (2, 3)): 28.7,
#  ((1, 3), (2, 3)): 28.700000000000003,
#  ((1, 9), (2, 3)): 28.699999999999996,
#  ((8, 4), (2, 3)): 26.13887,
#  ((8, 3), (2, 3)): 26.138869999095373,
#  ((8, 9), (2, 3)): 26.13887,
#  ((2, 5), (2, 4)): 27.413,
#  ((2, 4), (2, 4)): 27.413,
#  ((2, 10), (2, 4)): 27.413,
#  ((1, 5), (2, 4)): 28.7,
#  ((1, 4), (2, 4)): 28.700000000000003,
#  ((1, 10), (2, 4)): 28.699999999999996,
#  ((8, 5), (2, 4)): 26.13887,
#  ((8, 4), (2, 4)): 26.13887,
#  ((8, 10), (2, 4)): 26.13887,
#  ((2, 5), (2, 5)): 27.413,
#  ((1, 5), (2, 5)): 28.7,
#  ((8, 5), (2, 5)): 26.13887,
#  ((2, 6), (2, 6)): 11.56185335316698,
#  ((2, 0), (2, 6)): 10.108810160653624,
#  ((1, 6), (2, 6)): 9.547481521549456,
#  ((1, 0), (2, 6)): 15.829999999999998,
#  ((8, 6), (2, 6)): 10.058059984240089,
#  ((8, 0), (2, 6)): 10.33185839218322,
#  ((2, 7), (2, 7)): 10.484453693074855,
#  ((2, 1), (2, 7)): 13.192120200614168,
#  ((1, 7), (2, 7)): 28.7,
#  ((1, 1), (2, 7)): -100,
#  ((8, 7), (2, 7)): 11.4044608455884,
#  ((8, 1), (2, 7)): 11.894454421200372,
#  ((2, 8), (2, 8)): 27.412999998579345,
#  ((2, 2), (2, 8)): -100,
#  ((1, 8), (2, 8)): 28.699999999999996,
#  ((1, 2), (2, 8)): 28.699999997129996,
#  ((8, 8), (2, 8)): -100,
#  ((8, 2), (2, 8)): -15.90742000046881,
#  ((2, 9), (2, 9)): 27.413,
#  ((2, 3), (2, 9)): 27.413,
#  ((1, 9), (2, 9)): 28.7,
#  ((1, 3), (2, 9)): 28.7,
#  ((8, 9), (2, 9)): 26.13887,
#  ((8, 3), (2, 9)): 26.138869999095373,
#  ((2, 10), (2, 10)): 27.413,
#  ((2, 4), (2, 10)): 27.413,
#  ((1, 10), (2, 10)): 28.7,
#  ((1, 4), (2, 10)): 28.7,
#  ((8, 10), (2, 10)): 26.13887,
#  ((8, 4), (2, 10)): 26.13887,
#  ((2, 11), (2, 11)): 27.413,
#  ((2, 5), (2, 11)): 27.413,
#  ((1, 11), (2, 11)): 28.7,
#  ((1, 5), (2, 11)): 28.7,
#  ((8, 11), (2, 11)): 26.13887,
#  ((8, 5), (2, 11)): 26.13887,
#  ((3, 1), (3, 0)): 11.700215303488486,
#  ((3, 0), (3, 0)): 10.853560837566288,
#  ((3, 6), (3, 0)): 10.308281450073896,
#  ((2, 1), (3, 0)): 23.43134375,
#  ((2, 0), (3, 0)): 9.298026014289515,
#  ((2, 6), (3, 0)): 11.21631483657577,
#  ((9, 1), (3, 0)): 11.694262082524212,
#  ((9, 0), (3, 0)): 10.47512304324584,
#  ((9, 6), (3, 0)): 10.41196046279409,
#  ((3, 2), (3, 1)): 13.460812986085017,
#  ((3, 1), (3, 1)): 11.835489054987734,
#  ((3, 7), (3, 1)): 13.189198878589332,
#  ((2, 2), (3, 1)): -100,
#  ((2, 1), (3, 1)): 12.41940539753578,
#  ((2, 7), (3, 1)): 10.719904077376066,
#  ((9, 2), (3, 1)): 14.432537792530432,
#  ((9, 1), (3, 1)): 11.582763473783801,
#  ((9, 7), (3, 1)): 11.242682085195426,
#  ((3, 3), (3, 2)): -100,
#  ((3, 2), (3, 2)): 13.392857575272423,
#  ((3, 8), (3, 2)): 12.490954015684508,
#  ((2, 3), (3, 2)): 27.413,
#  ((2, 2), (3, 2)): -100,
#  ((2, 8), (3, 2)): 27.412999998595673,
#  ((9, 3), (3, 2)): 15.018732778944788,
#  ((9, 2), (3, 2)): 15.154772309172916,
#  ((9, 8), (3, 2)): 13.967054150957495,
#  ((3, 5), (3, 4)): 26.13887,
#  ((3, 4), (3, 4)): 26.13887,
#  ((3, 10), (3, 4)): 26.138870000000004,
#  ((2, 5), (3, 4)): 27.413,
#  ((2, 4), (3, 4)): 27.413,
#  ((2, 10), (3, 4)): 27.413,
#  ((9, 5), (3, 4)): 24.8774813,
#  ((9, 4), (3, 4)): 24.8774813,
#  ((9, 10), (3, 4)): 24.8774813,
#  ((3, 5), (3, 5)): 26.13887,
#  ((2, 5), (3, 5)): 27.413,
#  ((9, 5), (3, 5)): 24.8774813,
#  ((3, 6), (3, 6)): 9.131925343086591,
#  ((3, 0), (3, 6)): 13.713087687365725,
#  ((2, 6), (3, 6)): 10.14828669534598,
#  ((2, 0), (3, 6)): 10.79314665531075,
#  ((9, 6), (3, 6)): 9.760262230560883,
#  ((9, 0), (3, 6)): 10.281483993168354,
#  ((3, 7), (3, 7)): 14.736953356487348,
#  ((3, 1), (3, 7)): 12.310377936771802,
#  ((2, 7), (3, 7)): 10.43594432908927,
#  ((2, 1), (3, 7)): 18.6258965569964,
#  ((9, 7), (3, 7)): 11.494950345490981,
#  ((9, 1), (3, 7)): 11.832651054616349,
#  ((3, 8), (3, 8)): 12.437641324270754,
#  ((3, 2), (3, 8)): 13.500565203045676,
#  ((2, 8), (3, 8)): 27.41299999947383,
#  ((2, 2), (3, 8)): -100,
#  ((9, 8), (3, 8)): 13.42977186584002,
#  ((9, 2), (3, 8)): 13.86058149342593,
#  ((3, 9), (3, 9)): 26.138870000000004,
#  ((3, 3), (3, 9)): -100,
#  ((2, 9), (3, 9)): 27.413,
#  ((2, 3), (3, 9)): 27.413000000000004,
#  ((9, 9), (3, 9)): -100,
#  ((9, 3), (3, 9)): -16.748345799999996,
#  ((3, 10), (3, 10)): 26.138870000000004,
#  ((3, 4), (3, 10)): 26.138870002613892,
#  ((2, 10), (3, 10)): 27.413,
#  ((2, 4), (3, 10)): 27.413000000000004,
#  ((9, 10), (3, 10)): 24.8774813,
#  ((9, 4), (3, 10)): 24.8774813,
#  ((3, 11), (3, 11)): 26.13887,
#  ((3, 5), (3, 11)): 26.13887,
#  ((2, 11), (3, 11)): 27.413,
#  ((2, 5), (3, 11)): 27.413,
#  ((9, 11), (3, 11)): 24.8774813,
#  ((9, 5), (3, 11)): 24.8774813,
#  ((4, 1), (4, 0)): 19.224205663011748,
#  ((4, 0), (4, 0)): 14.976807889416932,
#  ((4, 6), (4, 0)): 15.391441486688283,
#  ((3, 1), (4, 0)): 11.674708760449029,
#  ((3, 0), (4, 0)): 10.614212361103633,
#  ((3, 6), (4, 0)): 9.854746377990262,
#  ((10, 1), (4, 0)): 11.04395030903434,
#  ((10, 0), (4, 0)): 13.490232454355986,
#  ((10, 6), (4, 0)): 13.691402153885226,
#  ((4, 2), (4, 1)): 5.601054458022075,
#  ((4, 1), (4, 1)): 15.600320707786176,
#  ((4, 7), (4, 1)): 13.311205446245854,
#  ((3, 2), (4, 1)): 22.299860913022066,
#  ((3, 1), (4, 1)): 11.811896363926657,
#  ((3, 7), (4, 1)): 16.192244867857873,
#  ((10, 2), (4, 1)): 5.012804977105704,
#  ((10, 1), (4, 1)): 11.04395030903434,
#  ((10, 7), (4, 1)): 13.311205446245854,
#  ((4, 3), (4, 2)): 4.0645677458374205,
#  ((4, 2), (4, 2)): 6.460098587903085,
#  ((4, 8), (4, 2)): 12.081693023541572,
#  ((3, 3), (4, 2)): -100,
#  ((3, 2), (4, 2)): 13.566384548894813,
#  ((3, 8), (4, 2)): 12.508724912836644,
#  ((10, 3), (4, 2)): 4.75566530122474,
#  ((10, 2), (4, 2)): 6.4025090207082,
#  ((10, 8), (4, 2)): 8.091802496872777,
#  ((4, 4), (4, 3)): -100,
#  ((4, 3), (4, 3)): -0.4012137115794383,
#  ((4, 9), (4, 3)): 3.5700509823060314,
#  ((3, 4), (4, 3)): 26.13887,
#  ((3, 3), (4, 3)): -100,
#  ((3, 9), (4, 3)): 26.138870000000004,
#  ((10, 4), (4, 3)): -7.27847013475,
#  ((10, 3), (4, 3)): 4.75566530122474,
#  ((10, 9), (4, 3)): 4.337308737829993,
#  ((4, 5), (4, 5)): 24.8774813,
#  ((3, 5), (4, 5)): 26.13887,
#  ((10, 5), (4, 5)): 23.628706487,
#  ((4, 6), (4, 6)): 13.97217362703029,
#  ((4, 0), (4, 6)): 16.965382227455866,
#  ((3, 6), (4, 6)): 9.300425734433272,
#  ((3, 0), (4, 6)): 20.185304536312277,
#  ((10, 6), (4, 6)): 13.691402153885226,
#  ((10, 0), (4, 6)): 13.370691368452766,
#  ((4, 7), (4, 7)): 13.311205446245854,
#  ((4, 1), (4, 7)): 15.600320707786176,
#  ((3, 7), (4, 7)): 13.385611238612405,
#  ((3, 1), (4, 7)): 11.700215303488486,
#  ((10, 7), (4, 7)): 13.311205446245854,
#  ((10, 1), (4, 7)): 11.04395030903434,
#  ((4, 8), (4, 8)): 11.907179183557073,
#  ((4, 2), (4, 8)): 6.460098587903085,
#  ((3, 8), (4, 8)): 12.508724912836644,
#  ((3, 2), (4, 8)): 13.566384548894813,
#  ((10, 8), (4, 8)): 8.091802496872777,
#  ((10, 2), (4, 8)): 5.557862282625912,
#  ((4, 9), (4, 9)): 3.5010221493320928,
#  ((4, 3), (4, 9)): 0.5225736289283445,
#  ((3, 9), (4, 9)): 26.138870000000004,
#  ((3, 3), (4, 9)): -100,
#  ((10, 9), (4, 9)): 4.337308737829993,
#  ((10, 3), (4, 9)): 4.75566530122474,
#  ((4, 10), (4, 10)): 24.8774813,
#  ((4, 4), (4, 10)): -100,
#  ((3, 10), (4, 10)): 26.13887,
#  ((3, 4), (4, 10)): 26.13887,
#  ((10, 10), (4, 10)): -100,
#  ((10, 4), (4, 10)): -17.580862341999996,
#  ((4, 11), (4, 11)): 24.8774813,
#  ((4, 5), (4, 11)): 24.8774813,
#  ((3, 11), (4, 11)): 26.13887,
#  ((3, 5), (4, 11)): 26.13887,
#  ((10, 11), (4, 11)): 23.628706487,
#  ((10, 5), (4, 11)): 23.628706487,
#  ((5, 1), (5, 0)): 14.635882399024583,
#  ((5, 0), (5, 0)): 15.422502281758453,
#  ((5, 6), (5, 0)): 13.11176768397162,
#  ((4, 1), (5, 0)): 19.947768145768986,
#  ((4, 0), (5, 0)): 15.439393696761261,
#  ((4, 6), (5, 0)): 15.526989033469913,
#  ((11, 1), (5, 0)): 13.671709736109516,
#  ((11, 0), (5, 0)): 13.128031167988963,
#  ((11, 6), (5, 0)): 13.755960244912973,
#  ((5, 2), (5, 1)): 15.874165543371458,
#  ((5, 1), (5, 1)): 13.962525011036318,
#  ((5, 7), (5, 1)): 15.504294327520466,
#  ((4, 2), (5, 1)): 4.742010328787075,
#  ((4, 1), (5, 1)): 15.600320707786176,
#  ((4, 7), (5, 1)): 13.311205446245854,
#  ((11, 2), (5, 1)): 13.355824379678683,
#  ((11, 1), (5, 1)): 13.273618870450395,
#  ((11, 7), (5, 1)): 13.037252418188991,
#  ((5, 3), (5, 2)): 17.83561022025265,
#  ((5, 2), (5, 2)): 13.730005160910551,
#  ((5, 8), (5, 2)): 11.262734696817802,
#  ((4, 3), (5, 2)): -0.4012137115794383,
#  ((4, 2), (5, 2)): 6.460098587903085,
#  ((4, 8), (5, 2)): 11.907179183557073,
#  ((11, 3), (5, 2)): 2.4599417966462553,
#  ((11, 2), (5, 2)): 12.042366608586782,
#  ((11, 8), (5, 2)): 10.893091059877616,
#  ((5, 4), (5, 3)): 20.287390098800774,
#  ((5, 3), (5, 3)): 16.8409981125936,
#  ((5, 9), (5, 3)): 14.66906254876889,
#  ((4, 4), (5, 3)): -100,
#  ((4, 3), (5, 3)): -0.4012137115794383,
#  ((4, 9), (5, 3)): 3.5010221493320928,
#  ((11, 4), (5, 3)): -40.96996107268314,
#  ((11, 3), (5, 3)): 8.521283472540473,
#  ((11, 9), (5, 3)): 14.687621326600965,
#  ((5, 5), (5, 4)): -100,
#  ((5, 4), (5, 4)): -17.580862341999996,
#  ((5, 10), (5, 4)): -3.055509368609903,
#  ((4, 5), (5, 4)): 24.8774813,
#  ((4, 4), (5, 4)): -100,
#  ((4, 10), (5, 4)): 24.8774813,
#  ((11, 5), (5, 4)): -99.99015742709012,
#  ((11, 4), (5, 4)): -35.32873423313742,
#  ((11, 10), (5, 4)): -16.08568284029261,
#  ((5, 6), (5, 6)): 12.564493309183806,
#  ((5, 0), (5, 6)): 15.801669789080051,
#  ((4, 6), (5, 6)): 13.425107193644251,
#  ((4, 0), (5, 6)): 15.083514390136799,
#  ((11, 6), (5, 6)): 12.228811084949136,
#  ((11, 0), (5, 6)): 13.129814937434457,
#  ((5, 7), (5, 7)): 14.395560682274777,
#  ((5, 1), (5, 7)): 13.962525011036318,
#  ((4, 7), (5, 7)): 13.311205446245854,
#  ((4, 1), (5, 7)): 17.790937346228443,
#  ((11, 7), (5, 7)): 13.037252418188991,
#  ((11, 1), (5, 7)): 13.273618870450395,
#  ((5, 8), (5, 8)): 10.893091059877616,
#  ((5, 2), (5, 8)): 13.133355525733728,
#  ((4, 8), (5, 8)): 11.907179183557073,
#  ((4, 2), (5, 8)): 6.460098587903085,
#  ((11, 8), (5, 8)): 10.893091059877616,
#  ((11, 2), (5, 8)): 12.617004382941369,
#  ((5, 9), (5, 9)): 12.54324568608053,
#  ((5, 3), (5, 9)): 17.469381018484476,
#  ((4, 9), (5, 9)): 3.5010221493320928,
#  ((4, 3), (5, 9)): -0.4012137115794383,
#  ((11, 9), (5, 9)): 14.195137924019871,
#  ((11, 3), (5, 9)): 5.869446488831355,
#  ((5, 10), (5, 10)): -3.055509368609903,
#  ((5, 4), (5, 10)): -1.097034810400002,
#  ((4, 10), (5, 10)): 24.8774813,
#  ((4, 4), (5, 10)): -100,
#  ((11, 10), (5, 10)): -11.2150039967519,
#  ((11, 4), (5, 10)): -40.96996107268314,
#  ((5, 11), (5, 11)): 23.628706487,
#  ((5, 5), (5, 11)): -100,
#  ((4, 11), (5, 11)): 24.8774813,
#  ((4, 5), (5, 11)): 24.8774813,
#  ((11, 11), (5, 11)): -100,
#  ((11, 5), (5, 11)): -99.99015742709012,
#  ((0, 1), (6, 0)): 30,
#  ((0, 0), (6, 0)): -100,
#  ((0, 6), (6, 0)): 30,
#  ((6, 1), (6, 0)): 28.7,
#  ((6, 0), (6, 0)): -14.199999999999996,
#  ((6, 6), (6, 0)): -100,
#  ((0, 2), (6, 1)): 30,
#  ((0, 1), (6, 1)): 30,
#  ((0, 7), (6, 1)): 30,
#  ((6, 2), (6, 1)): 28.7,
#  ((6, 1), (6, 1)): 28.7,
#  ((6, 7), (6, 1)): 28.7,
#  ((0, 3), (6, 2)): 30,
#  ((0, 2), (6, 2)): 30,
#  ((0, 8), (6, 2)): 30,
#  ((6, 3), (6, 2)): 28.7,
#  ((6, 2), (6, 2)): 28.7,
#  ((6, 8), (6, 2)): 28.7,
#  ((0, 4), (6, 3)): 30,
#  ((0, 3), (6, 3)): 30,
#  ((0, 9), (6, 3)): 30,
#  ((6, 4), (6, 3)): 28.7,
#  ((6, 3), (6, 3)): 28.7,
#  ((6, 9), (6, 3)): 28.7,
#  ((0, 5), (6, 4)): 30,
#  ((0, 4), (6, 4)): 30,
#  ((0, 10), (6, 4)): 30,
#  ((6, 5), (6, 4)): 28.7,
#  ((6, 4), (6, 4)): 28.7,
#  ((6, 10), (6, 4)): 28.7,
#  ((0, 5), (6, 5)): 30,
#  ((6, 5), (6, 5)): 28.7,
#  ((0, 7), (6, 7)): 30,
#  ((0, 1), (6, 7)): 30,
#  ((6, 7), (6, 7)): 28.7,
#  ((6, 1), (6, 7)): 28.7,
#  ((0, 8), (6, 8)): 30,
#  ((0, 2), (6, 8)): 30,
#  ((6, 8), (6, 8)): 28.7,
#  ((6, 2), (6, 8)): 28.7,
#  ((0, 9), (6, 9)): 30,
#  ((0, 3), (6, 9)): 30,
#  ((6, 9), (6, 9)): 28.7,
#  ((6, 3), (6, 9)): 28.7,
#  ((0, 10), (6, 10)): 30,
#  ((0, 4), (6, 10)): 30,
#  ((6, 10), (6, 10)): 28.7,
#  ((6, 4), (6, 10)): 28.7,
#  ((0, 11), (6, 11)): 30,
#  ((0, 5), (6, 11)): 30,
#  ((6, 11), (6, 11)): 28.7,
#  ((6, 5), (6, 11)): 28.7,
#  ((1, 1), (7, 0)): -100,
#  ((1, 0), (7, 0)): 4.738233033956099,
#  ((1, 6), (7, 0)): 10.27456657596841,
#  ((7, 1), (7, 0)): 9.2111428516823,
#  ((7, 0), (7, 0)): 6.28947292473073,
#  ((7, 6), (7, 0)): 10.883220269335187,
#  ((1, 2), (7, 1)): 28.7,
#  ((1, 1), (7, 1)): -100,
#  ((1, 7), (7, 1)): 28.7,
#  ((7, 2), (7, 1)): 27.41300000142065,
#  ((7, 1), (7, 1)): -4.44025,
#  ((7, 7), (7, 1)): -100,
#  ((1, 3), (7, 2)): 28.70000000287,
#  ((1, 2), (7, 2)): 28.7,
#  ((1, 8), (7, 2)): 28.7,
#  ((7, 3), (7, 2)): 27.412999999999997,
#  ((7, 2), (7, 2)): 27.4130000009471,
#  ((7, 8), (7, 2)): 27.413,
#  ((1, 4), (7, 3)): 28.7,
#  ((1, 3), (7, 3)): 28.7,
#  ((1, 9), (7, 3)): 28.7,
#  ((7, 4), (7, 3)): 27.412999999999997,
#  ((7, 3), (7, 3)): 27.412999999999997,
#  ((7, 9), (7, 3)): 27.413,
#  ((1, 5), (7, 4)): 28.7,
#  ((1, 4), (7, 4)): 28.7,
#  ((1, 10), (7, 4)): 28.7,
#  ((7, 5), (7, 4)): 27.413,
#  ((7, 4), (7, 4)): 27.412999999999997,
#  ((7, 10), (7, 4)): 27.413,
#  ((1, 5), (7, 5)): 28.7,
#  ((7, 5), (7, 5)): 27.413,
#  ((1, 6), (7, 6)): 10.447682065046536,
#  ((1, 0), (7, 6)): 13.55882352957,
#  ((7, 6), (7, 6)): 11.396558611084224,
#  ((7, 0), (7, 6)): 7.706665894326244,
#  ((1, 8), (7, 8)): 28.7,
#  ((1, 2), (7, 8)): 28.7,
#  ((7, 8), (7, 8)): 27.413,
#  ((7, 2), (7, 8)): 27.4130000009471,
#  ((1, 9), (7, 9)): 28.7,
#  ((1, 3), (7, 9)): 28.7,
#  ((7, 9), (7, 9)): 27.413,
#  ((7, 3), (7, 9)): 27.412999999999997,
#  ((1, 10), (7, 10)): 28.7,
#  ((1, 4), (7, 10)): 28.7,
#  ((7, 10), (7, 10)): 27.413,
#  ((7, 4), (7, 10)): 27.412999999999997,
#  ((1, 11), (7, 11)): 28.7,
#  ((1, 5), (7, 11)): 28.7,
#  ((7, 11), (7, 11)): 27.413,
#  ((7, 5), (7, 11)): 27.413,
#  ((2, 1), (8, 0)): 12.668301310977036,
#  ((2, 0), (8, 0)): 10.108810160653624,
#  ((2, 6), (8, 0)): 11.56185335316698,
#  ((8, 1), (8, 0)): 11.350944894597603,
#  ((8, 0), (8, 0)): 10.33185839218322,
#  ((8, 6), (8, 0)): 10.058059984240089,
#  ((2, 2), (8, 1)): -100,
#  ((2, 1), (8, 1)): 13.339478405303225,
#  ((2, 7), (8, 1)): 10.719904077376066,
#  ((8, 2), (8, 1)): 14.67170000101886,
#  ((8, 1), (8, 1)): 11.350944894597603,
#  ((8, 7), (8, 1)): 11.4044608455884,
#  ((2, 3), (8, 2)): 27.413,
#  ((2, 2), (8, 2)): -100,
#  ((2, 8), (8, 2)): 27.412999998579345,
#  ((8, 3), (8, 2)): 26.13886999790291,
#  ((8, 2), (8, 2)): -15.90742000046881,
#  ((8, 8), (8, 2)): -100,
#  ((2, 4), (8, 3)): 27.412999997258705,
#  ((2, 3), (8, 3)): 27.413000000000004,
#  ((2, 9), (8, 3)): 27.413,
#  ((8, 4), (8, 3)): 26.13887,
#  ((8, 3), (8, 3)): 26.138869999095373,
#  ((8, 9), (8, 3)): 26.13887,
#  ((2, 5), (8, 4)): 27.413,
#  ((2, 4), (8, 4)): 27.413,
#  ((2, 10), (8, 4)): 27.413,
#  ((8, 5), (8, 4)): 26.13887,
#  ((8, 4), (8, 4)): 26.13887,
#  ((8, 10), (8, 4)): 26.13887,
#  ((2, 5), (8, 5)): 27.413,
#  ((8, 5), (8, 5)): 26.13887,
#  ((2, 6), (8, 6)): 11.56185335316698,
#  ((2, 0), (8, 6)): 10.777661766509969,
#  ((8, 6), (8, 6)): 10.058059984240089,
#  ((8, 0), (8, 6)): 10.33185839218322,
#  ((2, 7), (8, 7)): 11.166669051209405,
#  ((2, 1), (8, 7)): 13.211303119123976,
#  ((8, 7), (8, 7)): 11.067096224315023,
#  ((8, 1), (8, 7)): 12.220560137162032,
#  ((2, 9), (8, 9)): 27.413,
#  ((2, 3), (8, 9)): 27.413,
#  ((8, 9), (8, 9)): 26.13887,
#  ((8, 3), (8, 9)): 26.138869999095373,
#  ((2, 10), (8, 10)): 27.413,
#  ((2, 4), (8, 10)): 27.413,
#  ((8, 10), (8, 10)): 26.13887,
#  ((8, 4), (8, 10)): 26.13887,
#  ((2, 11), (8, 11)): 27.413,
#  ((2, 5), (8, 11)): 27.413,
#  ((8, 11), (8, 11)): 26.13887,
#  ((8, 5), (8, 11)): 26.13887,
#  ((3, 1), (9, 0)): 11.700215303488486,
#  ((3, 0), (9, 0)): 12.177818377250812,
#  ((3, 6), (9, 0)): 10.308281450073896,
#  ((9, 1), (9, 0)): 11.694262082524212,
#  ((9, 0), (9, 0)): 10.281483993168354,
#  ((9, 6), (9, 0)): 10.41196046279409,
#  ((3, 2), (9, 1)): 13.381634314033091,
#  ((3, 1), (9, 1)): 11.700215303488486,
#  ((3, 7), (9, 1)): 13.385611238612405,
#  ((9, 2), (9, 1)): 13.45307838049117,
#  ((9, 1), (9, 1)): 11.138518885581513,
#  ((9, 7), (9, 1)): 11.494950345490981,
#  ((3, 3), (9, 2)): -100,
#  ((3, 2), (9, 2)): 13.566384548894813,
#  ((3, 8), (9, 2)): 12.508724912836644,
#  ((9, 3), (9, 2)): 17.384832422,
#  ((9, 2), (9, 2)): 13.981640112211146,
#  ((9, 8), (9, 2)): 13.665592597382581,
#  ((3, 4), (9, 3)): 26.13887,
#  ((3, 3), (9, 3)): -100,
#  ((3, 9), (9, 3)): 26.138870000000004,
#  ((9, 4), (9, 3)): 24.877481302487748,
#  ((9, 3), (9, 3)): -39.986064810940334,
#  ((9, 9), (9, 3)): -100,
#  ((3, 5), (9, 4)): 26.13887,
#  ((3, 4), (9, 4)): 26.13887,
#  ((3, 10), (9, 4)): 26.138870000000004,
#  ((9, 5), (9, 4)): 24.8774813,
#  ((9, 4), (9, 4)): 24.8774813,
#  ((9, 10), (9, 4)): 24.8774813,
#  ((3, 5), (9, 5)): 26.13887,
#  ((9, 5), (9, 5)): 24.8774813,
#  ((3, 6), (9, 6)): 9.55238966311666,
#  ((3, 0), (9, 6)): 13.502075918285543,
#  ((9, 6), (9, 6)): 10.41196046279409,
#  ((9, 0), (9, 6)): 10.281483993168354,
#  ((3, 7), (9, 7)): 13.385611238612405,
#  ((3, 1), (9, 7)): 11.856712691672406,
#  ((9, 7), (9, 7)): 11.494950345490981,
#  ((9, 1), (9, 7)): 11.694262082524212,
#  ((3, 8), (9, 8)): 12.508724912836644,
#  ((3, 2), (9, 8)): 13.398987011429586,
#  ((9, 8), (9, 8)): 13.543315181102873,
#  ((9, 2), (9, 8)): 15.60773909332141,
#  ((3, 10), (9, 10)): 26.138870000000004,
#  ((3, 4), (9, 10)): 26.13887,
#  ((9, 10), (9, 10)): 24.8774813,
#  ((9, 4), (9, 10)): 24.8774813,
#  ((3, 11), (9, 11)): 26.13887,
#  ((3, 5), (9, 11)): 26.13887,
#  ((9, 11), (9, 11)): 24.8774813,
#  ((9, 5), (9, 11)): 24.8774813,
#  ((4, 1), (10, 0)): 14.505012388565042,
#  ((4, 0), (10, 0)): 14.750122021954263,
#  ((4, 6), (10, 0)): 14.314090147970647,
#  ((10, 1), (10, 0)): 9.910322740428583,
#  ((10, 0), (10, 0)): 13.487997223065417,
#  ((10, 6), (10, 0)): 13.691402153885226,
#  ((4, 2), (10, 1)): 7.585292964253853,
#  ((4, 1), (10, 1)): 15.600320707786176,
#  ((4, 7), (10, 1)): 13.311205446245854,
#  ((10, 2), (10, 1)): 6.4025090207082,
#  ((10, 1), (10, 1)): 11.04395030903434,
#  ((10, 7), (10, 1)): 13.311205446245854,
#  ((4, 3), (10, 2)): 4.0645677458374205,
#  ((4, 2), (10, 2)): 6.460098587903085,
#  ((4, 8), (10, 2)): 11.907179183557073,
#  ((10, 3), (10, 2)): 5.054967202545985,
#  ((10, 2), (10, 2)): 6.4025090207082,
#  ((10, 8), (10, 2)): 7.193034198410116,
#  ((4, 4), (10, 3)): -100,
#  ((4, 3), (10, 3)): -0.4012137115794383,
#  ((4, 9), (10, 3)): 3.5010221493320928,
#  ((10, 4), (10, 3)): 8.175118176124998,
#  ((10, 3), (10, 3)): 4.75566530122474,
#  ((10, 9), (10, 3)): 4.510626526361597,
#  ((4, 5), (10, 4)): 24.8774813,
#  ((4, 4), (10, 4)): -100,
#  ((4, 10), (10, 4)): 24.8774813,
#  ((10, 5), (10, 4)): 23.628706487,
#  ((10, 4), (10, 4)): -17.580862341999996,
#  ((10, 10), (10, 4)): -100,
#  ((4, 5), (10, 5)): 24.8774813,
#  ((10, 5), (10, 5)): 23.628706487,
#  ((4, 6), (10, 6)): 14.314090147970647,
#  ((4, 0), (10, 6)): 15.365510162908597,
#  ((10, 6), (10, 6)): 13.691402153885226,
#  ((10, 0), (10, 6)): 13.377844104301683,
#  ((4, 7), (10, 7)): 13.311205446245854,
#  ((4, 1), (10, 7)): 15.600320707786176,
#  ((10, 7), (10, 7)): 13.311205446245854,
#  ((10, 1), (10, 7)): 11.04395030903434,
#  ((4, 8), (10, 8)): 11.907179183557073,
#  ((4, 2), (10, 8)): 6.460098587903085,
#  ((10, 8), (10, 8)): 8.091802496872777,
#  ((10, 2), (10, 8)): 5.557862282625912,
#  ((4, 9), (10, 9)): 3.5010221493320928,
#  ((4, 3), (10, 9)): -0.4012137115794383,
#  ((10, 9), (10, 9)): 3.990673160558803,
#  ((10, 3), (10, 9)): 6.091494840570092,
#  ((4, 11), (10, 11)): 24.8774813,
#  ((4, 5), (10, 11)): 24.8774813,
#  ((10, 11), (10, 11)): 23.628706487,
#  ((10, 5), (10, 11)): 23.628706487,
#  ((5, 1), (11, 0)): 14.277945698820737,
#  ((5, 0), (11, 0)): 15.422502281758453,
#  ((5, 6), (11, 0)): 13.11176768397162,
#  ((11, 1), (11, 0)): 13.391802096581099,
#  ((11, 0), (11, 0)): 13.128031169301767,
#  ((11, 6), (11, 0)): 12.67797260251422,
#  ((5, 2), (11, 1)): 14.895304823205262,
#  ((5, 1), (11, 1)): 13.962525011036318,
#  ((5, 7), (11, 1)): 14.395560682274777,
#  ((11, 2), (11, 1)): 13.935291041835951,
#  ((11, 1), (11, 1)): 13.273618870450395,
#  ((11, 7), (11, 1)): 13.037252418188991,
#  ((5, 3), (11, 2)): 15.495876470712243,
#  ((5, 2), (11, 2)): 13.133355525733728,
#  ((5, 8), (11, 2)): 10.893091059877616,
#  ((11, 3), (11, 2)): 4.891126313831151,
#  ((11, 2), (11, 2)): 12.042366608586782,
#  ((11, 8), (11, 2)): 10.893091059877616,
#  ((5, 4), (11, 3)): -1.0970348104000003,
#  ((5, 3), (11, 3)): 16.093158750853878,
#  ((5, 9), (11, 3)): 13.856250218759678,
#  ((11, 4), (11, 3)): -82.29098832180495,
#  ((11, 3), (11, 3)): 5.869446488831355,
#  ((11, 9), (11, 3)): 14.195137924019871,
#  ((5, 5), (11, 4)): -100,
#  ((5, 4), (11, 4)): -17.58086233787904,
#  ((5, 10), (11, 4)): -3.540231821766853,
#  ((11, 5), (11, 4)): -99.99015742709012,
#  ((11, 4), (11, 4)): -29.163953287219773,
#  ((11, 10), (11, 4)): -15.529033829848759,
#  ((5, 5), (11, 5)): -100,
#  ((11, 5), (11, 5)): -99.99015742709012,
#  ((5, 6), (11, 6)): 12.45503843416057,
#  ((5, 0), (11, 6)): 16.538324957887863,
#  ((11, 6), (11, 6)): 12.341101464441468,
#  ((11, 0), (11, 6)): 13.13088519831407,
#  ((5, 7), (11, 7)): 14.395560682274777,
#  ((5, 1), (11, 7)): 13.962525011036318,
#  ((11, 7), (11, 7)): 13.037252418188991,
#  ((11, 1), (11, 7)): 13.273618870450395,
#  ((5, 8), (11, 8)): 10.893091059877616,
#  ((5, 2), (11, 8)): 13.133355525733728,
#  ((11, 8), (11, 8)): 10.893091059877616,
#  ((11, 2), (11, 8)): 12.042366608586782,
#  ((5, 9), (11, 9)): 13.856250218759678,
#  ((5, 3), (11, 9)): 16.8409981125936,
#  ((11, 9), (11, 9)): 14.195137924019871,
#  ((11, 3), (11, 9)): 8.521283472540473,
#  ((5, 10), (11, 10)): -3.055509368609903,
#  ((5, 4), (11, 10)): -17.580862341999996,
#  ((11, 10), (11, 10)): -13.012516427208924,
#  ((11, 4), (11, 10)): -77.03269607262018,
#  ((5, 0), (-10, -10)): 15.801669789080051}

# %%
Policy
# Out:
# {((1, 0), (1, 0)): 'down',
#  ((1, 6), (1, 0)): 'stay',
#  ((7, 1), (1, 0)): 'up',
#  ((7, 0), (1, 0)): 'stay',
#  ((7, 6), (1, 0)): 'up',
#  ((1, 3), (1, 2)): 'left',
#  ((1, 2), (1, 2)): 'left',
#  ((1, 8), (1, 2)): 'left',
#  ((7, 3), (1, 2)): 'up',
#  ((7, 2), (1, 2)): 'up',
#  ((7, 8), (1, 2)): 'up',
#  ((1, 4), (1, 3)): 'left',
#  ((1, 3), (1, 3)): 'left',
#  ((1, 9), (1, 3)): 'left',
#  ((7, 4), (1, 3)): 'up',
#  ((7, 3), (1, 3)): 'up',
#  ((7, 9), (1, 3)): 'up',
#  ((1, 5), (1, 4)): 'left',
#  ((1, 4), (1, 4)): 'left',
#  ((1, 10), (1, 4)): 'left',
#  ((7, 5), (1, 4)): 'up',
#  ((7, 4), (1, 4)): 'up',
#  ((7, 10), (1, 4)): 'up',
#  ((1, 5), (1, 5)): 'left',
#  ((7, 5), (1, 5)): 'up',
#  ((1, 6), (1, 6)): 'stay',
#  ((1, 0), (1, 6)): 'left',
#  ((7, 6), (1, 6)): 'up',
#  ((7, 0), (1, 6)): 'stay',
#  ((1, 7), (1, 7)): 'left',
#  ((7, 1), (1, 7)): 'up',
#  ((1, 8), (1, 8)): 'left',
#  ((1, 2), (1, 8)): 'left',
#  ((7, 8), (1, 8)): 'up',
#  ((7, 2), (1, 8)): 'up',
#  ((1, 9), (1, 9)): 'left',
#  ((1, 3), (1, 9)): 'left',
#  ((7, 9), (1, 9)): 'up',
#  ((7, 3), (1, 9)): 'up',
#  ((1, 10), (1, 10)): 'left',
#  ((1, 4), (1, 10)): 'left',
#  ((7, 10), (1, 10)): 'up',
#  ((7, 4), (1, 10)): 'up',
#  ((1, 11), (1, 11)): 'left',
#  ((1, 5), (1, 11)): 'left',
#  ((7, 11), (1, 11)): 'up',
#  ((7, 5), (1, 11)): 'up',
#  ((2, 1), (2, 0)): 'down',
#  ((2, 0), (2, 0)): 'down',
#  ((2, 6), (2, 0)): 'left',
#  ((1, 0), (2, 0)): 'down',
#  ((1, 6), (2, 0)): 'stay',
#  ((8, 1), (2, 0)): 'stay',
#  ((8, 0), (2, 0)): 'up',
#  ((8, 6), (2, 0)): 'up',
#  ((2, 1), (2, 1)): 'down',
#  ((2, 7), (2, 1)): 'stay',
#  ((1, 2), (2, 1)): 'left',
#  ((1, 7), (2, 1)): 'left',
#  ((8, 2), (2, 1)): 'up',
#  ((8, 1), (2, 1)): 'stay',
#  ((8, 7), (2, 1)): 'up',
#  ((2, 4), (2, 3)): 'left',
#  ((2, 3), (2, 3)): 'left',
#  ((2, 9), (2, 3)): 'left',
#  ((1, 4), (2, 3)): 'left',
#  ((1, 3), (2, 3)): 'left',
#  ((1, 9), (2, 3)): 'left',
#  ((8, 4), (2, 3)): 'up',
#  ((8, 3), (2, 3)): 'up',
#  ((8, 9), (2, 3)): 'up',
#  ((2, 5), (2, 4)): 'left',
#  ((2, 4), (2, 4)): 'left',
#  ((2, 10), (2, 4)): 'left',
#  ((1, 5), (2, 4)): 'left',
#  ((1, 4), (2, 4)): 'left',
#  ((1, 10), (2, 4)): 'left',
#  ((8, 5), (2, 4)): 'up',
#  ((8, 4), (2, 4)): 'up',
#  ((8, 10), (2, 4)): 'up',
#  ((2, 5), (2, 5)): 'left',
#  ((1, 5), (2, 5)): 'left',
#  ((8, 5), (2, 5)): 'up',
#  ((2, 6), (2, 6)): 'left',
#  ((2, 0), (2, 6)): 'stay',
#  ((1, 6), (2, 6)): 'stay',
#  ((1, 0), (2, 6)): 'left',
#  ((8, 6), (2, 6)): 'up',
#  ((8, 0), (2, 6)): 'up',
#  ((2, 7), (2, 7)): 'down',
#  ((2, 1), (2, 7)): 'down',
#  ((1, 7), (2, 7)): 'left',
#  ((8, 7), (2, 7)): 'up',
#  ((8, 1), (2, 7)): 'stay',
#  ((2, 8), (2, 8)): 'left',
#  ((1, 8), (2, 8)): 'left',
#  ((1, 2), (2, 8)): 'left',
#  ((8, 2), (2, 8)): 'up',
#  ((2, 9), (2, 9)): 'left',
#  ((2, 3), (2, 9)): 'left',
#  ((1, 9), (2, 9)): 'left',
#  ((1, 3), (2, 9)): 'left',
#  ((8, 9), (2, 9)): 'up',
#  ((8, 3), (2, 9)): 'up',
#  ((2, 10), (2, 10)): 'left',
#  ((2, 4), (2, 10)): 'left',
#  ((1, 10), (2, 10)): 'left',
#  ((1, 4), (2, 10)): 'left',
#  ((8, 10), (2, 10)): 'up',
#  ((8, 4), (2, 10)): 'up',
#  ((2, 11), (2, 11)): 'left',
#  ((2, 5), (2, 11)): 'left',
#  ((1, 11), (2, 11)): 'left',
#  ((1, 5), (2, 11)): 'left',
#  ((8, 11), (2, 11)): 'up',
#  ((8, 5), (2, 11)): 'up',
#  ((3, 1), (3, 0)): 'stay',
#  ((3, 0), (3, 0)): 'left',
#  ((3, 6), (3, 0)): 'stay',
#  ((2, 1), (3, 0)): 'left',
#  ((2, 0), (3, 0)): 'down',
#  ((2, 6), (3, 0)): 'left',
#  ((9, 1), (3, 0)): 'up',
#  ((9, 0), (3, 0)): 'up',
#  ((9, 6), (3, 0)): 'up',
#  ((3, 2), (3, 1)): 'down',
#  ((3, 1), (3, 1)): 'down',
#  ((3, 7), (3, 1)): 'stay',
#  ((2, 1), (3, 1)): 'down',
#  ((2, 7), (3, 1)): 'stay',
#  ((9, 2), (3, 1)): 'stay',
#  ((9, 1), (3, 1)): 'up',
#  ((9, 7), (3, 1)): 'up',
#  ((3, 2), (3, 2)): 'down',
#  ((3, 8), (3, 2)): 'down',
#  ((2, 3), (3, 2)): 'left',
#  ((2, 8), (3, 2)): 'left',
#  ((9, 3), (3, 2)): 'up',
#  ((9, 2), (3, 2)): 'stay',
#  ((9, 8), (3, 2)): 'stay',
#  ((3, 5), (3, 4)): 'left',
#  ((3, 4), (3, 4)): 'left',
#  ((3, 10), (3, 4)): 'left',
#  ((2, 5), (3, 4)): 'left',
#  ((2, 4), (3, 4)): 'left',
#  ((2, 10), (3, 4)): 'left',
#  ((9, 5), (3, 4)): 'up',
#  ((9, 4), (3, 4)): 'up',
#  ((9, 10), (3, 4)): 'up',
#  ((3, 5), (3, 5)): 'left',
#  ((2, 5), (3, 5)): 'left',
#  ((9, 5), (3, 5)): 'up',
#  ((3, 6), (3, 6)): 'left',
#  ((3, 0), (3, 6)): 'left',
#  ((2, 6), (3, 6)): 'left',
#  ((2, 0), (3, 6)): 'stay',
#  ((9, 6), (3, 6)): 'up',
#  ((9, 0), (3, 6)): 'up',
#  ((3, 7), (3, 7)): 'left',
#  ((3, 1), (3, 7)): 'down',
#  ((2, 7), (3, 7)): 'down',
#  ((2, 1), (3, 7)): 'left',
#  ((9, 7), (3, 7)): 'up',
#  ((9, 1), (3, 7)): 'up',
#  ((3, 8), (3, 8)): 'down',
#  ((3, 2), (3, 8)): 'down',
#  ((2, 8), (3, 8)): 'left',
#  ((9, 8), (3, 8)): 'stay',
#  ((9, 2), (3, 8)): 'stay',
#  ((3, 9), (3, 9)): 'left',
#  ((2, 9), (3, 9)): 'left',
#  ((2, 3), (3, 9)): 'left',
#  ((9, 3), (3, 9)): 'up',
#  ((3, 10), (3, 10)): 'left',
#  ((3, 4), (3, 10)): 'left',
#  ((2, 10), (3, 10)): 'left',
#  ((2, 4), (3, 10)): 'left',
#  ((9, 10), (3, 10)): 'up',
#  ((9, 4), (3, 10)): 'up',
#  ((3, 11), (3, 11)): 'left',
#  ((3, 5), (3, 11)): 'left',
#  ((2, 11), (3, 11)): 'left',
#  ((2, 5), (3, 11)): 'left',
#  ((9, 11), (3, 11)): 'up',
#  ((9, 5), (3, 11)): 'up',
#  ((4, 1), (4, 0)): 'left',
#  ((4, 0), (4, 0)): 'stay',
#  ((4, 6), (4, 0)): 'left',
#  ((3, 1), (4, 0)): 'stay',
#  ((3, 0), (4, 0)): 'left',
#  ((3, 6), (4, 0)): 'stay',
#  ((10, 1), (4, 0)): 'up',
#  ((10, 0), (4, 0)): 'up',
#  ((10, 6), (4, 0)): 'up',
#  ((4, 2), (4, 1)): 'stay',
#  ((4, 1), (4, 1)): 'left',
#  ((4, 7), (4, 1)): 'stay',
#  ((3, 2), (4, 1)): 'left',
#  ((3, 1), (4, 1)): 'stay',
#  ((3, 7), (4, 1)): 'left',
#  ((10, 2), (4, 1)): 'up',
#  ((10, 1), (4, 1)): 'up',
#  ((10, 7), (4, 1)): 'up',
#  ((4, 3), (4, 2)): 'left',
#  ((4, 2), (4, 2)): 'stay',
#  ((4, 8), (4, 2)): 'left',
#  ((3, 2), (4, 2)): 'down',
#  ((3, 8), (4, 2)): 'down',
#  ((10, 3), (4, 2)): 'stay',
#  ((10, 2), (4, 2)): 'up',
#  ((10, 8), (4, 2)): 'up',
#  ((4, 3), (4, 3)): 'down',
#  ((4, 9), (4, 3)): 'down',
#  ((3, 4), (4, 3)): 'left',
#  ((3, 9), (4, 3)): 'left',
#  ((10, 4), (4, 3)): 'up',
#  ((10, 3), (4, 3)): 'stay',
#  ((10, 9), (4, 3)): 'stay',
#  ((4, 5), (4, 5)): 'left',
#  ((3, 5), (4, 5)): 'left',
#  ((10, 5), (4, 5)): 'up',
#  ((4, 6), (4, 6)): 'stay',
#  ((4, 0), (4, 6)): 'stay',
#  ((3, 6), (4, 6)): 'stay',
#  ((3, 0), (4, 6)): 'left',
#  ((10, 6), (4, 6)): 'up',
#  ((10, 0), (4, 6)): 'up',
#  ((4, 7), (4, 7)): 'stay',
#  ((4, 1), (4, 7)): 'left',
#  ((3, 7), (4, 7)): 'left',
#  ((3, 1), (4, 7)): 'stay',
#  ((10, 7), (4, 7)): 'up',
#  ((10, 1), (4, 7)): 'up',
#  ((4, 8), (4, 8)): 'left',
#  ((4, 2), (4, 8)): 'stay',
#  ((3, 8), (4, 8)): 'down',
#  ((3, 2), (4, 8)): 'down',
#  ((10, 8), (4, 8)): 'up',
#  ((10, 2), (4, 8)): 'up',
#  ((4, 9), (4, 9)): 'down',
#  ((4, 3), (4, 9)): 'down',
#  ((3, 9), (4, 9)): 'left',
#  ((10, 9), (4, 9)): 'stay',
#  ((10, 3), (4, 9)): 'stay',
#  ((4, 10), (4, 10)): 'left',
#  ((3, 10), (4, 10)): 'left',
#  ((3, 4), (4, 10)): 'left',
#  ((10, 4), (4, 10)): 'up',
#  ((4, 11), (4, 11)): 'left',
#  ((4, 5), (4, 11)): 'left',
#  ((3, 11), (4, 11)): 'left',
#  ((3, 5), (4, 11)): 'left',
#  ((10, 11), (4, 11)): 'up',
#  ((10, 5), (4, 11)): 'up',
#  ((5, 1), (5, 0)): 'stay',
#  ((5, 0), (5, 0)): 'left',
#  ((5, 6), (5, 0)): 'left',
#  ((4, 1), (5, 0)): 'left',
#  ((4, 0), (5, 0)): 'stay',
#  ((4, 6), (5, 0)): 'left',
#  ((11, 1), (5, 0)): 'up',
#  ((11, 0), (5, 0)): 'up',
#  ((11, 6), (5, 0)): 'up',
#  ((5, 2), (5, 1)): 'stay',
#  ((5, 1), (5, 1)): 'stay',
#  ((5, 7), (5, 1)): 'left',
#  ((4, 2), (5, 1)): 'stay',
#  ((4, 1), (5, 1)): 'left',
#  ((4, 7), (5, 1)): 'stay',
#  ((11, 2), (5, 1)): 'up',
#  ((11, 1), (5, 1)): 'up',
#  ((11, 7), (5, 1)): 'up',
#  ((5, 3), (5, 2)): 'stay',
#  ((5, 2), (5, 2)): 'stay',
#  ((5, 8), (5, 2)): 'stay',
#  ((4, 3), (5, 2)): 'down',
#  ((4, 2), (5, 2)): 'stay',
#  ((4, 8), (5, 2)): 'left',
#  ((11, 3), (5, 2)): 'up',
#  ((11, 2), (5, 2)): 'up',
#  ((11, 8), (5, 2)): 'up',
#  ((5, 4), (5, 3)): 'left',
#  ((5, 3), (5, 3)): 'stay',
#  ((5, 9), (5, 3)): 'stay',
#  ((4, 3), (5, 3)): 'down',
#  ((4, 9), (5, 3)): 'down',
#  ((11, 4), (5, 3)): 'up',
#  ((11, 3), (5, 3)): 'up',
#  ((11, 9), (5, 3)): 'up',
#  ((5, 4), (5, 4)): 'left',
#  ((5, 10), (5, 4)): 'stay',
#  ((4, 5), (5, 4)): 'left',
#  ((4, 10), (5, 4)): 'left',
#  ((11, 5), (5, 4)): 'stay',
#  ((11, 4), (5, 4)): 'up',
#  ((11, 10), (5, 4)): 'up',
#  ((5, 6), (5, 6)): 'left',
#  ((5, 0), (5, 6)): 'left',
#  ((4, 6), (5, 6)): 'stay',
#  ((4, 0), (5, 6)): 'stay',
#  ((11, 6), (5, 6)): 'up',
#  ((11, 0), (5, 6)): 'up',
#  ((5, 7), (5, 7)): 'left',
#  ((5, 1), (5, 7)): 'stay',
#  ((4, 7), (5, 7)): 'stay',
#  ((4, 1), (5, 7)): 'left',
#  ((11, 7), (5, 7)): 'up',
#  ((11, 1), (5, 7)): 'up',
#  ((5, 8), (5, 8)): 'stay',
#  ((5, 2), (5, 8)): 'stay',
#  ((4, 8), (5, 8)): 'left',
#  ((4, 2), (5, 8)): 'stay',
#  ((11, 8), (5, 8)): 'up',
#  ((11, 2), (5, 8)): 'up',
#  ((5, 9), (5, 9)): 'stay',
#  ((5, 3), (5, 9)): 'stay',
#  ((4, 9), (5, 9)): 'down',
#  ((4, 3), (5, 9)): 'down',
#  ((11, 9), (5, 9)): 'up',
#  ((11, 3), (5, 9)): 'up',
#  ((5, 10), (5, 10)): 'stay',
#  ((5, 4), (5, 10)): 'left',
#  ((4, 10), (5, 10)): 'left',
#  ((11, 10), (5, 10)): 'up',
#  ((11, 4), (5, 10)): 'up',
#  ((5, 11), (5, 11)): 'left',
#  ((4, 11), (5, 11)): 'left',
#  ((4, 5), (5, 11)): 'left',
#  ((11, 5), (5, 11)): 'stay',
#  ((6, 1), (6, 0)): 'up',
#  ((6, 0), (6, 0)): 'up',
#  ((6, 2), (6, 1)): 'up',
#  ((6, 1), (6, 1)): 'up',
#  ((6, 7), (6, 1)): 'up',
#  ((6, 3), (6, 2)): 'up',
#  ((6, 2), (6, 2)): 'up',
#  ((6, 8), (6, 2)): 'up',
#  ((6, 4), (6, 3)): 'up',
#  ((6, 3), (6, 3)): 'up',
#  ((6, 9), (6, 3)): 'up',
#  ((6, 5), (6, 4)): 'up',
#  ((6, 4), (6, 4)): 'up',
#  ((6, 10), (6, 4)): 'up',
#  ((6, 5), (6, 5)): 'up',
#  ((6, 7), (6, 7)): 'up',
#  ((6, 1), (6, 7)): 'up',
#  ((6, 8), (6, 8)): 'up',
#  ((6, 2), (6, 8)): 'up',
#  ((6, 9), (6, 9)): 'up',
#  ((6, 3), (6, 9)): 'up',
#  ((6, 10), (6, 10)): 'up',
#  ((6, 4), (6, 10)): 'up',
#  ((6, 11), (6, 11)): 'up',
#  ((6, 5), (6, 11)): 'up',
#  ((1, 0), (7, 0)): 'down',
#  ((1, 6), (7, 0)): 'stay',
#  ((7, 1), (7, 0)): 'up',
#  ((7, 0), (7, 0)): 'stay',
#  ((7, 6), (7, 0)): 'up',
#  ((1, 2), (7, 1)): 'left',
#  ((1, 7), (7, 1)): 'left',
#  ((7, 2), (7, 1)): 'up',
#  ((7, 1), (7, 1)): 'up',
#  ((1, 3), (7, 2)): 'left',
#  ((1, 2), (7, 2)): 'left',
#  ((1, 8), (7, 2)): 'left',
#  ((7, 3), (7, 2)): 'up',
#  ((7, 2), (7, 2)): 'up',
#  ((7, 8), (7, 2)): 'up',
#  ((1, 4), (7, 3)): 'left',
#  ((1, 3), (7, 3)): 'left',
#  ((1, 9), (7, 3)): 'left',
#  ((7, 4), (7, 3)): 'up',
#  ((7, 3), (7, 3)): 'up',
#  ((7, 9), (7, 3)): 'up',
#  ((1, 5), (7, 4)): 'left',
#  ((1, 4), (7, 4)): 'left',
#  ((1, 10), (7, 4)): 'left',
#  ((7, 5), (7, 4)): 'up',
#  ((7, 4), (7, 4)): 'up',
#  ((7, 10), (7, 4)): 'up',
#  ((1, 5), (7, 5)): 'left',
#  ((7, 5), (7, 5)): 'up',
#  ((1, 6), (7, 6)): 'stay',
#  ((1, 0), (7, 6)): 'left',
#  ((7, 6), (7, 6)): 'up',
#  ((7, 0), (7, 6)): 'stay',
#  ((1, 8), (7, 8)): 'left',
#  ((1, 2), (7, 8)): 'left',
#  ((7, 8), (7, 8)): 'up',
#  ((7, 2), (7, 8)): 'up',
#  ((1, 9), (7, 9)): 'left',
#  ((1, 3), (7, 9)): 'left',
#  ((7, 9), (7, 9)): 'up',
#  ((7, 3), (7, 9)): 'up',
#  ((1, 10), (7, 10)): 'left',
#  ((1, 4), (7, 10)): 'left',
#  ((7, 10), (7, 10)): 'up',
#  ((7, 4), (7, 10)): 'up',
#  ((1, 11), (7, 11)): 'left',
#  ((1, 5), (7, 11)): 'left',
#  ((7, 11), (7, 11)): 'up',
#  ((7, 5), (7, 11)): 'up',
#  ((2, 1), (8, 0)): 'down',
#  ((2, 0), (8, 0)): 'stay',
#  ((2, 6), (8, 0)): 'left',
#  ((8, 1), (8, 0)): 'stay',
#  ((8, 0), (8, 0)): 'up',
#  ((8, 6), (8, 0)): 'up',
#  ((2, 1), (8, 1)): 'down',
#  ((2, 7), (8, 1)): 'stay',
#  ((8, 2), (8, 1)): 'up',
#  ((8, 1), (8, 1)): 'stay',
#  ((8, 7), (8, 1)): 'up',
#  ((2, 3), (8, 2)): 'left',
#  ((2, 8), (8, 2)): 'left',
#  ((8, 3), (8, 2)): 'up',
#  ((8, 2), (8, 2)): 'up',
#  ((2, 4), (8, 3)): 'left',
#  ((2, 3), (8, 3)): 'left',
#  ((2, 9), (8, 3)): 'left',
#  ((8, 4), (8, 3)): 'up',
#  ((8, 3), (8, 3)): 'up',
#  ((8, 9), (8, 3)): 'up',
#  ((2, 5), (8, 4)): 'left',
#  ((2, 4), (8, 4)): 'left',
#  ((2, 10), (8, 4)): 'left',
#  ((8, 5), (8, 4)): 'up',
#  ((8, 4), (8, 4)): 'up',
#  ((8, 10), (8, 4)): 'up',
#  ((2, 5), (8, 5)): 'left',
#  ((8, 5), (8, 5)): 'up',
#  ((2, 6), (8, 6)): 'left',
#  ((2, 0), (8, 6)): 'stay',
#  ((8, 6), (8, 6)): 'up',
#  ((8, 0), (8, 6)): 'up',
#  ((2, 7), (8, 7)): 'stay',
#  ((2, 1), (8, 7)): 'down',
#  ((8, 7), (8, 7)): 'up',
#  ((8, 1), (8, 7)): 'stay',
#  ((2, 9), (8, 9)): 'left',
#  ((2, 3), (8, 9)): 'left',
#  ((8, 9), (8, 9)): 'up',
#  ((8, 3), (8, 9)): 'up',
#  ((2, 10), (8, 10)): 'left',
#  ((2, 4), (8, 10)): 'left',
#  ((8, 10), (8, 10)): 'up',
#  ((8, 4), (8, 10)): 'up',
#  ((2, 11), (8, 11)): 'left',
#  ((2, 5), (8, 11)): 'left',
#  ((8, 11), (8, 11)): 'up',
#  ((8, 5), (8, 11)): 'up',
#  ((3, 1), (9, 0)): 'stay',
#  ((3, 0), (9, 0)): 'left',
#  ((3, 6), (9, 0)): 'stay',
#  ((9, 1), (9, 0)): 'up',
#  ((9, 0), (9, 0)): 'up',
#  ((9, 6), (9, 0)): 'up',
#  ((3, 2), (9, 1)): 'down',
#  ((3, 1), (9, 1)): 'stay',
#  ((3, 7), (9, 1)): 'left',
#  ((9, 2), (9, 1)): 'stay',
#  ((9, 1), (9, 1)): 'up',
#  ((9, 7), (9, 1)): 'up',
#  ((3, 2), (9, 2)): 'down',
#  ((3, 8), (9, 2)): 'down',
#  ((9, 3), (9, 2)): 'up',
#  ((9, 2), (9, 2)): 'stay',
#  ((9, 8), (9, 2)): 'stay',
#  ((3, 4), (9, 3)): 'left',
#  ((3, 9), (9, 3)): 'left',
#  ((9, 4), (9, 3)): 'up',
#  ((9, 3), (9, 3)): 'stay',
#  ((3, 5), (9, 4)): 'left',
#  ((3, 4), (9, 4)): 'left',
#  ((3, 10), (9, 4)): 'left',
#  ((9, 5), (9, 4)): 'up',
#  ((9, 4), (9, 4)): 'up',
#  ((9, 10), (9, 4)): 'up',
#  ((3, 5), (9, 5)): 'left',
#  ((9, 5), (9, 5)): 'up',
#  ((3, 6), (9, 6)): 'stay',
#  ((3, 0), (9, 6)): 'left',
#  ((9, 6), (9, 6)): 'up',
#  ((9, 0), (9, 6)): 'up',
#  ((3, 7), (9, 7)): 'left',
#  ((3, 1), (9, 7)): 'stay',
#  ((9, 7), (9, 7)): 'up',
#  ((9, 1), (9, 7)): 'up',
#  ((3, 8), (9, 8)): 'down',
#  ((3, 2), (9, 8)): 'down',
#  ((9, 8), (9, 8)): 'stay',
#  ((9, 2), (9, 8)): 'stay',
#  ((3, 10), (9, 10)): 'left',
#  ((3, 4), (9, 10)): 'left',
#  ((9, 10), (9, 10)): 'up',
#  ((9, 4), (9, 10)): 'up',
#  ((3, 11), (9, 11)): 'left',
#  ((3, 5), (9, 11)): 'left',
#  ((9, 11), (9, 11)): 'up',
#  ((9, 5), (9, 11)): 'up',
#  ((4, 1), (10, 0)): 'left',
#  ((4, 0), (10, 0)): 'stay',
#  ((4, 6), (10, 0)): 'stay',
#  ((10, 1), (10, 0)): 'up',
#  ((10, 0), (10, 0)): 'up',
#  ((10, 6), (10, 0)): 'up',
#  ((4, 2), (10, 1)): 'stay',
#  ((4, 1), (10, 1)): 'left',
#  ((4, 7), (10, 1)): 'stay',
#  ((10, 2), (10, 1)): 'up',
#  ((10, 1), (10, 1)): 'up',
#  ((10, 7), (10, 1)): 'up',
#  ((4, 3), (10, 2)): 'left',
#  ((4, 2), (10, 2)): 'stay',
#  ((4, 8), (10, 2)): 'left',
#  ((10, 3), (10, 2)): 'stay',
#  ((10, 2), (10, 2)): 'up',
#  ((10, 8), (10, 2)): 'up',
#  ((4, 3), (10, 3)): 'down',
#  ((4, 9), (10, 3)): 'down',
#  ((10, 4), (10, 3)): 'up',
#  ((10, 3), (10, 3)): 'stay',
#  ((10, 9), (10, 3)): 'stay',
#  ((4, 5), (10, 4)): 'left',
#  ((4, 10), (10, 4)): 'left',
#  ((10, 5), (10, 4)): 'up',
#  ((10, 4), (10, 4)): 'up',
#  ((4, 5), (10, 5)): 'left',
#  ((10, 5), (10, 5)): 'up',
#  ((4, 6), (10, 6)): 'stay',
#  ((4, 0), (10, 6)): 'stay',
#  ((10, 6), (10, 6)): 'up',
#  ((10, 0), (10, 6)): 'up',
#  ((4, 7), (10, 7)): 'stay',
#  ((4, 1), (10, 7)): 'left',
#  ((10, 7), (10, 7)): 'up',
#  ((10, 1), (10, 7)): 'up',
#  ((4, 8), (10, 8)): 'left',
#  ((4, 2), (10, 8)): 'stay',
#  ((10, 8), (10, 8)): 'up',
#  ((10, 2), (10, 8)): 'up',
#  ((4, 9), (10, 9)): 'down',
#  ((4, 3), (10, 9)): 'down',
#  ((10, 9), (10, 9)): 'stay',
#  ((10, 3), (10, 9)): 'stay',
#  ((4, 11), (10, 11)): 'left',
#  ((4, 5), (10, 11)): 'left',
#  ((10, 11), (10, 11)): 'up',
#  ((10, 5), (10, 11)): 'up',
#  ((5, 1), (11, 0)): 'stay',
#  ((5, 0), (11, 0)): 'left',
#  ((5, 6), (11, 0)): 'left',
#  ((11, 1), (11, 0)): 'up',
#  ((11, 0), (11, 0)): 'up',
#  ((11, 6), (11, 0)): 'up',
#  ((5, 2), (11, 1)): 'stay',
#  ((5, 1), (11, 1)): 'stay',
#  ((5, 7), (11, 1)): 'left',
#  ((11, 2), (11, 1)): 'up',
#  ((11, 1), (11, 1)): 'up',
#  ((11, 7), (11, 1)): 'up',
#  ((5, 3), (11, 2)): 'stay',
#  ((5, 2), (11, 2)): 'stay',
#  ((5, 8), (11, 2)): 'stay',
#  ((11, 3), (11, 2)): 'up',
#  ((11, 2), (11, 2)): 'up',
#  ((11, 8), (11, 2)): 'up',
#  ((5, 4), (11, 3)): 'left',
#  ((5, 3), (11, 3)): 'stay',
#  ((5, 9), (11, 3)): 'stay',
#  ((11, 4), (11, 3)): 'up',
#  ((11, 3), (11, 3)): 'up',
#  ((11, 9), (11, 3)): 'up',
#  ((5, 4), (11, 4)): 'left',
#  ((5, 10), (11, 4)): 'stay',
#  ((11, 5), (11, 4)): 'stay',
#  ((11, 4), (11, 4)): 'up',
#  ((11, 10), (11, 4)): 'up',
#  ((11, 5), (11, 5)): 'stay',
#  ((5, 6), (11, 6)): 'left',
#  ((5, 0), (11, 6)): 'left',
#  ((11, 6), (11, 6)): 'up',
#  ((11, 0), (11, 6)): 'up',
#  ((5, 7), (11, 7)): 'left',
#  ((5, 1), (11, 7)): 'stay',
#  ((11, 7), (11, 7)): 'up',
#  ((11, 1), (11, 7)): 'up',
#  ((5, 8), (11, 8)): 'stay',
#  ((5, 2), (11, 8)): 'stay',
#  ((11, 8), (11, 8)): 'up',
#  ((11, 2), (11, 8)): 'up',
#  ((5, 9), (11, 9)): 'stay',
#  ((5, 3), (11, 9)): 'stay',
#  ((11, 9), (11, 9)): 'up',
#  ((11, 3), (11, 9)): 'up',
#  ((5, 10), (11, 10)): 'stay',
#  ((5, 4), (11, 10)): 'left',
#  ((11, 10), (11, 10)): 'up',
#  ((11, 4), (11, 10)): 'up',
#  ((5, 0), (-10, -10)): 'left'}

# %%
def extend_policy(policy):
    # take policy without velocity and convert it to policy with velocity
    policy_with_velocity = {}
    for ((i,j),(l,k)) in actions.keys():
        policy_with_velocity[((i,j),(l,k))] = policy[(i,j)]
    return policy_with_velocity

# %%
careful_eval_v2 = policy_eval2(extend_policy(careful_policy))
random_eval_v2 = policy_eval2(extend_policy(random_policy))
aggressive_eval_v2 = policy_eval2(extend_policy(aggressive_policy))
semiAggressive_eval_v2 = policy_eval2(extend_policy(semiAggressive_policy))
semiCareful_eval_v2 = policy_eval2(extend_policy(semiCareful_policy))
valueIteration_eval_v2 = policy_eval2(extend_policy(valueIteration_policy))
# [((5,0),(-10,-10))]

# %%
real_col = df.groupby(['behavior']).mean()['blueScore'].drop('carefulBehavior')
diff = pd.DataFrame({'Real': real_col,
                      'Prediction': [aggressive_intensity[5][0], randomBehavior_intensity[5][0], semiAggressive_intensity[5][0], semiCareful_intensity[5][0], np.NaN],
                     'Prediction with velocity': [aggressive_eval_v2[((5,0),(-10,-10))], random_eval_v2[((5,0),(-10,-10))], semiAggressive_eval_v2[((5,0),(-10,-10))], semiCareful_eval_v2[((5,0),(-10,-10))], valueIteration_eval_v2[((5,0),(-10,-10))]]},
                     index= real_col.index)
diff['different'] = abs(diff['Real']-diff['Prediction with velocity'])
diff
# Out:
#                                  Real  Prediction  Prediction with velocity  \
# behavior
# aggressiveBehavior             -13.43        0.80                     -6.42
# randomBehavior                 -58.26     -100.00                   -100.00
# semiAggressiveBehavior         -55.68      -47.11                    -54.26
# semiCarefulBehavior            -11.35       -4.25                    -13.60
# valueIterationBasedBehavior_v2  -1.39         NaN                     -3.08
#
#                                 different
# behavior
# aggressiveBehavior                   7.01
# randomBehavior                      41.74
# semiAggressiveBehavior               1.42
# semiCarefulBehavior                  2.25
# valueIterationBasedBehavior_v2       1.69

# %%
# real_col = df.groupby(['behavior']).mean()['blueScore'].append(pd.Series([np.NaN], index=['valueIterationBehavior']))
# diff = pd.DataFrame({'Real': real_col,
#                       'Prediction': [aggressive_intensity[5][0] , careful_intensity[5][0], randomBehavior_intensity[5][0], semiAggressive_intensity[5][0], semiCareful_intensity[5][0], np.NaN, optimal_V['a6 a1']],
#                      'Prediction with velocity': [aggressive_eval_v2[((5,0),(-10,-10))], careful_eval_v2[((5,0),(-10,-10))], random_eval_v2[((5,0),(-10,-10))], semiAggressive_eval_v2[((5,0),(-10,-10))], semiCareful_eval_v2[((5,0),(-10,-10))],  V[((5,0),(-10,-10))], valueIteration_eval_v2[((5,0),(-10,-10))]]},
#                      index= real_col.index)
# diff['different'] = abs(diff['Real']-diff['Prediction with velocity'])
# diff
# Out:
#                                  Real  Prediction  Prediction with velocity  \
# aggressiveBehavior             -13.43        0.80                     -6.42
# carefulBehavior                 20.57        1.46                     -4.55
# randomBehavior                 -58.26     -100.00                   -100.00
# semiAggressiveBehavior         -55.68      -47.11                    -54.26
# semiCarefulBehavior            -11.35       -4.25                    -13.60
# valueIterationBasedBehavior_v2  -1.39         NaN                     15.80
# valueIterationBehavior            NaN       12.64                     -3.08
#
#                                 different
# aggressiveBehavior                   7.01
# carefulBehavior                     25.12
# randomBehavior                      41.74
# semiAggressiveBehavior               1.42
# semiCarefulBehavior                  2.25
# valueIterationBasedBehavior_v2      17.19
# valueIterationBehavior                NaN

# %%
# real_col = df.groupby(['behavior']).mean()['blueScore'].append(pd.Series([np.NaN, np.NaN], index=['valueIterationBehavior', 'valueIterationBehavior_v2'])) #.drop('carefulBehavior')
# diff = pd.DataFrame({'Real': real_col,
#                       'Prediction': [aggressive_intensity[5][0], randomBehavior_intensity[5][0] , semiAggressive_intensity[5][0], semiCareful_intensity[5][0], np.NaN, optimal_V['a6 a1']],
#                      'Prediction with velocity': [aggressive_eval_v2[((5,0),(-10,-10))], random_eval_v2[((5,0),(-10,-10))] , semiAggressive_eval_v2[((5,0),(-10,-10))], semiCareful_eval_v2[((5,0),(-10,-10))],  V[((5,0),(-10,-10))], valueIteration_eval_v2[((5,0),(-10,-10))]]},
#                      index= real_col.index)
# diff['different'] = abs(diff['Real']-diff['Prediction with velocity'])
# diff

# %%
# valueIteration_eval_v2[((5,0),(-10,-10))]

# %%
V[((5,0),(-10,-10))] # this is from the value iteration
# Out:
# 15.801669789080051

# %%
a[((5,0),(-10,-10))] # this is from the eval policy
# Out:
# 15.801669789080051

# %% [markdown]
# # push to firebase:

# %%
import pyrebase

firebaseConfig = {
    "apiKey": "AIzaSyDROtt5r3t5VL_iPabcgVgsWmUZHMw7Pv8",
    "authDomain": "road-game.firebaseapp.com",
    "databaseURL": "https://road-game-default-rtdb.firebaseio.com",
    "projectId": "road-game",
    "storageBucket": "road-game.appspot.com",
    "messagingSenderId": "14363967441",
    "appId": "1:14363967441:web:9efd1c7c3db93ab12ceaf0"
  }

firebase=pyrebase.initialize_app(firebaseConfig)

db=firebase.database()

# %%
try:
    db.child("aggressiveBehavior").set(convertStates(extend_policy(aggressive_policy))[0])
    
    db.child("carefulBehavior").set(convertStates(extend_policy(careful_policy))[0])
    
    db.child("semiCarefulBehavior").set(convertStates(extend_policy(semiCareful_policy))[0])
    
    db.child("randomBehavior").set(convertStates(extend_policy(random_policy))[0])
    
    db.child("semiAggressiveBehavior").set(convertStates(extend_policy(semiAggressive_policy))[0])
    
    db.child("valueIterationBasedBehavior_v2").set(optimal_policy_v2)
    
    db.child("valueIterationBehavior").set(convertStates(extend_policy(valueIteration_policy))[0])
except Exception as err:
    print(err)

# %% [markdown]
# build opponent model:
# it uses the human model 50% of the time, and uses our mirrored model 50% of the time.
#
# Now find the maximum.
# I.e., find the optimal policy.
# Once you find a policy update the opponent model and find the optimal policy again. Hopefully it will converge.

# %%
def nextStateDistibution3(s, a, prev_action_at_prev_policy):
    # prev_action_at_prev_policy = what was the blue agent action at state
    # given state s and action a, return distibution of possibles new states by probs
    nxt = {}
#     print('s: ', s)
#     print('a: ', a)
    bluePossition = newPosGivenAction(s[0], a, 0)
#     print('bluePossition: ', bluePossition)
    
    if(prev_action_at_prev_policy == "left"):
        a_to_compare = "right"
    else:
        a_to_compare = prev_action_at_prev_policy
#     print('a_to_compare: ', a_to_compare)
    # red possible action given state
    if s[0][1] == 5:
        actions=["stay"]
    elif s[0][1] < 6:
        actions=["right","stay", "down"]
    else:
        actions=["stay", "up"]
#     print('actions: ', actions)
    for r_a in actions:
        redPossition = newPosGivenAction(s[0], r_a, 1)
#         print('r_a: ', r_a)
#         print('redPossition: ', redPossition)
        newState = ((bluePossition, redPossition),s[0])
#         print('newState: ', newState)
        try:
            nxt[newState] = probs[adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0])][r_a] * 0.75
            if(r_a == a_to_compare):
                nxt[newState] = nxt[newState] + 0.25 
        except KeyError:
#             print("Warning! State not found: assume random behavior. ", s[0])
            nxt[newState] = randomProbForAction(s[0]) * 0.75
            if(r_a == a_to_compare):
                nxt[newState] = nxt[newState] + 0.25
    assert abs(sum(nxt.values()) - 1.0) < 0.0001, "probs not sum to 1.0. \nstate: " + str(s) + " action: " + str(a) + " nxt: " + str(nxt) + "\nsum of probs: " + str(sum(nxt.values()))
    return nxt

# %%
s = ((1, 0), (1, 0))
a = "stay"
nextStateDistibution3(s, a, "stay")
# Out:
# {((1, 1), (1, 0)): 0.10714285717500001,
#  ((1, 0), (1, 0)): 0.785714285725,
#  ((1, 6), (1, 0)): 0.10714285717500001}

# %%
mirror_dict_pos = {0:5,
                  1:4,
                  2:3,
                  3:2,
                  4:1,
                  5:0,
                  6:11,
                  7:10,
                  8:9,
                  9:8,
                  10:7,
                  11:6,
                  -10:-10}

def mirror_pos(pos):
    return mirror_dict_pos[pos]

mirror_pos(7)
# Out:
# 10

# %%
def mirror_state(s):
    ((i,j),(l,k)) = s
    return ((mirror_pos(j), mirror_pos(i)),(mirror_pos(k), mirror_pos(l)))

# %%
mirror_state(((1, 5), (1, 4)))
# Out:
# ((0, 4), (1, 4))

# %%
# import copy

# %%
# prev_policy = {}

# %%
# while(prev_policy != Policy):
#     prev_policy = copy.deepcopy(Policy)

#     '''==================================================
#     Value Iteration
#     =================================================='''
#     iteration = 1
#     while True:
#         biggest_change = 0
#         for s in all_states:            
#             if s in Policy:

#                 old_v = V[s]
#                 new_v = np.NINF

#                 for a in actions[s]:
#                     try:
#                         blue_action_as_red = prev_policy[mirror_state(s)]
#                     except KeyError: # it can fail only if blue in end-state
#                         blue_action_as_red = "stay"

#                     nxt = nextStateDistibution3(s, a, blue_action_as_red)
#                     v=0
#                     #Calculate the value
#                     for next_state, prob in nxt.items():
#                         assert rewards[s] == -1, "rewards is not -1"
#                         v += prob * (rewards[s] + GAMMA * V[next_state])
#                     if v > new_v: #Is this the best action so far? If so, keep it
#                         new_v = v
#                         Policy[s] = a

#                #Save the best of all actions for the state                                
#                 V[s] = new_v
#                 biggest_change = max(biggest_change, np.abs(old_v - V[s]))


#        #See if the loop should stop now         
#         if biggest_change < SMALL_ENOUGH:
#             print('converge after: ' + str(iteration) + ' iterations')
#             break
#         iteration += 1

#         #Print every 100 iterations
#         if(iteration % 100 == 0):
#             print(iteration, "iterations")

# %%
# Policy

# %%
# policy_eval2(Policy)[((5,0),(-10,-10))]

# %%
# def humanBehavior():
#     # Behavior based on the data we gather
#     Policy={}
#     for s in actions.keys():
#         try:
#             row = probs[adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0])]
#             Policy[s] = np.random.choice(list(row.keys()), p=list(row.values()))
#         except KeyError:
# #             print("Warning! State not found: assume random behavior. ", s[0])
#             Policy[s] = np.random.choice(actions[s])
#         # take the action with higher prob
#     return Policy

# human_policy = humanBehavior()

# %%
# class Opponent_model:

#     def __init__(self, human_policy, mirrored_policy, p):
#         # humen_policy is made from the data
#         # mirrored_policy is the old policy of Value Iteration based agent.
#         self.human_policy = human_policy
#         self.mirrored_policy = mirrored_policy
#         self.p = p

#     def updateMirroredPolicy(self, new_mirrored_policy):
#         self.mirrored_policy = new_mirrored_policy
        
#     def getAction(self, state):
#         human_action = self.human_policy[state]
#         mirrored_action = self.mirrored_policy[state]
#         return np.random.choice([human_action, mirrored_action], p=[self.p, 1-self.p])

#     def __str__(self):
#         return "human_policy:\n " + str(self.human_policy) + "\n" + str(self.mirrored_policy) + "\n p: " + str(self.p)

# %%
# V[((5,0),(-10,-10))]

# %%
# Policy[((5,0),(-10,-10))]

# %%
# optimal_policy_v2, optimal_V_v2 = convertStates()

# %%
# try:
#     db.child("Value Iteration behavior v2").set(optimal_policy_v2)
# except Exception as err:
#     print(err)

# %%
df.groupby(['behavior']).mean()['blueScore'].append(pd.Series([np.NaN], index=['valueIterationBehavior'])).drop('carefulBehavior')
# Out:
# aggressiveBehavior               -13.43
# randomBehavior                   -58.26
# semiAggressiveBehavior           -55.68
# semiCarefulBehavior              -11.35
# valueIterationBasedBehavior_v2    -1.39
# valueIterationBehavior              NaN
# dtype: float64

# %%
# om = Opponent_model(Policy, human_policy, 0.5)
# action = om.getAction(s)
# action
