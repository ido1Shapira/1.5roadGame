# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import seaborn as sns

path = './data/road-game-default-rtdb-export.json'

branchs = ['all-games','complete-games']
childs = ['additional_comments',
          'log',
         'aggressively_value',
         'behavior',
         'birthYear',
         'computer_value',
         'drivinglicense',
         'education',
         'gender',
         'generously_value',
         'redScore',
          'blueScore',
         'steps',
         'win',
         'wisely_value']

# with open(path) as json_file:
#     data = json.load(json_file)
#     num_of_games = len(data[branchs[1]])
#     print("number of %s is %d" % (branchs[1], num_of_games))
#     for game_id in data[branchs[1]].values():
#         for child in childs:
#             print(child, game_id[child])
#         print()

# %%
#load data from the json file
with open(path) as train_file:
    data = json.load(train_file)

# %%
branch = branchs[1]
df = pd.DataFrame.from_dict(data[branch], orient='index')
df.reset_index(level=0, inplace=True)
df
# Out:
#                     index additional_comments aggressively_value  \
# 0    -MZiWIwdnrn8TJ034z2w                                      5
# 1    -MZiWUxZs8BvWglGhc9r                                      2
# 2    -MZiWYgxyToIiCSDQY8S                                      5
# 3    -MZiWYz_z_BcQlpReXf_                                      6
# 4    -MZiWaNZ6n3K3AZDfr-q                                      6
# ..                    ...                 ...                ...
# 130  -M_HdrkTl2-M1kF0d3Va                                      3
# 131  -M_HefdTaP5SV-i0bz7G          fastgame.                   6
# 132  -M_HjGWXEG1wJ2kWwvbt                                      2
# 133  -M_Hl4knjjAplOUpBQgF                                      2
# 134  -M_IvyIWQkuBuIyd_GFq                                      7
#
#                behavior birthYear  blueScore computer_value drivinglicense  \
# 0       carefulBehavior      1961        -10              5          valid
# 1       carefulBehavior      1982        -11              6          valid
# 2    aggressiveBehavior      1953        -94              7          valid
# 3    aggressiveBehavior      1990          6              7          valid
# 4    aggressiveBehavior      1953        -94              6          valid
# ..                  ...       ...        ...            ...            ...
# 130      randomBehavior      1960       -132              5        invalid
# 131      randomBehavior      1990       -108              7          valid
# 132      randomBehavior      1994       -108              5          valid
# 133      randomBehavior      1979        -13              7        invalid
# 134      randomBehavior      1977       -111              6          valid
#
#            education  gender generously_value  \
# 0                 BA    male                6
# 1                 BA  female                4
# 2                 BA  female                2
# 3    Master's degree    male                2
# 4                 BA  female                2
# ..               ...     ...              ...
# 130               BA  female                5
# 131             none    male                2
# 132               BA    male                4
# 133      High School  female                4
# 134               BA    male                6
#
#                                                    log  \
# 0    [None, {'blue': 'from: a6, action: left', 'red...
# 1    [None, {'blue': 'from: a6, action: left', 'red...
# 2    [None, {'blue': 'from: a6, action: left', 'red...
# 3    [None, {'blue': 'from: a6, action: left', 'red...
# 4    [None, {'blue': 'from: a6, action: left', 'red...
# ..                                                 ...
# 130  [None, {'blue': 'from: a6, action: stay', 'red...
# 131  [None, {'blue': 'from: a6, action: left', 'red...
# 132  [None, {'blue': 'from: a6, action: stay', 'red...
# 133  [None, {'blue': 'from: a6, action: stay', 'red...
# 134  [None, {'blue': 'from: a6, action: left', 'red...
#
#      press-the-read-instructions-button  redScore  steps    win wisely_value
# 0                                  True         3      7   True            1
# 1                                  True         2      8   True            4
# 2                                  True      -105      5  False            6
# 3                                  True         1      9   True            2
# 4                                  True      -105      5  False            1
# ..                                  ...       ...    ...    ...          ...
# 130                                True      -112     22   True            5
# 131                                True      -105      5  False            4
# 132                                True      -105      5  False            4
# 133                                True         3      7   True            4
# 134                                True      -107      7  False            7
#
# [135 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['index', 'additional_comments', 'aggressively_value', 'behavior',
#        'birthYear', 'blueScore', 'computer_value', 'drivinglicense',
#        'education', 'gender', 'generously_value', 'log',
#        'press-the-read-instructions-button', 'redScore', 'steps', 'win',
#        'wisely_value'],
#       dtype='object')

# %% [markdown]
# ## Survay results:

# %%
df['additional_comments']
# Out:
# 0
# 1
# 2
# 3
# 4
#           ...
# 130
# 131    fastgame.
# 132
# 133
# 134
# Name: additional_comments, Length: 135, dtype: object

# %%
df[['aggressively_value', 'computer_value', 'generously_value', 'generously_value']] = df[['aggressively_value', 'computer_value', 'generously_value', 'generously_value']].apply(pd.to_numeric)

# %%
df.groupby(['behavior']).mean()
# Out:
#                         aggressively_value  blueScore  computer_value  \
# behavior
# aggressiveBehavior                4.967742 -35.548387        6.096774
# carefulBehavior                   2.964286  -9.428571        5.214286
# randomBehavior                    4.142857 -77.057143        5.742857
# semiAggressiveBehavior            4.390244 -72.000000        6.048780
#
#                         generously_value  press-the-read-instructions-button  \
# behavior
# aggressiveBehavior              2.870968                                 1.0
# carefulBehavior                 5.071429                                 1.0
# randomBehavior                  4.285714                                 1.0
# semiAggressiveBehavior          3.024390                                 1.0
#
#                          redScore     steps       win
# behavior
# aggressiveBehavior     -38.967742  6.387097  0.612903
# carefulBehavior          2.285714  7.714286  1.000000
# randomBehavior         -69.257143  8.971429  0.542857
# semiAggressiveBehavior -74.121951  6.317073  0.292683

# %%
df.groupby('behavior').describe()
# Out:
#                        aggressively_value                                     \
#                                     count      mean       std  min  25%  50%
# behavior
# aggressiveBehavior                   31.0  4.967742  1.852635  1.0  4.0  5.0
# carefulBehavior                      28.0  2.964286  1.621205  1.0  2.0  2.0
# randomBehavior                       35.0  4.142857  1.972500  1.0  2.0  4.0
# semiAggressiveBehavior               41.0  4.390244  1.998475  1.0  3.0  4.0
#
#                                   blueScore             ... redScore       \
#                          75%  max     count       mean  ...      75%  max
# behavior                                                ...
# aggressiveBehavior      6.50  7.0      31.0 -35.548387  ...      2.5  3.0
# carefulBehavior         4.25  6.0      28.0  -9.428571  ...      3.0  5.0
# randomBehavior          6.00  7.0      35.0 -77.057143  ...      0.0  5.0
# semiAggressiveBehavior  6.00  7.0      41.0 -72.000000  ...     -1.0  1.0
#
#                        steps
#                        count      mean       std  min  25%  50%    75%   max
# behavior
# aggressiveBehavior      31.0  6.387097  2.155264  3.0  4.5  7.0   8.00  11.0
# carefulBehavior         28.0  7.714286  2.536506  5.0  7.0  7.0   8.25  18.0
# randomBehavior          35.0  8.971429  5.987662  3.0  5.0  7.0  10.00  35.0
# semiAggressiveBehavior  41.0  6.317073  3.101927  3.0  4.0  5.0   9.00  14.0
#
# [4 rows x 48 columns]

# %%
# Sort the dataframe by target
target_0 = df.loc[df['behavior'] == 'carefulBehavior']
target_1 = df.loc[df['behavior'] == 'semiAggressiveBehavior']
target_2 = df.loc[df['behavior'] == 'aggressiveBehavior']

sns.distplot(target_0[['aggressively_value']], bins = 10)
sns.distplot(target_1[['aggressively_value']], bins = 10)
sns.distplot(target_2[['aggressively_value']], bins = 10)

# %%
target_0[target_0['aggressively_value'] == '3'].count()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# index                                 0
# additional_comments                   0
# aggressively_value                    0
# behavior                              0
# birthYear                             0
# blueScore                             0
# computer_value                        0
# drivinglicense                        0
# education                             0
# gender                                0
# generously_value                      0
# log                                   0
# press-the-read-instructions-button    0
# redScore                              0
# steps                                 0
# win                                   0
# wisely_value                          0
# dtype: int64

# %%
target_0.count()
# Out:
# index                                 28
# additional_comments                   28
# aggressively_value                    28
# behavior                              28
# birthYear                             28
# blueScore                             28
# computer_value                        28
# drivinglicense                        28
# education                             28
# gender                                28
# generously_value                      28
# log                                   28
# press-the-read-instructions-button    28
# redScore                              28
# steps                                 28
# win                                   28
# wisely_value                          28
# dtype: int64

# %%
fig,(ax1) = plt.subplots(ncols=1, figsize=(8,5))
sns.kdeplot(df.aggressively_value[df['behavior'] == 'carefulBehavior'], label='carefulBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'semiAggressiveBehavior'], label='semiAggressiveBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'aggressiveBehavior'], label='aggressiveBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'randomBehavior'], label='aggressiveBehavior', shade=True)
ax1.set_ylabel('Distribution')
ax1.set_xlabel('aggressively_value')
# Out:
# Text(0.5, 0, 'aggressively_value')

# %%
def count_plot_by_behavior(feature):
    sns.countplot(x=df[feature],hue=df['behavior'])
    plt.show()
    
for value in ['aggressively_value', 'computer_value', 'generously_value', 'wisely_value']:
    count_plot_by_behavior(value)

# %%
def pie_count_plot(feature):
    list_gen=df[feature].value_counts().plot.pie(figsize=(6, 6))
    title = 'Distribution by: ', feature
    plt.title(title)
    plt.show()
    
for value in ['birthYear', 'drivinglicense', 'education', 'gender', 'redScore', 'steps', 'win']:
    pie_count_plot(value)

# %%
df.groupby('win')['gender'].value_counts().plot.pie(figsize=(6, 6))

# %%
df.groupby('gender').describe()
# Out:
#        aggressively_value                                                \
#                     count      mean       std  min  25%  50%   75%  max
# gender
# female               54.0  3.870370  1.833095  1.0  2.0  4.0  5.75  7.0
# male                 81.0  4.358025  2.069472  1.0  2.0  5.0  6.00  7.0
#
#        blueScore             ... redScore      steps                           \
#            count       mean  ...      75%  max count      mean       std  min
# gender                       ...
# female      54.0 -53.814815  ...      2.0  3.0  54.0  7.277778  3.482661  3.0
# male        81.0 -50.728395  ...      3.0  5.0  81.0  7.333333  4.245586  3.0
#
#
#         25%  50%  75%   max
# gender
# female  5.0  7.0  8.0  22.0
# male    5.0  7.0  9.0  35.0
#
# [2 rows x 48 columns]

# %%
df.groupby('behavior').describe()
# Out:
#                        aggressively_value                                     \
#                                     count      mean       std  min  25%  50%
# behavior
# aggressiveBehavior                   31.0  4.967742  1.852635  1.0  4.0  5.0
# carefulBehavior                      28.0  2.964286  1.621205  1.0  2.0  2.0
# randomBehavior                       35.0  4.142857  1.972500  1.0  2.0  4.0
# semiAggressiveBehavior               41.0  4.390244  1.998475  1.0  3.0  4.0
#
#                                   blueScore             ... redScore       \
#                          75%  max     count       mean  ...      75%  max
# behavior                                                ...
# aggressiveBehavior      6.50  7.0      31.0 -35.548387  ...      2.5  3.0
# carefulBehavior         4.25  6.0      28.0  -9.428571  ...      3.0  5.0
# randomBehavior          6.00  7.0      35.0 -77.057143  ...      0.0  5.0
# semiAggressiveBehavior  6.00  7.0      41.0 -72.000000  ...     -1.0  1.0
#
#                        steps
#                        count      mean       std  min  25%  50%    75%   max
# behavior
# aggressiveBehavior      31.0  6.387097  2.155264  3.0  4.5  7.0   8.00  11.0
# carefulBehavior         28.0  7.714286  2.536506  5.0  7.0  7.0   8.25  18.0
# randomBehavior          35.0  8.971429  5.987662  3.0  5.0  7.0  10.00  35.0
# semiAggressiveBehavior  41.0  6.317073  3.101927  3.0  4.0  5.0   9.00  14.0
#
# [4 rows x 48 columns]

# %% [markdown]
# # Statistics of the red agent movements:

# %% [markdown]
# ### Create the statistics table from the log column:

# %%
import flat_table

# %%
statistics_raw = pd.DataFrame.from_dict(data['all-games'], orient='index')
log_red = flat_table.normalize(statistics_raw).iloc[:,-2:]
log_red = log_red.dropna()
log_red['log.red'] = log_red['log.red'] + ' ' + log_red['log.blue']
log_red = log_red.drop('log.blue', axis=1)
log_red['log.red'] = log_red.apply(lambda x: x['log.red'].rsplit(' ', 1)[0], axis = 1)
for substr in ['from: ', ', action:']:
    log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(substr, '', 2), axis = 1)
log_red['log.red'] = log_red['log.red'].str.split().apply(reversed).apply(' '.join)
log_red['value']=1
log_red['action'] = log_red['log.red'].str.split().str[1]
log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(str(x['action'])+' ', '', 2), axis = 1)

log_red = log_red.groupby(['log.red', 'action']).count()
log_red.reset_index(inplace=True)
log_red = log_red.set_index('log.red')
log_red.sort_index()
# Out:
#         action  value
# log.red
# a1 a2    right      5
# a1 a3    right     24
# a1 a4    right     32
# a1 a5     down      3
# a1 a5    right     36
# ...        ...    ...
# b6 a5    right     10
# b6 b1     stay     11
# b6 b1       up      1
# b6 b4       up      1
# b6 b5       up      1
#
# [150 rows x 2 columns]

# %%
len(log_red.index)
# Out:
# 150

# %%
idx = log_red.index.drop_duplicates()
result = pd.DataFrame(index=log_red.index.drop_duplicates(), columns=['right', 'stay', 'up', 'down'])
# result.reset_index(level=0, inplace=True)
for action in ['right', 'stay', 'up', 'down']:
    result[action] = log_red[log_red['action'] == action]['value']
result = result.fillna(0)
result.reset_index(inplace=True)
result.sort_index()
# Out:
#    log.red  right  stay   up  down
# 0    a1 a2   5.00  0.00 0.00  0.00
# 1    a1 a3  24.00  0.00 0.00  0.00
# 2    a1 a4  32.00  0.00 0.00  0.00
# 3    a1 a5  36.00  2.00 0.00  3.00
# 4    a1 b1   0.00 19.00 5.00  0.00
# ..     ...    ...   ...  ...   ...
# 80   b6 a4  10.00  1.00 0.00  0.00
# 81   b6 a5  10.00  0.00 0.00  0.00
# 82   b6 b1   0.00 11.00 1.00  0.00
# 83   b6 b4   0.00  0.00 1.00  0.00
# 84   b6 b5   0.00  0.00 1.00  0.00
#
# [85 rows x 5 columns]

# %% [markdown]
# #### After Laplace's Smoothing:

# %%
for i in range(1,7):
    result.loc[result['log.red'].str.endswith('a'+str(i)), ['stay', 'right', 'down']] += 1
    
for i in range(1,7):
    result.loc[result['log.red'].str.endswith('b'+str(i)), ['stay', 'up']] += 1

result = result.set_index('log.red')
result
# Out:
#          right  stay   up  down
# log.red
# a1 a2     6.00  1.00 0.00  1.00
# a1 a3    25.00  1.00 0.00  1.00
# a1 a4    33.00  1.00 0.00  1.00
# a1 a5    37.00  3.00 0.00  4.00
# a1 b1     0.00 20.00 6.00  0.00
# ...        ...   ...  ...   ...
# b6 a4    11.00  2.00 0.00  1.00
# b6 a5    11.00  1.00 0.00  1.00
# b6 b1     0.00 12.00 2.00  0.00
# b6 b4     0.00  1.00 2.00  0.00
# b6 b5     0.00  1.00 2.00  0.00
#
# [85 rows x 4 columns]

# %% [markdown]
# #### Convert it to Probability table:

# %%
pd.options.display.float_format = "{:,.2f}".format
result_probs = result.div(result.sum(axis=1), axis=0)

# %% [markdown]
# #### Save data on computer for the policy iteration:

# %%
# with open('data/states.txt', 'w') as f:
#     for state in result.index.to_list():
#         f.write("%s\n" % state)

# %%
result_probs.to_json('data/probs.json' , orient='index', indent=4)

# %% [markdown]
# ### Create the statistics table from the statistics branch:

# %%
# red_moves = pd.DataFrame.from_dict(data['statistics'], orient='index')
# # red_moves.reset_index(level=0, inplace=True)
# red_moves = red_moves.fillna(0)
# red_moves.sort_index()

# %% [markdown]
# #### Convert it to Probability table:

# %%
# pd.options.display.float_format = "{:,.2f}".format
# red_moves.div(red_moves.sum(axis=1), axis=0)

# %%
import numpy as np
import pprint

# %%
'''==================================================
Initial set up
=================================================='''

#Hyperparameters
SMALL_ENOUGH = 0.5
GAMMA = 0.99

#Define all states
all_states=[]
for i in range(12):
    for j in range(12):
            all_states.append((i,j))

#Define rewards for all states
rewards = {}
# for i in all_states:
#     if i == (1,2):
#         rewards[i] = -1
#     elif i == (2,2):
#         rewards[i] = -1
#     elif i == (2,3):
#         rewards[i] = 1
#     else:
#         rewards[i] = 0
for (i,j) in all_states:
    if(i == 0): # blue agent in a1
        rewards[(i,j)] = 10
    elif(i == j): # crushed
        rewards[(i,j)] = -100
    else:
        rewards[(i,j)] = -1

#Dictionnary of possible actions. We have two "end" states (1,2 and 2,2)
actions = {}
#     (0,0):('D', 'R'), 
#     (0,1):('D', 'R', 'L'),    
#     (0,2):('D', 'L', 'R'),
#     (0,3):('D', 'L'),
#     (1,0):('D', 'U', 'R'),
#     (1,1):('D', 'R', 'L', 'U'),
#     (1,3):('D', 'L', 'U'),
#     (2,0):('U', 'R'),
#     (2,1):('U', 'L', 'R'),
#     }
for (i,j) in all_states:
    if i != 0 and i != j: #if s=(i, j) is not an "end" state
        actions[(i,j)] = ('S', 'L', 'D') if (i < 6) else ('U', 'S')

#Define an initial policy
policy={}
for s in actions.keys():
    policy[s] = np.random.choice(actions[s])

probs = {
    "a1 a2":{
        "right":0.75,
        "stay":0.125,
        "up":0.0,
        "down":0.125
    },
    "a1 a3":{
        "right":0.9259259259,
        "stay":0.037037037,
        "up":0.0,
        "down":0.037037037
    },
    "a1 a4":{
        "right":0.9428571429,
        "stay":0.0285714286,
        "up":0.0,
        "down":0.0285714286
    },
    "a1 a5":{
        "right":0.8409090909,
        "stay":0.0681818182,
        "up":0.0,
        "down":0.0909090909
    },
    "a1 b1":{
        "right":0.0,
        "stay":0.7692307692,
        "up":0.2307692308,
        "down":0.0
    },
    "a1 b2":{
        "right":0.0,
        "stay":0.2,
        "up":0.8,
        "down":0.0
    },
    "a1 b3":{
        "right":0.0,
        "stay":0.625,
        "up":0.375,
        "down":0.0
    },
    "a1 b5":{
        "right":0.0,
        "stay":0.4285714286,
        "up":0.5714285714,
        "down":0.0
    },
    "a2 a1":{
        "right":0.1739130435,
        "stay":0.6086956522,
        "up":0.0,
        "down":0.2173913043
    },
    "a2 a3":{
        "right":0.8333333333,
        "stay":0.0833333333,
        "up":0.0,
        "down":0.0833333333
    },
    "a2 a4":{
        "right":0.6666666667,
        "stay":0.1666666667,
        "up":0.0,
        "down":0.1666666667
    },
    "a2 a5":{
        "right":0.5,
        "stay":0.25,
        "up":0.0,
        "down":0.25
    },
    "a2 b1":{
        "right":0.0,
        "stay":0.5384615385,
        "up":0.4615384615,
        "down":0.0
    },
    "a2 b2":{
        "right":0.0,
        "stay":0.625,
        "up":0.375,
        "down":0.0
    },
    "a2 b3":{
        "right":0.0,
        "stay":0.2083333333,
        "up":0.7916666667,
        "down":0.0
    },
    "a2 b5":{
        "right":0.0,
        "stay":0.4,
        "up":0.6,
        "down":0.0
    },
    "a3 a1":{
        "right":0.2105263158,
        "stay":0.5789473684,
        "up":0.0,
        "down":0.2105263158
    },
    "a3 a2":{
        "right":0.2,
        "stay":0.2,
        "up":0.0,
        "down":0.6
    },
    "a3 a5":{
        "right":0.625,
        "stay":0.25,
        "up":0.0,
        "down":0.125
    },
    "a3 b1":{
        "right":0.0,
        "stay":0.625,
        "up":0.375,
        "down":0.0
    },
    "a3 b2":{
        "right":0.0,
        "stay":0.3846153846,
        "up":0.6153846154,
        "down":0.0
    },
    "a3 b3":{
        "right":0.0,
        "stay":0.6875,
        "up":0.3125,
        "down":0.0
    },
    "a3 b5":{
        "right":0.0,
        "stay":0.8,
        "up":0.2,
        "down":0.0
    },
    "a4 a1":{
        "right":0.3928571429,
        "stay":0.4642857143,
        "up":0.0,
        "down":0.1428571429
    },
    "a4 a2":{
        "right":0.5555555556,
        "stay":0.3333333333,
        "up":0.0,
        "down":0.1111111111
    },
    "a4 a3":{
        "right":0.1585365854,
        "stay":0.0243902439,
        "up":0.0,
        "down":0.8170731707
    },
    "a4 a5":{
        "right":0.3636363636,
        "stay":0.5454545455,
        "up":0.0,
        "down":0.0909090909
    },
    "a4 b1":{
        "right":0.0,
        "stay":0.6470588235,
        "up":0.3529411765,
        "down":0.0
    },
    "a4 b2":{
        "right":0.0,
        "stay":0.1538461538,
        "up":0.8461538462,
        "down":0.0
    },
    "a4 b3":{
        "right":0.0,
        "stay":0.4444444444,
        "up":0.5555555556,
        "down":0.0
    },
    "a4 b5":{
        "right":0.0,
        "stay":0.4,
        "up":0.6,
        "down":0.0
    },
    "a5 a1":{
        "right":0.2413793103,
        "stay":0.6206896552,
        "up":0.0,
        "down":0.1379310345
    },
    "a5 a2":{
        "right":0.8367346939,
        "stay":0.0408163265,
        "up":0.0,
        "down":0.1224489796
    },
    "a5 a3":{
        "right":0.5454545455,
        "stay":0.0909090909,
        "up":0.0,
        "down":0.3636363636
    },
    "a5 a4":{
        "right":0.3,
        "stay":0.1,
        "up":0.0,
        "down":0.6
    },
    "a5 b1":{
        "right":0.0,
        "stay":0.4666666667,
        "up":0.5333333333,
        "down":0.0
    },
    "a5 b3":{
        "right":0.0,
        "stay":0.3333333333,
        "up":0.6666666667,
        "down":0.0
    },
    "a5 b4":{
        "right":0.0,
        "stay":0.3333333333,
        "up":0.6666666667,
        "down":0.0
    },
    "a5 b5":{
        "right":0.0,
        "stay":0.75,
        "up":0.25,
        "down":0.0
    },
    "a6 a1":{
        "right":0.6626506024,
        "stay":0.1626506024,
        "up":0.0,
        "down":0.1746987952
    },
    "a6 a2":{
        "right":0.8666666667,
        "stay":0.0666666667,
        "up":0.0,
        "down":0.0666666667
    },
    "a6 a3":{
        "right":0.7,
        "stay":0.1,
        "up":0.0,
        "down":0.2
    },
    "a6 a4":{
        "right":0.6,
        "stay":0.1,
        "up":0.0,
        "down":0.3
    },
    "a6 a5":{
        "right":0.25,
        "stay":0.125,
        "up":0.0,
        "down":0.625
    },
    "a6 b1":{
        "right":0.0,
        "stay":0.85,
        "up":0.15,
        "down":0.0
    },
    "a6 b3":{
        "right":0.0,
        "stay":0.3333333333,
        "up":0.6666666667,
        "down":0.0
    },
    "a6 b4":{
        "right":0.0,
        "stay":0.3333333333,
        "up":0.6666666667,
        "down":0.0
    },
    "a6 b5":{
        "right":0.0,
        "stay":0.25,
        "up":0.75,
        "down":0.0
    },
    "b2 a1":{
        "right":0.1666666667,
        "stay":0.6666666667,
        "up":0.0,
        "down":0.1666666667
    },
    "b2 a2":{
        "right":0.6,
        "stay":0.2,
        "up":0.0,
        "down":0.2
    },
    "b2 a3":{
        "right":0.6666666667,
        "stay":0.1666666667,
        "up":0.0,
        "down":0.1666666667
    },
    "b2 a4":{
        "right":0.5,
        "stay":0.25,
        "up":0.0,
        "down":0.25
    },
    "b2 a5":{
        "right":0.25,
        "stay":0.25,
        "up":0.0,
        "down":0.5
    },
    "b2 b1":{
        "right":0.0,
        "stay":0.7894736842,
        "up":0.2105263158,
        "down":0.0
    },
    "b2 b5":{
        "right":0.0,
        "stay":0.6666666667,
        "up":0.3333333333,
        "down":0.0
    },
    "b3 a1":{
        "right":0.3333333333,
        "stay":0.5,
        "up":0.0,
        "down":0.1666666667
    },
    "b3 a2":{
        "right":0.7142857143,
        "stay":0.1428571429,
        "up":0.0,
        "down":0.1428571429
    },
    "b3 a3":{
        "right":0.6666666667,
        "stay":0.1666666667,
        "up":0.0,
        "down":0.1666666667
    },
    "b3 a4":{
        "right":0.6666666667,
        "stay":0.1666666667,
        "up":0.0,
        "down":0.1666666667
    },
    "b3 a5":{
        "right":0.25,
        "stay":0.25,
        "up":0.0,
        "down":0.5
    },
    "b3 b1":{
        "right":0.0,
        "stay":0.3333333333,
        "up":0.6666666667,
        "down":0.0
    },
    "b3 b2":{
        "right":0.0,
        "stay":0.25,
        "up":0.75,
        "down":0.0
    },
    "b3 b5":{
        "right":0.0,
        "stay":0.7142857143,
        "up":0.2857142857,
        "down":0.0
    },
    "b4 a1":{
        "right":0.3333333333,
        "stay":0.3333333333,
        "up":0.0,
        "down":0.3333333333
    },
    "b4 a2":{
        "right":0.6,
        "stay":0.2,
        "up":0.0,
        "down":0.2
    },
    "b4 a3":{
        "right":0.8125,
        "stay":0.09375,
        "up":0.0,
        "down":0.09375
    },
    "b4 a4":{
        "right":0.8823529412,
        "stay":0.0882352941,
        "up":0.0,
        "down":0.0294117647
    },
    "b4 a5":{
        "right":0.7941176471,
        "stay":0.1470588235,
        "up":0.0,
        "down":0.0588235294
    },
    "b4 b1":{
        "right":0.0,
        "stay":0.6666666667,
        "up":0.3333333333,
        "down":0.0
    },
    "b4 b3":{
        "right":0.0,
        "stay":0.2058823529,
        "up":0.7941176471,
        "down":0.0
    },
    "b5 a1":{
        "right":0.3076923077,
        "stay":0.6153846154,
        "up":0.0,
        "down":0.0769230769
    },
    "b5 a2":{
        "right":0.6,
        "stay":0.2,
        "up":0.0,
        "down":0.2
    },
    "b5 a3":{
        "right":0.6666666667,
        "stay":0.2222222222,
        "up":0.0,
        "down":0.1111111111
    },
    "b5 a4":{
        "right":0.6666666667,
        "stay":0.1111111111,
        "up":0.0,
        "down":0.2222222222
    },
    "b5 a5":{
        "right":0.5714285714,
        "stay":0.1428571429,
        "up":0.0,
        "down":0.2857142857
    },
    "b5 b1":{
        "right":0.0,
        "stay":0.6666666667,
        "up":0.3333333333,
        "down":0.0
    },
    "b5 b4":{
        "right":0.0,
        "stay":0.2,
        "up":0.8,
        "down":0.0
    },
    "b6 a1":{
        "right":0.375,
        "stay":0.375,
        "up":0.0,
        "down":0.25
    },
    "b6 a2":{
        "right":0.8181818182,
        "stay":0.0909090909,
        "up":0.0,
        "down":0.0909090909
    },
    "b6 a3":{
        "right":0.8333333333,
        "stay":0.0833333333,
        "up":0.0,
        "down":0.0833333333
    },
    "b6 a4":{
        "right":0.7857142857,
        "stay":0.1428571429,
        "up":0.0,
        "down":0.0714285714
    },
    "b6 a5":{
        "right":0.8461538462,
        "stay":0.0769230769,
        "up":0.0,
        "down":0.0769230769
    },
    "b6 b1":{
        "right":0.0,
        "stay":0.8571428571,
        "up":0.1428571429,
        "down":0.0
    },
    "b6 b4":{
        "right":0.0,
        "stay":0.3333333333,
        "up":0.6666666667,
        "down":0.0
    },
    "b6 b5":{
        "right":0.0,
        "stay":0.3333333333,
        "up":0.6666666667,
        "down":0.0
    }
}
    
#Define initial value function 
V={}
# for s in all_states:
#     if s in actions.keys():
#         V[s] = 0
#     if s ==(2,2):
#         V[s]=-1
#     if s == (1,2):
#         V[s]=-1
#     if s == (2,3):
#         V[s]=1
for (i,j) in all_states:
    if s in actions.keys():
        V[(i,j)] = 0
    if(i == 0): # blue agent in a1
        V[(i,j)] = 10
    if(i == j): # crushed
        V[(i,j)] = -100

# %%
# print('all_states: ', all_states)

# %%
# print('rewards: ', rewards)

# %%
# print('actions: ', actions)

# %%
# print('V: ', V)

# %%
probs['a1 a2']
# Out:
# {'right': 0.75, 'stay': 0.125, 'up': 0.0, 'down': 0.125}

# %%
def adapt_state(s):
    # takes (i,j) format state and convert it to "a|b[1-6] a|b[1-6]" format
    i = s[0]
    j = s[1]
    if i < 6:
        blueState = 'a' + str(i+1)
    else:
        blueState = 'b' + str(i-5)
    if j < 6:
        redState = 'a' + str(j+1)
    else:
        redState = 'b' + str(j-5)
    return blueState + ' ' + redState

# %%
print(adapt_state((0,1)))
print(adapt_state((0,7)))
print(adapt_state((6,8)))
print(adapt_state((10,11)))
# Out:
# a1 a2
# a1 b2
# b1 b3
# b5 b6

# %%
def newStateGivenAction(s, a, agent_i):
    # agent_i = 0 for blue and 1 for red
    if a == 'U' or a == "up":
        return s[agent_i]-6
    if a == 'D' or a == "down":
        return s[agent_i]+6
    if a == 'L' or a == "left":
        return s[agent_i]-1
    if a == 'R' or a == "right":
        return s[agent_i]+1
    if a == 'S' or a == "stay":
        return s[agent_i]

# %%
def randomProbForAction(s):
    # if aX return 1/3 else (it is bX) return 1/2
    if s[1] < 6:
        return 1.0/3
    else:
        return 1.0/2

# %%
def nextStateDistibution(s, a):
    # given state s and action a, return distibution of possibles new states by probs
    bluePossition = newStateGivenAction(s, a, 0)
    # red possible state
    nxt = {}
    for r_a in ["right","stay", "up", "down"]:
        redPossition = newStateGivenAction(s, r_a, 1)
        newState = (bluePossition, redPossition)
        if newState in all_states:
            try:
                nxt[newState] = probs[adapt_state(s)][r_a]
#                 nxt[newState] = {probs[adapt_state(s)][r_a], r_a, adapt_state(newState)}
            except KeyError:
                print("Warning! State not found: assume random behavior. ", newState)
                nxt[newState] = randomProbForAction(newState)                                                                       
    return nxt

# %%
pp.pprint(nextStateDistibution((10, 11), 'U'))
pp.pprint(nextStateDistibution((1, 5), 'S'))
# Out:
# Warning! State not found: assume random behavior.  (4, 11)
# Warning! State not found: assume random behavior.  (4, 5)
# {(4, 5): 0.3333333333333333, (4, 11): 0.5}
# Warning! State not found: assume random behavior.  (1, 6)
# Warning! State not found: assume random behavior.  (1, 5)
# Warning! State not found: assume random behavior.  (1, 11)
# {(1, 5): 0.3333333333333333, (1, 6): 0.5, (1, 11): 0.5}

# %%
'''==================================================
Value Iteration
=================================================='''

iteration = 0
pp = pprint.PrettyPrinter(depth=4)

while True:
    biggest_change = 0
    for s in all_states:            
        if s in policy:
            
            old_v = V[s]
            new_v = np.NINF
            
            for a in actions[s]:
                print("actions: ", actions[s])
                print("action: ", a)
                print("state: ", s)
                nxt = nextStateDistibution(s, a)
                print("nxt:", nxt)
                
                v=0
                #Calculate the value
                for next_state, prob in nxt.items():
                    print("next_state: ", next_state)
                    print("prob: ", prob)
                    print('V[next_state]: ', V[next_state])
                    v += prob * (rewards[s] + GAMMA * V[next_state])
                print('v: ', v)
                print()
                if v > new_v: #Is this the best action so far? If so, keep it
                    new_v = v
                    policy[s] = a

       #Save the best of all actions for the state                                
            V[s] = new_v
            biggest_change = max(biggest_change, np.abs(old_v - V[s]))

            
   #See if the loop should stop now         
    if biggest_change < SMALL_ENOUGH:
        break
    iteration += 1
    
    #Print every 100 iterations
    if(iteration % 100 == 0):
        print(iteration, ') ', V[(5, 0)]) # V([a6,a1])
    
    if(iteration % 1000 == 0):
        pp.pprint(iteration)
        pp.pprint(V)
# Out:
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (1, 0)
# nxt: {(1, 1): 0.1739130435, (1, 0): 0.6086956522, (1, 6): 0.2173913043}
# next_state:  (1, 1)
# prob:  0.1739130435
# V[next_state]:  -100
# next_state:  (1, 0)
# prob:  0.6086956522
# V[next_state]:  -12.056772524989372
# next_state:  (1, 6)
# prob:  0.2173913043
# V[next_state]:  -11.103277416286534
# v:  -27.872525671806144
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (1, 0)
# nxt: {(0, 1): 0.1739130435, (0, 0): 0.6086956522, (0, 6): 0.2173913043}
# next_state:  (0, 1)
# prob:  0.1739130435
# V[next_state]:  10
# next_state:  (0, 0)
# prob:  0.6086956522
# V[next_state]:  -100
# next_state:  (0, 6)
# prob:  0.2173913043
# V[next_state]:  10
# v:  -57.38695652458
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (1, 0)
# nxt: {(7, 1): 0.1739130435, (7, 0): 0.6086956522, (7, 6): 0.2173913043}
# next_state:  (7, 1)
# prob:  0.1739130435
# V[next_state]:  -13.75120000052866
# next_state:  (7, 0)
# prob:  0.6086956522
# V[next_state]:  -11.025610226161355
# next_state:  (7, 6)
# prob:  0.2173913043
# V[next_state]:  -9.502234007082336
# v:  -12.056772524989372
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (1, 2)
# nxt: {(1, 3): 0.8333333333, (1, 2): 0.0833333333, (1, 8): 0.0833333333}
# next_state:  (1, 3)
# prob:  0.8333333333
# V[next_state]:  8.90000000089
# next_state:  (1, 2)
# prob:  0.0833333333
# V[next_state]:  8.89999999911
# next_state:  (1, 8)
# prob:  0.0833333333
# V[next_state]:  8.9
# v:  7.810999999879725
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (1, 2)
# nxt: {(0, 3): 0.8333333333, (0, 2): 0.0833333333, (0, 8): 0.0833333333}
# next_state:  (0, 3)
# prob:  0.8333333333
# V[next_state]:  10
# next_state:  (0, 2)
# prob:  0.0833333333
# V[next_state]:  10
# next_state:  (0, 8)
# prob:  0.0833333333
# V[next_state]:  10
# v:  8.89999999911
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (1, 2)
# nxt: {(7, 3): 0.8333333333, (7, 2): 0.0833333333, (7, 8): 0.0833333333}
# next_state:  (7, 3)
# prob:  0.8333333333
# V[next_state]:  5.608250000220275
# next_state:  (7, 2)
# prob:  0.0833333333
# V[next_state]:  7.81100000122165
# next_state:  (7, 8)
# prob:  0.0833333333
# V[next_state]:  0
# v:  4.271213749939678
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (1, 3)
# nxt: {(1, 4): 0.6666666667, (1, 3): 0.1666666667, (1, 9): 0.1666666667}
# next_state:  (1, 4)
# prob:  0.6666666667
# V[next_state]:  8.9
# next_state:  (1, 3)
# prob:  0.1666666667
# V[next_state]:  8.90000000089
# next_state:  (1, 9)
# prob:  0.1666666667
# V[next_state]:  0
# v:  6.342500000634249
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (1, 3)
# nxt: {(0, 4): 0.6666666667, (0, 3): 0.1666666667, (0, 9): 0.1666666667}
# next_state:  (0, 4)
# prob:  0.6666666667
# V[next_state]:  10
# next_state:  (0, 3)
# prob:  0.1666666667
# V[next_state]:  10
# next_state:  (0, 9)
# prob:  0.1666666667
# V[next_state]:  10
# v:  8.90000000089
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (1, 3)
# nxt: {(7, 4): 0.6666666667, (7, 3): 0.1666666667, (7, 9): 0.1666666667}
# next_state:  (7, 4)
# prob:  0.6666666667
# V[next_state]:  5.60825
# next_state:  (7, 3)
# prob:  0.1666666667
# V[next_state]:  5.608250000220275
# next_state:  (7, 9)
# prob:  0.1666666667
# V[next_state]:  0
# v:  3.6268062503064895
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (1, 4)
# nxt: {(1, 5): 0.5, (1, 4): 0.25, (1, 10): 0.25}
# next_state:  (1, 5)
# prob:  0.5
# V[next_state]:  0
# next_state:  (1, 4)
# prob:  0.25
# V[next_state]:  8.9
# next_state:  (1, 10)
# prob:  0.25
# V[next_state]:  8.9
# v:  3.4055
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (1, 4)
# nxt: {(0, 5): 0.5, (0, 4): 0.25, (0, 10): 0.25}
# next_state:  (0, 5)
# prob:  0.5
# V[next_state]:  10
# next_state:  (0, 4)
# prob:  0.25
# V[next_state]:  10
# next_state:  (0, 10)
# prob:  0.25
# V[next_state]:  10
# v:  8.9
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (1, 4)
# nxt: {(7, 5): 0.5, (7, 4): 0.25, (7, 10): 0.25}
# next_state:  (7, 5)
# prob:  0.5
# V[next_state]:  0
# next_state:  (7, 4)
# prob:  0.25
# V[next_state]:  5.60825
# next_state:  (7, 10)
# prob:  0.25
# V[next_state]:  7.811
# v:  2.321264375
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (1, 5)
# Warning! State not found: assume random behavior.  (1, 6)
# Warning! State not found: assume random behavior.  (1, 5)
# Warning! State not found: assume random behavior.  (1, 11)
# nxt: {(1, 6): 0.5, (1, 5): 0.3333333333333333, (1, 11): 0.5}
# next_state:  (1, 6)
# prob:  0.5
# V[next_state]:  -11.103277416286534
# next_state:  (1, 5)
# prob:  0.3333333333333333
# V[next_state]:  0
# next_state:  (1, 11)
# prob:  0.5
# V[next_state]:  0
# v:  -6.829455654395168
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (1, 5)
# Warning! State not found: assume random behavior.  (0, 6)
# Warning! State not found: assume random behavior.  (0, 5)
# Warning! State not found: assume random behavior.  (0, 11)
# nxt: {(0, 6): 0.5, (0, 5): 0.3333333333333333, (0, 11): 0.5}
# next_state:  (0, 6)
# prob:  0.5
# V[next_state]:  10
# next_state:  (0, 5)
# prob:  0.3333333333333333
# V[next_state]:  10
# next_state:  (0, 11)
# prob:  0.5
# V[next_state]:  10
# v:  11.866666666666667
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (1, 5)
# Warning! State not found: assume random behavior.  (7, 6)
# Warning! State not found: assume random behavior.  (7, 5)
# Warning! State not found: assume random behavior.  (7, 11)
# nxt: {(7, 6): 0.5, (7, 5): 0.3333333333333333, (7, 11): 0.5}
# next_state:  (7, 6)
# prob:  0.5
# V[next_state]:  -9.502234007082336
# next_state:  (7, 5)
# prob:  0.3333333333333333
# V[next_state]:  0
# next_state:  (7, 11)
# prob:  0.5
# V[next_state]:  0
# v:  -6.0369391668390895
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (1, 6)
# nxt: {(1, 7): 0.0, (1, 6): 0.5384615385, (1, 0): 0.4615384615}
# next_state:  (1, 7)
# prob:  0.0
# V[next_state]:  8.9
# next_state:  (1, 6)
# prob:  0.5384615385
# V[next_state]:  -11.103277416286534
# next_state:  (1, 0)
# prob:  0.4615384615
# V[next_state]:  -12.056772524989372
# v:  -12.427918560986967
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (1, 6)
# nxt: {(0, 7): 0.0, (0, 6): 0.5384615385, (0, 0): 0.4615384615}
# next_state:  (0, 7)
# prob:  0.0
# V[next_state]:  10
# next_state:  (0, 6)
# prob:  0.5384615385
# V[next_state]:  10
# next_state:  (0, 0)
# prob:  0.4615384615
# V[next_state]:  -100
# v:  -41.36153845735
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (1, 6)
# nxt: {(7, 7): 0.0, (7, 6): 0.5384615385, (7, 0): 0.4615384615}
# next_state:  (7, 7)
# prob:  0.0
# V[next_state]:  -100
# next_state:  (7, 6)
# prob:  0.5384615385
# V[next_state]:  -9.502234007082336
# next_state:  (7, 0)
# prob:  0.4615384615
# V[next_state]:  -11.025610226161355
# v:  -11.103277416286534
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (1, 7)
# nxt: {(1, 8): 0.0, (1, 7): 0.625, (1, 1): 0.375}
# next_state:  (1, 8)
# prob:  0.0
# V[next_state]:  8.9
# next_state:  (1, 7)
# prob:  0.625
# V[next_state]:  8.9
# next_state:  (1, 1)
# prob:  0.375
# V[next_state]:  -100
# v:  -32.618125
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (1, 7)
# nxt: {(0, 8): 0.0, (0, 7): 0.625, (0, 1): 0.375}
# next_state:  (0, 8)
# prob:  0.0
# V[next_state]:  10
# next_state:  (0, 7)
# prob:  0.625
# V[next_state]:  10
# next_state:  (0, 1)
# prob:  0.375
# V[next_state]:  10
# v:  8.9
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (1, 7)
# nxt: {(7, 8): 0.0, (7, 7): 0.625, (7, 1): 0.375}
# next_state:  (7, 8)
# prob:  0.0
# V[next_state]:  0
# next_state:  (7, 7)
# prob:  0.625
# V[next_state]:  -100
# next_state:  (7, 1)
# prob:  0.375
# V[next_state]:  -13.75120000052866
# v:  -67.98013300019626
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (1, 8)
# nxt: {(1, 9): 0.0, (1, 8): 0.2083333333, (1, 2): 0.7916666667}
# next_state:  (1, 9)
# prob:  0.0
# V[next_state]:  0
# next_state:  (1, 8)
# prob:  0.2083333333
# V[next_state]:  8.9
# next_state:  (1, 2)
# prob:  0.7916666667
# V[next_state]:  8.89999999911
# v:  7.810999999302462
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (1, 8)
# nxt: {(0, 9): 0.0, (0, 8): 0.2083333333, (0, 2): 0.7916666667}
# next_state:  (0, 9)
# prob:  0.0
# V[next_state]:  10
# next_state:  (0, 8)
# prob:  0.2083333333
# V[next_state]:  10
# next_state:  (0, 2)
# prob:  0.7916666667
# V[next_state]:  10
# v:  8.9
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (1, 8)
# nxt: {(7, 9): 0.0, (7, 8): 0.2083333333, (7, 2): 0.7916666667}
# next_state:  (7, 9)
# prob:  0.0
# V[next_state]:  0
# next_state:  (7, 8)
# prob:  0.2083333333
# V[next_state]:  0
# next_state:  (7, 2)
# prob:  0.7916666667
# V[next_state]:  7.81100000122165
# v:  5.121871251215231
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (1, 9)
# Warning! State not found: assume random behavior.  (1, 10)
# Warning! State not found: assume random behavior.  (1, 9)
# Warning! State not found: assume random behavior.  (1, 3)
# nxt: {(1, 10): 0.5, (1, 9): 0.5, (1, 3): 0.3333333333333333}
# next_state:  (1, 10)
# prob:  0.5
# V[next_state]:  8.9
# next_state:  (1, 9)
# prob:  0.5
# V[next_state]:  0
# next_state:  (1, 3)
# prob:  0.3333333333333333
# V[next_state]:  8.90000000089
# v:  6.0091666669603665
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (1, 9)
# Warning! State not found: assume random behavior.  (0, 10)
# Warning! State not found: assume random behavior.  (0, 9)
# Warning! State not found: assume random behavior.  (0, 3)
# nxt: {(0, 10): 0.5, (0, 9): 0.5, (0, 3): 0.3333333333333333}
# next_state:  (0, 10)
# prob:  0.5
# V[next_state]:  10
# next_state:  (0, 9)
# prob:  0.5
# V[next_state]:  10
# next_state:  (0, 3)
# prob:  0.3333333333333333
# V[next_state]:  10
# v:  11.866666666666667
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (1, 9)
# Warning! State not found: assume random behavior.  (7, 10)
# Warning! State not found: assume random behavior.  (7, 9)
# Warning! State not found: assume random behavior.  (7, 3)
# nxt: {(7, 10): 0.5, (7, 9): 0.5, (7, 3): 0.3333333333333333}
# next_state:  (7, 10)
# prob:  0.5
# V[next_state]:  7.811
# next_state:  (7, 9)
# prob:  0.5
# V[next_state]:  0
# next_state:  (7, 3)
# prob:  0.3333333333333333
# V[next_state]:  5.608250000220275
# v:  4.383834166739358
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (1, 10)
# nxt: {(1, 11): 0.0, (1, 10): 0.4, (1, 4): 0.6}
# next_state:  (1, 11)
# prob:  0.0
# V[next_state]:  0
# next_state:  (1, 10)
# prob:  0.4
# V[next_state]:  8.9
# next_state:  (1, 4)
# prob:  0.6
# V[next_state]:  8.9
# v:  7.811
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (1, 10)
# nxt: {(0, 11): 0.0, (0, 10): 0.4, (0, 4): 0.6}
# next_state:  (0, 11)
# prob:  0.0
# V[next_state]:  10
# next_state:  (0, 10)
# prob:  0.4
# V[next_state]:  10
# next_state:  (0, 4)
# prob:  0.6
# V[next_state]:  10
# v:  8.9
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (1, 10)
# nxt: {(7, 11): 0.0, (7, 10): 0.4, (7, 4): 0.6}
# next_state:  (7, 11)
# prob:  0.0
# V[next_state]:  0
# next_state:  (7, 10)
# prob:  0.4
# V[next_state]:  7.811
# next_state:  (7, 4)
# prob:  0.6
# V[next_state]:  5.60825
# v:  5.4244565
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (1, 11)
# Warning! State not found: assume random behavior.  (1, 11)
# Warning! State not found: assume random behavior.  (1, 5)
# nxt: {(1, 11): 0.5, (1, 5): 0.3333333333333333}
# next_state:  (1, 11)
# prob:  0.5
# V[next_state]:  0
# next_state:  (1, 5)
# prob:  0.3333333333333333
# V[next_state]:  11.866666666666667
# v:  3.082666666666667
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (1, 11)
# Warning! State not found: assume random behavior.  (0, 11)
# Warning! State not found: assume random behavior.  (0, 5)
# nxt: {(0, 11): 0.5, (0, 5): 0.3333333333333333}
# next_state:  (0, 11)
# prob:  0.5
# V[next_state]:  10
# next_state:  (0, 5)
# prob:  0.3333333333333333
# V[next_state]:  10
# v:  7.416666666666667
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (1, 11)
# Warning! State not found: assume random behavior.  (7, 11)
# Warning! State not found: assume random behavior.  (7, 5)
# nxt: {(7, 11): 0.5, (7, 5): 0.3333333333333333}
# next_state:  (7, 11)
# prob:  0.5
# V[next_state]:  0
# next_state:  (7, 5)
# prob:  0.3333333333333333
# V[next_state]:  0
# v:  -0.8333333333333333
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (2, 0)
# nxt: {(2, 1): 0.2105263158, (2, 0): 0.5789473684, (2, 6): 0.2105263158}
# next_state:  (2, 1)
# prob:  0.2105263158
# V[next_state]:  -13.751200000176222
# next_state:  (2, 0)
# prob:  0.5789473684
# V[next_state]:  -11.692899657595259
# next_state:  (2, 6)
# prob:  0.2105263158
# V[next_state]:  -11.17469018746122
# v:  -12.896958021819032
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (2, 0)
# nxt: {(1, 1): 0.2105263158, (1, 0): 0.5789473684, (1, 6): 0.2105263158}
# next_state:  (1, 1)
# prob:  0.2105263158
# V[next_state]:  -100
# next_state:  (1, 0)
# prob:  0.5789473684
# V[next_state]:  -12.056772524989372
# next_state:  (1, 6)
# prob:  0.2105263158
# V[next_state]:  -11.103277416286534
# v:  -31.066696388571206
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (2, 0)
# nxt: {(8, 1): 0.2105263158, (8, 0): 0.5789473684, (8, 6): 0.2105263158}
# next_state:  (8, 1)
# prob:  0.2105263158
# V[next_state]:  -16.904178653757466
# next_state:  (8, 0)
# prob:  0.5789473684
# V[next_state]:  -12.156033917732026
# next_state:  (8, 6)
# prob:  0.2105263158
# V[next_state]:  -10.86128632415134
# v:  -13.754234246173919
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (2, 1)
# nxt: {(2, 2): 0.2, (2, 1): 0.2, (2, 7): 0.6}
# next_state:  (2, 2)
# prob:  0.2
# V[next_state]:  -100
# next_state:  (2, 1)
# prob:  0.2
# V[next_state]:  -13.751200000176222
# next_state:  (2, 7)
# prob:  0.6
# V[next_state]:  -14.982659706128416
# v:  -32.42243746547517
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (2, 1)
# nxt: {(1, 2): 0.2, (1, 1): 0.2, (1, 7): 0.6}
# next_state:  (1, 2)
# prob:  0.2
# V[next_state]:  8.89999999911
# next_state:  (1, 1)
# prob:  0.2
# V[next_state]:  -100
# next_state:  (1, 7)
# prob:  0.6
# V[next_state]:  8.9
# v:  -13.751200000176222
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (2, 1)
# nxt: {(8, 2): 0.2, (8, 1): 0.2, (8, 7): 0.6}
# next_state:  (8, 2)
# prob:  0.2
# V[next_state]:  -16.211185003187666
# next_state:  (8, 1)
# prob:  0.2
# V[next_state]:  -16.904178653757466
# next_state:  (8, 7)
# prob:  0.6
# V[next_state]:  -14.853519609054123
# v:  -16.379832651853285
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (2, 3)
# Warning! State not found: assume random behavior.  (2, 4)
# Warning! State not found: assume random behavior.  (2, 3)
# Warning! State not found: assume random behavior.  (2, 9)
# nxt: {(2, 4): 0.3333333333333333, (2, 3): 0.3333333333333333, (2, 9): 0.5}
# next_state:  (2, 4)
# prob:  0.3333333333333333
# V[next_state]:  2.304125
# next_state:  (2, 3)
# prob:  0.3333333333333333
# V[next_state]:  0
# next_state:  (2, 9)
# prob:  0.5
# V[next_state]:  0
# v:  -0.40630541666666664
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (2, 3)
# Warning! State not found: assume random behavior.  (1, 4)
# Warning! State not found: assume random behavior.  (1, 3)
# Warning! State not found: assume random behavior.  (1, 9)
# nxt: {(1, 4): 0.3333333333333333, (1, 3): 0.3333333333333333, (1, 9): 0.5}
# next_state:  (1, 4)
# prob:  0.3333333333333333
# V[next_state]:  8.9
# next_state:  (1, 3)
# prob:  0.3333333333333333
# V[next_state]:  8.90000000089
# next_state:  (1, 9)
# prob:  0.5
# V[next_state]:  11.866666666666667
# v:  10.581333333627033
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (2, 3)
# Warning! State not found: assume random behavior.  (8, 4)
# Warning! State not found: assume random behavior.  (8, 3)
# Warning! State not found: assume random behavior.  (8, 9)
# nxt: {(8, 4): 0.3333333333333333, (8, 3): 0.3333333333333333, (8, 9): 0.5}
# next_state:  (8, 4)
# prob:  0.3333333333333333
# V[next_state]:  3.4367159375000003
# next_state:  (8, 3)
# prob:  0.3333333333333333
# V[next_state]:  1.5187192718555096
# next_state:  (8, 9)
# prob:  0.5
# V[next_state]:  0
# v:  0.46862695242065155
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (2, 4)
# nxt: {(2, 5): 0.625, (2, 4): 0.25, (2, 10): 0.125}
# next_state:  (2, 5)
# prob:  0.625
# V[next_state]:  0
# next_state:  (2, 4)
# prob:  0.25
# V[next_state]:  2.304125
# next_state:  (2, 10)
# prob:  0.125
# V[next_state]:  7.811
# v:  0.5368821875
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (2, 4)
# nxt: {(1, 5): 0.625, (1, 4): 0.25, (1, 10): 0.125}
# next_state:  (1, 5)
# prob:  0.625
# V[next_state]:  11.866666666666667
# next_state:  (1, 4)
# prob:  0.25
# V[next_state]:  8.9
# next_state:  (1, 10)
# prob:  0.125
# V[next_state]:  8.9
# v:  9.646625
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (2, 4)
# nxt: {(8, 5): 0.625, (8, 4): 0.25, (8, 10): 0.125}
# next_state:  (8, 5)
# prob:  0.625
# V[next_state]:  0
# next_state:  (8, 4)
# prob:  0.25
# V[next_state]:  3.4367159375000003
# next_state:  (8, 10)
# prob:  0.125
# V[next_state]:  5.175231071506454
# v:  0.49102203963017377
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (2, 5)
# Warning! State not found: assume random behavior.  (2, 6)
# Warning! State not found: assume random behavior.  (2, 5)
# Warning! State not found: assume random behavior.  (2, 11)
# nxt: {(2, 6): 0.5, (2, 5): 0.3333333333333333, (2, 11): 0.5}
# next_state:  (2, 6)
# prob:  0.5
# V[next_state]:  -11.17469018746122
# next_state:  (2, 5)
# prob:  0.3333333333333333
# V[next_state]:  0
# next_state:  (2, 11)
# prob:  0.5
# V[next_state]:  0
# v:  -6.864804976126637
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (2, 5)
# Warning! State not found: assume random behavior.  (1, 6)
# Warning! State not found: assume random behavior.  (1, 5)
# Warning! State not found: assume random behavior.  (1, 11)
# nxt: {(1, 6): 0.5, (1, 5): 0.3333333333333333, (1, 11): 0.5}
# next_state:  (1, 6)
# prob:  0.5
# V[next_state]:  -11.103277416286534
# next_state:  (1, 5)
# prob:  0.3333333333333333
# V[next_state]:  11.866666666666667
# next_state:  (1, 11)
# prob:  0.5
# V[next_state]:  7.416666666666667
# v:  0.7577943456048324
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (2, 5)
# Warning! State not found: assume random behavior.  (8, 6)
# Warning! State not found: assume random behavior.  (8, 5)
# Warning! State not found: assume random behavior.  (8, 11)
# nxt: {(8, 6): 0.5, (8, 5): 0.3333333333333333, (8, 11): 0.5}
# next_state:  (8, 6)
# prob:  0.5
# V[next_state]:  -10.86128632415134
# next_state:  (8, 5)
# prob:  0.3333333333333333
# V[next_state]:  0
# next_state:  (8, 11)
# prob:  0.5
# V[next_state]:  0
# v:  -6.709670063788247
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (2, 6)
# nxt: {(2, 7): 0.0, (2, 6): 0.625, (2, 0): 0.375}
# next_state:  (2, 7)
# prob:  0.0
# V[next_state]:  -14.982659706128416
# next_state:  (2, 6)
# prob:  0.625
# V[next_state]:  -11.17469018746122
# next_state:  (2, 0)
# prob:  0.375
# V[next_state]:  -12.896958021819032
# v:  -12.702335219091946
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (2, 6)
# nxt: {(1, 7): 0.0, (1, 6): 0.625, (1, 0): 0.375}
# next_state:  (1, 7)
# prob:  0.0
# V[next_state]:  8.9
# next_state:  (1, 6)
# prob:  0.625
# V[next_state]:  -11.103277416286534
# next_state:  (1, 0)
# prob:  0.375
# V[next_state]:  -12.056772524989372
# v:  -12.346229701229596
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (2, 6)
# nxt: {(8, 7): 0.0, (8, 6): 0.625, (8, 0): 0.375}
# next_state:  (8, 7)
# prob:  0.0
# V[next_state]:  -14.853519609054123
# next_state:  (8, 6)
# prob:  0.625
# V[next_state]:  -10.86128632415134
# next_state:  (8, 0)
# prob:  0.375
# V[next_state]:  -12.156033917732026
# v:  -12.233348505026656
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (2, 7)
# nxt: {(2, 8): 0.0, (2, 7): 0.3846153846, (2, 1): 0.6153846154}
# next_state:  (2, 8)
# prob:  0.0
# V[next_state]:  7.810999999724656
# next_state:  (2, 7)
# prob:  0.3846153846
# V[next_state]:  -14.982659706128416
# next_state:  (2, 1)
# prob:  0.6153846154
# V[next_state]:  -13.751200000176222
# v:  -15.082589965114423
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (2, 7)
# nxt: {(1, 8): 0.0, (1, 7): 0.3846153846, (1, 1): 0.6153846154}
# next_state:  (1, 8)
# prob:  0.0
# V[next_state]:  8.9
# next_state:  (1, 7)
# prob:  0.3846153846
# V[next_state]:  8.9
# next_state:  (1, 1)
# prob:  0.6153846154
# V[next_state]:  -100
# v:  -58.5342307708894
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (2, 7)
# nxt: {(8, 8): 0.0, (8, 7): 0.3846153846, (8, 1): 0.6153846154}
# next_state:  (8, 8)
# prob:  0.0
# V[next_state]:  -100
# next_state:  (8, 7)
# prob:  0.3846153846
# V[next_state]:  -14.853519609054123
# next_state:  (8, 1)
# prob:  0.6153846154
# V[next_state]:  -16.904178653757466
# v:  -16.954309000229465
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (2, 8)
# nxt: {(2, 9): 0.0, (2, 8): 0.6875, (2, 2): 0.3125}
# next_state:  (2, 9)
# prob:  0.0
# V[next_state]:  0
# next_state:  (2, 8)
# prob:  0.6875
# V[next_state]:  7.810999999724656
# next_state:  (2, 2)
# prob:  0.3125
# V[next_state]:  -100
# v:  -26.621138125187407
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (2, 8)
# nxt: {(1, 9): 0.0, (1, 8): 0.6875, (1, 2): 0.3125}
# next_state:  (1, 9)
# prob:  0.0
# V[next_state]:  11.866666666666667
# next_state:  (1, 8)
# prob:  0.6875
# V[next_state]:  8.9
# next_state:  (1, 2)
# prob:  0.3125
# V[next_state]:  8.89999999911
# v:  7.810999999724656
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (2, 8)
# nxt: {(8, 9): 0.0, (8, 8): 0.6875, (8, 2): 0.3125}
# next_state:  (8, 9)
# prob:  0.0
# V[next_state]:  0
# next_state:  (8, 8)
# prob:  0.6875
# V[next_state]:  -100
# next_state:  (8, 2)
# prob:  0.3125
# V[next_state]:  -16.211185003187666
# v:  -74.07783536036118
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (2, 9)
# Warning! State not found: assume random behavior.  (2, 10)
# Warning! State not found: assume random behavior.  (2, 9)
# Warning! State not found: assume random behavior.  (2, 3)
# nxt: {(2, 10): 0.5, (2, 9): 0.5, (2, 3): 0.3333333333333333}
# next_state:  (2, 10)
# prob:  0.5
# V[next_state]:  7.811
# next_state:  (2, 9)
# prob:  0.5
# V[next_state]:  0
# next_state:  (2, 3)
# prob:  0.3333333333333333
# V[next_state]:  10.581333333627033
# v:  6.024951666763588
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (2, 9)
# Warning! State not found: assume random behavior.  (1, 10)
# Warning! State not found: assume random behavior.  (1, 9)
# Warning! State not found: assume random behavior.  (1, 3)
# nxt: {(1, 10): 0.5, (1, 9): 0.5, (1, 3): 0.3333333333333333}
# next_state:  (1, 10)
# prob:  0.5
# V[next_state]:  8.9
# next_state:  (1, 9)
# prob:  0.5
# V[next_state]:  11.866666666666667
# next_state:  (1, 3)
# prob:  0.3333333333333333
# V[next_state]:  8.90000000089
# v:  11.883166666960367
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (2, 9)
# Warning! State not found: assume random behavior.  (8, 10)
# Warning! State not found: assume random behavior.  (8, 9)
# Warning! State not found: assume random behavior.  (8, 3)
# nxt: {(8, 10): 0.5, (8, 9): 0.5, (8, 3): 0.3333333333333333}
# next_state:  (8, 10)
# prob:  0.5
# V[next_state]:  5.175231071506454
# next_state:  (8, 9)
# prob:  0.5
# V[next_state]:  0
# next_state:  (8, 3)
# prob:  0.3333333333333333
# V[next_state]:  1.5187192718555096
# v:  1.7295834067746796
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (2, 10)
# nxt: {(2, 11): 0.0, (2, 10): 0.8, (2, 4): 0.2}
# next_state:  (2, 11)
# prob:  0.0
# V[next_state]:  0
# next_state:  (2, 10)
# prob:  0.8
# V[next_state]:  7.811
# next_state:  (2, 4)
# prob:  0.2
# V[next_state]:  9.646625
# v:  7.09634375
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (2, 10)
# nxt: {(1, 11): 0.0, (1, 10): 0.8, (1, 4): 0.2}
# next_state:  (1, 11)
# prob:  0.0
# V[next_state]:  7.416666666666667
# next_state:  (1, 10)
# prob:  0.8
# V[next_state]:  8.9
# next_state:  (1, 4)
# prob:  0.2
# V[next_state]:  8.9
# v:  7.811
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (2, 10)
# nxt: {(8, 11): 0.0, (8, 10): 0.8, (8, 4): 0.2}
# next_state:  (8, 11)
# prob:  0.0
# V[next_state]:  0
# next_state:  (8, 10)
# prob:  0.8
# V[next_state]:  5.175231071506454
# next_state:  (8, 4)
# prob:  0.2
# V[next_state]:  3.4367159375000003
# v:  3.779252764258112
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (2, 11)
# Warning! State not found: assume random behavior.  (2, 11)
# Warning! State not found: assume random behavior.  (2, 5)
# nxt: {(2, 11): 0.5, (2, 5): 0.3333333333333333}
# next_state:  (2, 11)
# prob:  0.5
# V[next_state]:  0
# next_state:  (2, 5)
# prob:  0.3333333333333333
# V[next_state]:  0.7577943456048324
# v:  -0.5832611992837387
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (2, 11)
# Warning! State not found: assume random behavior.  (1, 11)
# Warning! State not found: assume random behavior.  (1, 5)
# nxt: {(1, 11): 0.5, (1, 5): 0.3333333333333333}
# next_state:  (1, 11)
# prob:  0.5
# V[next_state]:  7.416666666666667
# next_state:  (1, 5)
# prob:  0.3333333333333333
# V[next_state]:  11.866666666666667
# v:  6.753916666666667
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (2, 11)
# Warning! State not found: assume random behavior.  (8, 11)
# Warning! State not found: assume random behavior.  (8, 5)
# nxt: {(8, 11): 0.5, (8, 5): 0.3333333333333333}
# next_state:  (8, 11)
# prob:  0.5
# V[next_state]:  0
# next_state:  (8, 5)
# prob:  0.3333333333333333
# V[next_state]:  0
# v:  -0.8333333333333333
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (3, 0)
# nxt: {(3, 1): 0.3928571429, (3, 0): 0.4642857143, (3, 6): 0.1428571429}
# next_state:  (3, 1)
# prob:  0.3928571429
# V[next_state]:  0.8231420507262388
# next_state:  (3, 0)
# prob:  0.4642857143
# V[next_state]:  -2.27679072230891
# next_state:  (3, 6)
# prob:  0.1428571429
# V[next_state]:  -4.432245558677827
# v:  -2.353213288716441
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (3, 0)
# nxt: {(2, 1): 0.3928571429, (2, 0): 0.4642857143, (2, 6): 0.1428571429}
# next_state:  (2, 1)
# prob:  0.3928571429
# V[next_state]:  -13.751200000176222
# next_state:  (2, 0)
# prob:  0.4642857143
# V[next_state]:  -12.896958021819032
# next_state:  (2, 6)
# prob:  0.1428571429
# V[next_state]:  -12.233348505026656
# v:  -14.006374209336158
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (3, 0)
# nxt: {(9, 1): 0.3928571429, (9, 0): 0.4642857143, (9, 6): 0.1428571429}
# next_state:  (9, 1)
# prob:  0.3928571429
# V[next_state]:  0.8251783064836054
# next_state:  (9, 0)
# prob:  0.4642857143
# V[next_state]:  -2.9423450956917296
# next_state:  (9, 6)
# prob:  0.1428571429
# V[next_state]:  -4.676623007160435
# v:  -2.692900597887218
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (3, 1)
# nxt: {(3, 2): 0.5555555556, (3, 1): 0.3333333333, (3, 7): 0.1111111111}
# next_state:  (3, 2)
# prob:  0.5555555556
# V[next_state]:  2.9037028046515965
# next_state:  (3, 1)
# prob:  0.3333333333
# V[next_state]:  0.8231420507262388
# next_state:  (3, 7)
# prob:  0.1111111111
# V[next_state]:  -0.3161782097133238
# v:  0.8338938163336485
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (3, 1)
# nxt: {(2, 2): 0.5555555556, (2, 1): 0.3333333333, (2, 7): 0.1111111111}
# next_state:  (2, 2)
# prob:  0.5555555556
# V[next_state]:  -100
# next_state:  (2, 1)
# prob:  0.3333333333
# V[next_state]:  -13.751200000176222
# next_state:  (2, 7)
# prob:  0.1111111111
# V[next_state]:  -15.082589965114423
# v:  -62.196980900001044
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (3, 1)
# nxt: {(9, 2): 0.5555555556, (9, 1): 0.3333333333, (9, 7): 0.1111111111}
# next_state:  (9, 2)
# prob:  0.5555555556
# V[next_state]:  -5.3099162264432165
# next_state:  (9, 1)
# prob:  0.3333333333
# V[next_state]:  0.8251783064836054
# next_state:  (9, 7)
# prob:  0.1111111111
# V[next_state]:  0
# v:  -3.6481450836650464
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (3, 2)
# nxt: {(3, 3): 0.1585365854, (3, 2): 0.0243902439, (3, 8): 0.8170731707}
# next_state:  (3, 3)
# prob:  0.1585365854
# V[next_state]:  -100
# next_state:  (3, 2)
# prob:  0.0243902439
# V[next_state]:  2.9037028046515965
# next_state:  (3, 8)
# prob:  0.8170731707
# V[next_state]:  1.0584004609016766
# v:  -15.768865440922939
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (3, 2)
# nxt: {(2, 3): 0.1585365854, (2, 2): 0.0243902439, (2, 8): 0.8170731707}
# next_state:  (2, 3)
# prob:  0.1585365854
# V[next_state]:  10.581333333627033
# next_state:  (2, 2)
# prob:  0.0243902439
# V[next_state]:  -100
# next_state:  (2, 8)
# prob:  0.8170731707
# V[next_state]:  7.810999999724656
# v:  4.564455975787101
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (3, 2)
# nxt: {(9, 3): 0.1585365854, (9, 2): 0.0243902439, (9, 8): 0.8170731707}
# next_state:  (9, 3)
# prob:  0.1585365854
# V[next_state]:  -4.918356466075373
# next_state:  (9, 2)
# prob:  0.0243902439
# V[next_state]:  -5.3099162264432165
# next_state:  (9, 8)
# prob:  0.8170731707
# V[next_state]:  1.4985497401453935
# v:  -0.6879765560895521
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (3, 4)
# nxt: {(3, 5): 0.3636363636, (3, 4): 0.5454545455, (3, 10): 0.0909090909}
# next_state:  (3, 5)
# prob:  0.3636363636
# V[next_state]:  0
# next_state:  (3, 4)
# prob:  0.5454545455
# V[next_state]:  0.9472175000333867
# next_state:  (3, 10)
# prob:  0.0909090909
# V[next_state]:  3.46180625
# v:  -0.17693998747050269
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (3, 4)
# nxt: {(2, 5): 0.3636363636, (2, 4): 0.5454545455, (2, 10): 0.0909090909}
# next_state:  (2, 5)
# prob:  0.3636363636
# V[next_state]:  0.7577943456048324
# next_state:  (2, 4)
# prob:  0.5454545455
# V[next_state]:  9.646625
# next_state:  (2, 10)
# prob:  0.0909090909
# V[next_state]:  7.811
# v:  5.1849734647542585
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (3, 4)
# nxt: {(9, 5): 0.3636363636, (9, 4): 0.5454545455, (9, 10): 0.0909090909}
# next_state:  (9, 5)
# prob:  0.3636363636
# V[next_state]:  0
# next_state:  (9, 4)
# prob:  0.5454545455
# V[next_state]:  -0.6604969706512752
# next_state:  (9, 10)
# prob:  0.0909090909
# V[next_state]:  0
# v:  -1.3566683641814112
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (3, 5)
# Warning! State not found: assume random behavior.  (3, 6)
# Warning! State not found: assume random behavior.  (3, 5)
# Warning! State not found: assume random behavior.  (3, 11)
# nxt: {(3, 6): 0.5, (3, 5): 0.3333333333333333, (3, 11): 0.5}
# next_state:  (3, 6)
# prob:  0.5
# V[next_state]:  -4.432245558677827
# next_state:  (3, 5)
# prob:  0.3333333333333333
# V[next_state]:  0
# next_state:  (3, 11)
# prob:  0.5
# V[next_state]:  0
# v:  -3.5272948848788577
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (3, 5)
# Warning! State not found: assume random behavior.  (2, 6)
# Warning! State not found: assume random behavior.  (2, 5)
# Warning! State not found: assume random behavior.  (2, 11)
# nxt: {(2, 6): 0.5, (2, 5): 0.3333333333333333, (2, 11): 0.5}
# next_state:  (2, 6)
# prob:  0.5
# V[next_state]:  -12.233348505026656
# next_state:  (2, 5)
# prob:  0.3333333333333333
# V[next_state]:  0.7577943456048324
# next_state:  (2, 11)
# prob:  0.5
# V[next_state]:  6.753916666666667
# v:  -3.7955799592719344
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (3, 5)
# Warning! State not found: assume random behavior.  (9, 6)
# Warning! State not found: assume random behavior.  (9, 5)
# Warning! State not found: assume random behavior.  (9, 11)
# nxt: {(9, 6): 0.5, (9, 5): 0.3333333333333333, (9, 11): 0.5}
# next_state:  (9, 6)
# prob:  0.5
# V[next_state]:  -4.676623007160435
# next_state:  (9, 5)
# prob:  0.3333333333333333
# V[next_state]:  0
# next_state:  (9, 11)
# prob:  0.5
# V[next_state]:  0
# v:  -3.648261721877749
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (3, 6)
# nxt: {(3, 7): 0.0, (3, 6): 0.6470588235, (3, 0): 0.3529411765}
# next_state:  (3, 7)
# prob:  0.0
# V[next_state]:  -0.3161782097133238
# next_state:  (3, 6)
# prob:  0.6470588235
# V[next_state]:  -4.432245558677827
# next_state:  (3, 0)
# prob:  0.3529411765
# V[next_state]:  -2.353213288716441
# v:  -4.661484768702828
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (3, 6)
# nxt: {(2, 7): 0.0, (2, 6): 0.6470588235, (2, 0): 0.3529411765}
# next_state:  (2, 7)
# prob:  0.0
# V[next_state]:  -15.082589965114423
# next_state:  (2, 6)
# prob:  0.6470588235
# V[next_state]:  -12.233348505026656
# next_state:  (2, 0)
# prob:  0.3529411765
# V[next_state]:  -12.896958021819032
# v:  -13.342887992333754
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (3, 6)
# nxt: {(9, 7): 0.0, (9, 6): 0.6470588235, (9, 0): 0.3529411765}
# next_state:  (9, 7)
# prob:  0.0
# V[next_state]:  0
# next_state:  (9, 6)
# prob:  0.6470588235
# V[next_state]:  -4.676623007160435
# next_state:  (9, 0)
# prob:  0.3529411765
# V[next_state]:  -2.9423450956917296
# v:  -5.0238796715016205
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (3, 7)
# nxt: {(3, 8): 0.0, (3, 7): 0.1538461538, (3, 1): 0.8461538462}
# next_state:  (3, 8)
# prob:  0.0
# V[next_state]:  1.0584004609016766
# next_state:  (3, 7)
# prob:  0.1538461538
# V[next_state]:  -0.3161782097133238
# next_state:  (3, 1)
# prob:  0.8461538462
# V[next_state]:  0.8338938163336485
# v:  -0.34960993805198515
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (3, 7)
# nxt: {(2, 8): 0.0, (2, 7): 0.1538461538, (2, 1): 0.8461538462}
# next_state:  (2, 8)
# prob:  0.0
# V[next_state]:  7.810999999724656
# next_state:  (2, 7)
# prob:  0.1538461538
# V[next_state]:  -15.082589965114423
# next_state:  (2, 1)
# prob:  0.8461538462
# V[next_state]:  -13.751200000176222
# v:  -14.816468933234981
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (3, 7)
# nxt: {(9, 8): 0.0, (9, 7): 0.1538461538, (9, 1): 0.8461538462}
# next_state:  (9, 8)
# prob:  0.0
# V[next_state]:  1.4985497401453935
# next_state:  (9, 7)
# prob:  0.1538461538
# V[next_state]:  0
# next_state:  (9, 1)
# prob:  0.8461538462
# V[next_state]:  0.8251783064836054
# v:  -0.30875448014641405
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (3, 8)
# nxt: {(3, 9): 0.0, (3, 8): 0.4444444444, (3, 2): 0.5555555556}
# next_state:  (3, 9)
# prob:  0.0
# V[next_state]:  0
# next_state:  (3, 8)
# prob:  0.4444444444
# V[next_state]:  1.0584004609016766
# next_state:  (3, 2)
# prob:  0.5555555556
# V[next_state]:  4.564455975787101
# v:  1.9761469896339094
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (3, 8)
# nxt: {(2, 9): 0.0, (2, 8): 0.4444444444, (2, 2): 0.5555555556}
# next_state:  (2, 9)
# prob:  0.0
# V[next_state]:  11.883166666960367
# next_state:  (2, 8)
# prob:  0.4444444444
# V[next_state]:  7.810999999724656
# next_state:  (2, 2)
# prob:  0.5555555556
# V[next_state]:  -100
# v:  -52.56316000486484
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (3, 8)
# nxt: {(9, 9): 0.0, (9, 8): 0.4444444444, (9, 2): 0.5555555556}
# next_state:  (9, 9)
# prob:  0.0
# V[next_state]:  -100
# next_state:  (9, 8)
# prob:  0.4444444444
# V[next_state]:  1.4985497401453935
# next_state:  (9, 2)
# prob:  0.5555555556
# V[next_state]:  -5.3099162264432165
# v:  -3.2610920391793683
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (3, 9)
# Warning! State not found: assume random behavior.  (3, 10)
# Warning! State not found: assume random behavior.  (3, 9)
# Warning! State not found: assume random behavior.  (3, 3)
# nxt: {(3, 10): 0.5, (3, 9): 0.5, (3, 3): 0.3333333333333333}
# next_state:  (3, 10)
# prob:  0.5
# V[next_state]:  3.46180625
# next_state:  (3, 9)
# prob:  0.5
# V[next_state]:  0
# next_state:  (3, 3)
# prob:  0.3333333333333333
# V[next_state]:  -100
# v:  -32.61973923958333
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (3, 9)
# Warning! State not found: assume random behavior.  (2, 10)
# Warning! State not found: assume random behavior.  (2, 9)
# Warning! State not found: assume random behavior.  (2, 3)
# nxt: {(2, 10): 0.5, (2, 9): 0.5, (2, 3): 0.3333333333333333}
# next_state:  (2, 10)
# prob:  0.5
# V[next_state]:  7.811
# next_state:  (2, 9)
# prob:  0.5
# V[next_state]:  11.883166666960367
# next_state:  (2, 3)
# prob:  0.3333333333333333
# V[next_state]:  10.581333333627033
# v:  11.90711916690897
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (3, 9)
# Warning! State not found: assume random behavior.  (9, 10)
# Warning! State not found: assume random behavior.  (9, 9)
# Warning! State not found: assume random behavior.  (9, 3)
# nxt: {(9, 10): 0.5, (9, 9): 0.5, (9, 3): 0.3333333333333333}
# next_state:  (9, 10)
# prob:  0.5
# V[next_state]:  0
# next_state:  (9, 9)
# prob:  0.5
# V[next_state]:  -100
# next_state:  (9, 3)
# prob:  0.3333333333333333
# V[next_state]:  -4.918356466075373
# v:  -52.456390967138205
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (3, 10)
# nxt: {(3, 11): 0.0, (3, 10): 0.4, (3, 4): 0.6}
# next_state:  (3, 11)
# prob:  0.0
# V[next_state]:  0
# next_state:  (3, 10)
# prob:  0.4
# V[next_state]:  3.46180625
# next_state:  (3, 4)
# prob:  0.6
# V[next_state]:  5.1849734647542585
# v:  3.4507495130640295
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (3, 10)
# nxt: {(2, 11): 0.0, (2, 10): 0.4, (2, 4): 0.6}
# next_state:  (2, 11)
# prob:  0.0
# V[next_state]:  6.753916666666667
# next_state:  (2, 10)
# prob:  0.4
# V[next_state]:  7.811
# next_state:  (2, 4)
# prob:  0.6
# V[next_state]:  9.646625
# v:  7.823251249999999
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (3, 10)
# nxt: {(9, 11): 0.0, (9, 10): 0.4, (9, 4): 0.6}
# next_state:  (9, 11)
# prob:  0.0
# V[next_state]:  0
# next_state:  (9, 10)
# prob:  0.4
# V[next_state]:  0
# next_state:  (9, 4)
# prob:  0.6
# V[next_state]:  -0.6604969706512752
# v:  -1.3923352005668574
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (3, 11)
# Warning! State not found: assume random behavior.  (3, 11)
# Warning! State not found: assume random behavior.  (3, 5)
# nxt: {(3, 11): 0.5, (3, 5): 0.3333333333333333}
# next_state:  (3, 11)
# prob:  0.5
# V[next_state]:  0
# next_state:  (3, 5)
# prob:  0.3333333333333333
# V[next_state]:  -3.5272948848788577
# v:  -1.9973406453433562
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (3, 11)
# Warning! State not found: assume random behavior.  (2, 11)
# Warning! State not found: assume random behavior.  (2, 5)
# nxt: {(2, 11): 0.5, (2, 5): 0.3333333333333333}
# next_state:  (2, 11)
# prob:  0.5
# V[next_state]:  6.753916666666667
# next_state:  (2, 5)
# prob:  0.3333333333333333
# V[next_state]:  0.7577943456048324
# v:  2.7599275507162613
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (3, 11)
# Warning! State not found: assume random behavior.  (9, 11)
# Warning! State not found: assume random behavior.  (9, 5)
# nxt: {(9, 11): 0.5, (9, 5): 0.3333333333333333}
# next_state:  (9, 11)
# prob:  0.5
# V[next_state]:  0
# next_state:  (9, 5)
# prob:  0.3333333333333333
# V[next_state]:  0
# v:  -0.8333333333333333
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (4, 0)
# nxt: {(4, 1): 0.2413793103, (4, 0): 0.6206896552, (4, 6): 0.1379310345}
# next_state:  (4, 1)
# prob:  0.2413793103
# V[next_state]:  1.4002657048441562
# next_state:  (4, 0)
# prob:  0.6206896552
# V[next_state]:  -2.7531456714138907
# next_state:  (4, 6)
# prob:  0.1379310345
# V[next_state]:  -4.24984294955939
# v:  -2.937468710909207
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (4, 0)
# nxt: {(3, 1): 0.2413793103, (3, 0): 0.6206896552, (3, 6): 0.1379310345}
# next_state:  (3, 1)
# prob:  0.2413793103
# V[next_state]:  0.8338938163336485
# next_state:  (3, 0)
# prob:  0.6206896552
# V[next_state]:  -2.353213288716441
# next_state:  (3, 6)
# prob:  0.1379310345
# V[next_state]:  -4.661484768702828
# v:  -2.8832709085187034
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (4, 0)
# nxt: {(10, 1): 0.2413793103, (10, 0): 0.6206896552, (10, 6): 0.1379310345}
# next_state:  (10, 1)
# prob:  0.2413793103
# V[next_state]:  -4.820107688806093
# next_state:  (10, 0)
# prob:  0.6206896552
# V[next_state]:  -2.5744004650479413
# next_state:  (10, 6)
# prob:  0.1379310345
# V[next_state]:  -4.713434418325172
# v:  -4.377391822941959
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (4, 1)
# nxt: {(4, 2): 0.8367346939, (4, 1): 0.0408163265, (4, 7): 0.1224489796}
# next_state:  (4, 2)
# prob:  0.8367346939
# V[next_state]:  -6.897912960210836
# next_state:  (4, 1)
# prob:  0.0408163265
# V[next_state]:  1.4002657048441562
# next_state:  (4, 7)
# prob:  0.1224489796
# V[next_state]:  0
# v:  -6.6574236932440325
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (4, 1)
# nxt: {(3, 2): 0.8367346939, (3, 1): 0.0408163265, (3, 7): 0.1224489796}
# next_state:  (3, 2)
# prob:  0.8367346939
# V[next_state]:  4.564455975787101
# next_state:  (3, 1)
# prob:  0.0408163265
# V[next_state]:  0.8338938163336485
# next_state:  (3, 7)
# prob:  0.1224489796
# V[next_state]:  -0.30875448014641405
# v:  2.7773138001036615
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (4, 1)
# nxt: {(10, 2): 0.8367346939, (10, 1): 0.0408163265, (10, 7): 0.1224489796}
# next_state:  (10, 2)
# prob:  0.8367346939
# V[next_state]:  -9.38663851674729
# next_state:  (10, 1)
# prob:  0.0408163265
# V[next_state]:  -4.820107688806093
# next_state:  (10, 7)
# prob:  0.1224489796
# V[next_state]:  0
# v:  -8.970356543299443
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (4, 2)
# nxt: {(4, 3): 0.5454545455, (4, 2): 0.0909090909, (4, 8): 0.3636363636}
# next_state:  (4, 3)
# prob:  0.5454545455
# V[next_state]:  -10.618676402490085
# next_state:  (4, 2)
# prob:  0.0909090909
# V[next_state]:  -6.897912960210836
# next_state:  (4, 8)
# prob:  0.3636363636
# V[next_state]:  1.2657160032285018
# v:  -6.899239663062685
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (4, 2)
# nxt: {(3, 3): 0.5454545455, (3, 2): 0.0909090909, (3, 8): 0.3636363636}
# next_state:  (3, 3)
# prob:  0.5454545455
# V[next_state]:  -100
# next_state:  (3, 2)
# prob:  0.0909090909
# V[next_state]:  4.564455975787101
# next_state:  (3, 8)
# prob:  0.3636363636
# V[next_state]:  1.9761469896339094
# v:  -53.87778605052318
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (4, 2)
# nxt: {(10, 3): 0.5454545455, (10, 2): 0.0909090909, (10, 8): 0.3636363636}
# next_state:  (10, 3)
# prob:  0.5454545455
# V[next_state]:  -14.85999464466463
# next_state:  (10, 2)
# prob:  0.0909090909
# V[next_state]:  -9.38663851674729
# next_state:  (10, 8)
# prob:  0.3636363636
# V[next_state]:  0
# v:  -9.869194575210376
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (4, 3)
# nxt: {(4, 4): 0.3, (4, 3): 0.1, (4, 9): 0.6}
# next_state:  (4, 4)
# prob:  0.3
# V[next_state]:  -100
# next_state:  (4, 3)
# prob:  0.1
# V[next_state]:  -10.618676402490085
# next_state:  (4, 9)
# prob:  0.6
# V[next_state]:  -11.83182133512927
# v:  -38.77935083691331
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (4, 3)
# nxt: {(3, 4): 0.3, (3, 3): 0.1, (3, 9): 0.6}
# next_state:  (3, 4)
# prob:  0.3
# V[next_state]:  5.1849734647542585
# next_state:  (3, 3)
# prob:  0.1
# V[next_state]:  -100
# next_state:  (3, 9)
# prob:  0.6
# V[next_state]:  11.90711916690897
# v:  -2.287234095824058
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (4, 3)
# nxt: {(10, 4): 0.3, (10, 3): 0.1, (10, 9): 0.6}
# next_state:  (10, 4)
# prob:  0.3
# V[next_state]:  -14.632348805078546
# next_state:  (10, 3)
# prob:  0.1
# V[next_state]:  -14.85999464466463
# next_state:  (10, 9)
# prob:  0.6
# V[next_state]:  -11.752692335127744
# v:  -13.798046311996005
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (4, 5)
# Warning! State not found: assume random behavior.  (4, 6)
# Warning! State not found: assume random behavior.  (4, 5)
# Warning! State not found: assume random behavior.  (4, 11)
# nxt: {(4, 6): 0.5, (4, 5): 0.3333333333333333, (4, 11): 0.5}
# next_state:  (4, 6)
# prob:  0.5
# V[next_state]:  -4.24984294955939
# next_state:  (4, 5)
# prob:  0.3333333333333333
# V[next_state]:  0
# next_state:  (4, 11)
# prob:  0.5
# V[next_state]:  0
# v:  -3.4370055933652317
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (4, 5)
# Warning! State not found: assume random behavior.  (3, 6)
# Warning! State not found: assume random behavior.  (3, 5)
# Warning! State not found: assume random behavior.  (3, 11)
# nxt: {(3, 6): 0.5, (3, 5): 0.3333333333333333, (3, 11): 0.5}
# next_state:  (3, 6)
# prob:  0.5
# V[next_state]:  -4.661484768702828
# next_state:  (3, 5)
# prob:  0.3333333333333333
# V[next_state]:  -3.5272948848788577
# next_state:  (3, 11)
# prob:  0.5
# V[next_state]:  2.7599275507162613
# v:  -3.438611468246707
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (4, 5)
# Warning! State not found: assume random behavior.  (10, 6)
# Warning! State not found: assume random behavior.  (10, 5)
# Warning! State not found: assume random behavior.  (10, 11)
# nxt: {(10, 6): 0.5, (10, 5): 0.3333333333333333, (10, 11): 0.5}
# next_state:  (10, 6)
# prob:  0.5
# V[next_state]:  -4.713434418325172
# next_state:  (10, 5)
# prob:  0.3333333333333333
# V[next_state]:  0
# next_state:  (10, 11)
# prob:  0.5
# V[next_state]:  0
# v:  -3.666483370404294
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (4, 6)
# nxt: {(4, 7): 0.0, (4, 6): 0.4666666667, (4, 0): 0.5333333333}
# next_state:  (4, 7)
# prob:  0.0
# V[next_state]:  0
# next_state:  (4, 6)
# prob:  0.4666666667
# V[next_state]:  -4.24984294955939
# next_state:  (4, 0)
# prob:  0.5333333333
# V[next_state]:  -2.8832709085187034
# v:  -4.4857944824394105
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (4, 6)
# nxt: {(3, 7): 0.0, (3, 6): 0.4666666667, (3, 0): 0.5333333333}
# next_state:  (3, 7)
# prob:  0.0
# V[next_state]:  -0.30875448014641405
# next_state:  (3, 6)
# prob:  0.4666666667
# V[next_state]:  -4.661484768702828
# next_state:  (3, 0)
# prob:  0.5333333333
# V[next_state]:  -2.353213288716441
# v:  -4.396102579659161
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (4, 6)
# nxt: {(10, 7): 0.0, (10, 6): 0.4666666667, (10, 0): 0.5333333333}
# next_state:  (10, 7)
# prob:  0.0
# V[next_state]:  0
# next_state:  (10, 6)
# prob:  0.4666666667
# V[next_state]:  -4.713434418325172
# next_state:  (10, 0)
# prob:  0.5333333333
# V[next_state]:  -2.5744004650479413
# v:  -4.536890146882131
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (4, 7)
# Warning! State not found: assume random behavior.  (4, 8)
# Warning! State not found: assume random behavior.  (4, 7)
# Warning! State not found: assume random behavior.  (4, 1)
# nxt: {(4, 8): 0.5, (4, 7): 0.5, (4, 1): 0.3333333333333333}
# next_state:  (4, 8)
# prob:  0.5
# V[next_state]:  1.2657160032285018
# next_state:  (4, 7)
# prob:  0.5
# V[next_state]:  0
# next_state:  (4, 1)
# prob:  0.3333333333333333
# V[next_state]:  2.7773138001036615
# v:  0.20970964229898326
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (4, 7)
# Warning! State not found: assume random behavior.  (3, 8)
# Warning! State not found: assume random behavior.  (3, 7)
# Warning! State not found: assume random behavior.  (3, 1)
# nxt: {(3, 8): 0.5, (3, 7): 0.5, (3, 1): 0.3333333333333333}
# next_state:  (3, 8)
# prob:  0.5
# V[next_state]:  1.9761469896339094
# next_state:  (3, 7)
# prob:  0.5
# V[next_state]:  -0.30875448014641405
# next_state:  (3, 1)
# prob:  0.3333333333333333
# V[next_state]:  0.8338938163336485
# v:  -0.23278908174691915
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (4, 7)
# Warning! State not found: assume random behavior.  (10, 8)
# Warning! State not found: assume random behavior.  (10, 7)
# Warning! State not found: assume random behavior.  (10, 1)
# nxt: {(10, 8): 0.5, (10, 7): 0.5, (10, 1): 0.3333333333333333}
# next_state:  (10, 8)
# prob:  0.5
# V[next_state]:  0
# next_state:  (10, 7)
# prob:  0.5
# V[next_state]:  0
# next_state:  (10, 1)
# prob:  0.3333333333333333
# V[next_state]:  -4.820107688806093
# v:  -2.923968870639344
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (4, 8)
# nxt: {(4, 9): 0.0, (4, 8): 0.3333333333, (4, 2): 0.6666666667}
# next_state:  (4, 9)
# prob:  0.0
# V[next_state]:  -11.83182133512927
# next_state:  (4, 8)
# prob:  0.3333333333
# V[next_state]:  1.2657160032285018
# next_state:  (4, 2)
# prob:  0.6666666667
# V[next_state]:  -6.899239663062685
# v:  -5.13581189682541
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (4, 8)
# nxt: {(3, 9): 0.0, (3, 8): 0.3333333333, (3, 2): 0.6666666667}
# next_state:  (3, 9)
# prob:  0.0
# V[next_state]:  11.90711916690897
# next_state:  (3, 8)
# prob:  0.3333333333
# V[next_state]:  1.9761469896339094
# next_state:  (3, 2)
# prob:  0.6666666667
# V[next_state]:  4.564455975787101
# v:  2.66466945068409
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (4, 8)
# nxt: {(10, 9): 0.0, (10, 8): 0.3333333333, (10, 2): 0.6666666667}
# next_state:  (10, 9)
# prob:  0.0
# V[next_state]:  -11.752692335127744
# next_state:  (10, 8)
# prob:  0.3333333333
# V[next_state]:  0
# next_state:  (10, 2)
# prob:  0.6666666667
# V[next_state]:  -9.38663851674729
# v:  -7.195181421362969
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (4, 9)
# nxt: {(4, 10): 0.0, (4, 9): 0.3333333333, (4, 3): 0.6666666667}
# next_state:  (4, 10)
# prob:  0.0
# V[next_state]:  1.804827471883263
# next_state:  (4, 9)
# prob:  0.3333333333
# V[next_state]:  -11.83182133512927
# next_state:  (4, 3)
# prob:  0.6666666667
# V[next_state]:  -2.287234095824058
# v:  -6.414075543521566
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (4, 9)
# nxt: {(3, 10): 0.0, (3, 9): 0.3333333333, (3, 3): 0.6666666667}
# next_state:  (3, 10)
# prob:  0.0
# V[next_state]:  7.823251249999999
# next_state:  (3, 9)
# prob:  0.3333333333
# V[next_state]:  11.90711916690897
# next_state:  (3, 3)
# prob:  0.6666666667
# V[next_state]:  -100
# v:  -63.07065067861297
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (4, 9)
# nxt: {(10, 10): 0.0, (10, 9): 0.3333333333, (10, 3): 0.6666666667}
# next_state:  (10, 10)
# prob:  0.0
# V[next_state]:  -100
# next_state:  (10, 9)
# prob:  0.3333333333
# V[next_state]:  -11.752692335127744
# next_state:  (10, 3)
# prob:  0.6666666667
# V[next_state]:  -14.85999464466463
# v:  -14.685984936173352
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (4, 10)
# nxt: {(4, 11): 0.0, (4, 10): 0.75, (4, 4): 0.25}
# next_state:  (4, 11)
# prob:  0.0
# V[next_state]:  0
# next_state:  (4, 10)
# prob:  0.75
# V[next_state]:  1.804827471883263
# next_state:  (4, 4)
# prob:  0.25
# V[next_state]:  -100
# v:  -24.409915602126677
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (4, 10)
# nxt: {(3, 11): 0.0, (3, 10): 0.75, (3, 4): 0.25}
# next_state:  (3, 11)
# prob:  0.0
# V[next_state]:  2.7599275507162613
# next_state:  (3, 10)
# prob:  0.75
# V[next_state]:  7.823251249999999
# next_state:  (3, 4)
# prob:  0.25
# V[next_state]:  5.1849734647542585
# v:  6.092044985651679
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (4, 10)
# nxt: {(10, 11): 0.0, (10, 10): 0.75, (10, 4): 0.25}
# next_state:  (10, 11)
# prob:  0.0
# V[next_state]:  0
# next_state:  (10, 10)
# prob:  0.75
# V[next_state]:  -100
# next_state:  (10, 4)
# prob:  0.25
# V[next_state]:  -14.632348805078546
# v:  -78.87150632925695
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (4, 11)
# Warning! State not found: assume random behavior.  (4, 11)
# Warning! State not found: assume random behavior.  (4, 5)
# nxt: {(4, 11): 0.5, (4, 5): 0.3333333333333333}
# next_state:  (4, 11)
# prob:  0.5
# V[next_state]:  0
# ...
# state:  (5, 4)
# nxt: {(4, 5): 0.25, (4, 4): 0.125, (4, 10): 0.625}
# next_state:  (4, 5)
# prob:  0.25
# V[next_state]:  -3.731308697878104
# next_state:  (4, 4)
# prob:  0.125
# V[next_state]:  -100
# next_state:  (4, 10)
# prob:  0.625
# V[next_state]:  6.082418108349827
# v:  -10.535002698183375
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (5, 4)
# nxt: {(11, 5): 0.25, (11, 4): 0.125, (11, 10): 0.625}
# next_state:  (11, 5)
# prob:  0.25
# V[next_state]:  -38.042270019246516
# next_state:  (11, 4)
# prob:  0.125
# V[next_state]:  -33.079664458868656
# next_state:  (11, 10)
# prob:  0.625
# V[next_state]:  -8.795382605899254
# v:  -19.951213293948673
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (5, 6)
# nxt: {(5, 7): 0.0, (5, 6): 0.85, (5, 0): 0.15}
# next_state:  (5, 7)
# prob:  0.0
# V[next_state]:  1.638921331496221
# next_state:  (5, 6)
# prob:  0.85
# V[next_state]:  -5.126359997476116
# next_state:  (5, 0)
# prob:  0.15
# V[next_state]:  -0.06439712675405229
# v:  -5.323394911199128
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (5, 6)
# nxt: {(4, 7): 0.0, (4, 6): 0.85, (4, 0): 0.15}
# next_state:  (4, 7)
# prob:  0.0
# V[next_state]:  1.6835821661640722
# next_state:  (4, 6)
# prob:  0.85
# V[next_state]:  -4.312350859530428
# next_state:  (4, 0)
# prob:  0.15
# V[next_state]:  -2.414229653693971
# v:  -4.98735635186841
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (5, 6)
# nxt: {(11, 7): 0.0, (11, 6): 0.85, (11, 0): 0.15}
# next_state:  (11, 7)
# prob:  0.0
# V[next_state]:  -1.9398425967268653
# next_state:  (11, 6)
# prob:  0.85
# V[next_state]:  -5.381063612156823
# next_state:  (11, 0)
# prob:  0.15
# V[next_state]:  -3.224908438442619
# v:  -6.007063932738695
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (5, 7)
# Warning! State not found: assume random behavior.  (5, 8)
# Warning! State not found: assume random behavior.  (5, 7)
# Warning! State not found: assume random behavior.  (5, 1)
# nxt: {(5, 8): 0.5, (5, 7): 0.5, (5, 1): 0.3333333333333333}
# next_state:  (5, 8)
# prob:  0.5
# V[next_state]:  -1.2932668674434358
# next_state:  (5, 7)
# prob:  0.5
# V[next_state]:  1.638921331496221
# next_state:  (5, 1)
# prob:  0.3333333333333333
# V[next_state]:  -1.747387365724707
# v:  -1.7388722043163578
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (5, 7)
# Warning! State not found: assume random behavior.  (4, 8)
# Warning! State not found: assume random behavior.  (4, 7)
# Warning! State not found: assume random behavior.  (4, 1)
# nxt: {(4, 8): 0.5, (4, 7): 0.5, (4, 1): 0.3333333333333333}
# next_state:  (4, 8)
# prob:  0.5
# V[next_state]:  3.0320034194681655
# next_state:  (4, 7)
# prob:  0.5
# V[next_state]:  1.6835821661640722
# next_state:  (4, 1)
# prob:  0.3333333333333333
# V[next_state]:  3.155647647328023
# v:  2.0422452551728716
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (5, 7)
# Warning! State not found: assume random behavior.  (11, 8)
# Warning! State not found: assume random behavior.  (11, 7)
# Warning! State not found: assume random behavior.  (11, 1)
# nxt: {(11, 8): 0.5, (11, 7): 0.5, (11, 1): 0.3333333333333333}
# next_state:  (11, 8)
# prob:  0.5
# V[next_state]:  -4.553282305299904
# next_state:  (11, 7)
# prob:  0.5
# V[next_state]:  -1.9398425967268653
# next_state:  (11, 1)
# prob:  0.3333333333333333
# V[next_state]:  -2.723330787948575
# v:  -5.446129319859614
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (5, 8)
# nxt: {(5, 9): 0.0, (5, 8): 0.3333333333, (5, 2): 0.6666666667}
# next_state:  (5, 9)
# prob:  0.0
# V[next_state]:  -3.846447021603722
# next_state:  (5, 8)
# prob:  0.3333333333
# V[next_state]:  -1.2932668674434358
# next_state:  (5, 2)
# prob:  0.6666666667
# V[next_state]:  -1.8666206441909037
# v:  -2.658747691441251
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (5, 8)
# nxt: {(4, 9): 0.0, (4, 8): 0.3333333333, (4, 2): 0.6666666667}
# next_state:  (4, 9)
# prob:  0.0
# V[next_state]:  -3.759438188407846
# next_state:  (4, 8)
# prob:  0.3333333333
# V[next_state]:  3.0320034194681655
# next_state:  (4, 2)
# prob:  0.6666666667
# V[next_state]:  -1.243329293046445
# v:  -0.8200362051272451
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (5, 8)
# nxt: {(11, 9): 0.0, (11, 8): 0.3333333333, (11, 2): 0.6666666667}
# next_state:  (11, 9)
# prob:  0.0
# V[next_state]:  -4.137235536302307
# next_state:  (11, 8)
# prob:  0.3333333333
# V[next_state]:  -4.553282305299904
# next_state:  (11, 2)
# prob:  0.6666666667
# V[next_state]:  -3.8766631806235754
# v:  -5.061180859938199
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (5, 9)
# nxt: {(5, 10): 0.0, (5, 9): 0.3333333333, (5, 3): 0.6666666667}
# next_state:  (5, 10)
# prob:  0.0
# V[next_state]:  -2.661675440408155
# next_state:  (5, 9)
# prob:  0.3333333333
# V[next_state]:  -3.846447021603722
# next_state:  (5, 3)
# prob:  0.6666666667
# V[next_state]:  -8.69140651007513
# v:  -8.005655813938697
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (5, 9)
# nxt: {(4, 10): 0.0, (4, 9): 0.3333333333, (4, 3): 0.6666666667}
# next_state:  (4, 10)
# prob:  0.0
# V[next_state]:  6.082418108349827
# next_state:  (4, 9)
# prob:  0.3333333333
# V[next_state]:  -3.759438188407846
# next_state:  (4, 3)
# prob:  0.6666666667
# V[next_state]:  -1.9392030609437265
# v:  -3.5204886223373806
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (5, 9)
# nxt: {(11, 10): 0.0, (11, 9): 0.3333333333, (11, 3): 0.6666666667}
# next_state:  (11, 10)
# prob:  0.0
# V[next_state]:  -8.795382605899254
# next_state:  (11, 9)
# prob:  0.3333333333
# V[next_state]:  -4.137235536302307
# next_state:  (11, 3)
# prob:  0.6666666667
# V[next_state]:  -2.6913372077195183
# v:  -4.141570284026928
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (5, 10)
# nxt: {(5, 11): 0.0, (5, 10): 0.25, (5, 4): 0.75}
# next_state:  (5, 11)
# prob:  0.0
# V[next_state]:  -2.366441388207096
# next_state:  (5, 10)
# prob:  0.25
# V[next_state]:  -2.661675440408155
# next_state:  (5, 4)
# prob:  0.75
# V[next_state]:  -10.535002698183375
# v:  -9.481004174902175
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (5, 10)
# nxt: {(4, 11): 0.0, (4, 10): 0.25, (4, 4): 0.75}
# next_state:  (4, 11)
# prob:  0.0
# V[next_state]:  -0.8469714983659056
# next_state:  (4, 10)
# prob:  0.25
# V[next_state]:  6.082418108349827
# next_state:  (4, 4)
# prob:  0.75
# V[next_state]:  -100
# v:  -73.74460151818342
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (5, 10)
# nxt: {(11, 11): 0.0, (11, 10): 0.25, (11, 4): 0.75}
# next_state:  (11, 11)
# prob:  0.0
# V[next_state]:  -100
# next_state:  (11, 10)
# prob:  0.25
# V[next_state]:  -8.795382605899254
# next_state:  (11, 4)
# prob:  0.75
# V[next_state]:  -33.079664458868656
# v:  -27.73850805567004
#
# actions:  ('S', 'L', 'D')
# action:  S
# state:  (5, 11)
# Warning! State not found: assume random behavior.  (5, 11)
# Warning! State not found: assume random behavior.  (5, 5)
# nxt: {(5, 11): 0.5, (5, 5): 0.3333333333333333}
# next_state:  (5, 11)
# prob:  0.5
# V[next_state]:  -2.366441388207096
# next_state:  (5, 5)
# prob:  0.3333333333333333
# V[next_state]:  -100
# v:  -35.00472182049584
#
# actions:  ('S', 'L', 'D')
# action:  L
# state:  (5, 11)
# Warning! State not found: assume random behavior.  (4, 11)
# Warning! State not found: assume random behavior.  (4, 5)
# nxt: {(4, 11): 0.5, (4, 5): 0.3333333333333333}
# next_state:  (4, 11)
# prob:  0.5
# V[next_state]:  -0.8469714983659056
# next_state:  (4, 5)
# prob:  0.3333333333333333
# V[next_state]:  -3.731308697878104
# v:  -2.483916095324231
#
# actions:  ('S', 'L', 'D')
# action:  D
# state:  (5, 11)
# Warning! State not found: assume random behavior.  (11, 11)
# Warning! State not found: assume random behavior.  (11, 5)
# nxt: {(11, 11): 0.5, (11, 5): 0.3333333333333333}
# next_state:  (11, 11)
# prob:  0.5
# V[next_state]:  -100
# next_state:  (11, 5)
# prob:  0.3333333333333333
# V[next_state]:  -38.042270019246516
# v:  -62.88728243968468
#
# actions:  ('U', 'S')
# action:  U
# state:  (6, 0)
# Warning! State not found: assume random behavior.  (0, 1)
# Warning! State not found: assume random behavior.  (0, 0)
# Warning! State not found: assume random behavior.  (0, 6)
# nxt: {(0, 1): 0.3333333333333333, (0, 0): 0.3333333333333333, (0, 6): 0.5}
# next_state:  (0, 1)
# prob:  0.3333333333333333
# V[next_state]:  10
# next_state:  (0, 0)
# prob:  0.3333333333333333
# V[next_state]:  -100
# next_state:  (0, 6)
# prob:  0.5
# V[next_state]:  10
# v:  -25.91666666666666
#
# actions:  ('U', 'S')
# action:  S
# state:  (6, 0)
# Warning! State not found: assume random behavior.  (6, 1)
# Warning! State not found: assume random behavior.  (6, 0)
# Warning! State not found: assume random behavior.  (6, 6)
# nxt: {(6, 1): 0.3333333333333333, (6, 0): 0.3333333333333333, (6, 6): 0.5}
# next_state:  (6, 1)
# prob:  0.3333333333333333
# V[next_state]:  11.560333333333332
# next_state:  (6, 0)
# prob:  0.3333333333333333
# V[next_state]:  -25.91666666666666
# next_state:  (6, 6)
# prob:  0.5
# V[next_state]:  -100
# v:  -55.40425666666666
#
# actions:  ('U', 'S')
# action:  U
# state:  (6, 1)
# Warning! State not found: assume random behavior.  (0, 2)
# Warning! State not found: assume random behavior.  (0, 1)
# Warning! State not found: assume random behavior.  (0, 7)
# nxt: {(0, 2): 0.3333333333333333, (0, 1): 0.3333333333333333, (0, 7): 0.5}
# next_state:  (0, 2)
# prob:  0.3333333333333333
# V[next_state]:  10
# next_state:  (0, 1)
# prob:  0.3333333333333333
# V[next_state]:  10
# next_state:  (0, 7)
# prob:  0.5
# V[next_state]:  10
# v:  10.383333333333333
#
# actions:  ('U', 'S')
# action:  S
# state:  (6, 1)
# Warning! State not found: assume random behavior.  (6, 2)
# Warning! State not found: assume random behavior.  (6, 1)
# Warning! State not found: assume random behavior.  (6, 7)
# nxt: {(6, 2): 0.3333333333333333, (6, 1): 0.3333333333333333, (6, 7): 0.5}
# next_state:  (6, 2)
# prob:  0.3333333333333333
# V[next_state]:  11.560333333333332
# next_state:  (6, 1)
# prob:  0.3333333333333333
# V[next_state]:  11.560333333333332
# next_state:  (6, 7)
# prob:  0.5
# V[next_state]:  14.229576666666667
# v:  13.506793783333332
#
# actions:  ('U', 'S')
# action:  U
# state:  (6, 2)
# Warning! State not found: assume random behavior.  (0, 3)
# Warning! State not found: assume random behavior.  (0, 2)
# Warning! State not found: assume random behavior.  (0, 8)
# nxt: {(0, 3): 0.3333333333333333, (0, 2): 0.3333333333333333, (0, 8): 0.5}
# next_state:  (0, 3)
# prob:  0.3333333333333333
# V[next_state]:  10
# next_state:  (0, 2)
# prob:  0.3333333333333333
# V[next_state]:  10
# next_state:  (0, 8)
# prob:  0.5
# V[next_state]:  10
# v:  10.383333333333333
#
# actions:  ('U', 'S')
# action:  S
# state:  (6, 2)
# Warning! State not found: assume random behavior.  (6, 3)
# Warning! State not found: assume random behavior.  (6, 2)
# Warning! State not found: assume random behavior.  (6, 8)
# nxt: {(6, 3): 0.3333333333333333, (6, 2): 0.3333333333333333, (6, 8): 0.5}
# next_state:  (6, 3)
# prob:  0.3333333333333333
# V[next_state]:  11.560333333333332
# next_state:  (6, 2)
# prob:  0.3333333333333333
# V[next_state]:  11.560333333333332
# next_state:  (6, 8)
# prob:  0.5
# V[next_state]:  14.229576666666667
# v:  13.506793783333332
#
# actions:  ('U', 'S')
# action:  U
# state:  (6, 3)
# Warning! State not found: assume random behavior.  (0, 4)
# Warning! State not found: assume random behavior.  (0, 3)
# Warning! State not found: assume random behavior.  (0, 9)
# nxt: {(0, 4): 0.3333333333333333, (0, 3): 0.3333333333333333, (0, 9): 0.5}
# next_state:  (0, 4)
# prob:  0.3333333333333333
# V[next_state]:  10
# next_state:  (0, 3)
# prob:  0.3333333333333333
# V[next_state]:  10
# next_state:  (0, 9)
# prob:  0.5
# V[next_state]:  10
# v:  10.383333333333333
#
# actions:  ('U', 'S')
# action:  S
# state:  (6, 3)
# Warning! State not found: assume random behavior.  (6, 4)
# Warning! State not found: assume random behavior.  (6, 3)
# Warning! State not found: assume random behavior.  (6, 9)
# nxt: {(6, 4): 0.3333333333333333, (6, 3): 0.3333333333333333, (6, 9): 0.5}
# next_state:  (6, 4)
# prob:  0.3333333333333333
# V[next_state]:  12.049833333333334
# next_state:  (6, 3)
# prob:  0.3333333333333333
# V[next_state]:  11.560333333333332
# next_state:  (6, 9)
# prob:  0.5
# V[next_state]:  14.229576666666667
# v:  13.668328783333333
#
# actions:  ('U', 'S')
# action:  U
# state:  (6, 4)
# Warning! State not found: assume random behavior.  (0, 5)
# Warning! State not found: assume random behavior.  (0, 4)
# Warning! State not found: assume random behavior.  (0, 10)
# nxt: {(0, 5): 0.3333333333333333, (0, 4): 0.3333333333333333, (0, 10): 0.5}
# next_state:  (0, 5)
# prob:  0.3333333333333333
# V[next_state]:  10
# next_state:  (0, 4)
# prob:  0.3333333333333333
# V[next_state]:  10
# next_state:  (0, 10)
# prob:  0.5
# V[next_state]:  10
# v:  10.383333333333333
#
# actions:  ('U', 'S')
# action:  S
# state:  (6, 4)
# Warning! State not found: assume random behavior.  (6, 5)
# Warning! State not found: assume random behavior.  (6, 4)
# Warning! State not found: assume random behavior.  (6, 10)
# nxt: {(6, 5): 0.3333333333333333, (6, 4): 0.3333333333333333, (6, 10): 0.5}
# next_state:  (6, 5)
# prob:  0.3333333333333333
# V[next_state]:  11.866666666666667
# next_state:  (6, 4)
# prob:  0.3333333333333333
# V[next_state]:  12.049833333333334
# next_state:  (6, 10)
# prob:  0.5
# V[next_state]:  12.188361666666667
# v:  12.759017358333335
#
# actions:  ('U', 'S')
# action:  U
# state:  (6, 5)
# Warning! State not found: assume random behavior.  (0, 6)
# Warning! State not found: assume random behavior.  (0, 5)
# Warning! State not found: assume random behavior.  (0, 11)
# nxt: {(0, 6): 0.5, (0, 5): 0.3333333333333333, (0, 11): 0.5}
# next_state:  (0, 6)
# prob:  0.5
# V[next_state]:  10
# next_state:  (0, 5)
# prob:  0.3333333333333333
# V[next_state]:  10
# next_state:  (0, 11)
# prob:  0.5
# V[next_state]:  10
# v:  11.866666666666667
#
# actions:  ('U', 'S')
# action:  S
# state:  (6, 5)
# Warning! State not found: assume random behavior.  (6, 6)
# Warning! State not found: assume random behavior.  (6, 5)
# Warning! State not found: assume random behavior.  (6, 11)
# nxt: {(6, 6): 0.5, (6, 5): 0.3333333333333333, (6, 11): 0.5}
# next_state:  (6, 6)
# prob:  0.5
# V[next_state]:  -100
# next_state:  (6, 5)
# prob:  0.3333333333333333
# V[next_state]:  11.866666666666667
# next_state:  (6, 11)
# prob:  0.5
# V[next_state]:  7.416666666666667
# v:  -43.24608333333333
#
# actions:  ('U', 'S')
# action:  U
# state:  (6, 7)
# Warning! State not found: assume random behavior.  (0, 8)
# Warning! State not found: assume random behavior.  (0, 7)
# Warning! State not found: assume random behavior.  (0, 1)
# nxt: {(0, 8): 0.5, (0, 7): 0.5, (0, 1): 0.3333333333333333}
# next_state:  (0, 8)
# prob:  0.5
# V[next_state]:  10
# next_state:  (0, 7)
# prob:  0.5
# V[next_state]:  10
# next_state:  (0, 1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-192-b3bcbfda6ba5> in <module>
#      24                 #Calculate the value
#      25                 for next_state, prob in nxt.items():
# ---> 26                     print("next_state: ", next_state)
#      27                     print("prob: ", prob)
#      28                     print('V[next_state]: ', V[next_state])
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# print the results:
pp = pprint.PrettyPrinter(depth=4)
pp.pprint(iteration)
pp.pprint(V)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-bbb8ace249c1> in <module>
#       1 # print the results:
#       2 pp = pprint.PrettyPrinter(depth=4)
# ----> 3 pp.pprint(iteration)
#       4 pp.pprint(V)
#
# NameError: name 'iteration' is not defined
