# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import seaborn as sns

path = './data/road-game-default-rtdb-export.json'

branchs = ['all-games','complete-games']
childs = ['additional_comments',
          'log',
         'aggressively_value',
         'behavior',
         'birthYear',
         'computer_value',
         'drivinglicense',
         'education',
         'gender',
         'generously_value',
         'redScore',
          'blueScore',
         'steps',
         'win',
         'wisely_value']

# with open(path) as json_file:
#     data = json.load(json_file)
#     num_of_games = len(data[branchs[1]])
#     print("number of %s is %d" % (branchs[1], num_of_games))
#     for game_id in data[branchs[1]].values():
#         for child in childs:
#             print(child, game_id[child])
#         print()

# %%
#load data from the json file
with open(path) as train_file:
    data = json.load(train_file)

# %%
branch = branchs[1]
df = pd.DataFrame.from_dict(data[branch], orient='index')
df.reset_index(level=0, inplace=True)
df
# Out:
#                     index additional_comments aggressively_value  \
# 0    -MZiWIwdnrn8TJ034z2w                                      5
# 1    -MZiWUxZs8BvWglGhc9r                                      2
# 2    -MZiWYgxyToIiCSDQY8S                                      5
# 3    -MZiWYz_z_BcQlpReXf_                                      6
# 4    -MZiWaNZ6n3K3AZDfr-q                                      6
# ..                    ...                 ...                ...
# 130  -M_HdrkTl2-M1kF0d3Va                                      3
# 131  -M_HefdTaP5SV-i0bz7G          fastgame.                   6
# 132  -M_HjGWXEG1wJ2kWwvbt                                      2
# 133  -M_Hl4knjjAplOUpBQgF                                      2
# 134  -M_IvyIWQkuBuIyd_GFq                                      7
#
#                behavior birthYear  blueScore computer_value drivinglicense  \
# 0       carefulBehavior      1961        -10              5          valid
# 1       carefulBehavior      1982        -11              6          valid
# 2    aggressiveBehavior      1953        -94              7          valid
# 3    aggressiveBehavior      1990          6              7          valid
# 4    aggressiveBehavior      1953        -94              6          valid
# ..                  ...       ...        ...            ...            ...
# 130      randomBehavior      1960       -132              5        invalid
# 131      randomBehavior      1990       -108              7          valid
# 132      randomBehavior      1994       -108              5          valid
# 133      randomBehavior      1979        -13              7        invalid
# 134      randomBehavior      1977       -111              6          valid
#
#            education  gender generously_value  \
# 0                 BA    male                6
# 1                 BA  female                4
# 2                 BA  female                2
# 3    Master's degree    male                2
# 4                 BA  female                2
# ..               ...     ...              ...
# 130               BA  female                5
# 131             none    male                2
# 132               BA    male                4
# 133      High School  female                4
# 134               BA    male                6
#
#                                                    log  \
# 0    [None, {'blue': 'from: a6, action: left', 'red...
# 1    [None, {'blue': 'from: a6, action: left', 'red...
# 2    [None, {'blue': 'from: a6, action: left', 'red...
# 3    [None, {'blue': 'from: a6, action: left', 'red...
# 4    [None, {'blue': 'from: a6, action: left', 'red...
# ..                                                 ...
# 130  [None, {'blue': 'from: a6, action: stay', 'red...
# 131  [None, {'blue': 'from: a6, action: left', 'red...
# 132  [None, {'blue': 'from: a6, action: stay', 'red...
# 133  [None, {'blue': 'from: a6, action: stay', 'red...
# 134  [None, {'blue': 'from: a6, action: left', 'red...
#
#      press-the-read-instructions-button  redScore  steps    win wisely_value
# 0                                  True         3      7   True            1
# 1                                  True         2      8   True            4
# 2                                  True      -105      5  False            6
# 3                                  True         1      9   True            2
# 4                                  True      -105      5  False            1
# ..                                  ...       ...    ...    ...          ...
# 130                                True      -112     22   True            5
# 131                                True      -105      5  False            4
# 132                                True      -105      5  False            4
# 133                                True         3      7   True            4
# 134                                True      -107      7  False            7
#
# [135 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['index', 'additional_comments', 'aggressively_value', 'behavior',
#        'birthYear', 'blueScore', 'computer_value', 'drivinglicense',
#        'education', 'gender', 'generously_value', 'log',
#        'press-the-read-instructions-button', 'redScore', 'steps', 'win',
#        'wisely_value'],
#       dtype='object')

# %% [markdown]
# ## Survay results:

# %%
df['additional_comments']
# Out:
# 0
# 1
# 2
# 3
# 4
#           ...
# 130
# 131    fastgame.
# 132
# 133
# 134
# Name: additional_comments, Length: 135, dtype: object

# %%
df[['aggressively_value', 'computer_value', 'generously_value', 'generously_value']] = df[['aggressively_value', 'computer_value', 'generously_value', 'generously_value']].apply(pd.to_numeric)

# %%
df.groupby(['behavior']).mean()
# Out:
#                         aggressively_value  blueScore  computer_value  \
# behavior
# aggressiveBehavior                4.967742 -35.548387        6.096774
# carefulBehavior                   2.964286  -9.428571        5.214286
# randomBehavior                    4.142857 -77.057143        5.742857
# semiAggressiveBehavior            4.390244 -72.000000        6.048780
#
#                         generously_value  press-the-read-instructions-button  \
# behavior
# aggressiveBehavior              2.870968                                 1.0
# carefulBehavior                 5.071429                                 1.0
# randomBehavior                  4.285714                                 1.0
# semiAggressiveBehavior          3.024390                                 1.0
#
#                          redScore     steps       win
# behavior
# aggressiveBehavior     -38.967742  6.387097  0.612903
# carefulBehavior          2.285714  7.714286  1.000000
# randomBehavior         -69.257143  8.971429  0.542857
# semiAggressiveBehavior -74.121951  6.317073  0.292683

# %%
df.groupby('behavior').describe()
# Out:
#                        aggressively_value                                     \
#                                     count      mean       std  min  25%  50%
# behavior
# aggressiveBehavior                   31.0  4.967742  1.852635  1.0  4.0  5.0
# carefulBehavior                      28.0  2.964286  1.621205  1.0  2.0  2.0
# randomBehavior                       35.0  4.142857  1.972500  1.0  2.0  4.0
# semiAggressiveBehavior               41.0  4.390244  1.998475  1.0  3.0  4.0
#
#                                   blueScore             ... redScore       \
#                          75%  max     count       mean  ...      75%  max
# behavior                                                ...
# aggressiveBehavior      6.50  7.0      31.0 -35.548387  ...      2.5  3.0
# carefulBehavior         4.25  6.0      28.0  -9.428571  ...      3.0  5.0
# randomBehavior          6.00  7.0      35.0 -77.057143  ...      0.0  5.0
# semiAggressiveBehavior  6.00  7.0      41.0 -72.000000  ...     -1.0  1.0
#
#                        steps
#                        count      mean       std  min  25%  50%    75%   max
# behavior
# aggressiveBehavior      31.0  6.387097  2.155264  3.0  4.5  7.0   8.00  11.0
# carefulBehavior         28.0  7.714286  2.536506  5.0  7.0  7.0   8.25  18.0
# randomBehavior          35.0  8.971429  5.987662  3.0  5.0  7.0  10.00  35.0
# semiAggressiveBehavior  41.0  6.317073  3.101927  3.0  4.0  5.0   9.00  14.0
#
# [4 rows x 48 columns]

# %%
# Sort the dataframe by target
target_0 = df.loc[df['behavior'] == 'carefulBehavior']
target_1 = df.loc[df['behavior'] == 'semiAggressiveBehavior']
target_2 = df.loc[df['behavior'] == 'aggressiveBehavior']

sns.distplot(target_0[['aggressively_value']], bins = 10)
sns.distplot(target_1[['aggressively_value']], bins = 10)
sns.distplot(target_2[['aggressively_value']], bins = 10)

# %%
target_0[target_0['aggressively_value'] == '3'].count()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# index                                 0
# additional_comments                   0
# aggressively_value                    0
# behavior                              0
# birthYear                             0
# blueScore                             0
# computer_value                        0
# drivinglicense                        0
# education                             0
# gender                                0
# generously_value                      0
# log                                   0
# press-the-read-instructions-button    0
# redScore                              0
# steps                                 0
# win                                   0
# wisely_value                          0
# dtype: int64

# %%
target_0.count()
# Out:
# index                                 28
# additional_comments                   28
# aggressively_value                    28
# behavior                              28
# birthYear                             28
# blueScore                             28
# computer_value                        28
# drivinglicense                        28
# education                             28
# gender                                28
# generously_value                      28
# log                                   28
# press-the-read-instructions-button    28
# redScore                              28
# steps                                 28
# win                                   28
# wisely_value                          28
# dtype: int64

# %%
fig,(ax1) = plt.subplots(ncols=1, figsize=(8,5))
sns.kdeplot(df.aggressively_value[df['behavior'] == 'carefulBehavior'], label='carefulBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'semiAggressiveBehavior'], label='semiAggressiveBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'aggressiveBehavior'], label='aggressiveBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'randomBehavior'], label='aggressiveBehavior', shade=True)
ax1.set_ylabel('Distribution')
ax1.set_xlabel('aggressively_value')
# Out:
# Text(0.5, 0, 'aggressively_value')

# %%
def count_plot_by_behavior(feature):
    sns.countplot(x=df[feature],hue=df['behavior'])
    plt.show()
    
for value in ['aggressively_value', 'computer_value', 'generously_value', 'wisely_value']:
    count_plot_by_behavior(value)

# %%
def pie_count_plot(feature):
    list_gen=df[feature].value_counts().plot.pie(figsize=(6, 6))
    title = 'Distribution by: ', feature
    plt.title(title)
    plt.show()
    
for value in ['birthYear', 'drivinglicense', 'education', 'gender', 'redScore', 'steps', 'win']:
    pie_count_plot(value)

# %%
df.groupby('win')['gender'].value_counts().plot.pie(figsize=(6, 6))
# Out:
# <AxesSubplot:ylabel='gender'>

# %%
df.groupby('gender').describe()
# Out:
#        aggressively_value                                                \
#                     count      mean       std  min  25%  50%   75%  max
# gender
# female               54.0  3.870370  1.833095  1.0  2.0  4.0  5.75  7.0
# male                 81.0  4.358025  2.069472  1.0  2.0  5.0  6.00  7.0
#
#        blueScore             ... redScore      steps                           \
#            count       mean  ...      75%  max count      mean       std  min
# gender                       ...
# female      54.0 -53.814815  ...      2.0  3.0  54.0  7.277778  3.482661  3.0
# male        81.0 -50.728395  ...      3.0  5.0  81.0  7.333333  4.245586  3.0
#
#
#         25%  50%  75%   max
# gender
# female  5.0  7.0  8.0  22.0
# male    5.0  7.0  9.0  35.0
#
# [2 rows x 48 columns]

# %%
df.groupby('behavior').describe()
# Out:
#                        aggressively_value                                     \
#                                     count      mean       std  min  25%  50%
# behavior
# aggressiveBehavior                   31.0  4.967742  1.852635  1.0  4.0  5.0
# carefulBehavior                      28.0  2.964286  1.621205  1.0  2.0  2.0
# randomBehavior                       35.0  4.142857  1.972500  1.0  2.0  4.0
# semiAggressiveBehavior               41.0  4.390244  1.998475  1.0  3.0  4.0
#
#                                   blueScore             ... redScore       \
#                          75%  max     count       mean  ...      75%  max
# behavior                                                ...
# aggressiveBehavior      6.50  7.0      31.0 -35.548387  ...      2.5  3.0
# carefulBehavior         4.25  6.0      28.0  -9.428571  ...      3.0  5.0
# randomBehavior          6.00  7.0      35.0 -77.057143  ...      0.0  5.0
# semiAggressiveBehavior  6.00  7.0      41.0 -72.000000  ...     -1.0  1.0
#
#                        steps
#                        count      mean       std  min  25%  50%    75%   max
# behavior
# aggressiveBehavior      31.0  6.387097  2.155264  3.0  4.5  7.0   8.00  11.0
# carefulBehavior         28.0  7.714286  2.536506  5.0  7.0  7.0   8.25  18.0
# randomBehavior          35.0  8.971429  5.987662  3.0  5.0  7.0  10.00  35.0
# semiAggressiveBehavior  41.0  6.317073  3.101927  3.0  4.0  5.0   9.00  14.0
#
# [4 rows x 48 columns]

# %% [markdown]
# # Statistics of the red agent movements:

# %% [markdown]
# ### Create the statistics table from the log column:

# %%
import flat_table

# %%
statistics_raw = pd.DataFrame.from_dict(data['all-games'], orient='index')
log_red = flat_table.normalize(statistics_raw).iloc[:,-2:]
log_red = log_red.dropna()
log_red['log.red'] = log_red['log.red'] + ' ' + log_red['log.blue']
log_red = log_red.drop('log.blue', axis=1)
log_red['log.red'] = log_red.apply(lambda x: x['log.red'].rsplit(' ', 1)[0], axis = 1)
for substr in ['from: ', ', action:']:
    log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(substr, '', 2), axis = 1)
log_red['log.red'] = log_red['log.red'].str.split().apply(reversed).apply(' '.join)
log_red['value']=1
log_red['action'] = log_red['log.red'].str.split().str[1]
log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(str(x['action'])+' ', '', 2), axis = 1)

log_red = log_red.groupby(['log.red', 'action']).count()
log_red.reset_index(inplace=True)
log_red = log_red.set_index('log.red')
log_red.sort_index()
# Out:
#         action  value
# log.red
# a1 a2    right      5
# a1 a3    right     24
# a1 a4    right     32
# a1 a5     down      3
# a1 a5    right     36
# ...        ...    ...
# b6 a5    right     10
# b6 b1     stay     11
# b6 b1       up      1
# b6 b4       up      1
# b6 b5       up      1
#
# [150 rows x 2 columns]

# %%
len(log_red.index)
log_red[log_red.index == 'a4 a3']
# Out:
#         action  value
# log.red
# a4 a3     down     66
# a4 a3    right     12
# a4 a3     stay      1

# %%
idx = log_red.index.drop_duplicates()
result = pd.DataFrame(index=log_red.index.drop_duplicates(), columns=['right', 'stay', 'up', 'down'])
# result.reset_index(level=0, inplace=True)
for action in ['right', 'stay', 'up', 'down']:
    result[action] = log_red[log_red['action'] == action]['value']
result = result.fillna(0)
result.reset_index(inplace=True)
result.sort_index()
# Out:
#    log.red  right  stay   up  down
# 0    a1 a2    5.0   0.0  0.0   0.0
# 1    a1 a3   24.0   0.0  0.0   0.0
# 2    a1 a4   32.0   0.0  0.0   0.0
# 3    a1 a5   36.0   2.0  0.0   3.0
# 4    a1 b1    0.0  19.0  5.0   0.0
# ..     ...    ...   ...  ...   ...
# 80   b6 a4   10.0   1.0  0.0   0.0
# 81   b6 a5   10.0   0.0  0.0   0.0
# 82   b6 b1    0.0  11.0  1.0   0.0
# 83   b6 b4    0.0   0.0  1.0   0.0
# 84   b6 b5    0.0   0.0  1.0   0.0
#
# [85 rows x 5 columns]

# %% [markdown]
# #### After Laplace's Smoothing:

# %%
for i in range(1,7):
    result.loc[result['log.red'].str.endswith('a'+str(i)), ['stay', 'right', 'down']] += 1
    
for i in range(1,7):
    result.loc[result['log.red'].str.endswith('b'+str(i)), ['stay', 'up']] += 1

result = result.set_index('log.red')
result
# Out:
#          right  stay   up  down
# log.red
# a1 a2      6.0   1.0  0.0   1.0
# a1 a3     25.0   1.0  0.0   1.0
# a1 a4     33.0   1.0  0.0   1.0
# a1 a5     37.0   3.0  0.0   4.0
# a1 b1      0.0  20.0  6.0   0.0
# ...        ...   ...  ...   ...
# b6 a4     11.0   2.0  0.0   1.0
# b6 a5     11.0   1.0  0.0   1.0
# b6 b1      0.0  12.0  2.0   0.0
# b6 b4      0.0   1.0  2.0   0.0
# b6 b5      0.0   1.0  2.0   0.0
#
# [85 rows x 4 columns]

# %% [markdown]
# #### Convert it to Probability table:

# %%
pd.options.display.float_format = "{:,.2f}".format
result_probs = result.div(result.sum(axis=1), axis=0)

# %% [markdown]
# #### Save data on computer for the policy iteration:

# %%
# with open('data/states.txt', 'w') as f:
#     for state in result.index.to_list():
#         f.write("%s\n" % state)

# %%
result_probs.to_json('data/probs.json' , orient='index', indent=4)

# %% [markdown]
# ### Create the statistics table from the statistics branch:

# %%
# red_moves = pd.DataFrame.from_dict(data['statistics'], orient='index')
# # red_moves.reset_index(level=0, inplace=True)
# red_moves = red_moves.fillna(0)
# red_moves.sort_index()

# %% [markdown]
# #### Convert it to Probability table:

# %%
# pd.options.display.float_format = "{:,.2f}".format
# red_moves.div(red_moves.sum(axis=1), axis=0)

# %%
import numpy as np
import pprint

# %%
'''==================================================
Initial set up
=================================================='''

#Hyperparameters
SMALL_ENOUGH = 0.0005
GAMMA = 0.99

#Define all states
all_states=[]
for i in range(12):
    for j in range(12):
            all_states.append((i,j))

#Define rewards for all states
rewards = {}
# for i in all_states:
#     if i == (1,2):
#         rewards[i] = -1
#     elif i == (2,2):
#         rewards[i] = -1
#     elif i == (2,3):
#         rewards[i] = 1
#     else:
#         rewards[i] = 0
for (i,j) in all_states:
    if(i == 0): # blue agent in a1
        rewards[(i,j)] = 10
    elif(i == j): # crushed
        rewards[(i,j)] = -100
    else:
        rewards[(i,j)] = -1

#Dictionnary of possible actions. We have two "end" states (1,2 and 2,2)
actions = {}
#     (0,0):('D', 'R'), 
#     (0,1):('D', 'R', 'L'),    
#     (0,2):('D', 'L', 'R'),
#     (0,3):('D', 'L'),
#     (1,0):('D', 'U', 'R'),
#     (1,1):('D', 'R', 'L', 'U'),
#     (1,3):('D', 'L', 'U'),
#     (2,0):('U', 'R'),
#     (2,1):('U', 'L', 'R'),
#     }
for (i,j) in all_states:
    if i != 0 and i != j: #if s=(i, j) is not an "end" state
        actions[(i,j)] = ("stay", "left", "down") if (i < 6) else ("up", "stay")

#Define an initial policy
Policy={}
for s in actions.keys():
    Policy[s] = np.random.choice(actions[s])

probs = {
    "a1 a2":{
        "right":0.75,
        "stay":0.125,
        "up":0.0,
        "down":0.125
    },
    "a1 a3":{
        "right":0.9259259259,
        "stay":0.037037037,
        "up":0.0,
        "down":0.037037037
    },
    "a1 a4":{
        "right":0.9428571429,
        "stay":0.0285714286,
        "up":0.0,
        "down":0.0285714286
    },
    "a1 a5":{
        "right":0.8409090909,
        "stay":0.0681818182,
        "up":0.0,
        "down":0.0909090909
    },
    "a1 b1":{
        "right":0.0,
        "stay":0.7692307692,
        "up":0.2307692308,
        "down":0.0
    },
    "a1 b2":{
        "right":0.0,
        "stay":0.2,
        "up":0.8,
        "down":0.0
    },
    "a1 b3":{
        "right":0.0,
        "stay":0.625,
        "up":0.375,
        "down":0.0
    },
    "a1 b5":{
        "right":0.0,
        "stay":0.4285714286,
        "up":0.5714285714,
        "down":0.0
    },
    "a2 a1":{
        "right":0.1739130435,
        "stay":0.6086956522,
        "up":0.0,
        "down":0.2173913043
    },
    "a2 a3":{
        "right":0.8333333333,
        "stay":0.0833333333,
        "up":0.0,
        "down":0.0833333333
    },
    "a2 a4":{
        "right":0.6666666667,
        "stay":0.1666666667,
        "up":0.0,
        "down":0.1666666667
    },
    "a2 a5":{
        "right":0.5,
        "stay":0.25,
        "up":0.0,
        "down":0.25
    },
    "a2 b1":{
        "right":0.0,
        "stay":0.5384615385,
        "up":0.4615384615,
        "down":0.0
    },
    "a2 b2":{
        "right":0.0,
        "stay":0.625,
        "up":0.375,
        "down":0.0
    },
    "a2 b3":{
        "right":0.0,
        "stay":0.2083333333,
        "up":0.7916666667,
        "down":0.0
    },
    "a2 b5":{
        "right":0.0,
        "stay":0.4,
        "up":0.6,
        "down":0.0
    },
    "a3 a1":{
        "right":0.2105263158,
        "stay":0.5789473684,
        "up":0.0,
        "down":0.2105263158
    },
    "a3 a2":{
        "right":0.2,
        "stay":0.2,
        "up":0.0,
        "down":0.6
    },
    "a3 a5":{
        "right":0.625,
        "stay":0.25,
        "up":0.0,
        "down":0.125
    },
    "a3 b1":{
        "right":0.0,
        "stay":0.625,
        "up":0.375,
        "down":0.0
    },
    "a3 b2":{
        "right":0.0,
        "stay":0.3846153846,
        "up":0.6153846154,
        "stay":0.2,
        "up":0.8,
        "down":0.0
    },
    "b6 a1":{
        "right":0.375,
        "stay":0.375,
        "up":0.0,
        "down":0.25
    },
    "b6 a2":{
        "right":0.8181818182,
        "stay":0.0909090909,
        "up":0.0,
        "down":0.0909090909
    },
    "b6 a3":{
        "right":0.8333333333,
        "stay":0.0833333333,
        "up":0.0,
        "down":0.0833333333
    },
    "b6 a4":{
        "right":0.7857142857,
        "stay":0.1428571429,
        "up":0.0,
        "down":0.0714285714
    },
    "b6 a5":{
        "right":0.8461538462,
        "stay":0.0769230769,
        "up":0.0,
        "down":0.0769230769
    },
    "b6 b1":{
        "right":0.0,
        "stay":0.8571428571,
        "up":0.1428571429,
        "down":0.0
    },
    "b6 b4":{
        "right":0.0,
        "stay":0.3333333333,
        "up":0.6666666667,
        "down":0.0
    },
    "b6 b5":{
        "right":0.0,
        "stay":0.3333333333,
        "up":0.6666666667,
        "down":0.0
    }
}
    
#Define initial value function 
V={}
# for s in all_states:
#     if s in actions.keys():
#         V[s] = 0
#     if s ==(2,2):
#         V[s]=-1
#     if s == (1,2):
#         V[s]=-1
#     if s == (2,3):
#         V[s]=1
for (i,j) in all_states:
    if s in actions.keys():
        V[(i,j)] = -1
    if(i == 0): # blue agent in a1
        V[(i,j)] = 10
    if(i == j): # crushed
        V[(i,j)] = -100

# %%
# print('all_states: ', all_states)

# %%
# print('rewards: ', rewards)

# %%
# print('actions: ', actions)

# %%
# print('V: ', V)

# %%
probs['a1 a2']
# Out:
# {'right': 0.75, 'stay': 0.125, 'up': 0.0, 'down': 0.125}

# %%
def adapt_state(s):
    # takes (i,j) format state and convert it to "a|b[1-6] a|b[1-6]" format
    i = s[0]
    j = s[1]
    if i < 6:
        blueState = 'a' + str(i+1)
    else:
        blueState = 'b' + str(i-5)
    if j < 6:
        redState = 'a' + str(j+1)
    else:
        redState = 'b' + str(j-5)
    return blueState + ' ' + redState

# %%
print(adapt_state((0,1)))
print(adapt_state((0,7)))
print(adapt_state((6,8)))
print(adapt_state((10,11)))
# Out:
# a1 a2
# a1 b2
# b1 b3
# b5 b6

# %%
def newStateGivenAction(s, a, agent_i):
    # agent_i = 0 for blue and 1 for red
    if a == 'U' or a == "up":
        return s[agent_i]-6
    if a == 'D' or a == "down":
        return s[agent_i]+6
    if a == 'L' or a == "left":
        return s[agent_i]-1
    if a == 'R' or a == "right":
        return s[agent_i]+1
    if a == 'S' or a == "stay":
        return s[agent_i]

# %%
def randomProbForAction(s):
    # if aX return 1/3 else (it is bX) return 1/2
    if s[1] < 6:
        return 1.0/3
    else:
        return 1.0/2

# %%
def nextStateDistibution(s, a):
    # given state s and action a, return distibution of possibles new states by probs
    bluePossition = newStateGivenAction(s, a, 0)
    # red possible state
    nxt = {}
    for r_a in ["right","stay", "up", "down"]:
        redPossition = newStateGivenAction(s, r_a, 1)
        newState = (bluePossition, redPossition)
        if newState in all_states:
            try:
                nxt[newState] = probs[adapt_state(s)][r_a]
#                 nxt[newState] = {probs[adapt_state(s)][r_a], r_a, adapt_state(newState)}
            except KeyError:
                print("Warning! State not found: assume random behavior. ", newState)
                nxt[newState] = randomProbForAction(newState)                                                                       
    return nxt

# %%
pp = pprint.PrettyPrinter(depth=4)
pp.pprint(nextStateDistibution((10, 11), 'U'))
pp.pprint(nextStateDistibution((1, 5), 'S'))
# Out:
# Warning! State not found: assume random behavior.  (4, 11)
# Warning! State not found: assume random behavior.  (4, 5)
# {(4, 5): 0.3333333333333333, (4, 11): 0.5}
# Warning! State not found: assume random behavior.  (1, 6)
# Warning! State not found: assume random behavior.  (1, 5)
# Warning! State not found: assume random behavior.  (1, 11)
# {(1, 5): 0.3333333333333333, (1, 6): 0.5, (1, 11): 0.5}

# %%
'''==================================================
Value Iteration
=================================================='''

iteration = 0
pp = pprint.PrettyPrinter(depth=4)

while True:
    biggest_change = 0
    for s in all_states:            
        if s in Policy:
            
            old_v = V[s]
            new_v = np.NINF
            
            for a in actions[s]:
#                 print("actions: ", actions[s])
#                 print("action: ", a)
#                 print("state: ", s)
                nxt = nextStateDistibution(s, a)
#                 print("nxt:", nxt)
                
                v=0
                #Calculate the value
                for next_state, prob in nxt.items():
#                     print("next_state: ", next_state)
#                     print("prob: ", prob)
#                     print('V[next_state]: ', V[next_state])
                    v += prob * (rewards[s] + GAMMA * V[next_state])
#                 print('v: ', v)
#                 print()
                if v > new_v: #Is this the best action so far? If so, keep it
                    new_v = v
                    Policy[s] = a

       #Save the best of all actions for the state                                
            V[s] = new_v
            biggest_change = max(biggest_change, np.abs(old_v - V[s]))

            
   #See if the loop should stop now         
    if biggest_change < SMALL_ENOUGH:
        break
    iteration += 1
    
    #Print every 100 iterations
    if(iteration % 100 == 0):
        print(iteration, ') ', V[(5, 0)]) # V([a6,a1])
    
    if(iteration % 1000 == 0):
        pp.pprint(iteration)
        pp.pprint(V)
# Out:
# Warning! State not found: assume random behavior.  (1, 6)
# Warning! State not found: assume random behavior.  (1, 5)
# Warning! State not found: assume random behavior.  (1, 11)
# Warning! State not found: assume random behavior.  (0, 6)
# Warning! State not found: assume random behavior.  (0, 5)
# Warning! State not found: assume random behavior.  (0, 11)
# Warning! State not found: assume random behavior.  (7, 6)
# Warning! State not found: assume random behavior.  (7, 5)
# Warning! State not found: assume random behavior.  (7, 11)
# Warning! State not found: assume random behavior.  (1, 10)
# Warning! State not found: assume random behavior.  (1, 9)
# Warning! State not found: assume random behavior.  (1, 3)
# Warning! State not found: assume random behavior.  (0, 10)
# Warning! State not found: assume random behavior.  (0, 9)
# Warning! State not found: assume random behavior.  (0, 3)
# Warning! State not found: assume random behavior.  (7, 10)
# Warning! State not found: assume random behavior.  (7, 9)
# Warning! State not found: assume random behavior.  (7, 3)
# Warning! State not found: assume random behavior.  (1, 11)
# Warning! State not found: assume random behavior.  (1, 5)
# Warning! State not found: assume random behavior.  (0, 11)
# Warning! State not found: assume random behavior.  (0, 5)
# Warning! State not found: assume random behavior.  (7, 11)
# Warning! State not found: assume random behavior.  (7, 5)
# Warning! State not found: assume random behavior.  (2, 4)
# Warning! State not found: assume random behavior.  (2, 3)
# Warning! State not found: assume random behavior.  (2, 9)
# Warning! State not found: assume random behavior.  (1, 4)
# Warning! State not found: assume random behavior.  (1, 3)
# Warning! State not found: assume random behavior.  (1, 9)
# Warning! State not found: assume random behavior.  (8, 4)
# Warning! State not found: assume random behavior.  (8, 3)
# Warning! State not found: assume random behavior.  (8, 9)
# Warning! State not found: assume random behavior.  (2, 6)
# Warning! State not found: assume random behavior.  (2, 5)
# Warning! State not found: assume random behavior.  (2, 11)
# Warning! State not found: assume random behavior.  (1, 6)
# Warning! State not found: assume random behavior.  (1, 5)
# Warning! State not found: assume random behavior.  (1, 11)
# Warning! State not found: assume random behavior.  (8, 6)
# Warning! State not found: assume random behavior.  (8, 5)
# Warning! State not found: assume random behavior.  (8, 11)
# Warning! State not found: assume random behavior.  (2, 10)
# Warning! State not found: assume random behavior.  (2, 9)
# Warning! State not found: assume random behavior.  (2, 3)
# Warning! State not found: assume random behavior.  (1, 10)
# Warning! State not found: assume random behavior.  (1, 9)
# Warning! State not found: assume random behavior.  
# Warning! State not found: assume random behavior.  (4, 11)
# Warning! State not found: assume random behavior.  (10, 6)
# Warning! State not found: assume random behavior.  (10, 5)
# Warning! State not found: assume random behavior.  (10, 11)
# Warning! State not found: assume random behavior.  (4, 8)
# Warning! State not found: assume random behavior.  (4, 7)
# Warning! State not found: assume random behavior.  (4, 1)
# Warning! State not found: assume random behavior.  (10, 8)
# Warning! State not found: assume random behavior.  (10, 7)
# Warning! State not found: assume random behavior.  (10, 1)
# Warning! State not found: assume random behavior.  (4, 9)
# Warning! State not found: assume random behavior.  (4, 8)
# Warning! State not found: assume random behavior.  (4, 2)
# Warning! State not found: assume random behavior.  (10, 9)
# Warning! State not found: assume random behavior.  (10, 8)
# Warning! State not found: assume random behavior.  (10, 2)
# Warning! State not found: assume random behavior.  (4, 11)
# Warning! State not found: assume random behavior.  (4, 5)
# Warning! State not found: assume random behavior.  (10, 11)
# Warning! State not found: assume random behavior.  (10, 5)
# Warning! State not found: assume random behavior.  (5, 6)
# Warning! State not found: assume random behavior.  (5, 5)
# Warning! State not found: assume random behavior.  (5, 11)
# Warning! State not found: assume random behavior.  (11, 6)
# Warning! State not found: assume random behavior.  (11, 5)
# Warning! State not found: assume random behavior.  (11, 11)
# Warning! State not found: assume random behavior.  (5, 8)
# Warning! State not found: assume random behavior.  (5, 7)
# Warning! State not found: assume random behavior.  (5, 1)
# Warning! State not found: assume random behavior.  (11, 8)
# Warning! State not found: assume random behavior.  (11, 7)
# Warning! State not found: assume random behavior.  (11, 1)
# Warning! State not found: assume random behavior.  (5, 9)
# Warning! State not found: assume random behavior.  (5, 8)
# Warning! State not found: assume random behavior.  (5, 2)
# Warning! State not found: assume random behavior.  (11, 9)
# Warning! State not found: assume random behavior.  (11, 8)
# Warning! State not found: assume random behavior.  (11, 2)

# %%
import seaborn as sns
intensity = np.array(list(V.values())).reshape(12,12)
f, ax = plt.subplots(figsize=(20, 10))
sns.heatmap(intensity, vmin=-100, annot=True, linewidths=0.1, cmap="YlGnBu")

# %%
print(adapt_state((6,7)))
# Out:
# b1 b2

# %%
def convertStates():
    P_convert= {}
    V_convert = {}
    for s,v in V.items():
        V_convert[adapt_state(s)] = v
    
#     print()
    for s,p in Policy.items():
        P_convert[adapt_state(s)] = p
    
    pp.pprint(V_convert)
    pp.pprint(P_convert)
    return P_convert

# %%
# print the results:
print("iterations: ", iteration)
policy = convertStates()
# Out:
# iterations:  70
# {'a1 a1': -100,
#  'a1 a2': 10,
#  'a1 a3': 10,
#  'a1 a4': 10,
#  'a1 a5': 10,
#  'a1 a6': 10,
#  'a1 b1': 10,
#  'a1 b2': 10,
#  'a1 b3': 10,
#  'a1 b4': 10,
#  'a1 b5': 10,
#  'a1 b6': 10,
#  'a2 a1': -20.791338792334265,
#  'a2 a2': -100,
#  'a2 a3': 8.89999999911,
#  'a2 a4': 8.90000000089,
#  'a2 a5': 9.404318936877077,
#  'a2 a6': 11.866666666666667,
#  'a2 b1': -22.48763923035535,
#  'a2 b2': 8.9,
#  'a2 b3': 8.9,
#  'a2 b4': 11.899339934574984,
#  'a2 b5': 8.9,
#  'a2 b6': 7.416666666666667,
#  'a3 a1': -12.770354231393453,
#  'a3 a2': -10.324905282898953,
#  'a3 a3': -100,
#  'a3 a4': 13.243438505468854,
#  'a3 a5': 9.771443936877077,
#  'a3 a6': -4.877464752359231,
#  'a3 b1': -13.997605615484812,
#  'a3 b2': -10.369733559161583,
#  'a3 b3': 7.810999999724656,
#  'a3 b4': 13.768068643980758,
#  'a3 b5': 7.9108551495016615,
#  'a3 b6': 6.753916666666667,
#  'a4 a1': -0.6590180991146611,
#  'a4 a2': 2.9002903229002603,
#  'a4 a3': 4.982276629067389,
#  'a4 a4': -100,
#  'a4 a5': 3.2326693790635543,
#  'a4 a6': -3.8538295913169227,
#  'a4 b1': -3.42300624870002,
#  'a4 b2': 1.8449306696968046,
#  'a4 b3': 3.107593115455087,
#  'a4 b4': 13.768068651245187,
#  'a4 b5': 7.936936337707642,
#  'a4 b6': 0.9002920483881205,
#  'a5 a1': -1.1793032875629494,
#  'a5 a2': 3.4680014570007387,
#  'a5 a3': -0.8333243033305098,
#  'a5 a4': -1.7616644155784842,
#  'a5 a5': -100,
#  'a5 a6': -3.853840627622308,
#  'a5 b1': -2.9293904433231623,
#  'a5 b2': 2.874143074467225,
#  'a5 b3': 3.3138083033465198,
#  'a5 b4': -3.2279058749347005,
#  'a5 b5': 5.693260902066153,
#  'a5 b6': -1.659452534515798,
#  'a6 a1': 0.57855290451873,
#  'a6 a2': -1.296410713098901,
#  'a6 a3': -1.6471985019629987,
#  'a6 a4': -9.298023443780583,
#  'a6 a5': -10.80612037218309,
#  'a6 a6': -100,
#  'a6 b1': -3.6402085962595394,
#  'a6 b2': 2.874143079494714,
#  'a6 b3': -0.4564373002306402,
#  'a6 b4': -3.2279074529618645,
#  'a6 b5': -11.991419368897326,
#  'a6 b6': -2.9265297450340144,
#  'b1 a1': -8.275913813029149,
#  'b1 a2': 136.7335135352106,
#  'b1 a3': 58.057565133760306,
#  'b1 a4': 26.506060272592634,
#  'b1 a5': 14.546754691940585,
#  'b1 a6': 11.866666666666667,
#  'b1 b1': -100,
#  'b1 b2': 148.72625540654866,
#  'b1 b3': 63.26920620965213,
#  'b1 b4': 28.535957226490595,
#  'b1 b5': 14.13533803184178,
#  'b1 b6': 7.416666666666667,
#  'b2 a1': -20.732089438133315,
#  'b2 a2': -13.75120000052866,
#  'b2 a3': 8.662019179209814,
#  'b2 a4': 8.802974507781737,
#  'b2 a5': 8.670068936877076,
#  'b2 a6': -4.877464752359231,
#  'b2 b1': -22.909218115162357,
#  'b2 b2': -100,
#  'b2 b3': 14.683774779050538,
#  'b2 b4': 11.899339934574984,
#  'b2 b5': 7.977425249152793,
#  'b2 b6': 6.753916666666667,
#  'b3 a1': -12.310899138710624,
#  'b3 a2': -8.999257238725361,
#  'b3 a3': -7.47051558914119,
#  'b3 a4': 9.906051679111894,
#  'b3 a5': 4.12713314717149,
#  'b3 a6': -6.528522731276862,
#  'b3 b1': -13.619691719521072,
#  'b3 b2': -10.208569440489896,
#  'b3 b3': -100,
#  'b3 b4': 13.768068651245187,
#  'b3 b5': 7.358027426409377,
#  'b3 b6': 0.9002920483881205,
#  'b4 a1': -1.3899722280827616,
#  'b4 a2': 2.899026074200248,
#  'b4 a3': -6.511785047577538,
#  'b4 a4': -6.5105685711131045,
#  'b4 a5': -3.0969416944870707,
#  'b4 a6': -3.853840627622308,
#  'b4 b1': -3.476660096941063,
#  'b4 b2': 2.734194348606713,
#  'b4 b3': 3.550349252578628,
#  'b4 b4': -100,
#  'b4 b5': 4.107875612875042,
#  'b4 b6': -1.659452534515798,
#  'b5 a1': -0.8851456004373621,
#  'b5 a2': -0.23925001894766607,
#  'b5 a3': -1.981510947722648,
#  'b5 a4': -13.525733207393218,
#  'b5 a5': -15.712650332684849,
#  'b5 a6': -4.87657801447898,
#  'b5 b1': -3.3225677775468134,
#  'b5 b2': 2.874143079494714,
#  'b5 b3': -1.5658086513685507,
#  'b5 b4': -3.03436358037523,
#  'b5 b5': -100,
#  'b5 b6': -2.9265297450340144,
#  'b6 a1': -2.1674563390096244,
#  'b6 a2': -2.1922348736582546,
#  'b6 a3': -8.8444192943237,
#  'b6 a4': -10.948883260878343,
#  'b6 a5': -36.15791739466998,
#  'b6 a6': -37.58386881227364,
#  'b6 b1': -4.007153097865022,
#  'b6 b2': -0.5643845079202541,
#  'b6 b3': -3.700659491811413,
#  'b6 b4': -8.201904932572912,
#  'b6 b5': -12.08920783733784,
#  'b6 b6': -100}
# {'a2 a1': 'down',
#  'a2 a3': 'left',
#  'a2 a4': 'left',
#  'a2 a5': 'stay',
#  'a2 a6': 'left',
#  'a2 b1': 'stay',
#  'a2 b2': 'left',
#  'a2 b3': 'left',
#  'a2 b4': 'stay',
#  'a2 b5': 'left',
#  'a2 b6': 'left',
#  'a3 a1': 'down',
#  'a3 a2': 'down',
#  'a3 a4': 'stay',
#  'a3 a5': 'left',
#  'a3 a6': 'left',
#  'a3 b1': 'down',
#  'a3 b2': 'down',
#  'a3 b3': 'left',
#  'a3 b4': 'stay',
#  'a3 b5': 'left',
#  'a3 b6': 'left',
#  'a4 a1': 'stay',
#  'a4 a2': 'stay',
#  'a4 a3': 'left',
#  'a4 a5': 'left',
#  'a4 a6': 'stay',
#  'a4 b1': 'stay',
#  'a4 b2': 'down',
#  'a4 b3': 'stay',
#  'a4 b4': 'left',
#  'a4 b5': 'left',
#  'a4 b6': 'left',
#  'a5 a1': 'left',
#  'a5 a2': 'left',
#  'a5 a3': 'stay',
#  'a5 a4': 'left',
#  'a5 a6': 'left',
#  'a5 b1': 'left',
#  'a5 b2': 'stay',
#  'a5 b3': 'left',
#  'a5 b4': 'stay',
#  'a5 b5': 'left',
#  'a5 b6': 'left',
#  'a6 a1': 'left',
#  'a6 a2': 'left',
#  'a6 a3': 'left',
#  'a6 a4': 'stay',
#  'a6 a5': 'left',
#  'a6 b1': 'left',
#  'a6 b2': 'left',
#  'a6 b3': 'left',
#  'a6 b4': 'left',
#  'a6 b5': 'stay',
#  'a6 b6': 'left',
#  'b1 a1': 'stay',
#  'b1 a2': 'stay',
#  'b1 a3': 'stay',
#  'b1 a4': 'stay',
#  'b1 a5': 'stay',
#  'b1 a6': 'up',
#  'b1 b2': 'stay',
#  'b1 b3': 'stay',
#  'b1 b4': 'stay',
#  'b1 b5': 'stay',
#  'b1 b6': 'up',
#  'b2 a1': 'stay',
#  'b2 a2': 'up',
#  'b2 a3': 'stay',
#  'b2 a4': 'up',
#  'b2 a5': 'up',
#  'b2 a6': 'up',
#  'b2 b1': 'up',
#  'b2 b3': 'stay',
#  'b2 b4': 'up',
#  'b2 b5': 'up',
#  'b2 b6': 'up',
#  'b3 a1': 'stay',
#  'b3 a2': 'stay',
#  'b3 a3': 'up',
#  'b3 a4': 'up',
#  'b3 a5': 'up',
#  'b3 a6': 'up',
#  'b3 b1': 'stay',
#  'b3 b2': 'stay',
#  'b3 b4': 'up',
#  'b3 b5': 'up',
#  'b3 b6': 'up',
#  'b4 a1': 'up',
#  'b4 a2': 'up',
#  'b4 a3': 'stay',
#  'b4 a4': 'up',
#  'b4 a5': 'up',
#  'b4 a6': 'up',
#  'b4 b1': 'up',
#  'b4 b2': 'stay',
#  'b4 b3': 'up',
#  'b4 b5': 'up',
#  'b4 b6': 'up',
#  'b5 a1': 'up',
#  'b5 a2': 'up',
#  'b5 a3': 'up',
#  'b5 a4': 'stay',
#  'b5 a5': 'up',
#  'b5 a6': 'up',
#  'b5 b1': 'up',
#  'b5 b2': 'up',
#  'b5 b3': 'up',
#  'b5 b4': 'up',
#  'b5 b6': 'up',
#  'b6 a1': 'up',
#  'b6 a2': 'up',
#  'b6 a3': 'up',
#  'b6 a4': 'up',
#  'b6 a5': 'stay',
#  'b6 a6': 'up',
#  'b6 b1': 'up',
#  'b6 b2': 'up',
#  'b6 b3': 'up',
#  'b6 b4': 'up',
#  'b6 b5': 'up'}

# %% [markdown]
# # push to firebase:

# %%
import pyrebase

firebaseConfig = {
    "apiKey": "AIzaSyDROtt5r3t5VL_iPabcgVgsWmUZHMw7Pv8",
    "authDomain": "road-game.firebaseapp.com",
    "databaseURL": "https://road-game-default-rtdb.firebaseio.com",
    "projectId": "road-game",
    "storageBucket": "road-game.appspot.com",
    "messagingSenderId": "14363967441",
    "appId": "1:14363967441:web:9efd1c7c3db93ab12ceaf0"
  }

firebase=pyrebase.initialize_app(firebaseConfig)

db=firebase.database()

# %%
db.child("Value Iteration behavior").set(policy)
# Out:
# {'a2 a1': 'down',
#  'a2 a3': 'left',
#  'a2 a4': 'left',
#  'a2 a5': 'stay',
#  'a2 a6': 'left',
#  'a2 b1': 'stay',
#  'a2 b2': 'left',
#  'a2 b3': 'left',
#  'a2 b4': 'stay',
#  'a2 b5': 'left',
#  'a2 b6': 'left',
#  'a3 a1': 'down',
#  'a3 a2': 'down',
#  'a3 a4': 'stay',
#  'a3 a5': 'left',
#  'a3 a6': 'left',
#  'a3 b1': 'down',
#  'a3 b2': 'down',
#  'a3 b3': 'left',
#  'a3 b4': 'stay',
#  'a3 b5': 'left',
#  'a3 b6': 'left',
#  'a4 a1': 'stay',
#  'a4 a2': 'stay',
#  'a4 a3': 'left',
#  'a4 a5': 'left',
#  'a4 a6': 'stay',
#  'a4 b1': 'stay',
#  'a4 b2': 'down',
#  'a4 b3': 'stay',
#  'a4 b4': 'left',
#  'a4 b5': 'left',
#  'a4 b6': 'left',
#  'a5 a1': 'left',
#  'a5 a2': 'left',
#  'a5 a3': 'stay',
#  'a5 a4': 'left',
#  'a5 a6': 'left',
#  'a5 b1': 'left',
#  'a5 b2': 'stay',
#  'a5 b3': 'left',
#  'a5 b4': 'stay',
#  'a5 b5': 'left',
#  'a5 b6': 'left',
#  'a6 a1': 'left',
#  'a6 a2': 'left',
#  'a6 a3': 'left',
#  'a6 a4': 'stay',
#  'a6 a5': 'left',
#  'a6 b1': 'left',
#  'a6 b2': 'left',
#  'a6 b3': 'left',
#  'a6 b4': 'left',
#  'a6 b5': 'stay',
#  'a6 b6': 'left',
#  'b1 a1': 'stay',
#  'b1 a2': 'stay',
#  'b1 a3': 'stay',
#  'b1 a4': 'stay',
#  'b1 a5': 'stay',
#  'b1 a6': 'up',
#  'b1 b2': 'stay',
#  'b1 b3': 'stay',
#  'b1 b4': 'stay',
#  'b1 b5': 'stay',
#  'b1 b6': 'up',
#  'b2 a1': 'stay',
#  'b2 a2': 'up',
#  'b2 a3': 'stay',
#  'b2 a4': 'up',
#  'b2 a5': 'up',
#  'b2 a6': 'up',
#  'b2 b1': 'up',
#  'b2 b3': 'stay',
#  'b2 b4': 'up',
#  'b2 b5': 'up',
#  'b2 b6': 'up',
#  'b3 a1': 'stay',
#  'b3 a2': 'stay',
#  'b3 a3': 'up',
#  'b3 a4': 'up',
#  'b3 a5': 'up',
#  'b3 a6': 'up',
#  'b3 b1': 'stay',
#  'b3 b2': 'stay',
#  'b3 b4': 'up',
#  'b3 b5': 'up',
#  'b3 b6': 'up',
#  'b4 a1': 'up',
#  'b4 a2': 'up',
#  'b4 a3': 'stay',
#  'b4 a4': 'up',
#  'b4 a5': 'up',
#  'b4 a6': 'up',
#  'b4 b1': 'up',
#  'b4 b2': 'stay',
#  'b4 b3': 'up',
#  'b4 b5': 'up',
#  'b4 b6': 'up',
#  'b5 a1': 'up',
#  'b5 a2': 'up',
#  'b5 a3': 'up',
#  'b5 a4': 'stay',
#  'b5 a5': 'up',
#  'b5 a6': 'up',
#  'b5 b1': 'up',
#  'b5 b2': 'up',
#  'b5 b3': 'up',
#  'b5 b4': 'up',
#  'b5 b6': 'up',
#  'b6 a1': 'up',
#  'b6 a2': 'up',
#  'b6 a3': 'up',
#  'b6 a4': 'up',
#  'b6 a5': 'stay',
#  'b6 a6': 'up',
#  'b6 b1': 'up',
#  'b6 b2': 'up',
#  'b6 b3': 'up',
#  'b6 b4': 'up',
#  'b6 b5': 'up'}
