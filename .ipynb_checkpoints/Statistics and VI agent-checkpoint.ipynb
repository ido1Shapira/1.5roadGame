# %%
import json
import glob
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import seaborn as sns
import numpy as np
import pprint
import flat_table

pp = pprint.PrettyPrinter(depth=4)


path = './data/road-game-default-rtdb-export.json'

branchs = ['all-games','complete-games']

# %%
#load data from the json file
with open(path) as train_file:
    data = json.load(train_file)

# %%
branch = branchs[0]
df = pd.DataFrame.from_dict(data[branch], orient='index')
df.reset_index(level=0, inplace=True)
df.dropna(how='all')
# Out:
#                     index additional_comments  aggressively_value  \
# 0    -MZiWIwdnrn8TJ034z2w                                     5.0
# 1    -MZiWUxZs8BvWglGhc9r                                     2.0
# 2    -MZiWYgxyToIiCSDQY8S                                     5.0
# 3    -MZiWYz_z_BcQlpReXf_                                     6.0
# 4    -MZiWaNZ6n3K3AZDfr-q                                     6.0
# ..                    ...                 ...                 ...
# 667  -MbcRp52SnKf2_aDNt2a                 NaN                 NaN
# 668  -MbcURCQaLlJFHGxAvyW                 NaN                 NaN
# 669  -MbcbjkKh8M10JRrqfwb                 NaN                 NaN
# 670  -MbcfQpUktm_lYEmxpz2                 NaN                 NaN
# 671  -Mbcz6inzp9NEdJCbK17                 NaN                 NaN
#
#                            behavior birthYear  blueScore  computer_value  \
# 0                   carefulBehavior      1961       20.0             5.0
# 1                   carefulBehavior      1982       19.0             6.0
# 2                aggressiveBehavior      1953     -105.0             7.0
# 3                aggressiveBehavior      1990       25.0             7.0
# 4                aggressiveBehavior      1953     -105.0             6.0
# ..                              ...       ...        ...             ...
# 667  valueIterationBasedBehavior_v2       NaN        NaN             NaN
# 668  valueIterationBasedBehavior_v2       NaN        NaN             NaN
# 669  valueIterationBasedBehavior_v2       NaN        NaN             NaN
# 670  valueIterationBasedBehavior_v2       NaN        NaN             NaN
# 671  valueIterationBasedBehavior_v2       NaN        NaN             NaN
#
#     drivinglicense        education  gender  generously_value  \
# 0            valid               BA    male               6.0
# 1            valid               BA  female               4.0
# 2            valid               BA  female               2.0
# 3            valid  Master's degree    male               2.0
# 4            valid               BA  female               2.0
# ..             ...              ...     ...               ...
# 667            NaN              NaN     NaN               NaN
# 668            NaN              NaN     NaN               NaN
# 669            NaN              NaN     NaN               NaN
# 670            NaN              NaN     NaN               NaN
# 671            NaN              NaN     NaN               NaN
#
#                                                    log  \
# 0    [None, {'blue': 'from: a6, action: left', 'red...
# 1    [None, {'blue': 'from: a6, action: left', 'red...
# 2    [None, {'blue': 'from: a6, action: left', 'red...
# 3    [None, {'blue': 'from: a6, action: left', 'red...
# 4    [None, {'blue': 'from: a6, action: left', 'red...
# ..                                                 ...
# 667                                                NaN
# 668                                                NaN
# 669                                                NaN
# 670                                                NaN
# 671                                                NaN
#
#     press-the-read-instructions-button  redScore  steps    win  wisely_value  \
# 0                                 True      23.0    7.0   True           1.0
# 1                                 True      22.0    8.0   True           4.0
# 2                                 True    -105.0    5.0  False           6.0
# 3                                 True      21.0    9.0   True           2.0
# 4                                 True    -105.0    5.0  False           1.0
# ..                                 ...       ...    ...    ...           ...
# 667                                NaN       NaN    NaN    NaN           NaN
# 668                                NaN       NaN    NaN    NaN           NaN
# 669                                NaN       NaN    NaN    NaN           NaN
# 670                                NaN       NaN    NaN    NaN           NaN
# 671                                NaN       NaN    NaN    NaN           NaN
#
#      predictable_value answer-the-quiz
# 0                  NaN             NaN
# 1                  NaN             NaN
# 2                  NaN             NaN
# 3                  NaN             NaN
# 4                  NaN             NaN
# ..                 ...             ...
# 667                NaN             NaN
# 668                NaN             NaN
# 669                NaN             NaN
# 670                NaN             NaN
# 671                NaN             NaN
#
# [672 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['index', 'additional_comments', 'aggressively_value', 'behavior',
#        'birthYear', 'blueScore', 'computer_value', 'drivinglicense',
#        'education', 'gender', 'generously_value', 'log',
#        'press-the-read-instructions-button', 'redScore', 'steps', 'win',
#        'wisely_value', 'predictable_value', 'answer-the-quiz'],
#       dtype='object')

# %%
# df = df[df['answer-the-quiz'].notnull()]

# %% [markdown]
# number of people that start to play:

# %%
df['press-the-read-instructions-button'].count()
# Out:
# 553

# %% [markdown]
# ## Survay results:

# %% [markdown]
# upload Id workers and search for duplicate workers

# %%
path = './data/workers' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    fromOne = pd.read_csv(filename, index_col=None, header=0)
    fromOne['filename'] = filename
    li.append(fromOne)

workers = pd.concat(li, axis=0, ignore_index=True)

# %%
df['WorkerId'] = workers['WorkerId']

# %%
pd.concat(g for _, g in df.groupby('WorkerId') if len(g) > 1).groupby('WorkerId')['index'].count()
# Out:
# WorkerId
# A17AF42SNQNH9C    5
# A1AZLJ3R5FQ9B7    2
# A1BQI9JKLVCIL0    2
# A1K1E4KCVW1HOZ    3
# A1KZ21TSAYUHO4    2
# A1OW27AZS122X2    2
# A1QKW8E5J7NAF2    2
# A209KMZQTLEZZC    2
# A244IQQR0CTZ3I    2
# A2DCKE7398C0XV    2
# A2I6ZALE49CVSC    2
# A2IFXO71MXB9GK    2
# A2OU4N4VBIE91I    2
# A2YR29YNFLZSUG    2
# A2ZRL1ZWWXJ0L7    3
# A30YR5TPOKQYXJ    2
# A33XAJW8WGY3O9    2
# A34CPKFZXBX1PO    2
# A36UD0YBRIWTVL    2
# A37XBH865833FE    2
# A39ICPRR4OS3OX    2
# A3ADHMAWDD7M6V    2
# A3GWRDHAURRNK6    2
# A3H073G4EPBYOM    2
# A3H3BTRV6I3LYU    2
# A3KK1BNF5H0N1Z    3
# A3L7TVDAMZM0FG    2
# A3P35II1RN3FYV    2
# A3UWHJTAUTF6TO    2
# A6JUD4NCQCDWG     2
# ACXP8KHFX06KR     3
# AD1ILDUXZHASF     3
# ASNMT3I94HZ44     2
# ATJ92FYQX176Z     4
# Name: index, dtype: int64

# %% [markdown]
# We will keep the first one of any 'WorkerId' instance to keep samples unique

# %%
df = df.drop_duplicates(subset=['WorkerId'])

# %% [markdown]
# number of people that answer the survay:

# %%
len(df)
# Out:
# 403

# %%
df['additional_comments'][df['additional_comments'].notna()][df['additional_comments'] != ""]
# Out:
# 8                                    Thankyouandstaysafe
# 11     Icouldn'tmovetotherightusingtherightarrowasins...
# 12                                                  none
# 24                                           GodBlessYou
# 34                                                  none
#                              ...
# 380                                                 none
# 402                                                 cool
# 405                                                 None
# 425                                                 Good
# 428                                                  N/A
# Name: additional_comments, Length: 65, dtype: object

# %%
df.loc[:, ['aggressively_value', 'computer_value', 'generously_value', 'wisely_value', 'predictable_value']] = df.loc[:, ['aggressively_value', 'computer_value', 'generously_value', 'wisely_value', 'predictable_value']].apply(pd.to_numeric)

# %%
df.groupby('behavior').mean()
# Out:
#                                 aggressively_value  blueScore  computer_value  \
# behavior
# aggressiveBehavior                        5.084746 -15.933333        5.932203
# carefulBehavior                           2.964286  19.607143        5.214286
# randomBehavior                            3.469697 -77.515152        5.681818
# semiAggressiveBehavior                    4.610390 -59.714286        5.792208
# semiCarefulBehavior                       4.012987  -2.311688        5.766234
# valueIterationBasedBehavior_v2            4.915789  -3.873684        6.094737
#
#                                 generously_value   redScore      steps  \
# behavior
# aggressiveBehavior                      3.305085 -18.100000   6.932203
# carefulBehavior                         5.071429  22.285714   7.714286
# randomBehavior                          4.030303 -76.742424  10.227273
# semiAggressiveBehavior                  3.194805 -60.896104   6.480519
# semiCarefulBehavior                     4.220779  -0.506494  11.935065
# valueIterationBasedBehavior_v2          3.505263  -5.905263   8.589474
#
#                                 wisely_value  predictable_value
# behavior
# aggressiveBehavior                  4.525424           5.068966
# carefulBehavior                     4.035714                NaN
# randomBehavior                      3.696970           3.441176
# semiAggressiveBehavior              4.402597           4.675676
# semiCarefulBehavior                 5.046512           4.311688
# valueIterationBasedBehavior_v2      4.726316           4.803279

# %%
df.groupby('behavior')['blueScore', 'redScore'].describe()
# Out:
# <ipython-input-15-c4d30ac448c8>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('behavior')['blueScore', 'redScore'].describe()
#                                blueScore                                       \
#                                    count       mean        std    min     25%
# behavior
# aggressiveBehavior                  60.0 -15.933333  60.643964 -108.0 -103.00
# carefulBehavior                     28.0  19.607143   2.042861   12.0   19.75
# randomBehavior                      66.0 -77.515152  57.053886 -152.0 -109.75
# semiAggressiveBehavior              77.0 -59.714286  61.973861 -114.0 -105.00
# semiCarefulBehavior                 77.0  -2.311688  47.584899 -137.0   13.00
# valueIterationBasedBehavior_v2      95.0  -3.873684  53.047598 -125.0   13.00
#
#                                                   redScore             \
#                                   50%   75%   max    count       mean
# behavior
# aggressiveBehavior               25.0  25.0  25.0     60.0 -18.100000
# carefulBehavior                  20.0  20.0  22.0     28.0  22.285714
# randomBehavior                 -107.0 -22.0  22.0     66.0 -76.742424
# semiAggressiveBehavior         -104.0  24.0  25.0     77.0 -60.896104
# semiCarefulBehavior              17.0  19.0  22.0     77.0  -0.506494
# valueIterationBasedBehavior_v2   25.0  25.0  25.0     95.0  -5.905263
#
#
#                                       std    min     25%    50%   75%   max
# behavior
# aggressiveBehavior              59.179904 -108.0 -103.00   22.0  23.0  23.0
# carefulBehavior                  2.536506   12.0   21.75   23.0  23.0  25.0
# randomBehavior                  58.368408 -152.0 -109.75 -107.0 -20.5  25.0
# semiAggressiveBehavior          60.358487 -114.0 -105.00 -104.0  21.0  22.0
# semiCarefulBehavior             48.402812 -137.0   14.00   19.0  22.0  25.0
# valueIterationBasedBehavior_v2  51.978939 -125.0   13.00   21.0  23.0  25.0

# %%
fig,(ax1) = plt.subplots(ncols=1, figsize=(8,5))
sns.kdeplot(df.aggressively_value[df['behavior'] == 'carefulBehavior'], label='carefulBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'semiAggressiveBehavior'], label='semiAggressiveBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'aggressiveBehavior'], label='aggressiveBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'randomBehavior'], label='randomBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'valueIterationBasedBehavior_v2'], label='valueIterationBasedBehavior_v2', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'semiCarefulBehavior'], label='semiCarefulBehavior', shade=True)
ax1.set_ylabel('Distribution')
ax1.set_xlabel('aggressively_value')
# Out:
# Text(0.5, 0, 'aggressively_value')

# %%
df_temp = df[df.behavior != 'carefulBehavior']

def count_plot_by_behavior(feature):
    sns.countplot(x=df_temp[feature],hue=df_temp['behavior'])
    plt.show()
    
for value in ['aggressively_value', 'computer_value', 'generously_value', 'wisely_value', 'predictable_value']:
    count_plot_by_behavior(value)

# %%
def pie_count_plot(feature):
    list_gen=df[feature].value_counts().plot.pie(figsize=(6, 6))
    title = 'Distribution by: ', feature
    plt.title(title)
    plt.show()
    
for value in ['birthYear', 'drivinglicense', 'education', 'gender', 'redScore', 'steps', 'win']:
    pie_count_plot(value)

# %%
df.groupby('win')['gender'].value_counts().plot.pie(figsize=(6, 6))
# Out:
# <AxesSubplot:ylabel='gender'>

# %%
df.groupby('gender').mean()
# Out:
#         aggressively_value  blueScore  computer_value  generously_value  \
# gender
# female            4.314103 -26.275641        5.839744          3.615385
# male              4.349593 -26.264228        5.808943          3.833333
#
#          redScore     steps  wisely_value  predictable_value
# gender
# female -27.051282  8.737179      4.500000           4.552083
# male   -26.378049  8.825203      4.379464           4.401408

# %% [markdown]
# # Statistics of the red agent movements:

# %% [markdown]
# ### Create the statistics table from the log column:

# %%
statistics_raw = pd.DataFrame.from_dict(data[branch], orient='index')
log_red = flat_table.normalize(statistics_raw).iloc[:,-2:]
log_red = log_red.dropna()
log_red['log.red'] = log_red['log.red'] + ' ' + log_red['log.blue']
log_red = log_red.drop('log.blue', axis=1)
log_red['log.red'] = log_red.apply(lambda x: x['log.red'].rsplit(' ', 1)[0], axis = 1)
for substr in ['from: ', ', action:']:
    log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(substr, '', 2), axis = 1)
log_red['log.red'] = log_red['log.red'].str.split().apply(reversed).apply(' '.join)
log_red['value']=1
log_red['action'] = log_red['log.red'].str.split().str[1]
log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(str(x['action'])+' ', '', 2), axis = 1)

log_red = log_red.groupby(['log.red', 'action']).count()
log_red.reset_index(inplace=True)
log_red = log_red.set_index('log.red')

# s_r = df['log'].apply(pd.Series).iloc[:,1:]
# s_r.columns = s_r.columns.astype(str)
# s_r = flat_table.normalize(s_r).drop('index', axis=1)
# log_red = pd.concat([s_r.melt(id_vars=[str(i)+'.blue' for i in range(1,int(len(s_r.columns)/2))],var_name='red', value_name="log.red").iloc[:,-2:].dropna(),
#            s_r.melt(id_vars=[str(i)+'.red' for i in range(1,int(len(s_r.columns)/2))],var_name='blue', value_name="log.blue").iloc[:,-2:].dropna()
#           ], axis=1)
# log_red = log_red.drop(['red','blue'],axis=1)
# log_red['log.red'] = log_red['log.red'] + ' ' + log_red['log.blue']
# log_red = log_red.drop('log.blue', axis=1)
# log_red['log.red'] = log_red.apply(lambda x: x['log.red'].rsplit(' ', 1)[0], axis = 1)
# for substr in ['from: ', ', action:']:
#     log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(substr, '', 2), axis = 1)
# log_red['log.red'] = log_red['log.red'].str.split().apply(reversed).apply(' '.join)
# log_red['value']=1
# log_red['action'] = log_red['log.red'].str.split().str[1]
# log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(str(x['action'])+' ', '', 2), axis = 1)

# log_red = log_red.groupby(['log.red', 'action']).count()
# log_red.reset_index(inplace=True)
# log_red = log_red.set_index('log.red')

log_red.sort_index()
# Out:
#         action  value
# log.red
# a1 a2     down      2
# a1 a2    right     32
# a1 a2     stay      1
# a1 a3     down      5
# a1 a3    right    106
# ...        ...    ...
# b6 b1     stay     11
# b6 b1       up      3
# b6 b4       up      1
# b6 b5     stay      6
# b6 b5       up     34
#
# [195 rows x 2 columns]

# %%
len(log_red.index)
log_red[log_red.index == 'a1 a5']
# Out:
#         action  value
# log.red
# a1 a5     down      6
# a1 a5    right    174
# a1 a5     stay      8

# %%
result = pd.DataFrame(index=log_red.index.drop_duplicates(), columns=['right', 'stay', 'up', 'down'])
# result.reset_index(level=0, inplace=True)
for action in ['right', 'stay', 'up', 'down']:
    result[action] = log_red[log_red['action'] == action]['value']
result = result.fillna(0)
result.reset_index(inplace=True)
result.sort_index()
# Out:
#    log.red  right  stay    up  down
# 0    a1 a2   32.0   1.0   0.0   2.0
# 1    a1 a3  106.0  10.0   0.0   5.0
# 2    a1 a4  161.0   0.0   0.0   0.0
# 3    a1 a5  174.0   8.0   0.0   6.0
# 4    a1 b1    0.0  46.0  13.0   0.0
# ..     ...    ...   ...   ...   ...
# 88   b6 a4   11.0   1.0   0.0   0.0
# 89   b6 a5   36.0   5.0   0.0   5.0
# 90   b6 b1    0.0  11.0   3.0   0.0
# 91   b6 b4    0.0   0.0   1.0   0.0
# 92   b6 b5    0.0   6.0  34.0   0.0
#
# [93 rows x 5 columns]

# %% [markdown]
# #### After Laplace's Smoothing:

# %%
for i in range(1,7):
    result.loc[result['log.red'].str.endswith('a'+str(i)), ['stay', 'right', 'down']] += 1
    
for i in range(1,7):
    result.loc[result['log.red'].str.endswith('b'+str(i)), ['stay', 'up']] += 1

result = result.set_index('log.red')
result
# Out:
#          right  stay    up  down
# log.red
# a1 a2     33.0   2.0   0.0   3.0
# a1 a3    107.0  11.0   0.0   6.0
# a1 a4    162.0   1.0   0.0   1.0
# a1 a5    175.0   9.0   0.0   7.0
# a1 b1      0.0  47.0  14.0   0.0
# ...        ...   ...   ...   ...
# b6 a4     12.0   2.0   0.0   1.0
# b6 a5     37.0   6.0   0.0   6.0
# b6 b1      0.0  12.0   4.0   0.0
# b6 b4      0.0   1.0   2.0   0.0
# b6 b5      0.0   7.0  35.0   0.0
#
# [93 rows x 4 columns]

# %% [markdown]
# #### Convert it to Probability table:

# %%
pd.options.display.float_format = "{:,.2f}".format
result_probs = result.div(result.sum(axis=1), axis=0)

# %% [markdown]
# #### Save data on computer for the policy iteration:

# %%
result_probs.to_json('data/probs1.json' , orient='index', indent=4)

# %%
#To calculate the score:
crushing = -100;
richToDestination = 30;
step = -1;

# %%
'''==================================================
Initial set up                              version 1
=================================================='''
#Define all states
all_states=[]
for i in range(12):
    for j in range(12):
            all_states.append((i,j))

#Define rewards for all states
rewards = {}
for (i,j) in all_states:
    if(i == j): # crushed
        rewards[(i,j)] = crushing
    elif(i == 0 and j != 0): # blue agent in a1
        rewards[(i,j)] = richToDestination
    else:
        rewards[(i,j)] = step

#Dictionnary of possible actions. We have two "end" states (1,2 and 2,2)
actions = {}
for (i,j) in all_states:
    if i != 0 and i != j: #if s=(i, j) is not an "end" state
        actions[(i,j)] = ("stay", "left", "down") if (i < 6) else ("up", "stay")

#Define an initial policy
Policy={}
for s in actions.keys():
    Policy[s] = np.random.choice(actions[s])

probs = json.load(open('data/probs1.json',))
    
#Define initial value function 
V={}
for (i,j) in all_states:
    if (i,j) in actions.keys():
        V[(i,j)] = step
    elif(i == 0 and j != 0): # blue agent in a1
        V[(i,j)] = richToDestination
    elif(i == j): # crushed
        V[(i,j)] = crushing

# %%
def adapt_state(s):
    # takes (i,j) format state and convert it to "a|b[1-6] a|b[1-6]" format
    i = s[0]
    j = s[1]
    if i < 6:
        blueState = 'a' + str(i+1)
    else:
        blueState = 'b' + str(i-5)
    if j < 6:
        redState = 'a' + str(j+1)
    else:
        redState = 'b' + str(j-5)
    return blueState + ' ' + redState

# %%
print(adapt_state((0,1)))
print(adapt_state((0,7)))
print(adapt_state((6,8)))
print(adapt_state((10,11)))
# Out:
# a1 a2
# a1 b2
# b1 b3
# b5 b6

# %%
def newPosGivenAction(s, a, agent_i):
    # assert check
    if s[agent_i] == 5 and agent_i == 1:
        actions=["stay"]
    elif s[agent_i] == 0 and agent_i == 0:
        actions=["stay"]
    elif s[agent_i] < 6 and agent_i == 1:
        actions=["right","stay", "down"]
    elif s[agent_i] < 6 and agent_i == 0:
        actions=["left","stay", "down"]
    else:
        actions=["stay", "up"]
    assert a in actions , "action: " + str(a) + " is not vallid at state: " + str(s) + " for agent: " + str(agent_i)
    # agent_i = 0 for blue and 1 for red
    newPos = -1
    if a == "up":
        newPos = s[agent_i]-6
    if a == "down":
        newPos = s[agent_i]+6
    if a == "left":
        newPos = s[agent_i]-1
    if a == "right":
        newPos = s[agent_i]+1
    if a == "stay":
        newPos = s[agent_i]
    assert newPos > -1 and newPos < 12 , "Got out from board!\naction: " + str(a) + " ,state: " + str(s) + " for agent: " + str(agent_i)
    return newPos

# %%
def randomProbForAction(s):
    # if aX return 1/3 else (it is bX) return 1/2
    if s[1] == 5: # a6
        return 1
    if s[1] < 6:
        return 1.0/3
    else:
        return 1.0/2

# %%
def nextStateDistibution(s, a):
    # given state s and action a, return distibution of possibles new states by probs
    nxt = {}
#     print('s: ', s)
#     print('a: ', a)
    bluePossition = newPosGivenAction(s, a, 0)
#     print('bluePossition: ', bluePossition)
    
    # red possible action given state
    if s[1] == 5:
        actions=["stay"]
    elif s[1] < 6:
        actions=["right","stay", "down"]
    else:
        actions=["stay", "up"]
    for r_a in actions:
        redPossition = newPosGivenAction(s, r_a, 1)
#         print('redPossition: '+ str(redPossition))
        newState = (bluePossition, redPossition)
        try:
            nxt[newState] = probs[adapt_state(s)][r_a]
#                 nxt[newState] = {probs[adapt_state(s)][r_a], r_a, adapt_state(newState)}
        except KeyError:
#                 print("Warning! State not found: assume random behavior. ", s)
            nxt[newState] = randomProbForAction(s)
    assert abs(sum(nxt.values()) - 1.0) < 0.0001, "probs not sum to 1.0. \nstate: " + str(s) + " action: " + str(a) + " nxt: " + str(nxt) + "\nsum of probs: " + str(sum(nxt.values()))
    return nxt

# %%
pp.pprint(nextStateDistibution((10, 11), "up"))
pp.pprint(nextStateDistibution((1, 5), "stay"))
# Out:
# {(4, 5): 0.5, (4, 11): 0.5}
# {(1, 5): 1}

# %%
pp.pprint(nextStateDistibution((6, 7), "stay"))
# Out:
# {(6, 1): 0.5, (6, 7): 0.5}

# %%
adapt_state((0,2))
# Out:
# 'a1 a3'

# %%
'''==================================================
Value Iteration
=================================================='''

#Hyperparameters
SMALL_ENOUGH = 0.0001
GAMMA = 0.995

iteration = 1
while True:
    biggest_change = 0
    for s in all_states:
        if s in Policy:
            
            old_v = V[s]
            new_v = np.NINF
            
            for a in actions[s]:
                nxt = nextStateDistibution(s, a)
                v=0
                #Calculate the value
                for next_state, prob in nxt.items():
                    v += prob * (rewards[s] + GAMMA * V[next_state])
                if v > new_v: #Is this the best action so far? If so, keep it
                    new_v = v
                    Policy[s] = a

       #Save the best of all actions for the state                                
            V[s] = new_v
            biggest_change = max(biggest_change, np.abs(old_v - V[s]))

            
   #See if the loop should stop now         
    if biggest_change < SMALL_ENOUGH:
        print('converge after: ' + str(iteration) + ' iterations')
        break
    iteration += 1
    
#     #Print every 100 iterations
    if(iteration % 100 == 0):
        print(iteration, ') ', V[(5,0)]) #V[(a6, a1)]
# Out:
# 100 )  13.63945021547022
# converge after: 140 iterations

# %% [markdown]
# ## Results:

# %%
def convertStates():
    P_convert= {}
    V_convert = {}
    for s,v in V.items():
        V_convert[adapt_state(s)] = v
    
#     print()
    for s,p in Policy.items():
        P_convert[adapt_state(s)] = p
    
    pp.pprint(V_convert)
    pp.pprint(P_convert)
    return P_convert, V_convert

# %%
# print the results:
print("iterations: ", iteration)
optimal_policy, optimal_V = convertStates()
# Out:
# iterations:  140
# {'a1 a1': -100,
#  'a1 a2': 30,
#  'a1 a3': 30,
#  'a1 a4': 30,
#  'a1 a5': 30,
#  'a1 a6': 30,
#  'a1 b1': 30,
#  'a1 b2': 30,
#  'a1 b3': 30,
#  'a1 b4': 30,
#  'a1 b5': 30,
#  'a1 b6': 30,
#  'a2 a1': 2.3596381418071464,
#  'a2 a2': -100,
#  'a2 a3': 28.85,
#  'a2 a4': 28.85,
#  'a2 a5': 28.849999999999998,
#  'a2 a6': 28.85,
#  'a2 b1': 0.5576111250660646,
#  'a2 b2': 28.85,
#  'a2 b3': 28.85,
#  'a2 b4': 28.85,
#  'a2 b5': 28.85,
#  'a2 b6': 28.85,
#  'a3 a1': 16.152708324953405,
#  'a3 a2': 18.65688587289803,
#  'a3 a3': -100,
#  'a3 a4': 27.705750000000002,
#  'a3 a5': 27.705749997229425,
#  'a3 a6': 27.705750000000002,
#  'a3 b1': 15.237855649903612,
#  'a3 b2': 18.807600407521857,
#  'a3 b3': 27.705750000000002,
#  'a3 b4': 27.705750000000002,
#  'a3 b5': 27.705750000000002,
#  'a3 b6': 27.705750000000002,
#  'a4 a1': 16.258923532165667,
#  'a4 a2': 13.432810592277479,
#  'a4 a3': 13.615465910342198,
#  'a4 a4': -100,
#  'a4 a5': 26.567221246424374,
#  'a4 a6': 26.567221250000003,
#  'a4 b1': 14.330718076666361,
#  'a4 b2': 17.595945964737123,
#  'a4 b3': 11.211154744427688,
#  'a4 b4': 26.567221250000003,
#  'a4 b5': 26.567221247855887,
#  'a4 b6': 26.567221250000003,
#  'a5 a1': 13.887443842671816,
#  'a5 a2': 13.072036485485718,
#  'a5 a3': 11.236910248949671,
#  'a5 a4': 12.840946628307675,
#  'a5 a5': -100,
#  'a5 a6': 25.434385143750003,
#  'a5 b1': 14.388885760701635,
#  'a5 b2': 14.436806387114764,
#  'a5 b3': 11.749958710841916,
#  'a5 b4': 11.248620344384392,
#  'a5 b5': 25.434385141584958,
#  'a5 b6': 25.434385143750003,
#  'a6 a1': 13.63945021547022,
#  'a6 a2': 15.20582055883505,
#  'a6 a3': 16.356294735119793,
#  'a6 a4': 17.19912025697044,
#  'a6 a5': 19.412812694890622,
#  'a6 a6': -100,
#  'a6 b1': 13.226225930372713,
#  'a6 b2': 13.773502285564932,
#  'a6 b3': 14.947276556931147,
#  'a6 b4': 15.747527069009013,
#  'a6 b5': 16.15420656543756,
#  'a6 b6': 24.307213218031254,
#  'b1 a1': -14.266666666666666,
#  'b1 a2': 28.85,
#  'b1 a3': 28.85,
#  'b1 a4': 28.85,
#  'b1 a5': 28.85,
#  'b1 a6': 28.85,
#  'b1 b1': -100,
#  'b1 b2': 28.85,
#  'b1 b3': 28.85,
#  'b1 b4': 28.85,
#  'b1 b5': 28.85,
#  'b1 b6': 28.85,
#  'b2 a1': 2.9467512842282773,
#  'b2 a2': 10.611650001502952,
#  'b2 a3': 27.705750000000002,
#  'b2 a4': 27.705750000000002,
#  'b2 a5': 27.705750000000002,
#  'b2 a6': 27.705750000000002,
#  'b2 b1': 0.874781833578498,
#  'b2 b2': -100,
#  'b2 b3': 27.705750000000002,
#  'b2 b4': 27.705750000000002,
#  'b2 b5': 27.705750000000002,
#  'b2 b6': 27.705750000000002,
#  'b3 a1': 17.354238452343488,
#  'b3 a2': 20.444811127697335,
#  'b3 a3': 22.029106207172394,
#  'b3 a4': 26.567221247817592,
#  'b3 a5': 26.567221249448657,
#  'b3 a6': 26.567221250000003,
#  'b3 b1': 15.72814689293034,
#  'b3 b2': 19.247262175460822,
#  'b3 b3': -100,
#  'b3 b4': 26.567221250000003,
#  'b3 b5': 26.567221249212366,
#  'b3 b6': 26.567221250000003,
#  'b4 a1': 13.600779978674574,
#  'b4 a2': 12.466276768892273,
#  'b4 a3': 12.20413750769676,
#  'b4 a4': 13.760407518097194,
#  'b4 a5': 25.434385143402558,
#  'b4 a6': 25.434385143750003,
#  'b4 b1': 13.898585962293012,
#  'b4 b2': 13.746419771043794,
#  'b4 b3': 11.949316178269253,
#  'b4 b4': -100,
#  'b4 b5': 25.434385140904432,
#  'b4 b6': 25.434385143750003,
#  'b5 a1': 12.606746117812932,
#  'b5 a2': 11.182695150270451,
#  'b5 a3': 11.329817033697818,
#  'b5 a4': 9.583436983926328,
#  'b5 a5': 10.439745083602478,
#  'b5 a6': 24.307213218031254,
#  'b5 b1': 13.150629762434868,
#  'b5 b2': 12.685649329118739,
#  'b5 b3': 10.350886770882168,
#  'b5 b4': 11.512681119696047,
#  'b5 b5': -100,
#  'b5 b6': 24.307213218031254,
#  'b6 a1': 13.346608839247917,
#  'b6 a2': 15.231600795170667,
#  'b6 a3': 16.51204259414346,
#  'b6 a4': 17.778934821420467,
#  'b6 a5': -71.79928356983847,
#  'b6 a6': -100.5,
#  'b6 b1': 12.262884341638856,
#  'b6 b2': 13.417213115088991,
#  'b6 b3': 14.573526717795342,
#  'b6 b4': 16.14966598243832,
#  'b6 b5': 17.77536311484046,
#  'b6 b6': -100}
# {'a2 a1': 'down',
#  'a2 a3': 'left',
#  'a2 a4': 'left',
#  'a2 a5': 'left',
#  'a2 a6': 'left',
#  'a2 b1': 'down',
#  'a2 b2': 'left',
#  'a2 b3': 'left',
#  'a2 b4': 'left',
#  'a2 b5': 'left',
#  'a2 b6': 'left',
#  'a3 a1': 'down',
#  'a3 a2': 'down',
#  'a3 a4': 'left',
#  'a3 a5': 'left',
#  'a3 a6': 'left',
#  'a3 b1': 'down',
#  'a3 b2': 'down',
#  'a3 b3': 'left',
#  'a3 b4': 'left',
#  'a3 b5': 'left',
#  'a3 b6': 'left',
#  'a4 a1': 'left',
#  'a4 a2': 'stay',
#  'a4 a3': 'left',
#  'a4 a5': 'left',
#  'a4 a6': 'left',
#  'a4 b1': 'left',
#  'a4 b2': 'left',
#  'a4 b3': 'stay',
#  'a4 b4': 'left',
#  'a4 b5': 'left',
#  'a4 b6': 'left',
#  'a5 a1': 'left',
#  'a5 a2': 'left',
#  'a5 a3': 'stay',
#  'a5 a4': 'left',
#  'a5 a6': 'left',
#  'a5 b1': 'left',
#  'a5 b2': 'left',
#  'a5 b3': 'left',
#  'a5 b4': 'stay',
#  'a5 b5': 'left',
#  'a5 b6': 'left',
#  'a6 a1': 'stay',
#  'a6 a2': 'down',
#  'a6 a3': 'down',
#  'a6 a4': 'stay',
#  'a6 a5': 'left',
#  'a6 b1': 'left',
#  'a6 b2': 'stay',
#  'a6 b3': 'down',
#  'a6 b4': 'down',
#  'a6 b5': 'stay',
#  'a6 b6': 'left',
#  'b1 a1': 'up',
#  'b1 a2': 'up',
#  'b1 a3': 'up',
#  'b1 a4': 'up',
#  'b1 a5': 'up',
#  'b1 a6': 'up',
#  'b1 b2': 'up',
#  'b1 b3': 'up',
#  'b1 b4': 'up',
#  'b1 b5': 'up',
#  'b1 b6': 'up',
#  'b2 a1': 'stay',
#  'b2 a2': 'up',
#  'b2 a3': 'up',
#  'b2 a4': 'up',
#  'b2 a5': 'up',
#  'b2 a6': 'up',
#  'b2 b1': 'stay',
#  'b2 b3': 'up',
#  'b2 b4': 'up',
#  'b2 b5': 'up',
#  'b2 b6': 'up',
#  'b3 a1': 'stay',
#  'b3 a2': 'stay',
#  'b3 a3': 'up',
#  'b3 a4': 'up',
#  'b3 a5': 'up',
#  'b3 a6': 'up',
#  'b3 b1': 'stay',
#  'b3 b2': 'stay',
#  'b3 b4': 'up',
#  'b3 b5': 'up',
#  'b3 b6': 'up',
#  'b4 a1': 'up',
#  'b4 a2': 'up',
#  'b4 a3': 'stay',
#  'b4 a4': 'stay',
#  'b4 a5': 'up',
#  'b4 a6': 'up',
#  'b4 b1': 'up',
#  'b4 b2': 'up',
#  'b4 b3': 'up',
#  'b4 b5': 'up',
#  'b4 b6': 'up',
#  'b5 a1': 'up',
#  'b5 a2': 'up',
#  'b5 a3': 'up',
#  'b5 a4': 'stay',
#  'b5 a5': 'up',
#  'b5 a6': 'up',
#  'b5 b1': 'up',
#  'b5 b2': 'up',
#  'b5 b3': 'up',
#  'b5 b4': 'up',
#  'b5 b6': 'up',
#  'b6 a1': 'up',
#  'b6 a2': 'stay',
#  'b6 a3': 'stay',
#  'b6 a4': 'up',
#  'b6 a5': 'up',
#  'b6 a6': 'up',
#  'b6 b1': 'up',
#  'b6 b2': 'up',
#  'b6 b3': 'up',
#  'b6 b4': 'stay',
#  'b6 b5': 'up'}

# %%
import seaborn as sns
intensity = np.array(list(optimal_V.values())).reshape(12,12)
f, ax = plt.subplots(figsize=(20, 10))
sns.heatmap(intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
ax.set_title('Value Iteration results:')
# Out:
# Text(0.5, 1.0, 'Value Iteration results:')

# %% [markdown]
# # Policy evaluation:

# %%
def policy_eval(policy):
    V={}
    for (i,j) in all_states:
        if (i,j) in actions.keys():
            V[(i,j)] = step
        if(i == 0): # blue agent in a1
            V[(i,j)] = richToDestination
        if(i == j): # crushed
            V[(i,j)] = crushing
    while True:
        biggest_change = 0
        for s in all_states:
            if s in Policy:  
                old_v = V[s]
                nxt = nextStateDistibution(s, policy[s])
                v=0
                #Calculate the value
                for next_state, prob in nxt.items():
                    v += prob * (rewards[s] + GAMMA * V[next_state])
        
                #Save the best of all actions for the state                                
                V[s] = v
                biggest_change = max(biggest_change, np.abs(old_v - V[s]))
        #See if the loop should stop now         
        if biggest_change < SMALL_ENOUGH:
            return V

# %%
valueIteration_policy = Policy

# %% [markdown]
# # evaluate other behaviors:

# %%
def randomBehavior():
    Policy={}
    for s in actions.keys():
        Policy[s] = np.random.choice(actions[s])
    return Policy

random_policy = randomBehavior()

# %%
randomBehavior_intensity = np.array(list(policy_eval(random_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(randomBehavior_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: randomBehavior')

# %%
def carefulBehavior():
    Policy={}
    for s in actions.keys():
        blueState = s[0]
        redState = s[1]
        if redState + 1 == blueState or redState == blueState + 5 or redState + 6 == blueState or redState + 7 == blueState:
            if blueState < 6:
                Policy[s] = "down"
            else:
                Policy[s] = "stay"
        elif redState + 2 == blueState:
            if blueState < 6:
                Policy[s] = "down"
            else:
                Policy[s] = "up"
        else:
            if blueState < 6:
                Policy[s] = "left"
            else:
                Policy[s] = "up"
    return Policy

careful_policy = carefulBehavior()

# %%
careful_intensity = np.array(list(policy_eval(careful_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(careful_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: carefulBehavior')

# %%
def semiCarefulBehavior():
    Policy={}
    for s in actions.keys():
        blueState = s[0]
        redState = s[1]
        if redState + 1 == blueState:
            if blueState < 6:
                Policy[s] = "down"
            else:
                Policy[s] = "up"
        elif redState + 2 == blueState:
            if blueState < 6:
                Policy[s] = "stay"
            else:
                Policy[s] = "up"
        elif redState == blueState + 5 or redState + 6 == blueState or redState + 7 == blueState:
            if redState == 11 and blueState == 6:
                Policy[s] = "up"
            else:
                Policy[s] = "stay"
        else:
            if blueState < 6:
                Policy[s] = "left"
            else:
                Policy[s] = "up"
    return Policy

semiCareful_policy = semiCarefulBehavior()

# %%
semiCareful_intensity = np.array(list(policy_eval(semiCareful_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(semiCareful_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: carefulBehavior')

# %%
def semiAggressiveBehavior():
    Policy={}
    for s in actions.keys():
        blueState = s[0]
        redState = s[1]
        if redState + 1 == blueState:
            if blueState < 6:
                Policy[s] = "stay"
            else:
                Policy[s] = "up"
        elif redState == blueState + 5 or redState + 6 == blueState or redState + 7 == blueState:
            if blueState < 6:
                Policy[s] = "left"
            else:
                Policy[s] = "stay"
        else:
            if blueState < 6:
                Policy[s] = "left"
            else:
                Policy[s] = "up"
    return Policy

semiAggressive_policy = semiAggressiveBehavior()

# %%
semiAggressive_intensity = np.array(list(policy_eval(semiAggressive_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(semiAggressive_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: semiAggressiveBehavior')

# %%
def aggressiveBehavior():
    Policy={}
    for s in actions.keys():
        blueState = s[0]
        redState = s[1]
        if blueState > 5: #blue is in bX
            Policy[s] = "up"
        else:
            Policy[s] = "left"
    return Policy

aggressive_policy = aggressiveBehavior()

# %%
aggressive_intensity = np.array(list(policy_eval(aggressive_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(aggressive_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: aggressiveBehavior')

# %%
# diff = pd.DataFrame({'Real': df.groupby(['behavior']).mean()['blueScore'],
#                       'Prediction': [aggressive_intensity[5][0], careful_intensity[5][0], randomBehavior_intensity[5][0] , semiAggressive_intensity[5][0]]},
#                      index= df.groupby(['behavior']).mean()['blueScore'].index)
# diff['different'] = abs(diff['Real']-diff['Prediction'])
# diff

# %% [markdown]
# ## Value iteration with taking into account the previous state:

# %%
class OutOfBoard(Exception):
    pass

# %%
def get_pos_after_action(s, a):
    if a == 'U' or a == "up":
        if(s[0] == 'a'):
            raise OutOfBoard("An error occurred, state: "+ s + " action: " + a)
        return "a" + s[1]
    if a == 'D' or a == "down":
        if(s[0] == 'b'):
            raise OutOfBoard("An error occurred, state: "+ s + " action: " + a)
        return "b" + s[1]
    if a == 'L' or a == "left":
        if(s[0] == 'b' or s[1] == '1'):
            raise OutOfBoard("An error occurred, state: "+ s + " action: " + a)
        return "a" + str(int(s[1])-1)
    if a == 'R' or a == "right":
        if(s[0] == 'b' or s[1] == '6'):
            raise OutOfBoard("An error occurred, state: "+ s + " action: " + a)
        return "a" + str(int(s[1])+1)
    if a == 'S' or a == "stay":
        return s

# %%
def get_next_state(c_s):
    n_s = c_s.split()
    blueAction = n_s[3]
    blueState = n_s[2]
    redAction = n_s[1]
    redState = n_s[0]
    
    newPosBlue = get_pos_after_action(blueState, blueAction)
    newPosRed = get_pos_after_action(redState, redAction)
    
    return newPosBlue + ' ' + newPosRed

# %%
# s_r = df['log'].apply(pd.Series).iloc[:,1:]
# s_r.columns = s_r.columns.astype(str)
# log_red = flat_table.normalize(s_r).drop('index', axis=1)
# log_red = log_red.dropna(how='all')

# log_len = int(len(log_red.columns)/2)+1
# for i in range(1,log_len):
#     log_red[str(i)] = log_red[str(i)+'.red'] + ' ' + log_red[str(i)+'.blue']
#     log_red = log_red.drop([str(i)+'.red', str(i)+'.blue'],axis=1)
#     for substr in ['from: ', ', action:']:
#         log_red[str(i)] = log_red[str(i)].apply(lambda x: x.replace(substr, '', 2) if type(x) != float else x)
    
# log_len = len(log_red.columns)
# for i in range(1,log_len):
#     log_red[str(i) + '&' + str(i+1)] = log_red[str(i)] + '&' + log_red[str(i+1)]
#     log_red[str(i) + '&' + str(i+1)] = log_red[str(i) + '&' + str(i+1)].apply(lambda x: x.rsplit(' ', 2)[0] if type(x) != float else x)
# log_red = log_red.drop([str(i) for i in range(1,log_len+1)],axis=1)

# log_red = pd.DataFrame(log_red.to_numpy().flatten(), columns=['state'])
# log_red = log_red.dropna()

# log_red['action'] = log_red['state'].apply(lambda x: x.rsplit('&', 1)[1].rsplit(' ', 1)[1])
# log_red['state'] = log_red['state'].apply(lambda x: x.rsplit('&', 1)[0])

# log_red['nxt'] = log_red['state'].apply(get_next_state)
# log_red['state'] = log_red['state'].str.split().apply(reversed).apply(' '.join)

# log_red['value']=1

# for a in ['right', 'stay', 'up', 'down', 'left']:
#     log_red['state'] = log_red['state'].apply(lambda x: x.replace(a+' ', '', 2))

# log_red['state'] = log_red['state'] + ' nxt: ' + log_red['nxt']
# log_red = log_red.drop('nxt',axis=1)

# log_red = log_red.groupby(['state', 'action']).count()
# log_red.reset_index(inplace=True)
# log_red = log_red.set_index('state')

# log_red

s_r = df['log'].apply(pd.Series).iloc[:,1:]
s_r.columns = s_r.columns.astype(str)
s_r.set_index( df['index'], inplace=True)
log_red = flat_table.normalize(s_r)
log_red = log_red.dropna(how='all')
log_red.set_index(log_red['index'], inplace=True)
log_red = log_red.drop('index', axis=1)

log_len = int(len(log_red.columns)/2)+1
for i in range(1,log_len):
    log_red[str(i)] = log_red[str(i)+'.red'] + ' ' + log_red[str(i)+'.blue']
    log_red = log_red.drop([str(i)+'.red', str(i)+'.blue'],axis=1)
    for substr in ['from: ', ', action:']:
        log_red[str(i)] = log_red[str(i)].apply(lambda x: x.replace(substr, '', 2) if type(x) != float else x)
    
log_len = len(log_red.columns)
for i in range(1,log_len):
    log_red[str(i) + '&' + str(i+1)] = log_red[str(i)] + '&' + log_red[str(i+1)]
    log_red[str(i) + '&' + str(i+1)] = log_red[str(i) + '&' + str(i+1)].apply(lambda x: x.rsplit(' ', 2)[0] if type(x) != float else x)
log_red = log_red.drop([str(i) for i in range(1,log_len+1)],axis=1)

log_red_copy = log_red.copy(deep=True)

log_red = pd.DataFrame(log_red.to_numpy().flatten(), columns=['state'])
log_red = log_red.dropna()

log_red['action'] = log_red['state'].apply(lambda x: x.rsplit('&', 1)[1].rsplit(' ', 1)[1])
log_red['state'] = log_red['state'].apply(lambda x: x.rsplit('&', 1)[0])

log_red['nxt'] = log_red['state'].apply(get_next_state)
log_red['state'] = log_red['state'].str.split().apply(reversed).apply(' '.join)

log_red['value']=1

for a in ['right', 'stay', 'up', 'down', 'left']:
    log_red['state'] = log_red['state'].apply(lambda x: x.replace(a+' ', '', 2))

log_red['state'] = log_red['state'] + ' nxt: ' + log_red['nxt']
log_red = log_red.drop('nxt',axis=1)

log_red = log_red.groupby(['state', 'action']).count()
log_red.reset_index(inplace=True)
log_red = log_red.set_index('state')

log_red
# Out:
#                  action  value
# state
# a1 a2 nxt: a1 a2  right      1
# a1 a2 nxt: a1 a3   down      1
# a1 a2 nxt: a1 a3  right     25
# a1 a2 nxt: a1 a3   stay      1
# a1 a2 nxt: a1 b2   stay      1
# ...                 ...    ...
# b6 b5 nxt: b6 a5   down      3
# b6 b5 nxt: b6 a5  right     24
# b6 b5 nxt: b6 a5   stay      3
# b6 b5 nxt: b6 b5   stay      1
# b6 b5 nxt: b6 b5     up      2
#
# [423 rows x 2 columns]

# %%
log_red[log_red.index == 'a4 b3 nxt: a4 b3']
# Out:
#                  action  value
# state
# a4 b3 nxt: a4 b3   stay     23
# a4 b3 nxt: a4 b3     up     11

# %%
a = df[['index','win']]
a.set_index('index', inplace=True)

b = df[['index','behavior']]
b.set_index('index', inplace=True)

c = df[['index','blueScore']]
c.set_index('index', inplace=True)

d = df[['index','redScore']]
d.set_index('index', inplace=True)

e = df[['index','answer-the-quiz']]
e.set_index('index', inplace=True)

log_red_copy = pd.concat([log_red_copy,a, b, c ,d, e],axis=1)
log_red_copy = log_red_copy[log_red_copy['1&2'].notna()]

# %%
len(log_red_copy)
# Out:
# 403

# %%
# log_red_copy[log_red_copy['win'] == False][log_red_copy['blueScore'] != log_red_copy['redScore']]

# %%
# c = log_red_copy[log_red_copy['win'] == True][log_red_copy['answer-the-quiz'].notnull()][log_red_copy['behavior'] == 'valueIterationBasedBehavior_v2']
c = log_red_copy[log_red_copy['answer-the-quiz'].notnull()][log_red_copy['behavior'] == 'semiCarefulBehavior']
c
# Out:
# <ipython-input-62-2d508518919f>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c = log_red_copy[log_red_copy['answer-the-quiz'].notnull()][log_red_copy['behavior'] == 'semiCarefulBehavior']
#                                             1&2                        2&3  \
# index
# -Mb8Q0x-Cy_1KPfxwGI4  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -Mb8RgaFWFoBM1x_HF_S  a1 right a6 left&a2 right  a2 right a5 left&a3 right
# -Mb8W36QTkRd_uG0VkO8  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -Mb8WbmOrt6xozw8c_4R  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -Mb8XfXGX0rxfzmJm8vn  a1 right a6 left&a2 right  a2 right a5 left&a3 right
# -Mb8dWlSTnj0jW9rs3qX  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -Mb8jxwRzI9qbfw_V8Hx  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -Mb9GmWJhSgjC-qlLMVD   a1 stay a6 left&a1 right   a1 right a5 left&a2 down
# -MbDJrza0ghaeVewTAXI   a1 right a6 left&a2 stay    a2 stay a5 left&a2 down
# -MbDJx8l9jnGzlhqpD5r  a1 right a6 left&a2 right  a2 right a5 left&a3 right
# -MbDJxO4bjw3jVRSrS_U  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbDKHS1e9dqFuuYWZNv   a1 stay a6 left&a1 right   a1 right a5 left&a2 stay
# -MbDKuEXBIYZqELqb0wJ   a1 right a6 left&a2 down      a2 down a5 left&b2 up
# -MbDLFEhzuXPYEVSqp2b      a1 down a6 left&b1 up     b1 up a5 left&a1 right
# -MbDMKyIZcsBt6mW5uqg  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbDOLsaDHZqSw4jZPyi   a1 right a6 left&a2 down      a2 down a5 left&b2 up
# -MbDOVZ_AGPpsxtxAMx4  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbDPFmRRxNSg3_1MEVH  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbDQL3mU1VChQYCm-Nn    a1 stay a6 left&a1 down      a1 down a5 left&b1 up
# -MbDQYIFsFLYfGbDumPY  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbDSY0U-cbu1AMFXESz    a1 stay a6 left&a1 stay    a1 stay a5 left&a1 stay
# -MbDU3ACbK8eSFfjjM7o  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbDVQKHoXZXjJ0Fm87p    a1 stay a6 left&a1 stay    a1 stay a5 left&a1 stay
# -MbDXCiHM2bM5_JfnpxR  a1 right a6 left&a2 right  a2 right a5 left&a3 right
# -MbDYUppxghDQUiprnqu  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbDawhpQ85kPm0SlM9c      a1 down a6 left&b1 up     b1 up a5 left&a1 right
# -MbMUlNQctXe_S7NRJee  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbMUrK_7aAJjug_tLeO  a1 right a6 left&a2 right   a2 right a5 left&a3 stay
# -MbMUtNCAXKhu7gTKEg2  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbMVIIPvpYVkjejWCzL    a1 stay a6 left&a1 stay   a1 stay a5 left&a1 right
# -MbMVKB0JnnBgwkZcDlK  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbMVSZX7Ip55cIQjrdZ    a1 stay a6 left&a1 stay    a1 stay a5 left&a1 stay
# -MbMVdjFeBm0dxpC9vjv  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbMVlkoP9eoW1dk7AeO  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbMWOSsCLRpT00c08Uj  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbMWpOkaerwCXsyAzUQ   a1 right a6 left&a2 stay    a2 stay a5 left&a2 down
# -MbMbljNhFkFkFSyJwHD      a1 down a6 left&b1 up      b1 up a5 left&a1 down
# -MbMcUaa5BcFWRlgsd0v   a1 stay a6 left&a1 right   a1 right a5 left&a2 stay
# -MbMjbHpvelxKHVTFedP   a1 stay a6 left&a1 right   a1 right a5 left&a2 down
# -MbN-xMTYjYchEVTdJ0e      a1 down a6 left&b1 up     b1 up a5 left&a1 right
# -MbTT8AhnwoNxhvSev2B  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbTTrtKDNBfKgUF94l_  a1 right a6 left&a2 right   a2 right a5 left&a3 down
# -MbTVbO-0yOiOsU7WriY   a1 right a6 left&a2 down      a2 down a5 left&b2 up
#
#                                             3&4                        4&5  \
# index
# -Mb8Q0x-Cy_1KPfxwGI4      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -Mb8RgaFWFoBM1x_HF_S  a3 right a4 down&a4 right  a4 right b4 stay&a5 right
# -Mb8W36QTkRd_uG0VkO8      a3 down a4 down&b3 up        b3 up b4 up&a3 stay
# -Mb8WbmOrt6xozw8c_4R      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -Mb8XfXGX0rxfzmJm8vn  a3 right a4 down&a4 right   a4 right b4 stay&a5 stay
# -Mb8dWlSTnj0jW9rs3qX      a3 down a4 down&b3 up        b3 up b4 up&a3 stay
# -Mb8jxwRzI9qbfw_V8Hx    a3 down a4 down&b3 stay      b3 stay b4 up&b3 stay
# -Mb9GmWJhSgjC-qlLMVD    a2 down a4 stay&b2 stay    b2 stay a4 left&b2 stay
# -MbDJrza0ghaeVewTAXI    a2 down a4 stay&b2 stay    b2 stay a4 left&b2 stay
# -MbDJx8l9jnGzlhqpD5r  a3 right a4 down&a4 right   a4 right b4 stay&a5 down
# -MbDJxO4bjw3jVRSrS_U      a3 down a4 down&b3 up        b3 up b4 up&a3 stay
# -MbDKHS1e9dqFuuYWZNv   a2 stay a4 stay&a2 right   a2 right a4 stay&a3 down
# -MbDKuEXBIYZqELqb0wJ      b2 up a4 left&a2 down      a2 down a3 down&b2 up
# -MbDLFEhzuXPYEVSqp2b   a1 right a4 left&a2 down    a2 down a3 down&b2 stay
# -MbDMKyIZcsBt6mW5uqg      a3 down a4 down&b3 up        b3 up b4 up&a3 stay
# -MbDOLsaDHZqSw4jZPyi      b2 up a4 left&a2 down      a2 down a3 down&b2 up
# -MbDOVZ_AGPpsxtxAMx4      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -MbDPFmRRxNSg3_1MEVH    a3 down a4 down&b3 stay      b3 stay b4 up&b3 stay
# -MbDQL3mU1VChQYCm-Nn      b1 up a4 left&a1 down      a1 down a3 stay&b1 up
# -MbDQYIFsFLYfGbDumPY      a3 down a4 down&b3 up       b3 up b4 up&a3 right
# -MbDSY0U-cbu1AMFXESz    a1 stay a4 left&a1 stay    a1 stay a3 stay&a1 stay
# -MbDU3ACbK8eSFfjjM7o      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -MbDVQKHoXZXjJ0Fm87p    a1 stay a4 left&a1 stay    a1 stay a3 stay&a1 down
# -MbDXCiHM2bM5_JfnpxR  a3 right a4 down&a4 right  a4 right b4 stay&a5 right
# -MbDYUppxghDQUiprnqu      a3 down a4 down&b3 up       b3 up b4 up&a3 right
# -MbDawhpQ85kPm0SlM9c   a1 right a4 left&a2 down      a2 down a3 down&b2 up
# -MbMUlNQctXe_S7NRJee      a3 down a4 down&b3 up       b3 up b4 up&a3 right
# -MbMUrK_7aAJjug_tLeO   a3 stay a4 down&a3 right  a3 right b4 stay&a4 right
# -MbMUtNCAXKhu7gTKEg2      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -MbMVIIPvpYVkjejWCzL   a1 right a4 left&a2 down      a2 down a3 down&b2 up
# -MbMVKB0JnnBgwkZcDlK      a3 down a4 down&b3 up       b3 up b4 up&a3 right
# -MbMVSZX7Ip55cIQjrdZ    a1 stay a4 left&a1 stay    a1 stay a3 stay&a1 stay
# -MbMVdjFeBm0dxpC9vjv      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -MbMVlkoP9eoW1dk7AeO      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -MbMWOSsCLRpT00c08Uj      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -MbMWpOkaerwCXsyAzUQ    a2 down a4 stay&b2 stay    b2 stay a4 left&b2 stay
# -MbMbljNhFkFkFSyJwHD      a1 down a4 left&b1 up     b1 up a3 left&a1 right
# -MbMcUaa5BcFWRlgsd0v    a2 stay a4 stay&a2 stay    a2 stay a4 stay&a2 stay
# -MbMjbHpvelxKHVTFedP      a2 down a4 stay&b2 up     b2 up a4 left&a2 right
# -MbN-xMTYjYchEVTdJ0e   a1 right a4 left&a2 down      a2 down a3 down&b2 up
# -MbTT8AhnwoNxhvSev2B      a3 down a4 down&b3 up        b3 up b4 up&a3 stay
# -MbTTrtKDNBfKgUF94l_      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -MbTVbO-0yOiOsU7WriY      b2 up a4 left&a2 down      a2 down a3 down&b2 up
#
#                                             5&6                        6&7  \
# index
# -Mb8Q0x-Cy_1KPfxwGI4      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -Mb8RgaFWFoBM1x_HF_S                        NaN                        NaN
# -Mb8W36QTkRd_uG0VkO8   a3 stay a4 down&a3 right  a3 right b4 stay&a4 right
# -Mb8WbmOrt6xozw8c_4R    a3 down a4 down&b3 stay        b3 stay b4 up&b3 up
# -Mb8XfXGX0rxfzmJm8vn      a5 stay b4 up&a5 stay    a5 stay a4 left&a5 stay
# -Mb8dWlSTnj0jW9rs3qX   a3 stay a4 down&a3 right  a3 right b4 stay&a4 right
# -Mb8jxwRzI9qbfw_V8Hx    b3 stay a4 stay&b3 stay    b3 stay a4 stay&b3 stay
# -Mb9GmWJhSgjC-qlLMVD    b2 stay a3 stay&b2 stay    b2 stay a3 stay&b2 stay
# -MbDJrza0ghaeVewTAXI    b2 stay a3 stay&b2 stay      b2 stay a3 stay&b2 up
# -MbDJx8l9jnGzlhqpD5r        a5 down b4 up&b5 up      b5 up a4 left&a5 stay
# -MbDJxO4bjw3jVRSrS_U   a3 stay a4 down&a3 right  a3 right b4 stay&a4 right
# -MbDKHS1e9dqFuuYWZNv    a3 down a4 down&b3 stay      b3 stay b4 up&b3 stay
# -MbDKuEXBIYZqELqb0wJ        b2 up b3 up&a2 down      a2 down a3 down&b2 up
# -MbDLFEhzuXPYEVSqp2b        b2 stay b3 up&b2 up      b2 up a3 stay&a2 stay
# -MbDMKyIZcsBt6mW5uqg    a3 stay a4 down&a3 stay    a3 stay b4 stay&a3 stay
# -MbDOLsaDHZqSw4jZPyi        b2 up b3 up&a2 down      a2 down a3 down&b2 up
# -MbDOVZ_AGPpsxtxAMx4      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -MbDPFmRRxNSg3_1MEVH      b3 stay a4 stay&b3 up      b3 up a4 stay&a3 stay
# -MbDQL3mU1VChQYCm-Nn      b1 up a3 left&a1 down      a1 down a2 down&b1 up
# -MbDQYIFsFLYfGbDumPY  a3 right a4 down&a4 right  a4 right b4 stay&a5 right
# -MbDSY0U-cbu1AMFXESz    a1 stay a3 stay&a1 stay    a1 stay a3 stay&a1 down
# -MbDU3ACbK8eSFfjjM7o      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -MbDVQKHoXZXjJ0Fm87p    a1 down a3 stay&b1 stay    b1 stay a3 left&b1 stay
# -MbDXCiHM2bM5_JfnpxR                        NaN                        NaN
# -MbDYUppxghDQUiprnqu  a3 right a4 down&a4 right  a4 right b4 stay&a5 right
# -MbDawhpQ85kPm0SlM9c        b2 up b3 up&a2 down      a2 down a3 down&b2 up
# -MbMUlNQctXe_S7NRJee  a3 right a4 down&a4 right  a4 right b4 stay&a5 right
# -MbMUrK_7aAJjug_tLeO  a4 right b4 stay&a5 right                        NaN
# -MbMUtNCAXKhu7gTKEg2      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -MbMVIIPvpYVkjejWCzL       b2 up b3 up&a2 right   a2 right a3 down&a3 down
# -MbMVKB0JnnBgwkZcDlK  a3 right a4 down&a4 right  a4 right b4 stay&a5 right
# -MbMVSZX7Ip55cIQjrdZ    a1 stay a3 stay&a1 stay    a1 stay a3 stay&a1 stay
# -MbMVdjFeBm0dxpC9vjv      a3 down a4 down&b3 up        b3 up b4 up&a3 stay
# -MbMVlkoP9eoW1dk7AeO      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -MbMWOSsCLRpT00c08Uj      a3 down a4 down&b3 up        b3 up b4 up&a3 stay
# -MbMWpOkaerwCXsyAzUQ    b2 stay a3 stay&b2 stay    b2 stay a3 stay&b2 stay
# -MbMbljNhFkFkFSyJwHD   a1 right a2 down&a2 down                        NaN
# -MbMcUaa5BcFWRlgsd0v   a2 stay a4 stay&a2 right   a2 right a4 stay&a3 stay
# -MbMjbHpvelxKHVTFedP  a2 right a3 down&a3 right  a3 right b3 stay&a4 right
# -MbN-xMTYjYchEVTdJ0e        b2 up b3 up&a2 down      a2 down a3 down&b2 up
# -MbTT8AhnwoNxhvSev2B   a3 stay a4 down&a3 right  a3 right b4 stay&a4 right
# -MbTTrtKDNBfKgUF94l_      a3 down a4 down&b3 up        b3 up b4 up&a3 stay
# -MbTVbO-0yOiOsU7WriY        b2 up b3 up&a2 down      a2 down a3 down&b2 up
#
#                                             7&8                        8&9  \
# index
# -Mb8Q0x-Cy_1KPfxwGI4    a3 down a4 down&b3 stay        b3 stay b4 up&b3 up
# -Mb8RgaFWFoBM1x_HF_S                        NaN                        NaN
# -Mb8W36QTkRd_uG0VkO8  a4 right b4 stay&a5 right                        NaN
# -Mb8WbmOrt6xozw8c_4R     b3 up a4 stay&a3 right  a3 right a4 down&a4 right
# -Mb8XfXGX0rxfzmJm8vn    a5 stay a3 left&a5 stay   a5 stay a2 left&a5 right
# -Mb8dWlSTnj0jW9rs3qX  a4 right b4 stay&a5 right                        NaN
# -Mb8jxwRzI9qbfw_V8Hx    b3 stay a4 stay&b3 stay    b3 stay a4 stay&b3 stay
# -Mb9GmWJhSgjC-qlLMVD    b2 stay a3 stay&b2 stay      b2 stay a3 stay&b2 up
# -MbDJrza0ghaeVewTAXI      b2 up a3 stay&a2 down      a2 down a3 down&b2 up
# -MbDJx8l9jnGzlhqpD5r   a5 stay a3 left&a5 right                        NaN
# -MbDJxO4bjw3jVRSrS_U  a4 right b4 stay&a5 right                        NaN
# -MbDKHS1e9dqFuuYWZNv    b3 stay a4 stay&b3 stay    b3 stay a4 stay&b3 stay
# -MbDKuEXBIYZqELqb0wJ       b2 up b3 up&a2 right  a2 right a3 down&a3 right
# -MbDLFEhzuXPYEVSqp2b   a2 stay a3 down&a2 right  a2 right b3 stay&a3 right
# -MbDMKyIZcsBt6mW5uqg   a3 stay b4 stay&a3 right  a3 right b4 stay&a4 right
# -MbDOLsaDHZqSw4jZPyi        b2 up b3 up&a2 down      a2 down a3 down&b2 up
# -MbDOVZ_AGPpsxtxAMx4      a3 down a4 down&b3 up       b3 up b4 up&a3 right
# -MbDPFmRRxNSg3_1MEVH   a3 stay a4 down&a3 right  a3 right b4 stay&a4 right
# -MbDQL3mU1VChQYCm-Nn        b1 up b2 up&a1 down      a1 down a2 down&b1 up
# -MbDQYIFsFLYfGbDumPY                        NaN                        NaN
# -MbDSY0U-cbu1AMFXESz      a1 down a3 stay&b1 up      b1 up a3 left&a1 down
# -MbDU3ACbK8eSFfjjM7o      a3 down a4 down&b3 up        b3 up b4 up&a3 down
# -MbDVQKHoXZXjJ0Fm87p      b1 stay a2 stay&b1 up      b1 up a2 stay&a1 down
# -MbDXCiHM2bM5_JfnpxR                        NaN                        NaN
# -MbDYUppxghDQUiprnqu                        NaN                        NaN
# -MbDawhpQ85kPm0SlM9c        b2 up b3 up&a2 down      a2 down a3 down&b2 up
# -MbMUlNQctXe_S7NRJee                        NaN                        NaN
# -MbMUrK_7aAJjug_tLeO                        NaN                        NaN
# -MbMUtNCAXKhu7gTKEg2      a3 down a4 down&b3 up        b3 up b4 up&a3 stay
# -MbMVIIPvpYVkjejWCzL                        NaN                        NaN
# -MbMVKB0JnnBgwkZcDlK                        NaN                        NaN
# -MbMVSZX7Ip55cIQjrdZ    a1 stay a3 stay&a1 stay    a1 stay a3 stay&a1 stay
# -MbMVdjFeBm0dxpC9vjv   a3 stay a4 down&a3 right  a3 right b4 stay&a4 right
# -MbMVlkoP9eoW1dk7AeO    a3 down a4 down&b3 stay        b3 stay b4 up&b3 up
# -MbMWOSsCLRpT00c08Uj   a3 stay a4 down&a3 right  a3 right b4 stay&a4 right
# -MbMWpOkaerwCXsyAzUQ    b2 stay a3 stay&b2 stay    b2 stay a3 stay&b2 stay
# -MbMbljNhFkFkFSyJwHD                        NaN                        NaN
# -MbMcUaa5BcFWRlgsd0v    a3 stay a4 down&a3 down    a3 down b4 stay&b3 stay
# -MbMjbHpvelxKHVTFedP    a4 right b3 up&a5 right                        NaN
# -MbN-xMTYjYchEVTdJ0e        b2 up b3 up&a2 down      a2 down a3 down&b2 up
# -MbTT8AhnwoNxhvSev2B  a4 right b4 stay&a5 right                        NaN
# -MbTTrtKDNBfKgUF94l_   a3 stay a4 down&a3 right  a3 right b4 stay&a4 right
# -MbTVbO-0yOiOsU7WriY       b2 up b3 up&a2 right  a2 right a3 down&a3 right
#
#                                            9&10                      10&11  \
# index
# -Mb8Q0x-Cy_1KPfxwGI4      b3 up a4 stay&a3 down      a3 down a4 down&b3 up
# -Mb8RgaFWFoBM1x_HF_S                        NaN                        NaN
# -Mb8W36QTkRd_uG0VkO8                        NaN                        NaN
# -Mb8WbmOrt6xozw8c_4R  a4 right b4 stay&a5 right                        NaN
# -Mb8XfXGX0rxfzmJm8vn                        NaN                        NaN
# -Mb8dWlSTnj0jW9rs3qX                        NaN                        NaN
# -Mb8jxwRzI9qbfw_V8Hx    b3 stay a4 stay&b3 stay    b3 stay a4 stay&b3 stay
# -Mb9GmWJhSgjC-qlLMVD      b2 up a3 stay&a2 stay   a2 stay a3 down&a2 right
# -MbDJrza0ghaeVewTAXI        b2 up b3 up&a2 down    a2 down a3 down&b2 stay
# -MbDJx8l9jnGzlhqpD5r                        NaN                        NaN
# -MbDJxO4bjw3jVRSrS_U                        NaN                        NaN
# -MbDKHS1e9dqFuuYWZNv      b3 stay a4 stay&b3 up      b3 up a4 stay&a3 stay
# -MbDKuEXBIYZqELqb0wJ   a3 right b3 stay&a4 down        a4 down b3 up&b4 up
# -MbDLFEhzuXPYEVSqp2b  a3 right b3 stay&a4 right    a4 right b3 up&a5 right
# -MbDMKyIZcsBt6mW5uqg  a4 right b4 stay&a5 right                        NaN
# -MbDOLsaDHZqSw4jZPyi       b2 up b3 up&a2 right  a2 right a3 down&a3 right
# -MbDOVZ_AGPpsxtxAMx4  a3 right a4 down&a4 right  a4 right b4 stay&a5 right
# -MbDPFmRRxNSg3_1MEVH  a4 right b4 stay&a5 right                        NaN
# -MbDQL3mU1VChQYCm-Nn        b1 up b2 up&a1 down      a1 down a2 down&b1 up
# -MbDQYIFsFLYfGbDumPY                        NaN                        NaN
# -MbDSY0U-cbu1AMFXESz    a1 down a2 down&b1 stay        b1 stay b2 up&b1 up
# -MbDU3ACbK8eSFfjjM7o      a3 down a4 down&b3 up       b3 up b4 up&a3 right
# -MbDVQKHoXZXjJ0Fm87p      a1 down a2 down&b1 up        b1 up b2 up&a1 stay
# -MbDXCiHM2bM5_JfnpxR                        NaN                        NaN
# -MbDYUppxghDQUiprnqu                        NaN                        NaN
# -MbDawhpQ85kPm0SlM9c        b2 up b3 up&a2 stay   a2 stay a3 down&a2 right
# -MbMUlNQctXe_S7NRJee                        NaN                        NaN
# -MbMUrK_7aAJjug_tLeO                        NaN                        NaN
# -MbMUtNCAXKhu7gTKEg2   a3 stay a4 down&a3 right  a3 right b4 stay&a4 right
# -MbMVIIPvpYVkjejWCzL                        NaN                        NaN
# -MbMVKB0JnnBgwkZcDlK                        NaN                        NaN
# -MbMVSZX7Ip55cIQjrdZ    a1 stay a3 stay&a1 stay    a1 stay a3 stay&a1 stay
# -MbMVdjFeBm0dxpC9vjv  a4 right b4 stay&a5 right                        NaN
# -MbMVlkoP9eoW1dk7AeO      b3 up a4 stay&a3 down    a3 down a4 down&b3 stay
# -MbMWOSsCLRpT00c08Uj  a4 right b4 stay&a5 right                        NaN
# -MbMWpOkaerwCXsyAzUQ      b2 stay a3 stay&b2 up      b2 up a3 stay&a2 down
# -MbMbljNhFkFkFSyJwHD                        NaN                        NaN
# -MbMcUaa5BcFWRlgsd0v        b3 stay b4 up&b3 up      b3 up a4 stay&a3 down
# -MbMjbHpvelxKHVTFedP                        NaN                        NaN
# -MbN-xMTYjYchEVTdJ0e       b2 up b3 up&a2 right   a2 right a3 down&a3 down
# -MbTT8AhnwoNxhvSev2B                        NaN                        NaN
# -MbTTrtKDNBfKgUF94l_  a4 right b4 stay&a5 right                        NaN
# -MbTVbO-0yOiOsU7WriY  a3 right b3 stay&a4 right    a4 right b3 up&a5 right
#
#                       ... 47&48 48&49 49&50 50&51 51&52    win  \
# index                 ...
# -Mb8Q0x-Cy_1KPfxwGI4  ...   NaN   NaN   NaN   NaN   NaN   True
# -Mb8RgaFWFoBM1x_HF_S  ...   NaN   NaN   NaN   NaN   NaN   True
# -Mb8W36QTkRd_uG0VkO8  ...   NaN   NaN   NaN   NaN   NaN   True
# -Mb8WbmOrt6xozw8c_4R  ...   NaN   NaN   NaN   NaN   NaN   True
# -Mb8XfXGX0rxfzmJm8vn  ...   NaN   NaN   NaN   NaN   NaN   True
# -Mb8dWlSTnj0jW9rs3qX  ...   NaN   NaN   NaN   NaN   NaN   True
# -Mb8jxwRzI9qbfw_V8Hx  ...   NaN   NaN   NaN   NaN   NaN   True
# -Mb9GmWJhSgjC-qlLMVD  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDJrza0ghaeVewTAXI  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDJx8l9jnGzlhqpD5r  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDJxO4bjw3jVRSrS_U  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDKHS1e9dqFuuYWZNv  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDKuEXBIYZqELqb0wJ  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDLFEhzuXPYEVSqp2b  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDMKyIZcsBt6mW5uqg  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDOLsaDHZqSw4jZPyi  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDOVZ_AGPpsxtxAMx4  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDPFmRRxNSg3_1MEVH  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDQL3mU1VChQYCm-Nn  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDQYIFsFLYfGbDumPY  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDSY0U-cbu1AMFXESz  ...   NaN   NaN   NaN   NaN   NaN  False
# -MbDU3ACbK8eSFfjjM7o  ...   NaN   NaN   NaN   NaN   NaN  False
# -MbDVQKHoXZXjJ0Fm87p  ...   NaN   NaN   NaN   NaN   NaN  False
# -MbDXCiHM2bM5_JfnpxR  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDYUppxghDQUiprnqu  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbDawhpQ85kPm0SlM9c  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbMUlNQctXe_S7NRJee  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbMUrK_7aAJjug_tLeO  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbMUtNCAXKhu7gTKEg2  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbMVIIPvpYVkjejWCzL  ...   NaN   NaN   NaN   NaN   NaN  False
# -MbMVKB0JnnBgwkZcDlK  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbMVSZX7Ip55cIQjrdZ  ...   NaN   NaN   NaN   NaN   NaN  False
# -MbMVdjFeBm0dxpC9vjv  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbMVlkoP9eoW1dk7AeO  ...   NaN   NaN   NaN   NaN   NaN  False
# -MbMWOSsCLRpT00c08Uj  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbMWpOkaerwCXsyAzUQ  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbMbljNhFkFkFSyJwHD  ...   NaN   NaN   NaN   NaN   NaN  False
# -MbMcUaa5BcFWRlgsd0v  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbMjbHpvelxKHVTFedP  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbN-xMTYjYchEVTdJ0e  ...   NaN   NaN   NaN   NaN   NaN  False
# -MbTT8AhnwoNxhvSev2B  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbTTrtKDNBfKgUF94l_  ...   NaN   NaN   NaN   NaN   NaN   True
# -MbTVbO-0yOiOsU7WriY  ...   NaN   NaN   NaN   NaN   NaN   True
#
#                                  behavior blueScore redScore answer-the-quiz
# index
# -Mb8Q0x-Cy_1KPfxwGI4  semiCarefulBehavior     13.00    16.00            True
# -Mb8RgaFWFoBM1x_HF_S  semiCarefulBehavior     22.00    25.00            True
# -Mb8W36QTkRd_uG0VkO8  semiCarefulBehavior     19.00    22.00            True
# -Mb8WbmOrt6xozw8c_4R  semiCarefulBehavior     17.00    20.00            True
# -Mb8XfXGX0rxfzmJm8vn  semiCarefulBehavior     21.00    21.00            True
# -Mb8dWlSTnj0jW9rs3qX  semiCarefulBehavior     19.00    22.00            True
# -Mb8jxwRzI9qbfw_V8Hx  semiCarefulBehavior     11.00    14.00            True
# -Mb9GmWJhSgjC-qlLMVD  semiCarefulBehavior     14.00    16.00            True
# -MbDJrza0ghaeVewTAXI  semiCarefulBehavior      8.00    10.00            True
# -MbDJx8l9jnGzlhqpD5r  semiCarefulBehavior     21.00    22.00            True
# -MbDJxO4bjw3jVRSrS_U  semiCarefulBehavior     19.00    22.00            True
# -MbDKHS1e9dqFuuYWZNv  semiCarefulBehavior     13.00    16.00            True
# -MbDKuEXBIYZqELqb0wJ  semiCarefulBehavior     18.00    15.00            True
# -MbDLFEhzuXPYEVSqp2b  semiCarefulBehavior     17.00    19.00            True
# -MbDMKyIZcsBt6mW5uqg  semiCarefulBehavior     17.00    20.00            True
# -MbDOLsaDHZqSw4jZPyi  semiCarefulBehavior     15.00    17.00            True
# -MbDOVZ_AGPpsxtxAMx4  semiCarefulBehavior     16.00    19.00            True
# -MbDPFmRRxNSg3_1MEVH  semiCarefulBehavior     17.00    20.00            True
# -MbDQL3mU1VChQYCm-Nn  semiCarefulBehavior      2.00     2.00            True
# -MbDQYIFsFLYfGbDumPY  semiCarefulBehavior     20.00    23.00            True
# -MbDSY0U-cbu1AMFXESz  semiCarefulBehavior   -124.00  -124.00            True
# -MbDU3ACbK8eSFfjjM7o  semiCarefulBehavior   -113.00  -113.00            True
# -MbDVQKHoXZXjJ0Fm87p  semiCarefulBehavior   -113.00  -113.00            True
# -MbDXCiHM2bM5_JfnpxR  semiCarefulBehavior     22.00    25.00            True
# -MbDYUppxghDQUiprnqu  semiCarefulBehavior     20.00    23.00            True
# -MbDawhpQ85kPm0SlM9c  semiCarefulBehavior     14.00    16.00            True
# -MbMUlNQctXe_S7NRJee  semiCarefulBehavior     20.00    23.00            True
# -MbMUrK_7aAJjug_tLeO  semiCarefulBehavior     21.00    24.00            True
# -MbMUtNCAXKhu7gTKEg2  semiCarefulBehavior     15.00    18.00            True
# -MbMVIIPvpYVkjejWCzL  semiCarefulBehavior   -107.00  -107.00            True
# -MbMVKB0JnnBgwkZcDlK  semiCarefulBehavior     20.00    23.00            True
# -MbMVSZX7Ip55cIQjrdZ  semiCarefulBehavior   -137.00  -137.00            True
# -MbMVdjFeBm0dxpC9vjv  semiCarefulBehavior     17.00    20.00            True
# -MbMVlkoP9eoW1dk7AeO  semiCarefulBehavior   -136.00  -136.00            True
# -MbMWOSsCLRpT00c08Uj  semiCarefulBehavior     17.00    20.00            True
# -MbMWpOkaerwCXsyAzUQ  semiCarefulBehavior     12.00    14.00            True
# -MbMbljNhFkFkFSyJwHD  semiCarefulBehavior   -106.00  -106.00            True
# -MbMcUaa5BcFWRlgsd0v  semiCarefulBehavior      9.00    12.00            True
# -MbMjbHpvelxKHVTFedP  semiCarefulBehavior     20.00    22.00            True
# -MbN-xMTYjYchEVTdJ0e  semiCarefulBehavior   -111.00  -111.00            True
# -MbTT8AhnwoNxhvSev2B  semiCarefulBehavior     19.00    22.00            True
# -MbTTrtKDNBfKgUF94l_  semiCarefulBehavior     17.00    20.00            True
# -MbTVbO-0yOiOsU7WriY  semiCarefulBehavior     17.00    19.00            True
#
# [43 rows x 56 columns]

# %%
# c.to_json('data/c1.json', orient = "index", indent=2)

# %%
def numberOfStepsRemaining(col):
    blueState = col.split(' ')[2]
    prev = int(blueState[1])
    if prev == 1:
        return 0
    if blueState[0] == 'b':
        return prev
    else:
        return prev-1

def isColliding(col):
    if ('&a5 right' in col) and ('b6 stay&' not in col) and ('b6 up&' not in col):
        return False
    else:
        return True
def calcBlueRedScore(df):
    blueRedScoreById = pd.DataFrame(index=df.index, columns=['blueScore', 'redScore'])

    blueScores = []
    redScores = []
    df_len = len(df.columns)
    for i, row in df.iterrows():
        blueScore = -2
        redScore = -2
        NotNullLastCol = row[str(1) + '&' + str(1+1)]
        for i in range(2,df_len -4):
            if type(row[str(i) + '&' + str(i+1)]) != float: # game not ended
                redScore = redScore-1
                if row[str(i) + '&' + str(i+1)].split(' ')[2] != 'a1': #blueBall not get to 'a1'
                    blueScore = blueScore-1
                NotNullLastCol = row[str(i) + '&' + str(i+1)]
            else:
                if isColliding(NotNullLastCol):
#                     print(NotNullLastCol)
                    redScore += -100
                    blueScore = redScore
                else:
                    redScore += 30
                    blueScore += 30 + (-1)*numberOfStepsRemaining(NotNullLastCol) + 1
                break
        blueScores.append(blueScore)
        redScores.append(redScore)
#         print(redScore)
#         print(blueScore)
    blueRedScoreById['blueScore'] = blueScores
    blueRedScoreById['redScore'] = redScores
    return blueRedScoreById

# %%
# blueRedScoreById = calcBlueRedScore(log_red_copy)
# blueRedScoreById.reset_index(inplace=True)

# joined_df= df.merge(blueRedScoreById, on='index', how='left')
# joined_df = joined_df.rename(columns={'blueScore_y': 'blueScore', 'redScore_y': 'redScore'})
# joined_df.set_index(joined_df['index'], inplace=True)
# joined_df = joined_df.drop(['index','blueScore_x','redScore_x', 'WorkerId'], axis=1)
# joined_df

# %%
# joined_df.to_json('data/test.json', orient = "index", indent=2)

# %%
result = pd.DataFrame(index=log_red.index.drop_duplicates(), columns=['right', 'stay', 'up', 'down'])
# result.reset_index(level=0, inplace=True)
for action in ['right', 'stay', 'up', 'down']:
    result[action] = log_red[log_red['action'] == action]['value']
result = result.fillna(0)
result.reset_index(inplace=True)
result.sort_index()
# Out:
#                 state  right  stay   up  down
# 0    a1 a2 nxt: a1 a2   1.00  0.00 0.00  0.00
# 1    a1 a2 nxt: a1 a3  25.00  1.00 0.00  1.00
# 2    a1 a2 nxt: a1 b2   0.00  1.00 1.00  0.00
# 3    a1 a3 nxt: a1 a3   1.00  6.00 0.00  3.00
# 4    a1 a3 nxt: a1 a4  88.00  0.00 0.00  0.00
# ..                ...    ...   ...  ...   ...
# 245  b6 b1 nxt: b6 a1   2.00  0.00 0.00  0.00
# 246  b6 b1 nxt: b6 b1   0.00  2.00 0.00  0.00
# 247  b6 b4 nxt: a6 a4   1.00  0.00 0.00  0.00
# 248  b6 b5 nxt: b6 a5  24.00  3.00 0.00  3.00
# 249  b6 b5 nxt: b6 b5   0.00  1.00 2.00  0.00
#
# [250 rows x 5 columns]

# %%
# laplace smoving:
for i in range(1,7):
    result.loc[result['state'].str.endswith('a'+str(i)), ['stay', 'right', 'down']] += 1
    
for i in range(1,7):
    result.loc[result['state'].str.endswith('b'+str(i)), ['stay', 'up']] += 1

result = result.set_index('state')
result
# Out:
#                   right  stay   up  down
# state
# a1 a2 nxt: a1 a2   2.00  1.00 0.00  1.00
# a1 a2 nxt: a1 a3  26.00  2.00 0.00  2.00
# a1 a2 nxt: a1 b2   0.00  2.00 2.00  0.00
# a1 a3 nxt: a1 a3   2.00  7.00 0.00  4.00
# a1 a3 nxt: a1 a4  89.00  1.00 0.00  1.00
# ...                 ...   ...  ...   ...
# b6 b1 nxt: b6 a1   3.00  1.00 0.00  1.00
# b6 b1 nxt: b6 b1   0.00  3.00 1.00  0.00
# b6 b4 nxt: a6 a4   2.00  1.00 0.00  1.00
# b6 b5 nxt: b6 a5  25.00  4.00 0.00  4.00
# b6 b5 nxt: b6 b5   0.00  2.00 3.00  0.00
#
# [250 rows x 4 columns]

# %% [markdown]
# #### Convert it to Probability table:

# %%
pd.options.display.float_format = "{:,.2f}".format
result_probs = result.div(result.sum(axis=1), axis=0)

# %% [markdown]
# #### Save data on computer for the policy iteration:

# %%
result_probs.to_json('data/probs2.json' , orient='index', indent=4)

# %%
def possibleFutureStates(s):
    n_l = []
    for a in actions[s]:
#         print('s: ', adapt_state((3,2)))
#         print(a)
        n = nextStateDistibution(s, a)
        n_l.extend([elm for elm in n])
#         print('n: ', n)
#         print('n_l: ', n_l)
    return n_l

possibleStatesForState = {}
for s in all_states:
    if s in Policy:
        poss_states = possibleFutureStates(s)
        possibleStatesForState[s] = [s for s in poss_states]

# %%
'''==================================================
Initial set up                              version 2
=================================================='''
#Define all states
all_states=[]
for prev_state in possibleStatesForState:
    poss_states = possibleStatesForState[prev_state]
    for curr_state in poss_states:
        # current state: (i,j), previous state: (l,k)
        all_states.append((curr_state,prev_state))
all_states.append(((5,0),(-10, -10)))

#Define rewards for all states
rewards = {}
for ((i,j),(l,k)) in all_states:
    if(i == j): # crushed
        rewards[((i,j),(l,k))] = crushing
    elif(i == 0 and j != 0): # blue agent in a1
        rewards[((i,j),(l,k))] = richToDestination
    else:
        rewards[((i,j),(l,k))] = step

#Dictionnary of possible actions. We have two "end" states (1,2 and 2,2)
actions = {}
for ((i,j),(l,k)) in all_states:
    if i != 0 and i != j: #if s=((i, j),(l, k)) is not an "end" state
        actions[((i,j),(l,k))] = ("stay", "left", "down") if (i < 6) else ("up", "stay")

probs = json.load(open('data/probs2.json',))

#Define an initial policy
Policy={}
for s in actions.keys():
    Policy[s] = np.random.choice(actions[s])
    
#Define initial value function 
V={}
for s in all_states:
     V[s] = rewards[s]

# %%
def nextStateDistibution2(s, a):
    # given state s and action a, return distibution of possibles new states by probs
    nxt = {}
#     print('s: ', s)
#     print('a: ', a)
    bluePossition = newPosGivenAction(s[0], a, 0)
#     print('bluePossition: ', bluePossition)
    
    # red possible action given state
    if s[0][1] == 5:
        actions=["stay"]
    elif s[0][1] < 6:
        actions=["right","stay", "down"]
    else:
        actions=["stay", "up"]
#     print('actions: ', actions)
    for r_a in actions:
        redPossition = newPosGivenAction(s[0], r_a, 1)
#         print('r_a: ', r_a)
#         print('redPossition: ', redPossition)
        newState = ((bluePossition, redPossition),s[0])
#         print('newState: ', newState)
        try:
            nxt[newState] = probs[adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0])][r_a]
        except KeyError:
#             print("Warning! State not found: assume random behavior. ", s[0])
            nxt[newState] = randomProbForAction(s[0])
    assert abs(sum(nxt.values()) - 1.0) < 0.0001, "probs not sum to 1.0. \nstate: " + str(s) + " action: " + str(a) + " nxt: " + str(nxt) + "\nsum of probs: " + str(sum(nxt.values()))
    return nxt

# %%
pp.pprint(nextStateDistibution2(((0, 4),(1, 4)), "stay"))
pp.pprint(nextStateDistibution2(((4, 1),(5, 0)), "left"))
# Out:
# {((0, 4), (0, 4)): 0.25, ((0, 5), (0, 4)): 0.5, ((0, 10), (0, 4)): 0.25}
# {((3, 1), (4, 1)): 0.0307692308,
#  ((3, 2), (4, 1)): 0.8346153846,
#  ((3, 7), (4, 1)): 0.1346153846}

# %%
(adapt_state((1, 8)), adapt_state((1, 8)))
# Out:
# ('a2 b3', 'a2 b3')

# %%
(adapt_state((1, 2)), adapt_state((1, 8)))
# Out:
# ('a2 a3', 'a2 b3')

# %%
s = ((1, 8), (2, 8))
print((adapt_state((1, 8)), adapt_state((2, 8))))
print(adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0]))
probs[adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0])]
# Out:
# ('a2 b3', 'a3 b3')
# a3 b3 nxt: a2 b3
# {'right': 0.0, 'stay': 0.1166666667, 'up': 0.8833333333, 'down': 0.0}

# %%
pp.pprint(nextStateDistibution2(s, "stay"))
# Out:
# {((1, 2), (1, 8)): 0.8833333333, ((1, 8), (1, 8)): 0.1166666667}

# %%
'''==================================================
Value Iteration
=================================================='''

iteration = 1

while True:
    biggest_change = 0
    for s in all_states:            
        if s in Policy:
            
            old_v = V[s]
            new_v = np.NINF
            
            for a in actions[s]:
#                 print("actions: ", actions[s])
#                 print("action: ", a)
#                 print("state: ", s)
                nxt = nextStateDistibution2(s, a)
#                 print("nxt:", nxt)
                
                v=0
                #Calculate the value
                for next_state, prob in nxt.items():
#                     print("next_state: ", next_state)
#                     print("prob: ", prob)
#                     print('V[next_state]: ', V[next_state])
                    assert rewards[s] == -1, "rewards is not -1"
                    v += prob * (rewards[s] + GAMMA * V[next_state])
#                 print('v: ', v)
#                 print()
                if v > new_v: #Is this the best action so far? If so, keep it
                    new_v = v
                    Policy[s] = a

           #Save the best of all actions for the state                                
            V[s] = new_v
            biggest_change = max(biggest_change, np.abs(old_v - V[s]))

            
   #See if the loop should stop now         
    if biggest_change < SMALL_ENOUGH:
        print('converge after: ' + str(iteration) + ' iterations')
        break
    iteration += 1
    
    #Print every 100 iterations
    if(iteration % 100 == 0):
        print(iteration, ') ')
# Out:
# 100 )
# converge after: 140 iterations

# %%
def convertStates(Policy):
    P_convert= {}
    V_convert = {}
    for s,v in V.items():
        V_convert[adapt_state(s[0]) + ',' + adapt_state(s[1])] = v
    
#     print()
    for s,p in Policy.items():
        P_convert[adapt_state(s[0]) + ',' + adapt_state(s[1])] = p
    
#     pp.pprint(V_convert)
#     pp.pprint(P_convert)
    return P_convert, V_convert

# %%
# print the results:
print("iterations: ", iteration)
optimal_policy_v2, optimal_V_v2 = convertStates(Policy)
# Out:
# iterations:  140

# %%
optimal_policy_v2
# Out:
# {'a2 a1,a2 a1': 'down',
#  'a2 b1,a2 a1': 'down',
#  'b2 a2,a2 a1': 'up',
#  'b2 a1,a2 a1': 'stay',
#  'b2 b1,a2 a1': 'up',
#  'a2 a4,a2 a3': 'left',
#  'a2 a3,a2 a3': 'left',
#  'a2 b3,a2 a3': 'left',
#  'b2 a4,a2 a3': 'up',
#  'b2 a3,a2 a3': 'up',
#  'b2 b3,a2 a3': 'up',
#  'a2 a5,a2 a4': 'left',
#  'a2 a4,a2 a4': 'left',
#  'a2 b4,a2 a4': 'left',
#  'b2 a5,a2 a4': 'up',
#  'b2 a4,a2 a4': 'up',
#  'b2 b4,a2 a4': 'up',
#  'a2 a6,a2 a5': 'left',
#  'a2 a5,a2 a5': 'left',
#  'a2 b5,a2 a5': 'left',
#  'b2 a6,a2 a5': 'up',
#  'b2 a5,a2 a5': 'up',
#  'b2 b5,a2 a5': 'up',
#  'a2 a6,a2 a6': 'left',
#  'b2 a6,a2 a6': 'up',
#  'a2 b1,a2 b1': 'down',
#  'a2 a1,a2 b1': 'down',
#  'b2 b1,a2 b1': 'up',
#  'b2 a1,a2 b1': 'stay',
#  'a2 b2,a2 b2': 'left',
#  'b2 a2,a2 b2': 'up',
#  'a2 b3,a2 b3': 'left',
#  'a2 a3,a2 b3': 'left',
#  'b2 b3,a2 b3': 'up',
#  'b2 a3,a2 b3': 'up',
#  'a2 b4,a2 b4': 'left',
#  'a2 a4,a2 b4': 'left',
#  'b2 b4,a2 b4': 'up',
#  'b2 a4,a2 b4': 'up',
#  'a2 b5,a2 b5': 'left',
#  'a2 a5,a2 b5': 'left',
#  'b2 b5,a2 b5': 'up',
#  'b2 a5,a2 b5': 'up',
#  'a2 b6,a2 b6': 'left',
#  'a2 a6,a2 b6': 'left',
#  'b2 b6,a2 b6': 'up',
#  'b2 a6,a2 b6': 'up',
#  'a3 a2,a3 a1': 'down',
#  'a3 a1,a3 a1': 'down',
#  'a3 b1,a3 a1': 'left',
#  'a2 a1,a3 a1': 'down',
#  'a2 b1,a3 a1': 'down',
#  'b3 a2,a3 a1': 'stay',
#  'b3 a1,a3 a1': 'up',
#  'b3 b1,a3 a1': 'up',
#  'a3 a2,a3 a2': 'down',
#  'a3 b2,a3 a2': 'stay',
#  'a2 a3,a3 a2': 'left',
#  'a2 b2,a3 a2': 'left',
#  'b3 a3,a3 a2': 'up',
#  'b3 a2,a3 a2': 'stay',
#  'b3 b2,a3 a2': 'up',
#  'a3 a5,a3 a4': 'left',
#  'a3 a4,a3 a4': 'left',
#  'a3 b4,a3 a4': 'left',
#  'a2 a5,a3 a4': 'left',
#  'a2 a4,a3 a4': 'left',
#  'a2 b4,a3 a4': 'left',
#  'b3 a5,a3 a4': 'up',
#  'b3 a4,a3 a4': 'up',
#  'b3 b4,a3 a4': 'up',
#  'a3 a6,a3 a5': 'left',
#  'a3 a5,a3 a5': 'left',
#  'a3 b5,a3 a5': 'left',
#  'a2 a6,a3 a5': 'left',
#  'a2 a5,a3 a5': 'left',
#  'a2 b5,a3 a5': 'left',
#  'b3 a6,a3 a5': 'up',
#  'b3 a5,a3 a5': 'up',
#  'b3 b5,a3 a5': 'up',
#  'a3 a6,a3 a6': 'left',
#  'a2 a6,a3 a6': 'left',
#  'b3 a6,a3 a6': 'up',
#  'a3 b1,a3 b1': 'left',
#  'a3 a1,a3 b1': 'stay',
#  'a2 b1,a3 b1': 'down',
#  'a2 a1,a3 b1': 'left',
#  'b3 b1,a3 b1': 'up',
#  'b3 a1,a3 b1': 'up',
#  'a3 b2,a3 b2': 'down',
#  'a3 a2,a3 b2': 'down',
#  'a2 b2,a3 b2': 'left',
#  'b3 b2,a3 b2': 'up',
#  'b3 a2,a3 b2': 'stay',
#  'a3 b3,a3 b3': 'left',
#  'a2 b3,a3 b3': 'left',
#  'a2 a3,a3 b3': 'left',
#  'b3 a3,a3 b3': 'up',
#  'a3 b4,a3 b4': 'left',
#  'a3 a4,a3 b4': 'left',
#  'a2 b4,a3 b4': 'left',
#  'a2 a4,a3 b4': 'left',
#  'b3 b4,a3 b4': 'up',
#  'b3 a4,a3 b4': 'up',
#  'a3 b5,a3 b5': 'left',
#  'a3 a5,a3 b5': 'left',
#  'a2 b5,a3 b5': 'left',
#  'a2 a5,a3 b5': 'left',
#  'b3 b5,a3 b5': 'up',
#  'b3 a5,a3 b5': 'up',
#  'a3 b6,a3 b6': 'left',
#  'a3 a6,a3 b6': 'left',
#  'a2 b6,a3 b6': 'left',
#  'a2 a6,a3 b6': 'left',
#  'b3 b6,a3 b6': 'up',
#  'b3 a6,a3 b6': 'up',
#  'a4 a2,a4 a1': 'stay',
#  'a4 a1,a4 a1': 'left',
#  'a4 b1,a4 a1': 'stay',
#  'a3 a2,a4 a1': 'left',
#  'a3 a1,a4 a1': 'down',
#  'a3 b1,a4 a1': 'left',
#  'b4 a2,a4 a1': 'up',
#  'b4 a1,a4 a1': 'up',
#  'b4 b1,a4 a1': 'up',
#  'a4 a3,a4 a2': 'down',
#  'a4 a2,a4 a2': 'down',
#  'a4 b2,a4 a2': 'stay',
#  'a3 a2,a4 a2': 'down',
#  'a3 b2,a4 a2': 'stay',
#  'b4 a3,a4 a2': 'stay',
#  'b4 a2,a4 a2': 'up',
#  'b4 b2,a4 a2': 'up',
#  'a4 a3,a4 a3': 'down',
#  'a4 b3,a4 a3': 'down',
#  'a3 a4,a4 a3': 'left',
#  'a3 b3,a4 a3': 'left',
#  'b4 a4,a4 a3': 'up',
#  'b4 a3,a4 a3': 'stay',
#  'b4 b3,a4 a3': 'stay',
#  'a4 a6,a4 a5': 'left',
#  'a4 a5,a4 a5': 'left',
#  'a4 b5,a4 a5': 'left',
#  'a3 a6,a4 a5': 'left',
#  'a3 a5,a4 a5': 'left',
#  'a3 b5,a4 a5': 'left',
#  'b4 a6,a4 a5': 'up',
#  'b4 a5,a4 a5': 'up',
#  'b4 b5,a4 a5': 'up',
#  'a4 a6,a4 a6': 'left',
#  'a3 a6,a4 a6': 'left',
#  'b4 a6,a4 a6': 'up',
#  'a4 b1,a4 b1': 'down',
#  'a4 a1,a4 b1': 'left',
#  'a3 b1,a4 b1': 'stay',
#  'a3 a1,a4 b1': 'stay',
#  'b4 b1,a4 b1': 'up',
#  'b4 a1,a4 b1': 'up',
#  'a4 b2,a4 b2': 'left',
#  'a4 a2,a4 b2': 'down',
#  'a3 b2,a4 b2': 'down',
#  'a3 a2,a4 b2': 'left',
#  'b4 b2,a4 b2': 'up',
#  'b4 a2,a4 b2': 'up',
#  'a4 b3,a4 b3': 'down',
#  'a4 a3,a4 b3': 'down',
#  'a3 b3,a4 b3': 'left',
#  'b4 b3,a4 b3': 'stay',
#  'b4 a3,a4 b3': 'stay',
#  'a4 b4,a4 b4': 'left',
#  'a3 b4,a4 b4': 'left',
#  'a3 a4,a4 b4': 'left',
#  'b4 a4,a4 b4': 'up',
#  'a4 b5,a4 b5': 'left',
#  'a4 a5,a4 b5': 'left',
#  'a3 b5,a4 b5': 'left',
#  'a3 a5,a4 b5': 'left',
#  'b4 b5,a4 b5': 'up',
#  'b4 a5,a4 b5': 'up',
#  'a4 b6,a4 b6': 'left',
#  'a4 a6,a4 b6': 'left',
#  'a3 b6,a4 b6': 'left',
#  'a3 a6,a4 b6': 'left',
#  'b4 b6,a4 b6': 'up',
#  'b4 a6,a4 b6': 'up',
#  'a5 a2,a5 a1': 'left',
#  'a5 a1,a5 a1': 'stay',
#  'a5 b1,a5 a1': 'stay',
#  'a4 a2,a5 a1': 'stay',
#  'a4 a1,a5 a1': 'left',
#  'a4 b1,a5 a1': 'stay',
#  'b5 a2,a5 a1': 'up',
#  'b5 a1,a5 a1': 'up',
#  'b5 b1,a5 a1': 'up',
#  'a5 a3,a5 a2': 'stay',
#  'a5 a2,a5 a2': 'left',
#  'a5 b2,a5 a2': 'stay',
#  'a4 a3,a5 a2': 'left',
#  'a4 a2,a5 a2': 'stay',
#  'a4 b2,a5 a2': 'left',
#  'b5 a3,a5 a2': 'up',
#  'b5 a2,a5 a2': 'up',
#  'b5 b2,a5 a2': 'up',
#  'a5 a4,a5 a3': 'left',
#  'a5 a3,a5 a3': 'stay',
#  'a5 b3,a5 a3': 'left',
#  'a4 a3,a5 a3': 'down',
#  'a4 b3,a5 a3': 'down',
#  'b5 a4,a5 a3': 'stay',
#  'b5 a3,a5 a3': 'up',
#  'b5 b3,a5 a3': 'up',
#  'a5 a4,a5 a4': 'down',
#  'a5 b4,a5 a4': 'down',
#  'a4 a5,a5 a4': 'left',
#  'a4 b4,a5 a4': 'left',
#  'b5 a5,a5 a4': 'up',
#  'b5 a4,a5 a4': 'stay',
#  'b5 b4,a5 a4': 'stay',
#  'a5 a6,a5 a6': 'left',
#  'a4 a6,a5 a6': 'left',
#  'b5 a6,a5 a6': 'up',
#  'a5 b1,a5 b1': 'stay',
#  'a5 a1,a5 b1': 'stay',
#  'a4 b1,a5 b1': 'down',
#  'a4 a1,a5 b1': 'left',
#  'b5 b1,a5 b1': 'up',
#  'b5 a1,a5 b1': 'up',
#  'a5 b2,a5 b2': 'stay',
#  'a5 a2,a5 b2': 'left',
#  'a4 b2,a5 b2': 'left',
#  'a4 a2,a5 b2': 'stay',
#  'b5 b2,a5 b2': 'up',
#  'b5 a2,a5 b2': 'up',
#  'a5 b3,a5 b3': 'left',
#  'a5 a3,a5 b3': 'stay',
#  'a4 b3,a5 b3': 'down',
#  'a4 a3,a5 b3': 'down',
#  'b5 b3,a5 b3': 'up',
#  'b5 a3,a5 b3': 'up',
#  'a5 b4,a5 b4': 'down',
#  'a5 a4,a5 b4': 'down',
#  'a4 b4,a5 b4': 'left',
#  'b5 b4,a5 b4': 'stay',
#  'b5 a4,a5 b4': 'stay',
#  'a5 b5,a5 b5': 'left',
#  'a4 b5,a5 b5': 'left',
#  'a4 a5,a5 b5': 'left',
#  'b5 a5,a5 b5': 'up',
#  'a5 b6,a5 b6': 'left',
#  'a5 a6,a5 b6': 'left',
#  'a4 b6,a5 b6': 'left',
#  'a4 a6,a5 b6': 'left',
#  'b5 b6,a5 b6': 'up',
#  'b5 a6,a5 b6': 'up',
#  'a6 a2,a6 a1': 'stay',
#  'a6 a1,a6 a1': 'left',
#  'a6 b1,a6 a1': 'left',
#  'a5 a2,a6 a1': 'left',
#  'a5 a1,a6 a1': 'stay',
#  'a5 b1,a6 a1': 'left',
#  'b6 a2,a6 a1': 'up',
#  'b6 a1,a6 a1': 'up',
#  'b6 b1,a6 a1': 'up',
#  'a6 a3,a6 a2': 'stay',
#  'a6 a2,a6 a2': 'stay',
#  'a6 b2,a6 a2': 'left',
#  'a5 a3,a6 a2': 'stay',
#  'a5 a2,a6 a2': 'left',
#  'a5 b2,a6 a2': 'stay',
#  'b6 a3,a6 a2': 'up',
#  'b6 a2,a6 a2': 'up',
#  'b6 b2,a6 a2': 'up',
#  'a6 a4,a6 a3': 'stay',
#  'a6 a3,a6 a3': 'stay',
#  'a6 b3,a6 a3': 'down',
#  'a5 a4,a6 a3': 'down',
#  'a5 a3,a6 a3': 'stay',
#  'a5 b3,a6 a3': 'left',
#  'b6 a4,a6 a3': 'up',
#  'b6 a3,a6 a3': 'up',
#  'b6 b3,a6 a3': 'up',
#  'a6 a5,a6 a4': 'left',
#  'a6 a4,a6 a4': 'stay',
#  'a6 b4,a6 a4': 'stay',
#  'a5 a4,a6 a4': 'down',
#  'a5 b4,a6 a4': 'down',
#  'b6 a5,a6 a4': 'up',
#  'b6 a4,a6 a4': 'up',
#  'b6 b4,a6 a4': 'up',
#  'a6 a5,a6 a5': 'left',
#  'a6 b5,a6 a5': 'stay',
#  'a5 a6,a6 a5': 'left',
#  'a5 b5,a6 a5': 'left',
#  'b6 a6,a6 a5': 'up',
#  'b6 a5,a6 a5': 'up',
#  'b6 b5,a6 a5': 'up',
#  'a6 b1,a6 b1': 'left',
#  'a6 a1,a6 b1': 'left',
#  'a5 b1,a6 b1': 'stay',
#  'a5 a1,a6 b1': 'stay',
#  'b6 b1,a6 b1': 'up',
#  'b6 a1,a6 b1': 'up',
#  'a6 b2,a6 b2': 'left',
#  'a6 a2,a6 b2': 'stay',
#  'a5 b2,a6 b2': 'stay',
#  'a5 a2,a6 b2': 'left',
#  'b6 b2,a6 b2': 'up',
#  'b6 a2,a6 b2': 'up',
#  'a6 b3,a6 b3': 'down',
#  'a6 a3,a6 b3': 'stay',
#  'a5 b3,a6 b3': 'left',
#  'a5 a3,a6 b3': 'stay',
#  'b6 b3,a6 b3': 'up',
#  'b6 a3,a6 b3': 'up',
#  'a6 b4,a6 b4': 'stay',
#  'a6 a4,a6 b4': 'stay',
#  'a5 b4,a6 b4': 'down',
#  'a5 a4,a6 b4': 'down',
#  'b6 b4,a6 b4': 'up',
#  'b6 a4,a6 b4': 'up',
#  'a6 b5,a6 b5': 'stay',
#  'a6 a5,a6 b5': 'left',
#  'a5 b5,a6 b5': 'left',
#  'b6 b5,a6 b5': 'up',
#  'b6 a5,a6 b5': 'up',
#  'a6 b6,a6 b6': 'left',
#  'a5 b6,a6 b6': 'left',
#  'a5 a6,a6 b6': 'left',
#  'b6 a6,a6 b6': 'up',
#  'b1 a2,b1 a1': 'up',
#  'b1 a1,b1 a1': 'up',
#  'b1 a3,b1 a2': 'up',
#  'b1 a2,b1 a2': 'up',
#  'b1 b2,b1 a2': 'up',
#  'b1 a4,b1 a3': 'up',
#  'b1 a3,b1 a3': 'up',
#  'b1 b3,b1 a3': 'up',
#  'b1 a5,b1 a4': 'up',
#  'b1 a4,b1 a4': 'up',
#  'b1 b4,b1 a4': 'up',
#  'b1 a6,b1 a5': 'up',
#  'b1 a5,b1 a5': 'up',
#  'b1 b5,b1 a5': 'up',
#  'b1 a6,b1 a6': 'up',
#  'b1 b2,b1 b2': 'up',
#  'b1 a2,b1 b2': 'up',
#  'b1 b3,b1 b3': 'up',
#  'b1 a3,b1 b3': 'up',
#  'b1 b4,b1 b4': 'up',
#  'b1 a4,b1 b4': 'up',
#  'b1 b5,b1 b5': 'up',
#  'b1 a5,b1 b5': 'up',
#  'b1 b6,b1 b6': 'up',
#  'b1 a6,b1 b6': 'up',
#  'a2 a1,b2 a1': 'down',
#  'a2 b1,b2 a1': 'down',
#  'b2 a2,b2 a1': 'up',
#  'b2 a1,b2 a1': 'stay',
#  'b2 b1,b2 a1': 'up',
#  'a2 a3,b2 a2': 'left',
#  'a2 b2,b2 a2': 'left',
#  'b2 a3,b2 a2': 'up',
#  'b2 a2,b2 a2': 'up',
#  'a2 a4,b2 a3': 'left',
#  'a2 a3,b2 a3': 'left',
#  'a2 b3,b2 a3': 'left',
#  'b2 a4,b2 a3': 'up',
#  'b2 a3,b2 a3': 'up',
#  'b2 b3,b2 a3': 'up',
#  'a2 a5,b2 a4': 'left',
#  'a2 a4,b2 a4': 'left',
#  'a2 b4,b2 a4': 'left',
#  'b2 a5,b2 a4': 'up',
#  'b2 a4,b2 a4': 'up',
#  'b2 b4,b2 a4': 'up',
#  'a2 a6,b2 a5': 'left',
#  'a2 a5,b2 a5': 'left',
#  'a2 b5,b2 a5': 'left',
#  'b2 a6,b2 a5': 'up',
#  'b2 a5,b2 a5': 'up',
#  'b2 b5,b2 a5': 'up',
#  'a2 a6,b2 a6': 'left',
#  'b2 a6,b2 a6': 'up',
#  'a2 b1,b2 b1': 'down',
#  'a2 a1,b2 b1': 'left',
#  'b2 b1,b2 b1': 'up',
#  'b2 a1,b2 b1': 'stay',
#  'a2 b3,b2 b3': 'left',
#  'a2 a3,b2 b3': 'left',
#  'b2 b3,b2 b3': 'up',
#  'b2 a3,b2 b3': 'up',
#  'a2 b4,b2 b4': 'left',
#  'a2 a4,b2 b4': 'left',
#  'b2 b4,b2 b4': 'up',
#  'b2 a4,b2 b4': 'up',
#  'a2 b5,b2 b5': 'left',
#  'a2 a5,b2 b5': 'left',
#  'b2 b5,b2 b5': 'up',
#  'b2 a5,b2 b5': 'up',
#  'a2 b6,b2 b6': 'left',
#  'a2 a6,b2 b6': 'left',
#  'b2 b6,b2 b6': 'up',
#  'b2 a6,b2 b6': 'up',
#  'a3 a2,b3 a1': 'down',
#  'a3 a1,b3 a1': 'stay',
#  'a3 b1,b3 a1': 'left',
#  'b3 a2,b3 a1': 'stay',
#  'b3 a1,b3 a1': 'up',
#  'b3 b1,b3 a1': 'up',
#  'a3 a2,b3 a2': 'down',
#  'a3 b2,b3 a2': 'stay',
#  'b3 a3,b3 a2': 'up',
#  'b3 a2,b3 a2': 'stay',
#  'b3 b2,b3 a2': 'up',
#  'a3 a4,b3 a3': 'left',
#  'a3 b3,b3 a3': 'left',
#  'b3 a4,b3 a3': 'up',
#  'b3 a3,b3 a3': 'up',
#  'a3 a5,b3 a4': 'left',
#  'a3 a4,b3 a4': 'left',
#  'a3 b4,b3 a4': 'left',
#  'b3 a5,b3 a4': 'up',
#  'b3 a4,b3 a4': 'up',
#  'b3 b4,b3 a4': 'up',
#  'a3 a6,b3 a5': 'left',
#  'a3 a5,b3 a5': 'left',
#  'a3 b5,b3 a5': 'left',
#  'b3 a6,b3 a5': 'up',
#  'b3 a5,b3 a5': 'up',
#  'b3 b5,b3 a5': 'up',
#  'a3 a6,b3 a6': 'left',
#  'b3 a6,b3 a6': 'up',
#  'a3 b1,b3 b1': 'left',
#  'a3 a1,b3 b1': 'stay',
#  'b3 b1,b3 b1': 'up',
#  'b3 a1,b3 b1': 'up',
#  'a3 b2,b3 b2': 'stay',
#  'a3 a2,b3 b2': 'down',
#  'b3 b2,b3 b2': 'up',
#  'b3 a2,b3 b2': 'stay',
#  'a3 b4,b3 b4': 'left',
#  'a3 a4,b3 b4': 'left',
#  'b3 b4,b3 b4': 'up',
#  'b3 a4,b3 b4': 'up',
#  'a3 b5,b3 b5': 'left',
#  'a3 a5,b3 b5': 'left',
#  'b3 b5,b3 b5': 'up',
#  'b3 a5,b3 b5': 'up',
#  'a3 b6,b3 b6': 'left',
#  'a3 a6,b3 b6': 'left',
#  'b3 b6,b3 b6': 'up',
#  'b3 a6,b3 b6': 'up',
#  'a4 a2,b4 a1': 'stay',
#  'a4 a1,b4 a1': 'left',
#  'a4 b1,b4 a1': 'stay',
#  'b4 a2,b4 a1': 'up',
#  'b4 a1,b4 a1': 'up',
#  'b4 b1,b4 a1': 'up',
#  'a4 a3,b4 a2': 'down',
#  'a4 a2,b4 a2': 'stay',
#  'a4 b2,b4 a2': 'left',
#  'b4 a3,b4 a2': 'stay',
#  'b4 a2,b4 a2': 'up',
#  'b4 b2,b4 a2': 'up',
#  'a4 a3,b4 a3': 'down',
#  'a4 b3,b4 a3': 'down',
#  'b4 a4,b4 a3': 'up',
#  'b4 a3,b4 a3': 'stay',
#  'b4 b3,b4 a3': 'stay',
#  'a4 a5,b4 a4': 'left',
#  'a4 b4,b4 a4': 'left',
#  'b4 a5,b4 a4': 'up',
#  'b4 a4,b4 a4': 'stay',
#  'a4 a6,b4 a5': 'left',
#  'a4 a5,b4 a5': 'left',
#  'a4 b5,b4 a5': 'left',
#  'b4 a6,b4 a5': 'up',
#  'b4 a5,b4 a5': 'up',
#  'b4 b5,b4 a5': 'up',
#  'a4 a6,b4 a6': 'left',
#  'b4 a6,b4 a6': 'up',
#  'a4 b1,b4 b1': 'stay',
#  'a4 a1,b4 b1': 'left',
#  'b4 b1,b4 b1': 'up',
#  'b4 a1,b4 b1': 'up',
#  'a4 b2,b4 b2': 'left',
#  'a4 a2,b4 b2': 'down',
#  'b4 b2,b4 b2': 'up',
#  'b4 a2,b4 b2': 'up',
#  'a4 b3,b4 b3': 'down',
#  'a4 a3,b4 b3': 'down',
#  'b4 b3,b4 b3': 'stay',
#  'b4 a3,b4 b3': 'stay',
#  'a4 b5,b4 b5': 'left',
#  'a4 a5,b4 b5': 'left',
#  'b4 b5,b4 b5': 'up',
#  'b4 a5,b4 b5': 'up',
#  'a4 b6,b4 b6': 'left',
#  'a4 a6,b4 b6': 'left',
#  'b4 b6,b4 b6': 'up',
#  'b4 a6,b4 b6': 'up',
#  'a5 a2,b5 a1': 'left',
#  'a5 a1,b5 a1': 'stay',
#  'a5 b1,b5 a1': 'stay',
#  'b5 a2,b5 a1': 'up',
#  'b5 a1,b5 a1': 'up',
#  'b5 b1,b5 a1': 'up',
#  'a5 a3,b5 a2': 'stay',
#  'a5 a2,b5 a2': 'left',
#  'a5 b2,b5 a2': 'stay',
#  'b5 a3,b5 a2': 'up',
#  'b5 a2,b5 a2': 'up',
#  'b5 b2,b5 a2': 'up',
#  'a5 a4,b5 a3': 'left',
#  'a5 a3,b5 a3': 'stay',
#  'a5 b3,b5 a3': 'left',
#  'b5 a4,b5 a3': 'stay',
#  'b5 a3,b5 a3': 'up',
#  'b5 b3,b5 a3': 'up',
#  'a5 a4,b5 a4': 'down',
#  'a5 b4,b5 a4': 'down',
#  'b5 a5,b5 a4': 'up',
#  'b5 a4,b5 a4': 'stay',
#  'b5 b4,b5 a4': 'stay',
#  'a5 a6,b5 a5': 'left',
#  'a5 b5,b5 a5': 'left',
#  'b5 a6,b5 a5': 'up',
#  'b5 a5,b5 a5': 'up',
#  'a5 a6,b5 a6': 'left',
#  'b5 a6,b5 a6': 'up',
#  'a5 b1,b5 b1': 'stay',
#  'a5 a1,b5 b1': 'stay',
#  'b5 b1,b5 b1': 'up',
#  'b5 a1,b5 b1': 'up',
#  'a5 b2,b5 b2': 'stay',
#  'a5 a2,b5 b2': 'left',
#  'b5 b2,b5 b2': 'up',
#  'b5 a2,b5 b2': 'up',
#  'a5 b3,b5 b3': 'left',
#  'a5 a3,b5 b3': 'stay',
#  'b5 b3,b5 b3': 'up',
#  'b5 a3,b5 b3': 'up',
#  'a5 b4,b5 b4': 'down',
#  'a5 a4,b5 b4': 'down',
#  'b5 b4,b5 b4': 'stay',
#  'b5 a4,b5 b4': 'stay',
#  'a5 b6,b5 b6': 'left',
#  'a5 a6,b5 b6': 'left',
#  'b5 b6,b5 b6': 'up',
#  'b5 a6,b5 b6': 'up',
#  'a6 a2,b6 a1': 'stay',
#  'a6 a1,b6 a1': 'left',
#  'a6 b1,b6 a1': 'left',
#  'b6 a2,b6 a1': 'up',
#  'b6 a1,b6 a1': 'up',
#  'b6 b1,b6 a1': 'up',
#  'a6 a3,b6 a2': 'stay',
#  'a6 a2,b6 a2': 'stay',
#  'a6 b2,b6 a2': 'left',
#  'b6 a3,b6 a2': 'up',
#  'b6 a2,b6 a2': 'up',
#  'b6 b2,b6 a2': 'up',
#  'a6 a4,b6 a3': 'stay',
#  'a6 a3,b6 a3': 'stay',
#  'a6 b3,b6 a3': 'down',
#  'b6 a4,b6 a3': 'up',
#  'b6 a3,b6 a3': 'up',
#  'b6 b3,b6 a3': 'up',
#  'a6 a5,b6 a4': 'left',
#  'a6 a4,b6 a4': 'stay',
#  'a6 b4,b6 a4': 'stay',
#  'b6 a5,b6 a4': 'up',
#  'b6 a4,b6 a4': 'up',
#  'b6 b4,b6 a4': 'up',
#  'a6 a5,b6 a5': 'left',
#  'a6 b5,b6 a5': 'stay',
#  'b6 a6,b6 a5': 'up',
#  'b6 a5,b6 a5': 'up',
#  'b6 b5,b6 a5': 'up',
#  'b6 a6,b6 a6': 'up',
#  'a6 b1,b6 b1': 'left',
#  'a6 a1,b6 b1': 'left',
#  'b6 b1,b6 b1': 'up',
#  'b6 a1,b6 b1': 'up',
#  'a6 b2,b6 b2': 'left',
#  'a6 a2,b6 b2': 'stay',
#  'b6 b2,b6 b2': 'up',
#  'b6 a2,b6 b2': 'up',
#  'a6 b3,b6 b3': 'down',
#  'a6 a3,b6 b3': 'stay',
#  'b6 b3,b6 b3': 'up',
#  'b6 a3,b6 b3': 'up',
#  'a6 b4,b6 b4': 'stay',
#  'a6 a4,b6 b4': 'stay',
#  'b6 b4,b6 b4': 'up',
#  'b6 a4,b6 b4': 'up',
#  'a6 b5,b6 b5': 'stay',
#  'a6 a5,b6 b5': 'left',
#  'b6 b5,b6 b5': 'up',
#  'b6 a5,b6 b5': 'up',
#  'a6 a1,a-9 a-9': 'left'}

# %%
def policy_eval2(policy):
    V={}
    for s in all_states:
        V[s] = rewards[s]
    while True:
        biggest_change = 0
        for s in all_states:
            if s in policy:
                old_v = V[s]
                nxt = nextStateDistibution2(s, policy[s])
                v=0
                #Calculate the value
                for next_state, prob in nxt.items():
                    assert rewards[s] == -1, "rewards[s] is not -1"
                    v += prob * (rewards[s] + GAMMA * V[next_state])
        
                #Save the best of all actions for the state                                
                V[s] = v
                biggest_change = max(biggest_change, np.abs(old_v - V[s]))
        #See if the loop should stop now         
        if biggest_change < SMALL_ENOUGH:
            return V

# %%
Policy
# Out:
# {((1, 0), (1, 0)): 'down',
#  ((1, 6), (1, 0)): 'down',
#  ((7, 1), (1, 0)): 'up',
#  ((7, 0), (1, 0)): 'stay',
#  ((7, 6), (1, 0)): 'up',
#  ((1, 3), (1, 2)): 'left',
#  ((1, 2), (1, 2)): 'left',
#  ((1, 8), (1, 2)): 'left',
#  ((7, 3), (1, 2)): 'up',
#  ((7, 2), (1, 2)): 'up',
#  ((7, 8), (1, 2)): 'up',
#  ((1, 4), (1, 3)): 'left',
#  ((1, 3), (1, 3)): 'left',
#  ((1, 9), (1, 3)): 'left',
#  ((7, 4), (1, 3)): 'up',
#  ((7, 3), (1, 3)): 'up',
#  ((7, 9), (1, 3)): 'up',
#  ((1, 5), (1, 4)): 'left',
#  ((1, 4), (1, 4)): 'left',
#  ((1, 10), (1, 4)): 'left',
#  ((7, 5), (1, 4)): 'up',
#  ((7, 4), (1, 4)): 'up',
#  ((7, 10), (1, 4)): 'up',
#  ((1, 5), (1, 5)): 'left',
#  ((7, 5), (1, 5)): 'up',
#  ((1, 6), (1, 6)): 'down',
#  ((1, 0), (1, 6)): 'down',
#  ((7, 6), (1, 6)): 'up',
#  ((7, 0), (1, 6)): 'stay',
#  ((1, 7), (1, 7)): 'left',
#  ((7, 1), (1, 7)): 'up',
#  ((1, 8), (1, 8)): 'left',
#  ((1, 2), (1, 8)): 'left',
#  ((7, 8), (1, 8)): 'up',
#  ((7, 2), (1, 8)): 'up',
#  ((1, 9), (1, 9)): 'left',
#  ((1, 3), (1, 9)): 'left',
#  ((7, 9), (1, 9)): 'up',
#  ((7, 3), (1, 9)): 'up',
#  ((1, 10), (1, 10)): 'left',
#  ((1, 4), (1, 10)): 'left',
#  ((7, 10), (1, 10)): 'up',
#  ((7, 4), (1, 10)): 'up',
#  ((1, 11), (1, 11)): 'left',
#  ((1, 5), (1, 11)): 'left',
#  ((7, 11), (1, 11)): 'up',
#  ((7, 5), (1, 11)): 'up',
#  ((2, 1), (2, 0)): 'down',
#  ((2, 0), (2, 0)): 'down',
#  ((2, 6), (2, 0)): 'left',
#  ((1, 0), (2, 0)): 'down',
#  ((1, 6), (2, 0)): 'down',
#  ((8, 1), (2, 0)): 'stay',
#  ((8, 0), (2, 0)): 'up',
#  ((8, 6), (2, 0)): 'up',
#  ((2, 1), (2, 1)): 'down',
#  ((2, 7), (2, 1)): 'stay',
#  ((1, 2), (2, 1)): 'left',
#  ((1, 7), (2, 1)): 'left',
#  ((8, 2), (2, 1)): 'up',
#  ((8, 1), (2, 1)): 'stay',
#  ((8, 7), (2, 1)): 'up',
#  ((2, 4), (2, 3)): 'left',
#  ((2, 3), (2, 3)): 'left',
#  ((2, 9), (2, 3)): 'left',
#  ((1, 4), (2, 3)): 'left',
#  ((1, 3), (2, 3)): 'left',
#  ((1, 9), (2, 3)): 'left',
#  ((8, 4), (2, 3)): 'up',
#  ((8, 3), (2, 3)): 'up',
#  ((8, 9), (2, 3)): 'up',
#  ((2, 5), (2, 4)): 'left',
#  ((2, 4), (2, 4)): 'left',
#  ((2, 10), (2, 4)): 'left',
#  ((1, 5), (2, 4)): 'left',
#  ((1, 4), (2, 4)): 'left',
#  ((1, 10), (2, 4)): 'left',
#  ((8, 5), (2, 4)): 'up',
#  ((8, 4), (2, 4)): 'up',
#  ((8, 10), (2, 4)): 'up',
#  ((2, 5), (2, 5)): 'left',
#  ((1, 5), (2, 5)): 'left',
#  ((8, 5), (2, 5)): 'up',
#  ((2, 6), (2, 6)): 'left',
#  ((2, 0), (2, 6)): 'stay',
#  ((1, 6), (2, 6)): 'down',
#  ((1, 0), (2, 6)): 'left',
#  ((8, 6), (2, 6)): 'up',
#  ((8, 0), (2, 6)): 'up',
#  ((2, 7), (2, 7)): 'down',
#  ((2, 1), (2, 7)): 'down',
#  ((1, 7), (2, 7)): 'left',
#  ((8, 7), (2, 7)): 'up',
#  ((8, 1), (2, 7)): 'stay',
#  ((2, 8), (2, 8)): 'left',
#  ((1, 8), (2, 8)): 'left',
#  ((1, 2), (2, 8)): 'left',
#  ((8, 2), (2, 8)): 'up',
#  ((2, 9), (2, 9)): 'left',
#  ((2, 3), (2, 9)): 'left',
#  ((1, 9), (2, 9)): 'left',
#  ((1, 3), (2, 9)): 'left',
#  ((8, 9), (2, 9)): 'up',
#  ((8, 3), (2, 9)): 'up',
#  ((2, 10), (2, 10)): 'left',
#  ((2, 4), (2, 10)): 'left',
#  ((1, 10), (2, 10)): 'left',
#  ((1, 4), (2, 10)): 'left',
#  ((8, 10), (2, 10)): 'up',
#  ((8, 4), (2, 10)): 'up',
#  ((2, 11), (2, 11)): 'left',
#  ((2, 5), (2, 11)): 'left',
#  ((1, 11), (2, 11)): 'left',
#  ((1, 5), (2, 11)): 'left',
#  ((8, 11), (2, 11)): 'up',
#  ((8, 5), (2, 11)): 'up',
#  ((3, 1), (3, 0)): 'stay',
#  ((3, 0), (3, 0)): 'left',
#  ((3, 6), (3, 0)): 'stay',
#  ((2, 1), (3, 0)): 'left',
#  ((2, 0), (3, 0)): 'down',
#  ((2, 6), (3, 0)): 'left',
#  ((9, 1), (3, 0)): 'up',
#  ((9, 0), (3, 0)): 'up',
#  ((9, 6), (3, 0)): 'up',
#  ((3, 2), (3, 1)): 'down',
#  ((3, 1), (3, 1)): 'down',
#  ((3, 7), (3, 1)): 'stay',
#  ((2, 1), (3, 1)): 'down',
#  ((2, 7), (3, 1)): 'stay',
#  ((9, 2), (3, 1)): 'stay',
#  ((9, 1), (3, 1)): 'up',
#  ((9, 7), (3, 1)): 'up',
#  ((3, 2), (3, 2)): 'down',
#  ((3, 8), (3, 2)): 'down',
#  ((2, 3), (3, 2)): 'left',
#  ((2, 8), (3, 2)): 'left',
#  ((9, 3), (3, 2)): 'up',
#  ((9, 2), (3, 2)): 'stay',
#  ((9, 8), (3, 2)): 'stay',
#  ((3, 5), (3, 4)): 'left',
#  ((3, 4), (3, 4)): 'left',
#  ((3, 10), (3, 4)): 'left',
#  ((2, 5), (3, 4)): 'left',
#  ((2, 4), (3, 4)): 'left',
#  ((2, 10), (3, 4)): 'left',
#  ((9, 5), (3, 4)): 'up',
#  ((9, 4), (3, 4)): 'up',
#  ((9, 10), (3, 4)): 'up',
#  ((3, 5), (3, 5)): 'left',
#  ((2, 5), (3, 5)): 'left',
#  ((9, 5), (3, 5)): 'up',
#  ((3, 6), (3, 6)): 'down',
#  ((3, 0), (3, 6)): 'left',
#  ((2, 6), (3, 6)): 'stay',
#  ((2, 0), (3, 6)): 'stay',
#  ((9, 6), (3, 6)): 'up',
#  ((9, 0), (3, 6)): 'up',
#  ((3, 7), (3, 7)): 'left',
#  ((3, 1), (3, 7)): 'down',
#  ((2, 7), (3, 7)): 'down',
#  ((2, 1), (3, 7)): 'left',
#  ((9, 7), (3, 7)): 'up',
#  ((9, 1), (3, 7)): 'up',
#  ((3, 8), (3, 8)): 'down',
#  ((3, 2), (3, 8)): 'down',
#  ((2, 8), (3, 8)): 'left',
#  ((9, 8), (3, 8)): 'stay',
#  ((9, 2), (3, 8)): 'stay',
#  ((3, 9), (3, 9)): 'left',
#  ((2, 9), (3, 9)): 'left',
#  ((2, 3), (3, 9)): 'left',
#  ((9, 3), (3, 9)): 'up',
#  ((3, 10), (3, 10)): 'left',
#  ((3, 4), (3, 10)): 'left',
#  ((2, 10), (3, 10)): 'left',
#  ((2, 4), (3, 10)): 'left',
#  ((9, 10), (3, 10)): 'up',
#  ((9, 4), (3, 10)): 'up',
#  ((3, 11), (3, 11)): 'left',
#  ((3, 5), (3, 11)): 'left',
#  ((2, 11), (3, 11)): 'left',
#  ((2, 5), (3, 11)): 'left',
#  ((9, 11), (3, 11)): 'up',
#  ((9, 5), (3, 11)): 'up',
#  ((4, 1), (4, 0)): 'left',
#  ((4, 0), (4, 0)): 'stay',
#  ((4, 6), (4, 0)): 'stay',
#  ((3, 1), (4, 0)): 'stay',
#  ((3, 0), (4, 0)): 'left',
#  ((3, 6), (4, 0)): 'stay',
#  ((10, 1), (4, 0)): 'up',
#  ((10, 0), (4, 0)): 'up',
#  ((10, 6), (4, 0)): 'up',
#  ((4, 2), (4, 1)): 'stay',
#  ((4, 1), (4, 1)): 'left',
#  ((4, 7), (4, 1)): 'stay',
#  ((3, 2), (4, 1)): 'left',
#  ((3, 1), (4, 1)): 'stay',
#  ((3, 7), (4, 1)): 'left',
#  ((10, 2), (4, 1)): 'up',
#  ((10, 1), (4, 1)): 'up',
#  ((10, 7), (4, 1)): 'up',
#  ((4, 3), (4, 2)): 'left',
#  ((4, 2), (4, 2)): 'stay',
#  ((4, 8), (4, 2)): 'left',
#  ((3, 2), (4, 2)): 'down',
#  ((3, 8), (4, 2)): 'down',
#  ((10, 3), (4, 2)): 'stay',
#  ((10, 2), (4, 2)): 'up',
#  ((10, 8), (4, 2)): 'up',
#  ((4, 3), (4, 3)): 'down',
#  ((4, 9), (4, 3)): 'down',
#  ((3, 4), (4, 3)): 'left',
#  ((3, 9), (4, 3)): 'left',
#  ((10, 4), (4, 3)): 'up',
#  ((10, 3), (4, 3)): 'stay',
#  ((10, 9), (4, 3)): 'stay',
#  ((4, 5), (4, 5)): 'left',
#  ((3, 5), (4, 5)): 'left',
#  ((10, 5), (4, 5)): 'up',
#  ((4, 6), (4, 6)): 'stay',
#  ((4, 0), (4, 6)): 'stay',
#  ((3, 6), (4, 6)): 'down',
#  ((3, 0), (4, 6)): 'left',
#  ((10, 6), (4, 6)): 'up',
#  ((10, 0), (4, 6)): 'up',
#  ((4, 7), (4, 7)): 'stay',
#  ((4, 1), (4, 7)): 'left',
#  ((3, 7), (4, 7)): 'left',
#  ((3, 1), (4, 7)): 'stay',
#  ((10, 7), (4, 7)): 'up',
#  ((10, 1), (4, 7)): 'up',
#  ((4, 8), (4, 8)): 'left',
#  ((4, 2), (4, 8)): 'stay',
#  ((3, 8), (4, 8)): 'down',
#  ((3, 2), (4, 8)): 'down',
#  ((10, 8), (4, 8)): 'up',
#  ((10, 2), (4, 8)): 'up',
#  ((4, 9), (4, 9)): 'down',
#  ((4, 3), (4, 9)): 'down',
#  ((3, 9), (4, 9)): 'left',
#  ((10, 9), (4, 9)): 'stay',
#  ((10, 3), (4, 9)): 'stay',
#  ((4, 10), (4, 10)): 'left',
#  ((3, 10), (4, 10)): 'left',
#  ((3, 4), (4, 10)): 'left',
#  ((10, 4), (4, 10)): 'up',
#  ((4, 11), (4, 11)): 'left',
#  ((4, 5), (4, 11)): 'left',
#  ((3, 11), (4, 11)): 'left',
#  ((3, 5), (4, 11)): 'left',
#  ((10, 11), (4, 11)): 'up',
#  ((10, 5), (4, 11)): 'up',
#  ((5, 1), (5, 0)): 'stay',
#  ((5, 0), (5, 0)): 'left',
#  ((5, 6), (5, 0)): 'left',
#  ((4, 1), (5, 0)): 'left',
#  ((4, 0), (5, 0)): 'stay',
#  ((4, 6), (5, 0)): 'left',
#  ((11, 1), (5, 0)): 'up',
#  ((11, 0), (5, 0)): 'up',
#  ((11, 6), (5, 0)): 'up',
#  ((5, 2), (5, 1)): 'stay',
#  ((5, 1), (5, 1)): 'stay',
#  ((5, 7), (5, 1)): 'left',
#  ((4, 2), (5, 1)): 'stay',
#  ((4, 1), (5, 1)): 'left',
#  ((4, 7), (5, 1)): 'stay',
#  ((11, 2), (5, 1)): 'up',
#  ((11, 1), (5, 1)): 'up',
#  ((11, 7), (5, 1)): 'up',
#  ((5, 3), (5, 2)): 'stay',
#  ((5, 2), (5, 2)): 'stay',
#  ((5, 8), (5, 2)): 'down',
#  ((4, 3), (5, 2)): 'down',
#  ((4, 2), (5, 2)): 'stay',
#  ((4, 8), (5, 2)): 'left',
#  ((11, 3), (5, 2)): 'up',
#  ((11, 2), (5, 2)): 'up',
#  ((11, 8), (5, 2)): 'up',
#  ((5, 4), (5, 3)): 'left',
#  ((5, 3), (5, 3)): 'stay',
#  ((5, 9), (5, 3)): 'stay',
#  ((4, 3), (5, 3)): 'down',
#  ((4, 9), (5, 3)): 'down',
#  ((11, 4), (5, 3)): 'up',
#  ((11, 3), (5, 3)): 'up',
#  ((11, 9), (5, 3)): 'up',
#  ((5, 4), (5, 4)): 'left',
#  ((5, 10), (5, 4)): 'stay',
#  ((4, 5), (5, 4)): 'left',
#  ((4, 10), (5, 4)): 'left',
#  ((11, 5), (5, 4)): 'up',
#  ((11, 4), (5, 4)): 'up',
#  ((11, 10), (5, 4)): 'up',
#  ((5, 6), (5, 6)): 'left',
#  ((5, 0), (5, 6)): 'left',
#  ((4, 6), (5, 6)): 'stay',
#  ((4, 0), (5, 6)): 'stay',
#  ((11, 6), (5, 6)): 'up',
#  ((11, 0), (5, 6)): 'up',
#  ((5, 7), (5, 7)): 'left',
#  ((5, 1), (5, 7)): 'stay',
#  ((4, 7), (5, 7)): 'stay',
#  ((4, 1), (5, 7)): 'left',
#  ((11, 7), (5, 7)): 'up',
#  ((11, 1), (5, 7)): 'up',
#  ((5, 8), (5, 8)): 'down',
#  ((5, 2), (5, 8)): 'stay',
#  ((4, 8), (5, 8)): 'left',
#  ((4, 2), (5, 8)): 'stay',
#  ((11, 8), (5, 8)): 'up',
#  ((11, 2), (5, 8)): 'up',
#  ((5, 9), (5, 9)): 'stay',
#  ((5, 3), (5, 9)): 'stay',
#  ((4, 9), (5, 9)): 'down',
#  ((4, 3), (5, 9)): 'down',
#  ((11, 9), (5, 9)): 'up',
#  ((11, 3), (5, 9)): 'up',
#  ((5, 10), (5, 10)): 'stay',
#  ((5, 4), (5, 10)): 'left',
#  ((4, 10), (5, 10)): 'left',
#  ((11, 10), (5, 10)): 'up',
#  ((11, 4), (5, 10)): 'up',
#  ((5, 11), (5, 11)): 'left',
#  ((4, 11), (5, 11)): 'left',
#  ((4, 5), (5, 11)): 'left',
#  ((11, 5), (5, 11)): 'up',
#  ((6, 1), (6, 0)): 'up',
#  ((6, 0), (6, 0)): 'up',
#  ((6, 2), (6, 1)): 'up',
#  ((6, 1), (6, 1)): 'up',
#  ((6, 7), (6, 1)): 'up',
#  ((6, 3), (6, 2)): 'up',
#  ((6, 2), (6, 2)): 'up',
#  ((6, 8), (6, 2)): 'up',
#  ((6, 4), (6, 3)): 'up',
#  ((6, 3), (6, 3)): 'up',
#  ((6, 9), (6, 3)): 'up',
#  ((6, 5), (6, 4)): 'up',
#  ((6, 4), (6, 4)): 'up',
#  ((6, 10), (6, 4)): 'up',
#  ((6, 5), (6, 5)): 'up',
#  ((6, 7), (6, 7)): 'up',
#  ((6, 1), (6, 7)): 'up',
#  ((6, 8), (6, 8)): 'up',
#  ((6, 2), (6, 8)): 'up',
#  ((6, 9), (6, 9)): 'up',
#  ((6, 3), (6, 9)): 'up',
#  ((6, 10), (6, 10)): 'up',
#  ((6, 4), (6, 10)): 'up',
#  ((6, 11), (6, 11)): 'up',
#  ((6, 5), (6, 11)): 'up',
#  ((1, 0), (7, 0)): 'down',
#  ((1, 6), (7, 0)): 'down',
#  ((7, 1), (7, 0)): 'up',
#  ((7, 0), (7, 0)): 'stay',
#  ((7, 6), (7, 0)): 'up',
#  ((1, 2), (7, 1)): 'left',
#  ((1, 7), (7, 1)): 'left',
#  ((7, 2), (7, 1)): 'up',
#  ((7, 1), (7, 1)): 'up',
#  ((1, 3), (7, 2)): 'left',
#  ((1, 2), (7, 2)): 'left',
#  ((1, 8), (7, 2)): 'left',
#  ((7, 3), (7, 2)): 'up',
#  ((7, 2), (7, 2)): 'up',
#  ((7, 8), (7, 2)): 'up',
#  ((1, 4), (7, 3)): 'left',
#  ((1, 3), (7, 3)): 'left',
#  ((1, 9), (7, 3)): 'left',
#  ((7, 4), (7, 3)): 'up',
#  ((7, 3), (7, 3)): 'up',
#  ((7, 9), (7, 3)): 'up',
#  ((1, 5), (7, 4)): 'left',
#  ((1, 4), (7, 4)): 'left',
#  ((1, 10), (7, 4)): 'left',
#  ((7, 5), (7, 4)): 'up',
#  ((7, 4), (7, 4)): 'up',
#  ((7, 10), (7, 4)): 'up',
#  ((1, 5), (7, 5)): 'left',
#  ((7, 5), (7, 5)): 'up',
#  ((1, 6), (7, 6)): 'down',
#  ((1, 0), (7, 6)): 'left',
#  ((7, 6), (7, 6)): 'up',
#  ((7, 0), (7, 6)): 'stay',
#  ((1, 8), (7, 8)): 'left',
#  ((1, 2), (7, 8)): 'left',
#  ((7, 8), (7, 8)): 'up',
#  ((7, 2), (7, 8)): 'up',
#  ((1, 9), (7, 9)): 'left',
#  ((1, 3), (7, 9)): 'left',
#  ((7, 9), (7, 9)): 'up',
#  ((7, 3), (7, 9)): 'up',
#  ((1, 10), (7, 10)): 'left',
#  ((1, 4), (7, 10)): 'left',
#  ((7, 10), (7, 10)): 'up',
#  ((7, 4), (7, 10)): 'up',
#  ((1, 11), (7, 11)): 'left',
#  ((1, 5), (7, 11)): 'left',
#  ((7, 11), (7, 11)): 'up',
#  ((7, 5), (7, 11)): 'up',
#  ((2, 1), (8, 0)): 'down',
#  ((2, 0), (8, 0)): 'stay',
#  ((2, 6), (8, 0)): 'left',
#  ((8, 1), (8, 0)): 'stay',
#  ((8, 0), (8, 0)): 'up',
#  ((8, 6), (8, 0)): 'up',
#  ((2, 1), (8, 1)): 'down',
#  ((2, 7), (8, 1)): 'stay',
#  ((8, 2), (8, 1)): 'up',
#  ((8, 1), (8, 1)): 'stay',
#  ((8, 7), (8, 1)): 'up',
#  ((2, 3), (8, 2)): 'left',
#  ((2, 8), (8, 2)): 'left',
#  ((8, 3), (8, 2)): 'up',
#  ((8, 2), (8, 2)): 'up',
#  ((2, 4), (8, 3)): 'left',
#  ((2, 3), (8, 3)): 'left',
#  ((2, 9), (8, 3)): 'left',
#  ((8, 4), (8, 3)): 'up',
#  ((8, 3), (8, 3)): 'up',
#  ((8, 9), (8, 3)): 'up',
#  ((2, 5), (8, 4)): 'left',
#  ((2, 4), (8, 4)): 'left',
#  ((2, 10), (8, 4)): 'left',
#  ((8, 5), (8, 4)): 'up',
#  ((8, 4), (8, 4)): 'up',
#  ((8, 10), (8, 4)): 'up',
#  ((2, 5), (8, 5)): 'left',
#  ((8, 5), (8, 5)): 'up',
#  ((2, 6), (8, 6)): 'left',
#  ((2, 0), (8, 6)): 'stay',
#  ((8, 6), (8, 6)): 'up',
#  ((8, 0), (8, 6)): 'up',
#  ((2, 7), (8, 7)): 'stay',
#  ((2, 1), (8, 7)): 'down',
#  ((8, 7), (8, 7)): 'up',
#  ((8, 1), (8, 7)): 'stay',
#  ((2, 9), (8, 9)): 'left',
#  ((2, 3), (8, 9)): 'left',
#  ((8, 9), (8, 9)): 'up',
#  ((8, 3), (8, 9)): 'up',
#  ((2, 10), (8, 10)): 'left',
#  ((2, 4), (8, 10)): 'left',
#  ((8, 10), (8, 10)): 'up',
#  ((8, 4), (8, 10)): 'up',
#  ((2, 11), (8, 11)): 'left',
#  ((2, 5), (8, 11)): 'left',
#  ((8, 11), (8, 11)): 'up',
#  ((8, 5), (8, 11)): 'up',
#  ((3, 1), (9, 0)): 'stay',
#  ((3, 0), (9, 0)): 'left',
#  ((3, 6), (9, 0)): 'stay',
#  ((9, 1), (9, 0)): 'up',
#  ((9, 0), (9, 0)): 'up',
#  ((9, 6), (9, 0)): 'up',
#  ((3, 2), (9, 1)): 'down',
#  ((3, 1), (9, 1)): 'stay',
#  ((3, 7), (9, 1)): 'left',
#  ((9, 2), (9, 1)): 'stay',
#  ((9, 1), (9, 1)): 'up',
#  ((9, 7), (9, 1)): 'up',
#  ((3, 2), (9, 2)): 'down',
#  ((3, 8), (9, 2)): 'down',
#  ((9, 3), (9, 2)): 'up',
#  ((9, 2), (9, 2)): 'stay',
#  ((9, 8), (9, 2)): 'stay',
#  ((3, 4), (9, 3)): 'left',
#  ((3, 9), (9, 3)): 'left',
#  ((9, 4), (9, 3)): 'up',
#  ((9, 3), (9, 3)): 'stay',
#  ((3, 5), (9, 4)): 'left',
#  ((3, 4), (9, 4)): 'left',
#  ((3, 10), (9, 4)): 'left',
#  ((9, 5), (9, 4)): 'up',
#  ((9, 4), (9, 4)): 'up',
#  ((9, 10), (9, 4)): 'up',
#  ((3, 5), (9, 5)): 'left',
#  ((9, 5), (9, 5)): 'up',
#  ((3, 6), (9, 6)): 'stay',
#  ((3, 0), (9, 6)): 'left',
#  ((9, 6), (9, 6)): 'up',
#  ((9, 0), (9, 6)): 'up',
#  ((3, 7), (9, 7)): 'left',
#  ((3, 1), (9, 7)): 'down',
#  ((9, 7), (9, 7)): 'up',
#  ((9, 1), (9, 7)): 'up',
#  ((3, 8), (9, 8)): 'down',
#  ((3, 2), (9, 8)): 'down',
#  ((9, 8), (9, 8)): 'stay',
#  ((9, 2), (9, 8)): 'stay',
#  ((3, 10), (9, 10)): 'left',
#  ((3, 4), (9, 10)): 'left',
#  ((9, 10), (9, 10)): 'up',
#  ((9, 4), (9, 10)): 'up',
#  ((3, 11), (9, 11)): 'left',
#  ((3, 5), (9, 11)): 'left',
#  ((9, 11), (9, 11)): 'up',
#  ((9, 5), (9, 11)): 'up',
#  ((4, 1), (10, 0)): 'left',
#  ((4, 0), (10, 0)): 'stay',
#  ((4, 6), (10, 0)): 'stay',
#  ((10, 1), (10, 0)): 'up',
#  ((10, 0), (10, 0)): 'up',
#  ((10, 6), (10, 0)): 'up',
#  ((4, 2), (10, 1)): 'stay',
#  ((4, 1), (10, 1)): 'left',
#  ((4, 7), (10, 1)): 'stay',
#  ((10, 2), (10, 1)): 'up',
#  ((10, 1), (10, 1)): 'up',
#  ((10, 7), (10, 1)): 'up',
#  ((4, 3), (10, 2)): 'left',
#  ((4, 2), (10, 2)): 'stay',
#  ((4, 8), (10, 2)): 'left',
#  ((10, 3), (10, 2)): 'stay',
#  ((10, 2), (10, 2)): 'up',
#  ((10, 8), (10, 2)): 'up',
#  ((4, 3), (10, 3)): 'down',
#  ((4, 9), (10, 3)): 'down',
#  ((10, 4), (10, 3)): 'up',
#  ((10, 3), (10, 3)): 'stay',
#  ((10, 9), (10, 3)): 'stay',
#  ((4, 5), (10, 4)): 'left',
#  ((4, 10), (10, 4)): 'left',
#  ((10, 5), (10, 4)): 'up',
#  ((10, 4), (10, 4)): 'up',
#  ((4, 5), (10, 5)): 'left',
#  ((10, 5), (10, 5)): 'up',
#  ((4, 6), (10, 6)): 'stay',
#  ((4, 0), (10, 6)): 'stay',
#  ((10, 6), (10, 6)): 'up',
#  ((10, 0), (10, 6)): 'up',
#  ((4, 7), (10, 7)): 'stay',
#  ((4, 1), (10, 7)): 'left',
#  ((10, 7), (10, 7)): 'up',
#  ((10, 1), (10, 7)): 'up',
#  ((4, 8), (10, 8)): 'left',
#  ((4, 2), (10, 8)): 'stay',
#  ((10, 8), (10, 8)): 'up',
#  ((10, 2), (10, 8)): 'up',
#  ((4, 9), (10, 9)): 'down',
#  ((4, 3), (10, 9)): 'down',
#  ((10, 9), (10, 9)): 'stay',
#  ((10, 3), (10, 9)): 'stay',
#  ((4, 11), (10, 11)): 'left',
#  ((4, 5), (10, 11)): 'left',
#  ((10, 11), (10, 11)): 'up',
#  ((10, 5), (10, 11)): 'up',
#  ((5, 1), (11, 0)): 'stay',
#  ((5, 0), (11, 0)): 'left',
#  ((5, 6), (11, 0)): 'left',
#  ((11, 1), (11, 0)): 'up',
#  ((11, 0), (11, 0)): 'up',
#  ((11, 6), (11, 0)): 'up',
#  ((5, 2), (11, 1)): 'stay',
#  ((5, 1), (11, 1)): 'stay',
#  ((5, 7), (11, 1)): 'left',
#  ((11, 2), (11, 1)): 'up',
#  ((11, 1), (11, 1)): 'up',
#  ((11, 7), (11, 1)): 'up',
#  ((5, 3), (11, 2)): 'stay',
#  ((5, 2), (11, 2)): 'stay',
#  ((5, 8), (11, 2)): 'down',
#  ((11, 3), (11, 2)): 'up',
#  ((11, 2), (11, 2)): 'up',
#  ((11, 8), (11, 2)): 'up',
#  ((5, 4), (11, 3)): 'left',
#  ((5, 3), (11, 3)): 'stay',
#  ((5, 9), (11, 3)): 'stay',
#  ((11, 4), (11, 3)): 'up',
#  ((11, 3), (11, 3)): 'up',
#  ((11, 9), (11, 3)): 'up',
#  ((5, 4), (11, 4)): 'left',
#  ((5, 10), (11, 4)): 'stay',
#  ((11, 5), (11, 4)): 'up',
#  ((11, 4), (11, 4)): 'up',
#  ((11, 10), (11, 4)): 'up',
#  ((11, 5), (11, 5)): 'up',
#  ((5, 6), (11, 6)): 'left',
#  ((5, 0), (11, 6)): 'left',
#  ((11, 6), (11, 6)): 'up',
#  ((11, 0), (11, 6)): 'up',
#  ((5, 7), (11, 7)): 'left',
#  ((5, 1), (11, 7)): 'stay',
#  ((11, 7), (11, 7)): 'up',
#  ((11, 1), (11, 7)): 'up',
#  ((5, 8), (11, 8)): 'down',
#  ((5, 2), (11, 8)): 'stay',
#  ((11, 8), (11, 8)): 'up',
#  ((11, 2), (11, 8)): 'up',
#  ((5, 9), (11, 9)): 'stay',
#  ((5, 3), (11, 9)): 'stay',
#  ((11, 9), (11, 9)): 'up',
#  ((11, 3), (11, 9)): 'up',
#  ((5, 10), (11, 10)): 'stay',
#  ((5, 4), (11, 10)): 'left',
#  ((11, 10), (11, 10)): 'up',
#  ((11, 4), (11, 10)): 'up',
#  ((5, 0), (-10, -10)): 'left'}

# %%
def extend_policy(policy):
    # take policy without velocity and convert it to policy with velocity
    policy_with_velocity = {}
    for ((i,j),(l,k)) in actions.keys():
        policy_with_velocity[((i,j),(l,k))] = policy[(i,j)]
    return policy_with_velocity

# %%
careful_eval_v2 = policy_eval2(extend_policy(careful_policy))
random_eval_v2 = policy_eval2(extend_policy(random_policy))
aggressive_eval_v2 = policy_eval2(extend_policy(aggressive_policy))
semiAggressive_eval_v2 = policy_eval2(extend_policy(semiAggressive_policy))
semiCareful_eval_v2 = policy_eval2(extend_policy(semiCareful_policy))
valueIteration_eval_v2 = policy_eval2(extend_policy(valueIteration_policy))
# [((5,0),(-10,-10))]

# %%
real_col = df.groupby(['behavior']).mean()['blueScore'].drop('carefulBehavior')
diff = pd.DataFrame({'Real': real_col,
                      'Prediction': [aggressive_intensity[5][0], randomBehavior_intensity[5][0], semiAggressive_intensity[5][0], semiCareful_intensity[5][0], np.NaN],
                     'Prediction with velocity': [aggressive_eval_v2[((5,0),(-10,-10))], random_eval_v2[((5,0),(-10,-10))], semiAggressive_eval_v2[((5,0),(-10,-10))], semiCareful_eval_v2[((5,0),(-10,-10))], optimal_V_v2['a6 a1,a-9 a-9']]},
                     index= real_col.index)
diff['different'] = abs(diff['Real']-diff['Prediction with velocity'])
diff
# Out:
#                                  Real  Prediction  Prediction with velocity  \
# behavior
# aggressiveBehavior             -15.93        1.14                     -4.16
# randomBehavior                 -77.52     -108.77                   -112.76
# semiAggressiveBehavior         -59.71      -47.81                    -54.79
# semiCarefulBehavior             -2.31       -4.21                    -15.20
# valueIterationBasedBehavior_v2  -3.87         NaN                     16.73
#
#                                 different
# behavior
# aggressiveBehavior                  11.77
# randomBehavior                      35.24
# semiAggressiveBehavior               4.92
# semiCarefulBehavior                 12.89
# valueIterationBasedBehavior_v2      20.61

# %%
V[((5,0),(-10,-10))] # this is from the value iteration
# Out:
# 16.734842087468344

# %% [markdown]
# # push to firebase:

# %%
import pyrebase

firebaseConfig = {
    "apiKey": "AIzaSyDROtt5r3t5VL_iPabcgVgsWmUZHMw7Pv8",
    "authDomain": "road-game.firebaseapp.com",
    "databaseURL": "https://road-game-default-rtdb.firebaseio.com",
    "projectId": "road-game",
    "storageBucket": "road-game.appspot.com",
    "messagingSenderId": "14363967441",
    "appId": "1:14363967441:web:9efd1c7c3db93ab12ceaf0"
  }

firebase=pyrebase.initialize_app(firebaseConfig)

db=firebase.database()

# %%
try:
    db.child("aggressiveBehavior").set(convertStates(extend_policy(aggressive_policy))[0])
    
    db.child("carefulBehavior").set(convertStates(extend_policy(careful_policy))[0])
    
    db.child("semiCarefulBehavior").set(convertStates(extend_policy(semiCareful_policy))[0])
    
    db.child("randomBehavior").set(convertStates(extend_policy(random_policy))[0])
    
    db.child("semiAggressiveBehavior").set(convertStates(extend_policy(semiAggressive_policy))[0])
    
    db.child("valueIterationBasedBehavior_v2").set(optimal_policy_v2)
    
    db.child("valueIterationBehavior").set(convertStates(extend_policy(valueIteration_policy))[0])
except Exception as err:
    print(err)

# %% [markdown]
# build opponent model:
# it uses the human model 50% of the time, and uses our mirrored model 50% of the time.
#
# Now find the maximum.
# I.e., find the optimal policy.
# Once you find a policy update the opponent model and find the optimal policy again. Hopefully it will converge.

# %%
def nextStateDistibution3(s, a, prev_action_at_prev_policy):
    # prev_action_at_prev_policy = what was the blue agent action at state
    # given state s and action a, return distibution of possibles new states by probs
    nxt = {}
#     print('s: ', s)
#     print('a: ', a)
    bluePossition = newPosGivenAction(s[0], a, 0)
#     print('bluePossition: ', bluePossition)
    
    if(prev_action_at_prev_policy == "left"):
        a_to_compare = "right"
    else:
        a_to_compare = prev_action_at_prev_policy
#     print('a_to_compare: ', a_to_compare)
    # red possible action given state
    if s[0][1] == 5:
        actions=["stay"]
    elif s[0][1] < 6:
        actions=["right","stay", "down"]
    else:
        actions=["stay", "up"]
#     print('actions: ', actions)
    for r_a in actions:
        redPossition = newPosGivenAction(s[0], r_a, 1)
#         print('r_a: ', r_a)
#         print('redPossition: ', redPossition)
        newState = ((bluePossition, redPossition),s[0])
#         print('newState: ', newState)
        try:
            nxt[newState] = probs[adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0])][r_a] * 0.75
            if(r_a == a_to_compare):
                nxt[newState] = nxt[newState] + 0.25 
        except KeyError:
#             print("Warning! State not found: assume random behavior. ", s[0])
            nxt[newState] = randomProbForAction(s[0]) * 0.75
            if(r_a == a_to_compare):
                nxt[newState] = nxt[newState] + 0.25
    assert abs(sum(nxt.values()) - 1.0) < 0.0001, "probs not sum to 1.0. \nstate: " + str(s) + " action: " + str(a) + " nxt: " + str(nxt) + "\nsum of probs: " + str(sum(nxt.values()))
    return nxt

# %%
s = ((1, 0), (1, 0))
a = "stay"
nextStateDistibution3(s, a, "stay")
# Out:
# {((1, 1), (1, 0)): 0.10714285717500001,
#  ((1, 0), (1, 0)): 0.785714285725,
#  ((1, 6), (1, 0)): 0.10714285717500001}

# %%
mirror_dict_pos = {0:5,
                  1:4,
                  2:3,
                  3:2,
                  4:1,
                  5:0,
                  6:11,
                  7:10,
                  8:9,
                  9:8,
                  10:7,
                  11:6,
                  -10:-10}

def mirror_pos(pos):
    return mirror_dict_pos[pos]

mirror_pos(7)
# Out:
# 10

# %%
def mirror_state(s):
    ((i,j),(l,k)) = s
    return ((mirror_pos(j), mirror_pos(i)),(mirror_pos(k), mirror_pos(l)))

# %%
mirror_state(((1, 5), (1, 4)))
# Out:
# ((0, 4), (1, 4))

# %%
# import copy

# %%
# prev_policy = {}

# %%
# while(prev_policy != Policy):
#     prev_policy = copy.deepcopy(Policy)

#     '''==================================================
#     Value Iteration
#     =================================================='''
#     iteration = 1
#     while True:
#         biggest_change = 0
#         for s in all_states:            
#             if s in Policy:

#                 old_v = V[s]
#                 new_v = np.NINF

#                 for a in actions[s]:
#                     try:
#                         blue_action_as_red = prev_policy[mirror_state(s)]
#                     except KeyError: # it can fail only if blue in end-state
#                         blue_action_as_red = "stay"

#                     nxt = nextStateDistibution3(s, a, blue_action_as_red)
#                     v=0
#                     #Calculate the value
#                     for next_state, prob in nxt.items():
#                         assert rewards[s] == -1, "rewards is not -1"
#                         v += prob * (rewards[s] + GAMMA * V[next_state])
#                     if v > new_v: #Is this the best action so far? If so, keep it
#                         new_v = v
#                         Policy[s] = a

#                #Save the best of all actions for the state                                
#                 V[s] = new_v
#                 biggest_change = max(biggest_change, np.abs(old_v - V[s]))


#        #See if the loop should stop now         
#         if biggest_change < SMALL_ENOUGH:
#             print('converge after: ' + str(iteration) + ' iterations')
#             break
#         iteration += 1

#         #Print every 100 iterations
#         if(iteration % 100 == 0):
#             print(iteration, "iterations")

# %%
# Policy

# %%
# policy_eval2(Policy)[((5,0),(-10,-10))]

# %%
# def humanBehavior():
#     # Behavior based on the data we gather
#     Policy={}
#     for s in actions.keys():
#         try:
#             row = probs[adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0])]
#             Policy[s] = np.random.choice(list(row.keys()), p=list(row.values()))
#         except KeyError:
# #             print("Warning! State not found: assume random behavior. ", s[0])
#             Policy[s] = np.random.choice(actions[s])
#         # take the action with higher prob
#     return Policy

# human_policy = humanBehavior()

# %%
# class Opponent_model:

#     def __init__(self, human_policy, mirrored_policy, p):
#         # humen_policy is made from the data
#         # mirrored_policy is the old policy of Value Iteration based agent.
#         self.human_policy = human_policy
#         self.mirrored_policy = mirrored_policy
#         self.p = p

#     def updateMirroredPolicy(self, new_mirrored_policy):
#         self.mirrored_policy = new_mirrored_policy
        
#     def getAction(self, state):
#         human_action = self.human_policy[state]
#         mirrored_action = self.mirrored_policy[state]
#         return np.random.choice([human_action, mirrored_action], p=[self.p, 1-self.p])

#     def __str__(self):
#         return "human_policy:\n " + str(self.human_policy) + "\n" + str(self.mirrored_policy) + "\n p: " + str(self.p)

# %%
# V[((5,0),(-10,-10))]

# %%
# Policy[((5,0),(-10,-10))]

# %%
# optimal_policy_v3, optimal_V_v3 = convertStates()

# %%
# try:
#     db.child("valueIterationBasedBehavior_v3").set(optimal_policy_v3)
# except Exception as err:
#     print(err)
