# %%
import json
import glob
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import seaborn as sns
import numpy as np
import pprint
import flat_table

pp = pprint.PrettyPrinter(depth=4)


path = './data/road-game-default-rtdb-export_prev.json'

branchs = ['all-games','complete-games']

# %%
#load data from the json file
with open(path) as train_file:
    data = json.load(train_file)

# %%
branch = branchs[0]
df = pd.DataFrame.from_dict(data[branch], orient='index')
df.reset_index(level=0, inplace=True)
df
# Out:
#                     index additional_comments aggressively_value  \
# 0    -MZiWIwdnrn8TJ034z2w                                      5
# 1    -MZiWUxZs8BvWglGhc9r                                      2
# 2    -MZiWYgxyToIiCSDQY8S                                      5
# 3    -MZiWYz_z_BcQlpReXf_                                      6
# 4    -MZiWaNZ6n3K3AZDfr-q                                      6
# ..                    ...                 ...                ...
# 668  -MbcURCQaLlJFHGxAvyW                 NaN                NaN
# 669  -MbcbjkKh8M10JRrqfwb                 NaN                NaN
# 670  -MbcfQpUktm_lYEmxpz2                 NaN                NaN
# 671  -Mbcz6inzp9NEdJCbK17                 NaN                NaN
# 672             undefined                 NaN                NaN
#
#                            behavior birthYear  blueScore computer_value  \
# 0                   carefulBehavior      1961       20.0              5
# 1                   carefulBehavior      1982       19.0              6
# 2                aggressiveBehavior      1953     -105.0              7
# 3                aggressiveBehavior      1990       34.0              7
# 4                aggressiveBehavior      1953     -105.0              6
# ..                              ...       ...        ...            ...
# 668  valueIterationBasedBehavior_v2       NaN        NaN            NaN
# 669  valueIterationBasedBehavior_v2       NaN        NaN            NaN
# 670  valueIterationBasedBehavior_v2       NaN        NaN            NaN
# 671  valueIterationBasedBehavior_v2       NaN        NaN            NaN
# 672                             NaN       NaN        NaN            NaN
#
#     drivinglicense        education  gender generously_value  \
# 0            valid               BA    male                6
# 1            valid               BA  female                4
# 2            valid               BA  female                2
# 3            valid  Master's degree    male                2
# 4            valid               BA  female                2
# ..             ...              ...     ...              ...
# 668            NaN              NaN     NaN              NaN
# 669            NaN              NaN     NaN              NaN
# 670            NaN              NaN     NaN              NaN
# 671            NaN              NaN     NaN              NaN
# 672            NaN              NaN     NaN              NaN
#
#                                                    log  \
# 0    [None, {'blue': 'from: a6, action: left', 'red...
# 1    [None, {'blue': 'from: a6, action: left', 'red...
# 2    [None, {'blue': 'from: a6, action: left', 'red...
# 3    [None, {'blue': 'from: a6, action: left', 'red...
# 4    [None, {'blue': 'from: a6, action: left', 'red...
# ..                                                 ...
# 668                                                NaN
# 669                                                NaN
# 670                                                NaN
# 671                                                NaN
# 672                                                NaN
#
#     press-the-read-instructions-button  redScore  steps    win wisely_value  \
# 0                                 True      23.0    7.0   True            1
# 1                                 True      22.0    8.0   True            4
# 2                                 True    -105.0    5.0  False            6
# 3                                 True      21.0    9.0   True            2
# 4                                 True    -105.0    5.0  False            1
# ..                                 ...       ...    ...    ...          ...
# 668                                NaN       NaN    NaN    NaN          NaN
# 669                                NaN       NaN    NaN    NaN          NaN
# 670                                NaN       NaN    NaN    NaN          NaN
# 671                                NaN       NaN    NaN    NaN          NaN
# 672                               True       NaN    NaN    NaN          NaN
#
#     predictable_value answer-the-quiz
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# ..                ...             ...
# 668               NaN             NaN
# 669               NaN             NaN
# 670               NaN             NaN
# 671               NaN             NaN
# 672               NaN            True
#
# [673 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['index', 'additional_comments', 'aggressively_value', 'behavior',
#        'birthYear', 'blueScore', 'computer_value', 'drivinglicense',
#        'education', 'gender', 'generously_value', 'log',
#        'press-the-read-instructions-button', 'redScore', 'steps', 'win',
#        'wisely_value', 'predictable_value', 'answer-the-quiz'],
#       dtype='object')

# %%
# df = df[df['answer-the-quiz'].notnull()]

# %% [markdown]
# number of people that start to play:

# %%
df['press-the-read-instructions-button'].count()
# Out:
# 554

# %%
len(df)
# Out:
# 673

# %%
df[['blueScore']]
# Out:
#      blueScore
# 0         20.0
# 1         19.0
# 2       -105.0
# 3         34.0
# 4       -105.0
# ..         ...
# 668        NaN
# 669        NaN
# 670        NaN
# 671        NaN
# 672        NaN
#
# [673 rows x 1 columns]

# %%
# df['behavior'] = np.where((df['answer-the-quiz'].notnull() & df['win'] == True & df['behavior'] == 'valueIterationBasedBehavior_v2'), 'valueIterationBasedBehavior_v2.1', 'valueIterationBasedBehavior_v2')

# %%
# df.loc[(df['answer-the-quiz'].isnull()) & (df['win'] == True), 'blueScore'] -= 10

# %%
# df.loc[(df['answer-the-quiz'].notnull()) & (df['win'] == True) & (df['behavior'] == 'carefulBehavior'), 'blueScore'] += 10

# %%
# df.loc[df['win'] == True, ['blueScore']] += 10

# %%
# df.loc[df['win'] == True, ['redScore']] += 20
# df[df['answer-the-quiz'].notnull()].loc[df['win'] == True, ['blueScore']] += 30

# %%
# df.loc[df['answer-the-quiz'].notnull()].loc[df['win'] == True].loc[df['behavior'] == 'valueIterationBasedBehavior_v2' , ['blueScore']]

# %%
# df.loc[(df['win'] == True) & (df['answer-the-quiz'].notnull()), ['blueScore']] += 30

# %%
# df.loc[(df['win'] == True) & (df['answer-the-quiz'].notnull()) & (), ['blueScore', 'behavior']].groupby('behavior').mean()

# %%
# df.loc[df['win'] == False, ['blueScore']] = df.loc[df['win'] == False, ['redScore']].to_numpy()

# %%
# df.loc[df['win'] == False, ['blueScore', 'redScore']]

# %%
# df.loc[(df['win'] == True) & (df['answer-the-quiz'].notnull()), ['blueScore', 'behavior']].groupby('behavior').min()

# %%
# df.to_json('data/test.json', orient = "index", indent=2)

# %% [markdown]
# ## Survay results:

# %% [markdown]
# upload Id workers and search for duplicate workers

# %%
path = './data/workers' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    fromOne = pd.read_csv(filename, index_col=None, header=0)
    fromOne['filename'] = filename
    li.append(fromOne)

workers = pd.concat(li, axis=0, ignore_index=True)

# %%
df['WorkerId'] = workers['WorkerId']

# %%
pd.concat(g for _, g in df.groupby('WorkerId') if len(g) > 1).groupby('WorkerId')['index'].count()
# Out:
# WorkerId
# A17AF42SNQNH9C    5
# A1AZLJ3R5FQ9B7    2
# A1BQI9JKLVCIL0    2
# A1K1E4KCVW1HOZ    3
# A1KZ21TSAYUHO4    2
# A1OW27AZS122X2    2
# A1QKW8E5J7NAF2    2
# A209KMZQTLEZZC    2
# A244IQQR0CTZ3I    2
# A2DCKE7398C0XV    2
# A2I6ZALE49CVSC    2
# A2IFXO71MXB9GK    2
# A2OU4N4VBIE91I    2
# A2YR29YNFLZSUG    2
# A2ZRL1ZWWXJ0L7    3
# A30YR5TPOKQYXJ    2
# A33XAJW8WGY3O9    2
# A34CPKFZXBX1PO    2
# A36UD0YBRIWTVL    2
# A37XBH865833FE    2
# A39ICPRR4OS3OX    2
# A3ADHMAWDD7M6V    2
# A3GWRDHAURRNK6    2
# A3H073G4EPBYOM    2
# A3H3BTRV6I3LYU    2
# A3KK1BNF5H0N1Z    3
# A3L7TVDAMZM0FG    2
# A3P35II1RN3FYV    2
# A3UWHJTAUTF6TO    2
# A6JUD4NCQCDWG     2
# ACXP8KHFX06KR     3
# AD1ILDUXZHASF     3
# ASNMT3I94HZ44     2
# ATJ92FYQX176Z     4
# Name: index, dtype: int64

# %% [markdown]
# We will keep the first one of any 'WorkerId' instance to keep samples unique

# %%
df = df.drop_duplicates(subset=['WorkerId'])

# %% [markdown]
# number of people that answer the survay:

# %%
df['birthYear'].count()
# Out:
# 402

# %%
df['additional_comments'][df['additional_comments'].notna()][df['additional_comments'] != ""]
# Out:
# 8                                    Thankyouandstaysafe
# 11     Icouldn'tmovetotherightusingtherightarrowasins...
# 12                                                  none
# 24                                           GodBlessYou
# 34                                                  none
#                              ...
# 380                                                 none
# 402                                                 cool
# 405                                                 None
# 425                                                 Good
# 428                                                  N/A
# Name: additional_comments, Length: 65, dtype: object

# %%
df.loc[:, ['aggressively_value', 'computer_value', 'generously_value', 'wisely_value', 'predictable_value']] = df.loc[:, ['aggressively_value', 'computer_value', 'generously_value', 'wisely_value', 'predictable_value']].apply(pd.to_numeric)
# Out:
# /home/ido/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1786: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)

# %%
df.groupby('behavior').mean()
# Out:
#                                 aggressively_value  blueScore  computer_value  \
# behavior
# aggressiveBehavior                        5.084746 -11.474576        5.932203
# carefulBehavior                           2.964286  20.214286        5.214286
# randomBehavior                            3.469697 -64.803030        5.681818
# semiAggressiveBehavior                    4.610390 -58.155844        5.792208
# semiCarefulBehavior                       4.012987 -15.337662        5.766234
# valueIterationBasedBehavior_v2            4.915789  -0.726316        6.094737
#
#                                 generously_value   redScore      steps  \
# behavior
# aggressiveBehavior                      3.305085 -16.593220   6.932203
# carefulBehavior                         5.071429  22.285714   7.714286
# randomBehavior                          4.030303 -55.075758  10.227273
# semiAggressiveBehavior                  3.194805 -60.896104   6.480519
# semiCarefulBehavior                     4.220779  -0.883117  11.935065
# valueIterationBasedBehavior_v2          3.505263  -5.957895   8.589474
#
#                                 wisely_value  predictable_value
# behavior
# aggressiveBehavior                  4.525424           5.068966
# carefulBehavior                     4.035714                NaN
# randomBehavior                      3.696970           3.441176
# semiAggressiveBehavior              4.402597           4.675676
# semiCarefulBehavior                 5.046512           4.311688
# valueIterationBasedBehavior_v2      4.726316           4.803279

# %%
df.groupby('behavior')['blueScore', 'redScore'].describe()
# Out:
# <ipython-input-29-c4d30ac448c8>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('behavior')['blueScore', 'redScore'].describe()
#                                blueScore                                      \
#                                    count       mean        std    min    25%
# behavior
# aggressiveBehavior                  59.0 -11.474576  62.040964 -108.0 -103.0
# carefulBehavior                     28.0  20.214286   1.707438   15.0   20.0
# randomBehavior                      66.0 -64.803030  55.519427 -152.0 -107.0
# semiAggressiveBehavior              77.0 -58.155844  64.175144 -114.0 -105.0
# semiCarefulBehavior                 77.0 -15.337662  44.757419 -137.0  -15.0
# valueIterationBasedBehavior_v2      95.0  -0.726316  54.656459 -124.0   22.0
#
#                                                    redScore             \
#                                   50%    75%   max    count       mean
# behavior
# aggressiveBehavior               25.0  34.00  35.0     59.0 -16.593220
# carefulBehavior                  20.0  20.25  25.0     28.0  22.285714
# randomBehavior                 -105.0 -13.50  23.0     66.0 -55.075758
# semiAggressiveBehavior         -104.0  24.00  34.0     77.0 -60.896104
# semiCarefulBehavior             -10.0  18.00  32.0     77.0  -0.883117
# valueIterationBasedBehavior_v2   25.0  28.00  35.0     95.0  -5.957895
#
#
#                                       std    min     25%    50%   75%   max
# behavior
# aggressiveBehavior              58.515580 -108.0 -103.00   22.0  23.0  23.0
# carefulBehavior                  2.536506   12.0   21.75   23.0  23.0  25.0
# randomBehavior                  65.718118 -152.0 -107.00 -105.0  20.0  25.0
# semiAggressiveBehavior          60.358487 -114.0 -105.00 -104.0  21.0  22.0
# semiCarefulBehavior             48.346059 -137.0   14.00   19.0  22.0  25.0
# valueIterationBasedBehavior_v2  51.948607 -125.0   13.00   21.0  23.0  23.0

# %%
fig,(ax1) = plt.subplots(ncols=1, figsize=(8,5))
sns.kdeplot(df.aggressively_value[df['behavior'] == 'carefulBehavior'], label='carefulBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'semiAggressiveBehavior'], label='semiAggressiveBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'aggressiveBehavior'], label='aggressiveBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'randomBehavior'], label='randomBehavior', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'valueIterationBasedBehavior_v2'], label='valueIterationBasedBehavior_v2', shade=True)
sns.kdeplot(df.aggressively_value[df['behavior'] == 'semiCarefulBehavior'], label='semiCarefulBehavior', shade=True)
ax1.set_ylabel('Distribution')
ax1.set_xlabel('aggressively_value')
# Out:
# Text(0.5, 0, 'aggressively_value')

# %%
df_temp = df[df.behavior != 'carefulBehavior']

def count_plot_by_behavior(feature):
    sns.countplot(x=df_temp[feature],hue=df_temp['behavior'])
    plt.show()
    
for value in ['aggressively_value', 'computer_value', 'generously_value', 'wisely_value', 'predictable_value']:
    count_plot_by_behavior(value)

# %%
def pie_count_plot(feature):
    list_gen=df[feature].value_counts().plot.pie(figsize=(6, 6))
    title = 'Distribution by: ', feature
    plt.title(title)
    plt.show()
    
for value in ['birthYear', 'drivinglicense', 'education', 'gender', 'redScore', 'steps', 'win']:
    pie_count_plot(value)

# %%
df.groupby('win')['gender'].value_counts().plot.pie(figsize=(6, 6))
# Out:
# <AxesSubplot:ylabel='gender'>

# %%
df.groupby('gender').mean()
# Out:
#         aggressively_value  blueScore  computer_value  generously_value  \
# gender
# female            4.314103 -24.089744        5.839744          3.615385
# male              4.349593 -25.845528        5.808943          3.833333
#
#          redScore     steps  wisely_value  predictable_value
# gender
# female -23.089744  8.737179      4.500000           4.552083
# male   -23.215447  8.825203      4.379464           4.401408

# %% [markdown]
# # Statistics of the red agent movements:

# %% [markdown]
# ### Create the statistics table from the log column:

# %%
statistics_raw = pd.DataFrame.from_dict(data[branch], orient='index')
log_red = flat_table.normalize(statistics_raw).iloc[:,-2:]
log_red = log_red.dropna()
log_red['log.red'] = log_red['log.red'] + ' ' + log_red['log.blue']
log_red = log_red.drop('log.blue', axis=1)
log_red['log.red'] = log_red.apply(lambda x: x['log.red'].rsplit(' ', 1)[0], axis = 1)
for substr in ['from: ', ', action:']:
    log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(substr, '', 2), axis = 1)
log_red['log.red'] = log_red['log.red'].str.split().apply(reversed).apply(' '.join)
log_red['value']=1
log_red['action'] = log_red['log.red'].str.split().str[1]
log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(str(x['action'])+' ', '', 2), axis = 1)

log_red = log_red.groupby(['log.red', 'action']).count()
log_red.reset_index(inplace=True)
log_red = log_red.set_index('log.red')

# s_r = df['log'].apply(pd.Series).iloc[:,1:]
# s_r.columns = s_r.columns.astype(str)
# s_r = flat_table.normalize(s_r).drop('index', axis=1)
# log_red = pd.concat([s_r.melt(id_vars=[str(i)+'.blue' for i in range(1,int(len(s_r.columns)/2))],var_name='red', value_name="log.red").iloc[:,-2:].dropna(),
#            s_r.melt(id_vars=[str(i)+'.red' for i in range(1,int(len(s_r.columns)/2))],var_name='blue', value_name="log.blue").iloc[:,-2:].dropna()
#           ], axis=1)
# log_red = log_red.drop(['red','blue'],axis=1)
# log_red['log.red'] = log_red['log.red'] + ' ' + log_red['log.blue']
# log_red = log_red.drop('log.blue', axis=1)
# log_red['log.red'] = log_red.apply(lambda x: x['log.red'].rsplit(' ', 1)[0], axis = 1)
# for substr in ['from: ', ', action:']:
#     log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(substr, '', 2), axis = 1)
# log_red['log.red'] = log_red['log.red'].str.split().apply(reversed).apply(' '.join)
# log_red['value']=1
# log_red['action'] = log_red['log.red'].str.split().str[1]
# log_red['log.red'] = log_red.apply(lambda x: x['log.red'].replace(str(x['action'])+' ', '', 2), axis = 1)

# log_red = log_red.groupby(['log.red', 'action']).count()
# log_red.reset_index(inplace=True)
# log_red = log_red.set_index('log.red')

log_red.sort_index()
# Out:
#         action  value
# log.red
# a1 a2     down      2
# a1 a2    right     32
# a1 a2     stay      1
# a1 a3     down      5
# a1 a3    right    106
# ...        ...    ...
# b6 b1     stay     11
# b6 b1       up      3
# b6 b4       up      1
# b6 b5     stay      6
# b6 b5       up     34
#
# [195 rows x 2 columns]

# %%
len(log_red.index)
log_red[log_red.index == 'a1 a5']
# Out:
#         action  value
# log.red
# a1 a5     down      6
# a1 a5    right    174
# a1 a5     stay      8

# %%
result = pd.DataFrame(index=log_red.index.drop_duplicates(), columns=['right', 'stay', 'up', 'down'])
# result.reset_index(level=0, inplace=True)
for action in ['right', 'stay', 'up', 'down']:
    result[action] = log_red[log_red['action'] == action]['value']
result = result.fillna(0)
result.reset_index(inplace=True)
result.sort_index()
# Out:
#    log.red  right  stay    up  down
# 0    a1 a2   32.0   1.0   0.0   2.0
# 1    a1 a3  106.0  10.0   0.0   5.0
# 2    a1 a4  161.0   0.0   0.0   0.0
# 3    a1 a5  174.0   8.0   0.0   6.0
# 4    a1 b1    0.0  46.0  13.0   0.0
# ..     ...    ...   ...   ...   ...
# 88   b6 a4   11.0   1.0   0.0   0.0
# 89   b6 a5   36.0   5.0   0.0   5.0
# 90   b6 b1    0.0  11.0   3.0   0.0
# 91   b6 b4    0.0   0.0   1.0   0.0
# 92   b6 b5    0.0   6.0  34.0   0.0
#
# [93 rows x 5 columns]

# %% [markdown]
# #### After Laplace's Smoothing:

# %%
for i in range(1,7):
    result.loc[result['log.red'].str.endswith('a'+str(i)), ['stay', 'right', 'down']] += 1
    
for i in range(1,7):
    result.loc[result['log.red'].str.endswith('b'+str(i)), ['stay', 'up']] += 1

result = result.set_index('log.red')
result
# Out:
#          right  stay    up  down
# log.red
# a1 a2     33.0   2.0   0.0   3.0
# a1 a3    107.0  11.0   0.0   6.0
# a1 a4    162.0   1.0   0.0   1.0
# a1 a5    175.0   9.0   0.0   7.0
# a1 b1      0.0  47.0  14.0   0.0
# ...        ...   ...   ...   ...
# b6 a4     12.0   2.0   0.0   1.0
# b6 a5     37.0   6.0   0.0   6.0
# b6 b1      0.0  12.0   4.0   0.0
# b6 b4      0.0   1.0   2.0   0.0
# b6 b5      0.0   7.0  35.0   0.0
#
# [93 rows x 4 columns]

# %% [markdown]
# #### Convert it to Probability table:

# %%
pd.options.display.float_format = "{:,.2f}".format
result_probs = result.div(result.sum(axis=1), axis=0)

# %% [markdown]
# #### Save data on computer for the policy iteration:

# %%
result_probs.to_json('data/probs1.json' , orient='index', indent=4)

# %%
#To calculate the score:
crushing = -100;
richToDestination = 30;
step = -1;

# %%
'''==================================================
Initial set up                              version 1
=================================================='''
#Define all states
all_states=[]
for i in range(12):
    for j in range(12):
            all_states.append((i,j))

#Define rewards for all states
rewards = {}
for (i,j) in all_states:
    if(i == j): # crushed
        rewards[(i,j)] = crushing
    elif(i == 0): # blue agent in a1
        rewards[(i,j)] = richToDestination
    else:
        rewards[(i,j)] = step

#Dictionnary of possible actions. We have two "end" states (1,2 and 2,2)
actions = {}
for (i,j) in all_states:
    if i != 0 and i != j: #if s=(i, j) is not an "end" state
        actions[(i,j)] = ("stay", "left", "down") if (i < 6) else ("up", "stay")

#Define an initial policy
Policy={}
for s in actions.keys():
    Policy[s] = np.random.choice(actions[s])

probs = json.load(open('data/probs1.json',))
    
#Define initial value function 
V={}
for (i,j) in all_states:
    if (i,j) in actions.keys():
        V[(i,j)] = step
    if(i == 0): # blue agent in a1
        V[(i,j)] = richToDestination
    if(i == j): # crushed
        V[(i,j)] = crushing

# %%
# print('all_states: ', all_states)

# %%
# print('rewards: ', rewards)

# %%
# print('actions: ', actions)

# %%
# print('V: ', V)

# %%
def adapt_state(s):
    # takes (i,j) format state and convert it to "a|b[1-6] a|b[1-6]" format
    i = s[0]
    j = s[1]
    if i < 6:
        blueState = 'a' + str(i+1)
    else:
        blueState = 'b' + str(i-5)
    if j < 6:
        redState = 'a' + str(j+1)
    else:
        redState = 'b' + str(j-5)
    return blueState + ' ' + redState

# %%
print(adapt_state((0,1)))
print(adapt_state((0,7)))
print(adapt_state((6,8)))
print(adapt_state((10,11)))
# Out:
# a1 a2
# a1 b2
# b1 b3
# b5 b6

# %%
def newPosGivenAction(s, a, agent_i):
    # assert check
    if s[agent_i] == 5 and agent_i == 1:
        actions=["stay"]
    elif s[agent_i] == 0 and agent_i == 0:
        actions=["stay"]
    elif s[agent_i] < 6 and agent_i == 1:
        actions=["right","stay", "down"]
    elif s[agent_i] < 6 and agent_i == 0:
        actions=["left","stay", "down"]
    else:
        actions=["stay", "up"]
    assert a in actions , "action: " + str(a) + " is not vallid at state: " + str(s) + " for agent: " + str(agent_i)
    # agent_i = 0 for blue and 1 for red
    newPos = -1
    if a == "up":
        newPos = s[agent_i]-6
    if a == "down":
        newPos = s[agent_i]+6
    if a == "left":
        newPos = s[agent_i]-1
    if a == "right":
        newPos = s[agent_i]+1
    if a == "stay":
        newPos = s[agent_i]
    assert newPos > -1 and newPos < 12 , "Got out from board!\naction: " + str(a) + " ,state: " + str(s) + " for agent: " + str(agent_i)
    return newPos

# %%
def randomProbForAction(s):
    # if aX return 1/3 else (it is bX) return 1/2
    if s[1] == 5: # a6
        return 1
    if s[1] < 6:
        return 1.0/3
    else:
        return 1.0/2

# %%
def nextStateDistibution(s, a):
    # given state s and action a, return distibution of possibles new states by probs
    nxt = {}
#     print('s: ', s)
#     print('a: ', a)
    bluePossition = newPosGivenAction(s, a, 0)
#     print('bluePossition: ', bluePossition)
    
    # red possible action given state
    if s[1] == 5:
        actions=["stay"]
    elif s[1] < 6:
        actions=["right","stay", "down"]
    else:
        actions=["stay", "up"]
    for r_a in actions:
        redPossition = newPosGivenAction(s, r_a, 1)
#         print('redPossition: '+ str(redPossition))
        newState = (bluePossition, redPossition)
        try:
            nxt[newState] = probs[adapt_state(s)][r_a]
#                 nxt[newState] = {probs[adapt_state(s)][r_a], r_a, adapt_state(newState)}
        except KeyError:
#                 print("Warning! State not found: assume random behavior. ", s)
            nxt[newState] = randomProbForAction(s)
    assert abs(sum(nxt.values()) - 1.0) < 0.0001, "probs not sum to 1.0. \nstate: " + str(s) + " action: " + str(a) + " nxt: " + str(nxt) + "\nsum of probs: " + str(sum(nxt.values()))
    return nxt

# %%
pp.pprint(nextStateDistibution((10, 11), "up"))
pp.pprint(nextStateDistibution((1, 5), "stay"))
# Out:
# {(4, 5): 0.5, (4, 11): 0.5}
# {(1, 5): 1}

# %%
pp.pprint(nextStateDistibution((6, 7), "stay"))
# Out:
# {(6, 1): 0.5, (6, 7): 0.5}

# %%
adapt_state((0,2))
# Out:
# 'a1 a3'

# %%
'''==================================================
Value Iteration
=================================================='''

#Hyperparameters
SMALL_ENOUGH = 0.0001
GAMMA = 0.99

iteration = 1
while True:
    biggest_change = 0
    for s in all_states:
        if s in Policy:
            
            old_v = V[s]
            new_v = np.NINF
            
            for a in actions[s]:
                nxt = nextStateDistibution(s, a)
                v=0
                #Calculate the value
                for next_state, prob in nxt.items():
                    v += prob * (rewards[s] + GAMMA * V[next_state])
                if v > new_v: #Is this the best action so far? If so, keep it
                    new_v = v
                    Policy[s] = a

       #Save the best of all actions for the state                                
            V[s] = new_v
            biggest_change = max(biggest_change, np.abs(old_v - V[s]))

            
   #See if the loop should stop now         
    if biggest_change < SMALL_ENOUGH:
        print('converge after: ' + str(iteration) + ' iterations')
        break
    iteration += 1
    
#     #Print every 100 iterations
    if(iteration % 100 == 0):
        print(iteration, ') ', V[(5,0)]) #V[(a6, a1)]
# Out:
# 100 )  12.613913935696198
# 200 )  12.613913935696198
# 300 )  12.613913935696198
# 400 )  12.613913935696198
# 500 )  12.613913935696198
# 600 )  12.613913935696198
# 700 )  12.613913935696198
# 800 )  12.613913935696198
# 900 )  12.613913935696198
# converge after: 917 iterations

# %% [markdown]
# ## Results:

# %%
def convertStates():
    P_convert= {}
    V_convert = {}
    for s,v in V.items():
        V_convert[adapt_state(s)] = v
    
#     print()
    for s,p in Policy.items():
        P_convert[adapt_state(s)] = p
    
    pp.pprint(V_convert)
    pp.pprint(P_convert)
    return P_convert, V_convert

# %%
# print the results:
print("iterations: ", iteration)
optimal_policy, optimal_V = convertStates()
# Out:
# iterations:  917
# {'a1 a1': -100,
#  'a1 a2': 30,
#  'a1 a3': 30,
#  'a1 a4': 30,
#  'a1 a5': 30,
#  'a1 a6': 30,
#  'a1 b1': 30,
#  'a1 b2': 30,
#  'a1 b3': 30,
#  'a1 b4': 30,
#  'a1 b5': 30,
#  'a1 b6': 30,
#  'a2 a1': 2.0575029370921283,
#  'a2 a2': -100,
#  'a2 a3': 28.7,
#  'a2 a4': 28.700000000000003,
#  'a2 a5': 28.7,
#  'a2 a6': 28.7,
#  'a2 b1': 0.2404624999045077,
#  'a2 b2': 28.7,
#  'a2 b3': 28.700000000000003,
#  'a2 b4': 28.699999999999996,
#  'a2 b5': 28.699999999999996,
#  'a2 b6': 28.7,
#  'a3 a1': 15.288797680707043,
#  'a3 a2': 17.963265663158104,
#  'a3 a3': -100,
#  'a3 a4': 27.413,
#  'a3 a5': 27.4129999972587,
#  'a3 a6': 27.413,
#  'a3 b1': 14.31350058515585,
#  'a3 b2': 18.12513062873254,
#  'a3 b3': 27.413000000000004,
#  'a3 b4': 27.413,
#  'a3 b5': 27.412999999999997,
#  'a3 b6': 27.413,
#  'a4 a1': 15.397485718936768,
#  'a4 a2': 12.856168664983105,
#  'a4 a3': 13.281739994405413,
#  'a4 a4': -100,
#  'a4 a5': 26.138869996481482,
#  'a4 a6': 26.13887,
#  'a4 b1': 13.34968091671541,
#  'a4 b2': 16.818195937409374,
#  'a4 b3': 10.747626100706697,
#  'a4 b4': 26.13887,
#  'a4 b5': 26.138869997889202,
#  'a4 b6': 26.13887,
#  'a5 a1': 13.060262651686612,
#  'a5 a2': 12.603167210064436,
#  'a5 a3': 10.728588257971662,
#  'a5 a4': 12.389733168954999,
#  'a5 a5': -100,
#  'a5 a6': 24.8774813,
#  'a5 b1': 13.410054307265835,
#  'a5 b2': 13.688810478184276,
#  'a5 b3': 11.312665009624409,
#  'a5 b4': 10.712274465023366,
#  'a5 b5': 24.87748129787934,
#  'a5 b6': 24.8774813,
#  'a6 a1': 12.613913935696198,
#  'a6 a2': 14.265795065871002,
#  'a6 a3': 15.493154873261947,
#  'a6 a4': 16.39908832273456,
#  'a6 a5': 18.780521914166734,
#  'a6 a6': -100,
#  'a6 b1': 12.212991266195212,
#  'a6 b2': 12.747312739414244,
#  'a6 b3': 13.99146221136408,
#  'a6 b4': 14.843029407247444,
#  'a6 b5': 15.286977151646276,
#  'a6 b6': 23.628706487,
#  'b1 a1': -14.199999999999996,
#  'b1 a2': 28.7,
#  'b1 a3': 28.7,
#  'b1 a4': 28.7,
#  'b1 a5': 28.7,
#  'b1 a6': 28.7,
#  'b1 b1': -100,
#  'b1 b2': 28.7,
#  'b1 b3': 28.7,
#  'b1 b4': 28.7,
#  'b1 b5': 28.7,
#  'b1 b6': 28.7,
#  'b2 a1': 2.642949025545728,
#  'b2 a2': 10.424600001505798,
#  'b2 a3': 27.413000000000004,
#  'b2 a4': 27.413,
#  'b2 a5': 27.412999999999997,
#  'b2 a6': 27.413,
#  'b2 b1': 0.5580141235503339,
#  'b2 b2': -100,
#  'b2 b3': 27.413000000000004,
#  'b2 b4': 27.413,
#  'b2 b5': 27.412999999999997,
#  'b2 b6': 27.413,
#  'b3 a1': 16.575411555647204,
#  'b3 a2': 19.9029573463812,
#  'b3 a3': 21.633910358944842,
#  'b3 a4': 26.138869997851508,
#  'b3 a5': 26.138869999457224,
#  'b3 a6': 26.13887,
#  'b3 b1': 14.835480039976972,
#  'b3 b2': 18.60079664539965,
#  'b3 b3': -100,
#  'b3 b4': 26.13887,
#  'b3 b5': 26.138869999224603,
#  'b3 b6': 26.13887,
#  'b4 a1': 12.729100647936733,
#  'b4 a2': 11.85165122238196,
#  'b4 a3': 11.568512077001644,
#  'b4 a4': 13.164197028238902,
#  'b4 a5': 24.87748129965978,
#  'b4 a6': 24.8774813,
#  'b4 b1': 12.891959692213725,
#  'b4 b2': 13.035075978103194,
#  'b4 b3': 11.521729405770927,
#  'b4 b4': -100,
#  'b4 b5': 24.87748129721349,
#  'b4 b6': 24.8774813,
#  'b5 a1': 11.817059701327475,
#  'b5 a2': 10.578593007508413,
#  'b5 a3': 10.814030681699872,
#  'b5 a4': 8.990334920497155,
#  'b5 a5': 9.892183544907104,
#  'b5 a6': 23.628706487,
#  'b5 b1': 12.160522517863575,
#  'b5 b2': 12.014528955683112,
#  'b5 b3': 9.814047703418076,
#  'b5 b4': 10.989055151061374,
#  'b5 b5': -100,
#  'b5 b6': 23.628706487,
#  'b6 a1': 12.307624526205004,
#  'b6 a2': 14.292901243606877,
#  'b6 a3': 15.65889301115668,
#  'b6 a4': 17.018492955447996,
#  'b6 a5': -71.62528684604857,
#  'b6 a6': -99.99015742709012,
#  'b6 b1': 11.190089714234755,
#  'b6 b2': 12.371488363616196,
#  'b6 b3': 13.594885456889884,
#  'b6 b4': 15.271948284557183,
#  'b6 b5': 17.016281809093904,
#  'b6 b6': -100}
# {'a2 a1': 'down',
#  'a2 a3': 'left',
#  'a2 a4': 'left',
#  'a2 a5': 'left',
#  'a2 a6': 'left',
#  'a2 b1': 'down',
#  'a2 b2': 'left',
#  'a2 b3': 'left',
#  'a2 b4': 'left',
#  'a2 b5': 'left',
#  'a2 b6': 'left',
#  'a3 a1': 'down',
#  'a3 a2': 'down',
#  'a3 a4': 'left',
#  'a3 a5': 'left',
#  'a3 a6': 'left',
#  'a3 b1': 'down',
#  'a3 b2': 'down',
#  'a3 b3': 'left',
#  'a3 b4': 'left',
#  'a3 b5': 'left',
#  'a3 b6': 'left',
#  'a4 a1': 'left',
#  'a4 a2': 'stay',
#  'a4 a3': 'left',
#  'a4 a5': 'left',
#  'a4 a6': 'left',
#  'a4 b1': 'left',
#  'a4 b2': 'left',
#  'a4 b3': 'stay',
#  'a4 b4': 'left',
#  'a4 b5': 'left',
#  'a4 b6': 'left',
#  'a5 a1': 'left',
#  'a5 a2': 'left',
#  'a5 a3': 'stay',
#  'a5 a4': 'left',
#  'a5 a6': 'left',
#  'a5 b1': 'left',
#  'a5 b2': 'left',
#  'a5 b3': 'left',
#  'a5 b4': 'stay',
#  'a5 b5': 'left',
#  'a5 b6': 'left',
#  'a6 a1': 'stay',
#  'a6 a2': 'down',
#  'a6 a3': 'down',
#  'a6 a4': 'stay',
#  'a6 a5': 'left',
#  'a6 b1': 'left',
#  'a6 b2': 'stay',
#  'a6 b3': 'down',
#  'a6 b4': 'down',
#  'a6 b5': 'stay',
#  'a6 b6': 'left',
#  'b1 a1': 'up',
#  'b1 a2': 'up',
#  'b1 a3': 'up',
#  'b1 a4': 'up',
#  'b1 a5': 'up',
#  'b1 a6': 'up',
#  'b1 b2': 'up',
#  'b1 b3': 'up',
#  'b1 b4': 'up',
#  'b1 b5': 'up',
#  'b1 b6': 'up',
#  'b2 a1': 'stay',
#  'b2 a2': 'up',
#  'b2 a3': 'up',
#  'b2 a4': 'up',
#  'b2 a5': 'up',
#  'b2 a6': 'up',
#  'b2 b1': 'stay',
#  'b2 b3': 'up',
#  'b2 b4': 'up',
#  'b2 b5': 'up',
#  'b2 b6': 'up',
#  'b3 a1': 'stay',
#  'b3 a2': 'stay',
#  'b3 a3': 'up',
#  'b3 a4': 'up',
#  'b3 a5': 'up',
#  'b3 a6': 'up',
#  'b3 b1': 'stay',
#  'b3 b2': 'stay',
#  'b3 b4': 'up',
#  'b3 b5': 'up',
#  'b3 b6': 'up',
#  'b4 a1': 'up',
#  'b4 a2': 'up',
#  'b4 a3': 'stay',
#  'b4 a4': 'stay',
#  'b4 a5': 'up',
#  'b4 a6': 'up',
#  'b4 b1': 'up',
#  'b4 b2': 'up',
#  'b4 b3': 'up',
#  'b4 b5': 'up',
#  'b4 b6': 'up',
#  'b5 a1': 'up',
#  'b5 a2': 'up',
#  'b5 a3': 'up',
#  'b5 a4': 'stay',
#  'b5 a5': 'up',
#  'b5 a6': 'up',
#  'b5 b1': 'up',
#  'b5 b2': 'up',
#  'b5 b3': 'up',
#  'b5 b4': 'up',
#  'b5 b6': 'up',
#  'b6 a1': 'up',
#  'b6 a2': 'stay',
#  'b6 a3': 'stay',
#  'b6 a4': 'up',
#  'b6 a5': 'up',
#  'b6 a6': 'stay',
#  'b6 b1': 'up',
#  'b6 b2': 'up',
#  'b6 b3': 'up',
#  'b6 b4': 'stay',
#  'b6 b5': 'up'}

# %%
import seaborn as sns
intensity = np.array(list(optimal_V.values())).reshape(12,12)
f, ax = plt.subplots(figsize=(20, 10))
sns.heatmap(intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
ax.set_title('Value Iteration results:')
# Out:
# Text(0.5, 1.0, 'Value Iteration results:')

# %% [markdown]
# # Policy evaluation:

# %%
def policy_eval(policy):
    V={}
    for (i,j) in all_states:
        if (i,j) in actions.keys():
            V[(i,j)] = step
        if(i == 0): # blue agent in a1
            V[(i,j)] = richToDestination
        if(i == j): # crushed
            V[(i,j)] = crushing
    while True:
        biggest_change = 0
        for s in all_states:
            if s in Policy:  
                old_v = V[s]
                nxt = nextStateDistibution(s, policy[s])
                v=0
                #Calculate the value
                for next_state, prob in nxt.items():
                    v += prob * (rewards[s] + GAMMA * V[next_state])
        
                #Save the best of all actions for the state                                
                V[s] = v
                biggest_change = max(biggest_change, np.abs(old_v - V[s]))
        #See if the loop should stop now         
        if biggest_change < SMALL_ENOUGH:
            return V

# %%
valueIteration_policy = Policy

# %% [markdown]
# # evaluate other behaviors:

# %%
def randomBehavior():
    Policy={}
    for s in actions.keys():
        Policy[s] = np.random.choice(actions[s])
    return Policy

random_policy = randomBehavior()

# %%
randomBehavior_intensity = np.array(list(policy_eval(random_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(randomBehavior_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: randomBehavior')

# %%
def carefulBehavior():
    Policy={}
    for s in actions.keys():
        blueState = s[0]
        redState = s[1]
        if redState + 1 == blueState or redState == blueState + 5 or redState + 6 == blueState or redState + 7 == blueState:
            if blueState < 6:
                Policy[s] = "down"
            else:
                Policy[s] = "stay"
        elif redState + 2 == blueState:
            if blueState < 6:
                Policy[s] = "down"
            else:
                Policy[s] = "up"
        else:
            if blueState < 6:
                Policy[s] = "left"
            else:
                Policy[s] = "up"
    return Policy

careful_policy = carefulBehavior()

# %%
careful_intensity = np.array(list(policy_eval(careful_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(careful_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: carefulBehavior')

# %%
def semiCarefulBehavior():
    Policy={}
    for s in actions.keys():
        blueState = s[0]
        redState = s[1]
        if redState + 1 == blueState:
            if blueState < 6:
                Policy[s] = "down"
            else:
                Policy[s] = "up"
        elif redState + 2 == blueState:
            if blueState < 6:
                Policy[s] = "stay"
            else:
                Policy[s] = "up"
        elif redState == blueState + 5 or redState + 6 == blueState or redState + 7 == blueState:
            if redState == 11 and blueState == 6:
                Policy[s] = "up"
            else:
                Policy[s] = "stay"
        else:
            if blueState < 6:
                Policy[s] = "left"
            else:
                Policy[s] = "up"
    return Policy

semiCareful_policy = semiCarefulBehavior()

# %%
semiCareful_intensity = np.array(list(policy_eval(semiCareful_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(semiCareful_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: carefulBehavior')

# %%
def semiAggressiveBehavior():
    Policy={}
    for s in actions.keys():
        blueState = s[0]
        redState = s[1]
        if redState + 1 == blueState:
            if blueState < 6:
                Policy[s] = "stay"
            else:
                Policy[s] = "up"
        elif redState == blueState + 5 or redState + 6 == blueState or redState + 7 == blueState:
            if blueState < 6:
                Policy[s] = "left"
            else:
                Policy[s] = "stay"
        else:
            if blueState < 6:
                Policy[s] = "left"
            else:
                Policy[s] = "up"
    return Policy

semiAggressive_policy = semiAggressiveBehavior()

# %%
semiAggressive_intensity = np.array(list(policy_eval(semiAggressive_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(semiAggressive_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: semiAggressiveBehavior')

# %%
def aggressiveBehavior():
    Policy={}
    for s in actions.keys():
        blueState = s[0]
        redState = s[1]
        if blueState > 5: #blue is in bX
            Policy[s] = "up"
        else:
            Policy[s] = "left"
    return Policy

aggressive_policy = aggressiveBehavior()

# %%
aggressive_intensity = np.array(list(policy_eval(aggressive_policy).values())).reshape(12,12)
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(aggressive_intensity, vmin=-100, vmax=10, annot=True, linewidths=0.1, cmap="YlGnBu")
# ax.set_title('Value function for: aggressiveBehavior')

# %%
# diff = pd.DataFrame({'Real': df.groupby(['behavior']).mean()['blueScore'],
#                       'Prediction': [aggressive_intensity[5][0], careful_intensity[5][0], randomBehavior_intensity[5][0] , semiAggressive_intensity[5][0]]},
#                      index= df.groupby(['behavior']).mean()['blueScore'].index)
# diff['different'] = abs(diff['Real']-diff['Prediction'])
# diff

# %% [markdown]
# ## Value iteration with taking into account the previous state:

# %%
class OutOfBoard(Exception):
    pass

# %%
def get_pos_after_action(s, a):
    if a == 'U' or a == "up":
        if(s[0] == 'a'):
            raise OutOfBoard("An error occurred, state: "+ s + " action: " + a)
        return "a" + s[1]
    if a == 'D' or a == "down":
        if(s[0] == 'b'):
            raise OutOfBoard("An error occurred, state: "+ s + " action: " + a)
        return "b" + s[1]
    if a == 'L' or a == "left":
        if(s[0] == 'b' or s[1] == '1'):
            raise OutOfBoard("An error occurred, state: "+ s + " action: " + a)
        return "a" + str(int(s[1])-1)
    if a == 'R' or a == "right":
        if(s[0] == 'b' or s[1] == '6'):
            raise OutOfBoard("An error occurred, state: "+ s + " action: " + a)
        return "a" + str(int(s[1])+1)
    if a == 'S' or a == "stay":
        return s

# %%
def get_next_state(c_s):
    n_s = c_s.split()
    blueAction = n_s[3]
    blueState = n_s[2]
    redAction = n_s[1]
    redState = n_s[0]
    
    newPosBlue = get_pos_after_action(blueState, blueAction)
    newPosRed = get_pos_after_action(redState, redAction)
    
    return newPosBlue + ' ' + newPosRed

# %%
# s_r = df['log'].apply(pd.Series).iloc[:,1:]
# s_r.columns = s_r.columns.astype(str)
# log_red = flat_table.normalize(s_r).drop('index', axis=1)
# log_red = log_red.dropna(how='all')

# log_len = int(len(log_red.columns)/2)+1
# for i in range(1,log_len):
#     log_red[str(i)] = log_red[str(i)+'.red'] + ' ' + log_red[str(i)+'.blue']
#     log_red = log_red.drop([str(i)+'.red', str(i)+'.blue'],axis=1)
#     for substr in ['from: ', ', action:']:
#         log_red[str(i)] = log_red[str(i)].apply(lambda x: x.replace(substr, '', 2) if type(x) != float else x)
    
# log_len = len(log_red.columns)
# for i in range(1,log_len):
#     log_red[str(i) + '&' + str(i+1)] = log_red[str(i)] + '&' + log_red[str(i+1)]
#     log_red[str(i) + '&' + str(i+1)] = log_red[str(i) + '&' + str(i+1)].apply(lambda x: x.rsplit(' ', 2)[0] if type(x) != float else x)
# log_red = log_red.drop([str(i) for i in range(1,log_len+1)],axis=1)

# log_red = pd.DataFrame(log_red.to_numpy().flatten(), columns=['state'])
# log_red = log_red.dropna()

# log_red['action'] = log_red['state'].apply(lambda x: x.rsplit('&', 1)[1].rsplit(' ', 1)[1])
# log_red['state'] = log_red['state'].apply(lambda x: x.rsplit('&', 1)[0])

# log_red['nxt'] = log_red['state'].apply(get_next_state)
# log_red['state'] = log_red['state'].str.split().apply(reversed).apply(' '.join)

# log_red['value']=1

# for a in ['right', 'stay', 'up', 'down', 'left']:
#     log_red['state'] = log_red['state'].apply(lambda x: x.replace(a+' ', '', 2))

# log_red['state'] = log_red['state'] + ' nxt: ' + log_red['nxt']
# log_red = log_red.drop('nxt',axis=1)

# log_red = log_red.groupby(['state', 'action']).count()
# log_red.reset_index(inplace=True)
# log_red = log_red.set_index('state')

# log_red

s_r = df['log'].apply(pd.Series).iloc[:,1:]
s_r.columns = s_r.columns.astype(str)
s_r.set_index( df['index'], inplace=True)
log_red = flat_table.normalize(s_r)
log_red = log_red.dropna(how='all')
log_red.set_index(log_red['index'], inplace=True)
log_red = log_red.drop('index', axis=1)

log_len = int(len(log_red.columns)/2)+1
for i in range(1,log_len):
    log_red[str(i)] = log_red[str(i)+'.red'] + ' ' + log_red[str(i)+'.blue']
    log_red = log_red.drop([str(i)+'.red', str(i)+'.blue'],axis=1)
    for substr in ['from: ', ', action:']:
        log_red[str(i)] = log_red[str(i)].apply(lambda x: x.replace(substr, '', 2) if type(x) != float else x)
    
log_len = len(log_red.columns)
for i in range(1,log_len):
    log_red[str(i) + '&' + str(i+1)] = log_red[str(i)] + '&' + log_red[str(i+1)]
    log_red[str(i) + '&' + str(i+1)] = log_red[str(i) + '&' + str(i+1)].apply(lambda x: x.rsplit(' ', 2)[0] if type(x) != float else x)
log_red = log_red.drop([str(i) for i in range(1,log_len+1)],axis=1)

log_red_copy = log_red.copy(deep=True)

log_red = pd.DataFrame(log_red.to_numpy().flatten(), columns=['state'])
log_red = log_red.dropna()

log_red['action'] = log_red['state'].apply(lambda x: x.rsplit('&', 1)[1].rsplit(' ', 1)[1])
log_red['state'] = log_red['state'].apply(lambda x: x.rsplit('&', 1)[0])

log_red['nxt'] = log_red['state'].apply(get_next_state)
log_red['state'] = log_red['state'].str.split().apply(reversed).apply(' '.join)

log_red['value']=1

for a in ['right', 'stay', 'up', 'down', 'left']:
    log_red['state'] = log_red['state'].apply(lambda x: x.replace(a+' ', '', 2))

log_red['state'] = log_red['state'] + ' nxt: ' + log_red['nxt']
log_red = log_red.drop('nxt',axis=1)

log_red = log_red.groupby(['state', 'action']).count()
log_red.reset_index(inplace=True)
log_red = log_red.set_index('state')

log_red
# Out:
#                  action  value
# state
# a1 a2 nxt: a1 a2  right      1
# a1 a2 nxt: a1 a3   down      1
# a1 a2 nxt: a1 a3  right     25
# a1 a2 nxt: a1 a3   stay      1
# a1 a2 nxt: a1 b2   stay      1
# ...                 ...    ...
# b6 b5 nxt: b6 a5   down      3
# b6 b5 nxt: b6 a5  right     24
# b6 b5 nxt: b6 a5   stay      3
# b6 b5 nxt: b6 b5   stay      1
# b6 b5 nxt: b6 b5     up      2
#
# [423 rows x 2 columns]

# %%
log_red[log_red.index == 'a4 b3 nxt: a4 b3']
# Out:
#                  action  value
# state
# a4 b3 nxt: a4 b3   stay     23
# a4 b3 nxt: a4 b3     up     11

# %%
a = df[['index','win']]
a.set_index('index', inplace=True)

b = df[['index','behavior']]
b.set_index('index', inplace=True)

c = df[['index','blueScore']]
c.set_index('index', inplace=True)

d = df[['index','redScore']]
d.set_index('index', inplace=True)

e = df[['index','answer-the-quiz']]
e.set_index('index', inplace=True)

log_red_copy = pd.concat([log_red_copy,a, b, c ,d, e],axis=1)

# %%
# log_red_copy['1&2'].apply(lambda x: x.rsplit(' ', 3)[0] if type(x) != float else x)

# %% [markdown]
# aggressiveBehavior
#
# carefulBehavior
#
# randomBehavior
#
# semiAggressiveBehavior
#
# semiCarefulBehavior
#
# valueIterationBasedBehavior_v2

# %%
log_red_copy[log_red_copy['win'] == False][log_red_copy['blueScore'] != log_red_copy['redScore']]
# Out:
# <ipython-input-104-014a3da5a659>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   log_red_copy[log_red_copy['win'] == False][log_red_copy['blueScore'] != log_red_copy['redScore']]
#                                           1&2                      2&3  \
# index
# -Mbc5y71NVYdV2K6bEK2  a1 down a6 left&b1 stay  b1 stay a5 left&b1 stay
# -MbcM7sdvckN292XzTpJ    a1 down a6 left&b1 up    b1 up a5 left&a1 down
#
#                                           3&4                      4&5  \
# index
# -Mbc5y71NVYdV2K6bEK2  b1 stay a4 stay&b1 stay  b1 stay a4 stay&b1 stay
# -MbcM7sdvckN292XzTpJ    a1 down a4 left&b1 up    b1 up a3 left&a1 down
#
#                                           5&6                      6&7  \
# index
# -Mbc5y71NVYdV2K6bEK2  b1 stay a4 stay&b1 stay  b1 stay a4 stay&b1 stay
# -MbcM7sdvckN292XzTpJ  a1 down a2 left&b1 stay  b1 stay a1 stay&b1 stay
#
#                                           7&8                      8&9  \
# index
# -Mbc5y71NVYdV2K6bEK2  b1 stay a4 stay&b1 stay  b1 stay a4 stay&b1 stay
# -MbcM7sdvckN292XzTpJ    b1 stay a1 stay&b1 up                      NaN
#
#                                          9&10                    10&11  ...  \
# index                                                                   ...
# -Mbc5y71NVYdV2K6bEK2  b1 stay a4 stay&b1 stay  b1 stay a4 stay&b1 stay  ...
# -MbcM7sdvckN292XzTpJ                      NaN                      NaN  ...
#
#                      47&48 48&49 49&50 50&51 51&52    win  \
# index
# -Mbc5y71NVYdV2K6bEK2   NaN   NaN   NaN   NaN   NaN  False
# -MbcM7sdvckN292XzTpJ   NaN   NaN   NaN   NaN   NaN  False
#
#                                             behavior blueScore redScore  \
# index
# -Mbc5y71NVYdV2K6bEK2  valueIterationBasedBehavior_v2   -124.00  -125.00
# -MbcM7sdvckN292XzTpJ  valueIterationBasedBehavior_v2   -105.00  -108.00
#
#                      answer-the-quiz
# index
# -Mbc5y71NVYdV2K6bEK2            True
# -MbcM7sdvckN292XzTpJ            True
#
# [2 rows x 56 columns]

# %%
# log_red_copy[log_red_copy['blueScore'] != np.NaN]

# %%
c = log_red_copy[log_red_copy['win'] == True][log_red_copy['answer-the-quiz'].notnull()][log_red_copy['behavior'] == 'aggressiveBehavior']
# log_red_copy['win'].isnull().count()
# c = log_red_copy.tail(103)[['8&9','9&10','10&11','11&12','12&13', '13&14','14&15','15&16']]
c
# Out:
# <ipython-input-108-c7857b997127>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c = log_red_copy[log_red_copy['win'] == True][log_red_copy['answer-the-quiz'].notnull()][log_red_copy['behavior'] == 'aggressiveBehavior']
#                                             1&2                       2&3  \
# index
# -Mb8VfP4PJ_CS9k9DOo8  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -Mb8gguswoRNGTu5xQmY  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbDJHhfY9s5XVsbAuE6  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbDJV9i1SRK4IBf9Q2K  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbDKkuktv-UbUE6GO-8   a1 right a6 left&a2 stay   a2 stay a5 left&a2 down
# -MbDLHJJ0DIlYXuohnmt  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbDQlZLhVODYHaIcWwR  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbDTYiUQxqBA8PwJG4a  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbMUuboGEIPi13efHY-  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbMUvTndsomk-MZUj4E  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbMVUodpc7J5hRs6Igr      a1 down a6 left&b1 up    b1 up a5 left&a1 right
# -MbMWFa0c_NusrL3lmlS  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbMX790ON2X6SDzBku6      a1 down a6 left&b1 up    b1 up a5 left&a1 right
# -MbMZMBrkHUpngae8d6R   a1 right a6 left&a2 down     a2 down a5 left&b2 up
# -MbM_3kKkevPh_t1q-Gj  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbM_9CZ7P1EPqKL9jWE  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbMceXLb6g8wcwoB5XJ  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbMf-NzN9BMCTGGIlCl  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbMm9__hqRuUqRO-FZq  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbMnUjk6OAx34engcty  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbTVHBKPWRk_mryh_Jc  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbTXxX4XvriwbXsKehp  a1 right a6 left&a2 right  a2 right a5 left&a3 down
# -MbTiimSJf0fzavJktY5  a1 right a6 left&a2 right  a2 right a5 left&a3 down
#
#                                            3&4                      4&5  \
# index
# -Mb8VfP4PJ_CS9k9DOo8   a3 down a4 left&b3 stay    b3 stay a3 left&b3 up
# -Mb8gguswoRNGTu5xQmY   a3 down a4 left&b3 stay    b3 stay a3 left&b3 up
# -MbDJHhfY9s5XVsbAuE6     a3 down a4 left&b3 up   b3 up a3 left&a3 right
# -MbDJV9i1SRK4IBf9Q2K     a3 down a4 left&b3 up   b3 up a3 left&a3 right
# -MbDKkuktv-UbUE6GO-8   a2 down a4 left&b2 stay  b2 stay a3 left&b2 stay
# -MbDLHJJ0DIlYXuohnmt   a3 down a4 left&b3 stay    b3 stay a3 left&b3 up
# -MbDQlZLhVODYHaIcWwR   a3 down a4 left&b3 stay    b3 stay a3 left&b3 up
# -MbDTYiUQxqBA8PwJG4a     a3 down a4 left&b3 up    b3 up a3 left&a3 stay
# -MbMUuboGEIPi13efHY-   a3 down a4 left&b3 stay    b3 stay a3 left&b3 up
# -MbMUvTndsomk-MZUj4E   a3 down a4 left&b3 stay  b3 stay a3 left&b3 stay
# -MbMVUodpc7J5hRs6Igr  a1 right a4 left&a2 down    a2 down a3 left&b2 up
# -MbMWFa0c_NusrL3lmlS   a3 down a4 left&b3 stay    b3 stay a3 left&b3 up
# -MbMX790ON2X6SDzBku6  a1 right a4 left&a2 down  a2 down a3 left&b2 stay
# -MbMZMBrkHUpngae8d6R     b2 up a4 left&a2 down    a2 down a3 left&b2 up
# -MbM_3kKkevPh_t1q-Gj     a3 down a4 left&b3 up   b3 up a3 left&a3 right
# -MbM_9CZ7P1EPqKL9jWE     a3 down a4 left&b3 up   b3 up a3 left&a3 right
# -MbMceXLb6g8wcwoB5XJ   a3 down a4 left&b3 stay    b3 stay a3 left&b3 up
# -MbMf-NzN9BMCTGGIlCl     a3 down a4 left&b3 up   b3 up a3 left&a3 right
# -MbMm9__hqRuUqRO-FZq   a3 down a4 left&b3 stay    b3 stay a3 left&b3 up
# -MbMnUjk6OAx34engcty   a3 down a4 left&b3 stay    b3 stay a3 left&b3 up
# -MbTVHBKPWRk_mryh_Jc     a3 down a4 left&b3 up   b3 up a3 left&a3 right
# -MbTXxX4XvriwbXsKehp     a3 down a4 left&b3 up   b3 up a3 left&a3 right
# -MbTiimSJf0fzavJktY5     a3 down a4 left&b3 up   b3 up a3 left&a3 right
#
#                                             5&6                        6&7  \
# index
# -Mb8VfP4PJ_CS9k9DOo8     b3 up a2 left&a3 right  a3 right a1 stay&a4 right
# -Mb8gguswoRNGTu5xQmY     b3 up a2 left&a3 right  a3 right a1 stay&a4 right
# -MbDJHhfY9s5XVsbAuE6  a3 right a2 left&a4 right  a4 right a1 stay&a5 right
# -MbDJV9i1SRK4IBf9Q2K  a3 right a2 left&a4 right  a4 right a1 stay&a5 right
# -MbDKkuktv-UbUE6GO-8    b2 stay a2 left&b2 stay      b2 stay a1 stay&b2 up
# -MbDLHJJ0DIlYXuohnmt     b3 up a2 left&a3 right  a3 right a1 stay&a4 right
# -MbDQlZLhVODYHaIcWwR     b3 up a2 left&a3 right  a3 right a1 stay&a4 right
# -MbDTYiUQxqBA8PwJG4a   a3 stay a2 left&a3 right  a3 right a1 stay&a4 right
# -MbMUuboGEIPi13efHY-     b3 up a2 left&a3 right  a3 right a1 stay&a4 right
# -MbMUvTndsomk-MZUj4E    b3 stay a2 left&b3 stay    b3 stay a1 stay&b3 stay
# -MbMVUodpc7J5hRs6Igr     b2 up a2 left&a2 right  a2 right a1 stay&a3 right
# -MbMWFa0c_NusrL3lmlS     b3 up a2 left&a3 right  a3 right a1 stay&a4 right
# -MbMX790ON2X6SDzBku6      b2 stay a2 left&b2 up     b2 up a1 stay&a2 right
# -MbMZMBrkHUpngae8d6R     b2 up a2 left&a2 right  a2 right a1 stay&a3 right
# -MbM_3kKkevPh_t1q-Gj  a3 right a2 left&a4 right  a4 right a1 stay&a5 right
# -MbM_9CZ7P1EPqKL9jWE  a3 right a2 left&a4 right  a4 right a1 stay&a5 right
# -MbMceXLb6g8wcwoB5XJ     b3 up a2 left&a3 right  a3 right a1 stay&a4 right
# -MbMf-NzN9BMCTGGIlCl  a3 right a2 left&a4 right  a4 right a1 stay&a5 right
# -MbMm9__hqRuUqRO-FZq     b3 up a2 left&a3 right  a3 right a1 stay&a4 right
# -MbMnUjk6OAx34engcty     b3 up a2 left&a3 right  a3 right a1 stay&a4 right
# -MbTVHBKPWRk_mryh_Jc  a3 right a2 left&a4 right  a4 right a1 stay&a5 right
# -MbTXxX4XvriwbXsKehp  a3 right a2 left&a4 right  a4 right a1 stay&a5 right
# -MbTiimSJf0fzavJktY5  a3 right a2 left&a4 right  a4 right a1 stay&a5 right
#
#                                             7&8                        8&9  \
# index
# -Mb8VfP4PJ_CS9k9DOo8  a4 right a1 stay&a5 right                        NaN
# -Mb8gguswoRNGTu5xQmY  a4 right a1 stay&a5 right                        NaN
# -MbDJHhfY9s5XVsbAuE6                        NaN                        NaN
# -MbDJV9i1SRK4IBf9Q2K                        NaN                        NaN
# -MbDKkuktv-UbUE6GO-8      b2 up a1 stay&a2 stay   a2 stay a1 stay&a2 right
# -MbDLHJJ0DIlYXuohnmt  a4 right a1 stay&a5 right                        NaN
# -MbDQlZLhVODYHaIcWwR  a4 right a1 stay&a5 right                        NaN
# -MbDTYiUQxqBA8PwJG4a  a4 right a1 stay&a5 right                        NaN
# -MbMUuboGEIPi13efHY-  a4 right a1 stay&a5 right                        NaN
# -MbMUvTndsomk-MZUj4E      b3 stay a1 stay&b3 up     b3 up a1 stay&a3 right
# -MbMVUodpc7J5hRs6Igr  a3 right a1 stay&a4 right  a4 right a1 stay&a5 right
# -MbMWFa0c_NusrL3lmlS  a4 right a1 stay&a5 right                        NaN
# -MbMX790ON2X6SDzBku6  a2 right a1 stay&a3 right  a3 right a1 stay&a4 right
# -MbMZMBrkHUpngae8d6R  a3 right a1 stay&a4 right  a4 right a1 stay&a5 right
# -MbM_3kKkevPh_t1q-Gj                        NaN                        NaN
# -MbM_9CZ7P1EPqKL9jWE                        NaN                        NaN
# -MbMceXLb6g8wcwoB5XJ  a4 right a1 stay&a5 right                        NaN
# -MbMf-NzN9BMCTGGIlCl                        NaN                        NaN
# -MbMm9__hqRuUqRO-FZq  a4 right a1 stay&a5 right                        NaN
# -MbMnUjk6OAx34engcty  a4 right a1 stay&a5 right                        NaN
# -MbTVHBKPWRk_mryh_Jc                        NaN                        NaN
# -MbTXxX4XvriwbXsKehp                        NaN                        NaN
# -MbTiimSJf0fzavJktY5                        NaN                        NaN
#
#                                            9&10                      10&11  \
# index
# -Mb8VfP4PJ_CS9k9DOo8                        NaN                        NaN
# -Mb8gguswoRNGTu5xQmY                        NaN                        NaN
# -MbDJHhfY9s5XVsbAuE6                        NaN                        NaN
# -MbDJV9i1SRK4IBf9Q2K                        NaN                        NaN
# -MbDKkuktv-UbUE6GO-8   a2 right a1 stay&a3 stay    a3 stay a1 stay&a3 down
# -MbDLHJJ0DIlYXuohnmt                        NaN                        NaN
# -MbDQlZLhVODYHaIcWwR                        NaN                        NaN
# -MbDTYiUQxqBA8PwJG4a                        NaN                        NaN
# -MbMUuboGEIPi13efHY-                        NaN                        NaN
# -MbMUvTndsomk-MZUj4E  a3 right a1 stay&a4 right  a4 right a1 stay&a5 right
# -MbMVUodpc7J5hRs6Igr                        NaN                        NaN
# -MbMWFa0c_NusrL3lmlS                        NaN                        NaN
# -MbMX790ON2X6SDzBku6  a4 right a1 stay&a5 right                        NaN
# -MbMZMBrkHUpngae8d6R                        NaN                        NaN
# -MbM_3kKkevPh_t1q-Gj                        NaN                        NaN
# -MbM_9CZ7P1EPqKL9jWE                        NaN                        NaN
# -MbMceXLb6g8wcwoB5XJ                        NaN                        NaN
# -MbMf-NzN9BMCTGGIlCl                        NaN                        NaN
# -MbMm9__hqRuUqRO-FZq                        NaN                        NaN
# -MbMnUjk6OAx34engcty                        NaN                        NaN
# -MbTVHBKPWRk_mryh_Jc                        NaN                        NaN
# -MbTXxX4XvriwbXsKehp                        NaN                        NaN
# -MbTiimSJf0fzavJktY5                        NaN                        NaN
#
#                       ... 47&48 48&49 49&50 50&51 51&52   win  \
# index                 ...
# -Mb8VfP4PJ_CS9k9DOo8  ...   NaN   NaN   NaN   NaN   NaN  True
# -Mb8gguswoRNGTu5xQmY  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbDJHhfY9s5XVsbAuE6  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbDJV9i1SRK4IBf9Q2K  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbDKkuktv-UbUE6GO-8  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbDLHJJ0DIlYXuohnmt  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbDQlZLhVODYHaIcWwR  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbDTYiUQxqBA8PwJG4a  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbMUuboGEIPi13efHY-  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbMUvTndsomk-MZUj4E  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbMVUodpc7J5hRs6Igr  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbMWFa0c_NusrL3lmlS  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbMX790ON2X6SDzBku6  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbMZMBrkHUpngae8d6R  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbM_3kKkevPh_t1q-Gj  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbM_9CZ7P1EPqKL9jWE  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbMceXLb6g8wcwoB5XJ  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbMf-NzN9BMCTGGIlCl  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbMm9__hqRuUqRO-FZq  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbMnUjk6OAx34engcty  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbTVHBKPWRk_mryh_Jc  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbTXxX4XvriwbXsKehp  ...   NaN   NaN   NaN   NaN   NaN  True
# -MbTiimSJf0fzavJktY5  ...   NaN   NaN   NaN   NaN   NaN  True
#
#                                 behavior blueScore redScore answer-the-quiz
# index
# -Mb8VfP4PJ_CS9k9DOo8  aggressiveBehavior     25.00    22.00            True
# -Mb8gguswoRNGTu5xQmY  aggressiveBehavior     25.00    22.00            True
# -MbDJHhfY9s5XVsbAuE6  aggressiveBehavior     25.00    23.00            True
# -MbDJV9i1SRK4IBf9Q2K  aggressiveBehavior     25.00    23.00            True
# -MbDKkuktv-UbUE6GO-8  aggressiveBehavior     25.00    11.00            True
# -MbDLHJJ0DIlYXuohnmt  aggressiveBehavior     25.00    22.00            True
# -MbDQlZLhVODYHaIcWwR  aggressiveBehavior     25.00    22.00            True
# -MbDTYiUQxqBA8PwJG4a  aggressiveBehavior     25.00    22.00            True
# -MbMUuboGEIPi13efHY-  aggressiveBehavior     25.00    22.00            True
# -MbMUvTndsomk-MZUj4E  aggressiveBehavior     25.00    19.00            True
# -MbMVUodpc7J5hRs6Igr  aggressiveBehavior     25.00    21.00            True
# -MbMWFa0c_NusrL3lmlS  aggressiveBehavior     25.00    22.00            True
# -MbMX790ON2X6SDzBku6  aggressiveBehavior     25.00    20.00            True
# -MbMZMBrkHUpngae8d6R  aggressiveBehavior     25.00    21.00            True
# -MbM_3kKkevPh_t1q-Gj  aggressiveBehavior     25.00    23.00            True
# -MbM_9CZ7P1EPqKL9jWE  aggressiveBehavior     25.00    23.00            True
# -MbMceXLb6g8wcwoB5XJ  aggressiveBehavior     25.00    22.00            True
# -MbMf-NzN9BMCTGGIlCl  aggressiveBehavior     25.00    23.00            True
# -MbMm9__hqRuUqRO-FZq  aggressiveBehavior     25.00    22.00            True
# -MbMnUjk6OAx34engcty  aggressiveBehavior     25.00    22.00            True
# -MbTVHBKPWRk_mryh_Jc  aggressiveBehavior     25.00    23.00            True
# -MbTXxX4XvriwbXsKehp  aggressiveBehavior     25.00    23.00            True
# -MbTiimSJf0fzavJktY5  aggressiveBehavior     25.00    23.00            True
#
# [23 rows x 56 columns]

# %%
def numberOfStepsRemaining(col):
    blueState = col.split(' ')[2]
    prev = int(blueState[1])
    if prev == 1:
        return 0
    moreSteps = prev-3
    if blueState[0] == 'b':
        moreSteps = moreSteps+1;
    return moreSteps

def isColliding(col):
    if '&a5 right' in col and 'b6 stay&' not in col and 'b6 up&' not in col:
        return False
    else:
        return True
def calcBlueRedScore(df):
    blueRedScoreById = pd.DataFrame(index=df.index, columns=['blueScore', 'redScore'])

    blueScores = []
    redScores = []
    df_len = len(df.columns)
    for i, row in df.iterrows():
        blueScore = -2
        redScore = -2
        NotNullLastCol = row[str(1) + '&' + str(1+1)]
        for i in range(2,df_len -4):
            if type(row[str(i) + '&' + str(i+1)]) != float: # game not ended
                redScore = redScore-1
                if row[str(i) + '&' + str(i+1)].split(' ')[2] != 'a1': #blueBall not get to 'a1'
                    blueScore = blueScore-1
                NotNullLastCol = row[str(i) + '&' + str(i+1)]
            else:
                if isColliding(NotNullLastCol):
#                     print(NotNullLastCol)
                    redScore += -100
                    blueScore = redScore
                else:
                    redScore += 30
                    blueScore += 30 + (-1)*numberOfStepsRemaining(NotNullLastCol)
                break
        blueScores.append(blueScore)
        redScores.append(redScore)
#         print(redScore)
#         print(blueScore)
    blueRedScoreById['blueScore'] = blueScores
    blueRedScoreById['redScore'] = redScores
    return blueRedScoreById
                

blueRedScoreById = calcBlueRedScore(log_red_copy)

# %%
blueRedScoreById.loc['-Mb8VfP4PJ_CS9k9DOo8']
# Out:
# blueScore    24
# redScore     22
# Name: -Mb8VfP4PJ_CS9k9DOo8, dtype: int64

# %%
aaaaaa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-f93a0ac260e9> in <module>
# ----> 1 aaaaaa
#
# NameError: name 'aaaaaa' is not defined

# %%
# mask = np.column_stack([log_red_copy[col].str.contains("b3 stay a3 left", na=False) for col in log_red_copy])
# find_result = np.where(mask==True)[0].tolist()
# first_filter = np.array(log_red_copy.index.tolist())[find_result]
# first_filter_log_red = log_red_copy.loc[first_filter,:] #[['3&4','4&5','5&6','6&7','7&8']]

# # mask = np.column_stack([first_filter_log_red[col].str.endswith(" right") for col in first_filter_log_red])
# # find_result = np.where(mask==True)[0].tolist()
# # second_filter = np.array(first_filter_log_red.index.tolist())[find_result]

# # second_filter_log_red = first_filter_log_red.loc[second_filter,:]
# first_filter_log_red

# %%
result = pd.DataFrame(index=log_red.index.drop_duplicates(), columns=['right', 'stay', 'up', 'down'])
# result.reset_index(level=0, inplace=True)
for action in ['right', 'stay', 'up', 'down']:
    result[action] = log_red[log_red['action'] == action]['value']
result = result.fillna(0)
result.reset_index(inplace=True)
result.sort_index()

# %%
# laplace smoving:
for i in range(1,7):
    result.loc[result['state'].str.endswith('a'+str(i)), ['stay', 'right', 'down']] += 1
    
for i in range(1,7):
    result.loc[result['state'].str.endswith('b'+str(i)), ['stay', 'up']] += 1

result = result.set_index('state')
result

# %% [markdown]
# #### Convert it to Probability table:

# %%
pd.options.display.float_format = "{:,.2f}".format
result_probs = result.div(result.sum(axis=1), axis=0)

# %% [markdown]
# #### Save data on computer for the policy iteration:

# %%
result_probs.to_json('data/probs2.json' , orient='index', indent=4)

# %%
def possibleFutureStates(s):
    n_l = []
    for a in actions[s]:
#         print('s: ', adapt_state((3,2)))
#         print(a)
        n = nextStateDistibution(s, a)
        n_l.extend([elm for elm in n])
#         print('n: ', n)
#         print('n_l: ', n_l)
    return n_l

possibleStatesForState = {}
for s in all_states:
    if s in Policy:
        poss_states = possibleFutureStates(s)
        possibleStatesForState[s] = [s for s in poss_states]

# %%
'''==================================================
Initial set up                              version 2
=================================================='''

#Hyperparameters
SMALL_ENOUGH = 0.0001
GAMMA = 0.99

#Define all states
all_states=[]
for prev_state in possibleStatesForState:
    poss_states = possibleStatesForState[prev_state]
    for curr_state in poss_states:
        # current state: (i,j), previous state: (l,k)
        all_states.append((curr_state,prev_state))
all_states.append(((5,0),(-10, -10)))

#Define rewards for all states
rewards = {}
for ((i,j),(l,k)) in all_states:
    if(i == 0): # blue agent in a1
        rewards[((i,j),(l,k))] = richToDestination
    elif(i == j): # crushed
        rewards[((i,j),(l,k))] = crushing
    else:
        rewards[((i,j),(l,k))] = step

#Dictionnary of possible actions. We have two "end" states (1,2 and 2,2)
actions = {}
for ((i,j),(l,k)) in all_states:
    if i != 0 and i != j: #if s=((i, j),(l, k)) is not an "end" state
        actions[((i,j),(l,k))] = ("stay", "left", "down") if (i < 6) else ("up", "stay")

probs = json.load(open('data/probs2.json',))

#Define an initial policy
Policy={}
for s in actions.keys():
    Policy[s] = np.random.choice(actions[s])
    
#Define initial value function 
V={}
for ((i,j),(l,k)) in all_states:
    if ((i,j),(l,k)) in actions.keys():
        V[((i,j),(l,k))] = step
    if(i == 0): # blue agent in a1
        V[((i,j),(l,k))] = richToDestination
    if(i == j): # crushed
        V[((i,j),(l,k))] = crushing

# %%
def nextStateDistibution2(s, a):
    # given state s and action a, return distibution of possibles new states by probs
    nxt = {}
#     print('s: ', s)
#     print('a: ', a)
    bluePossition = newPosGivenAction(s[0], a, 0)
#     print('bluePossition: ', bluePossition)
    
    # red possible action given state
    if s[0][1] == 5:
        actions=["stay"]
    elif s[0][1] < 6:
        actions=["right","stay", "down"]
    else:
        actions=["stay", "up"]
#     print('actions: ', actions)
    for r_a in actions:
        redPossition = newPosGivenAction(s[0], r_a, 1)
#         print('r_a: ', r_a)
#         print('redPossition: ', redPossition)
        newState = ((bluePossition, redPossition),s[0])
#         print('newState: ', newState)
        try:
            nxt[newState] = probs[adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0])][r_a]
        except KeyError:
#             print("Warning! State not found: assume random behavior. ", s[0])
            nxt[newState] = randomProbForAction(s[0])
    assert abs(sum(nxt.values()) - 1.0) < 0.0001, "probs not sum to 1.0. \nstate: " + str(s) + " action: " + str(a) + " nxt: " + str(nxt) + "\nsum of probs: " + str(sum(nxt.values()))
    return nxt

# %%
pp.pprint(nextStateDistibution2(((0, 4),(1, 4)), "stay"))
pp.pprint(nextStateDistibution2(((4, 1),(5, 0)), "left"))

# %%
(adapt_state((1, 8)), adapt_state((1, 8)))

# %%
(adapt_state((1, 2)), adapt_state((1, 8)))

# %%
s = ((1, 8), (2, 8))
print((adapt_state((1, 8)), adapt_state((2, 8))))
print(adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0]))
probs[adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0])]

# %%
pp.pprint(nextStateDistibution2(s, "stay"))

# %%
'''==================================================
Value Iteration
=================================================='''

iteration = 1

while True:
    biggest_change = 0
    for s in all_states:            
        if s in Policy:
            
            old_v = V[s]
            new_v = np.NINF
            
            for a in actions[s]:
#                 print("actions: ", actions[s])
#                 print("action: ", a)
#                 print("state: ", s)
                nxt = nextStateDistibution2(s, a)
#                 print("nxt:", nxt)
                
                v=0
                #Calculate the value
                for next_state, prob in nxt.items():
#                     print("next_state: ", next_state)
#                     print("prob: ", prob)
#                     print('V[next_state]: ', V[next_state])
                    assert rewards[s] == -1, "rewards is not -1"
                    v += prob * (rewards[s] + GAMMA * V[next_state])
#                 print('v: ', v)
#                 print()
                if v > new_v: #Is this the best action so far? If so, keep it
                    new_v = v
                    Policy[s] = a

           #Save the best of all actions for the state                                
            V[s] = new_v
            biggest_change = max(biggest_change, np.abs(old_v - V[s]))

            
   #See if the loop should stop now         
    if biggest_change < SMALL_ENOUGH:
        print('converge after: ' + str(iteration) + ' iterations')
        break
    iteration += 1
    
    #Print every 100 iterations
#     if(iteration % 100 == 0):
#         print(iteration, ') ', V[(5, 0)]) # V([a6,a1])

# %%
def convertStates(Policy):
    P_convert= {}
    V_convert = {}
    for s,v in V.items():
        V_convert[adapt_state(s[0]) + ',' + adapt_state(s[1])] = v
    
#     print()
    for s,p in Policy.items():
        P_convert[adapt_state(s[0]) + ',' + adapt_state(s[1])] = p
    
#     pp.pprint(V_convert)
#     pp.pprint(P_convert)
    return P_convert, V_convert

# %%
# print the results:
print("iterations: ", iteration)
optimal_policy_v2, optimal_V_v2 = convertStates(Policy)

# %%
# intensity = np.array(list(V.values())).reshape(1, 693)
# f, ax = plt.subplots(figsize=(2^16, 2^16))
# sns.heatmap(intensity, annot=True, linewidths=0.1, cmap="YlGnBu")

# %%
optimal_policy_v2

# %%
def policy_eval2(policy):
    V={}
    for ((i,j),(l,k)) in all_states:
        if ((i,j),(l,k)) in actions.keys():
            V[((i,j),(l,k))] = step
        if(i == 0): # blue agent in a1
            V[((i,j),(l,k))] = richToDestination
        if(i == j): # crashed
            V[((i,j),(l,k))] = crushing
    while True:
        biggest_change = 0
        for s in all_states:
            if s in Policy:
                old_v = V[s]
                nxt = nextStateDistibution2(s, policy[s])
                v=0
                #Calculate the value
                for next_state, prob in nxt.items():
                    assert rewards[s] == -1, "rewards[s] is not -1"
                    v += prob * (rewards[s] + GAMMA * V[next_state])
        
                #Save the best of all actions for the state                                
                V[s] = v
                biggest_change = max(biggest_change, np.abs(old_v - V[s]))
        #See if the loop should stop now         
        if biggest_change < SMALL_ENOUGH:
            return V

# %%
a = policy_eval2(Policy)
a

# %%
Policy

# %%
def extend_policy(policy):
    # take policy without velocity and convert it to policy with velocity
    policy_with_velocity = {}
    for ((i,j),(l,k)) in actions.keys():
        policy_with_velocity[((i,j),(l,k))] = policy[(i,j)]
    return policy_with_velocity

# %%
careful_eval_v2 = policy_eval2(extend_policy(careful_policy))
random_eval_v2 = policy_eval2(extend_policy(random_policy))
aggressive_eval_v2 = policy_eval2(extend_policy(aggressive_policy))
semiAggressive_eval_v2 = policy_eval2(extend_policy(semiAggressive_policy))
semiCareful_eval_v2 = policy_eval2(extend_policy(semiCareful_policy))
valueIteration_eval_v2 = policy_eval2(extend_policy(valueIteration_policy))
# [((5,0),(-10,-10))]

# %%
real_col = df.groupby(['behavior']).mean()['blueScore'].drop('carefulBehavior')
diff = pd.DataFrame({'Real': real_col,
                      'Prediction': [aggressive_intensity[5][0], randomBehavior_intensity[5][0], semiAggressive_intensity[5][0], semiCareful_intensity[5][0], np.NaN],
                     'Prediction with velocity': [aggressive_eval_v2[((5,0),(-10,-10))], random_eval_v2[((5,0),(-10,-10))], semiAggressive_eval_v2[((5,0),(-10,-10))], semiCareful_eval_v2[((5,0),(-10,-10))], valueIteration_eval_v2[((5,0),(-10,-10))]]},
                     index= real_col.index)
diff['different'] = abs(diff['Real']-diff['Prediction with velocity'])
diff

# %%
# real_col = df.groupby(['behavior']).mean()['blueScore'].append(pd.Series([np.NaN], index=['valueIterationBehavior']))
# diff = pd.DataFrame({'Real': real_col,
#                       'Prediction': [aggressive_intensity[5][0] , careful_intensity[5][0], randomBehavior_intensity[5][0], semiAggressive_intensity[5][0], semiCareful_intensity[5][0], np.NaN, optimal_V['a6 a1']],
#                      'Prediction with velocity': [aggressive_eval_v2[((5,0),(-10,-10))], careful_eval_v2[((5,0),(-10,-10))], random_eval_v2[((5,0),(-10,-10))], semiAggressive_eval_v2[((5,0),(-10,-10))], semiCareful_eval_v2[((5,0),(-10,-10))],  V[((5,0),(-10,-10))], valueIteration_eval_v2[((5,0),(-10,-10))]]},
#                      index= real_col.index)
# diff['different'] = abs(diff['Real']-diff['Prediction with velocity'])
# diff

# %%
# real_col = df.groupby(['behavior']).mean()['blueScore'].append(pd.Series([np.NaN, np.NaN], index=['valueIterationBehavior', 'valueIterationBehavior_v2'])) #.drop('carefulBehavior')
# diff = pd.DataFrame({'Real': real_col,
#                       'Prediction': [aggressive_intensity[5][0], randomBehavior_intensity[5][0] , semiAggressive_intensity[5][0], semiCareful_intensity[5][0], np.NaN, optimal_V['a6 a1']],
#                      'Prediction with velocity': [aggressive_eval_v2[((5,0),(-10,-10))], random_eval_v2[((5,0),(-10,-10))] , semiAggressive_eval_v2[((5,0),(-10,-10))], semiCareful_eval_v2[((5,0),(-10,-10))],  V[((5,0),(-10,-10))], valueIteration_eval_v2[((5,0),(-10,-10))]]},
#                      index= real_col.index)
# diff['different'] = abs(diff['Real']-diff['Prediction with velocity'])
# diff

# %%
# valueIteration_eval_v2[((5,0),(-10,-10))]

# %%
V[((5,0),(-10,-10))] # this is from the value iteration

# %%
a[((5,0),(-10,-10))] # this is from the eval policy

# %% [markdown]
# # push to firebase:

# %%
import pyrebase

firebaseConfig = {
    "apiKey": "AIzaSyDROtt5r3t5VL_iPabcgVgsWmUZHMw7Pv8",
    "authDomain": "road-game.firebaseapp.com",
    "databaseURL": "https://road-game-default-rtdb.firebaseio.com",
    "projectId": "road-game",
    "storageBucket": "road-game.appspot.com",
    "messagingSenderId": "14363967441",
    "appId": "1:14363967441:web:9efd1c7c3db93ab12ceaf0"
  }

firebase=pyrebase.initialize_app(firebaseConfig)

db=firebase.database()

# %%
try:
    db.child("aggressiveBehavior").set(convertStates(extend_policy(aggressive_policy))[0])
    
    db.child("carefulBehavior").set(convertStates(extend_policy(careful_policy))[0])
    
    db.child("semiCarefulBehavior").set(convertStates(extend_policy(semiCareful_policy))[0])
    
    db.child("randomBehavior").set(convertStates(extend_policy(random_policy))[0])
    
    db.child("semiAggressiveBehavior").set(convertStates(extend_policy(semiAggressive_policy))[0])
    
    db.child("valueIterationBasedBehavior_v2").set(optimal_policy_v2)
    
    db.child("valueIterationBehavior").set(convertStates(extend_policy(valueIteration_policy))[0])
except Exception as err:
    print(err)

# %% [markdown]
# build opponent model:
# it uses the human model 50% of the time, and uses our mirrored model 50% of the time.
#
# Now find the maximum.
# I.e., find the optimal policy.
# Once you find a policy update the opponent model and find the optimal policy again. Hopefully it will converge.

# %%
def nextStateDistibution3(s, a, prev_action_at_prev_policy):
    # prev_action_at_prev_policy = what was the blue agent action at state
    # given state s and action a, return distibution of possibles new states by probs
    nxt = {}
#     print('s: ', s)
#     print('a: ', a)
    bluePossition = newPosGivenAction(s[0], a, 0)
#     print('bluePossition: ', bluePossition)
    
    if(prev_action_at_prev_policy == "left"):
        a_to_compare = "right"
    else:
        a_to_compare = prev_action_at_prev_policy
#     print('a_to_compare: ', a_to_compare)
    # red possible action given state
    if s[0][1] == 5:
        actions=["stay"]
    elif s[0][1] < 6:
        actions=["right","stay", "down"]
    else:
        actions=["stay", "up"]
#     print('actions: ', actions)
    for r_a in actions:
        redPossition = newPosGivenAction(s[0], r_a, 1)
#         print('r_a: ', r_a)
#         print('redPossition: ', redPossition)
        newState = ((bluePossition, redPossition),s[0])
#         print('newState: ', newState)
        try:
            nxt[newState] = probs[adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0])][r_a] * 0.75
            if(r_a == a_to_compare):
                nxt[newState] = nxt[newState] + 0.25 
        except KeyError:
#             print("Warning! State not found: assume random behavior. ", s[0])
            nxt[newState] = randomProbForAction(s[0]) * 0.75
            if(r_a == a_to_compare):
                nxt[newState] = nxt[newState] + 0.25
    assert abs(sum(nxt.values()) - 1.0) < 0.0001, "probs not sum to 1.0. \nstate: " + str(s) + " action: " + str(a) + " nxt: " + str(nxt) + "\nsum of probs: " + str(sum(nxt.values()))
    return nxt

# %%
s = ((1, 0), (1, 0))
a = "stay"
nextStateDistibution3(s, a, "stay")

# %%
mirror_dict_pos = {0:5,
                  1:4,
                  2:3,
                  3:2,
                  4:1,
                  5:0,
                  6:11,
                  7:10,
                  8:9,
                  9:8,
                  10:7,
                  11:6,
                  -10:-10}

def mirror_pos(pos):
    return mirror_dict_pos[pos]

mirror_pos(7)

# %%
def mirror_state(s):
    ((i,j),(l,k)) = s
    return ((mirror_pos(j), mirror_pos(i)),(mirror_pos(k), mirror_pos(l)))

# %%
mirror_state(((1, 5), (1, 4)))

# %%
# import copy

# %%
# prev_policy = {}

# %%
# while(prev_policy != Policy):
#     prev_policy = copy.deepcopy(Policy)

#     '''==================================================
#     Value Iteration
#     =================================================='''
#     iteration = 1
#     while True:
#         biggest_change = 0
#         for s in all_states:            
#             if s in Policy:

#                 old_v = V[s]
#                 new_v = np.NINF

#                 for a in actions[s]:
#                     try:
#                         blue_action_as_red = prev_policy[mirror_state(s)]
#                     except KeyError: # it can fail only if blue in end-state
#                         blue_action_as_red = "stay"

#                     nxt = nextStateDistibution3(s, a, blue_action_as_red)
#                     v=0
#                     #Calculate the value
#                     for next_state, prob in nxt.items():
#                         assert rewards[s] == -1, "rewards is not -1"
#                         v += prob * (rewards[s] + GAMMA * V[next_state])
#                     if v > new_v: #Is this the best action so far? If so, keep it
#                         new_v = v
#                         Policy[s] = a

#                #Save the best of all actions for the state                                
#                 V[s] = new_v
#                 biggest_change = max(biggest_change, np.abs(old_v - V[s]))


#        #See if the loop should stop now         
#         if biggest_change < SMALL_ENOUGH:
#             print('converge after: ' + str(iteration) + ' iterations')
#             break
#         iteration += 1

#         #Print every 100 iterations
#         if(iteration % 100 == 0):
#             print(iteration, "iterations")

# %%
# Policy

# %%
# policy_eval2(Policy)[((5,0),(-10,-10))]

# %%
# def humanBehavior():
#     # Behavior based on the data we gather
#     Policy={}
#     for s in actions.keys():
#         try:
#             row = probs[adapt_state(s[1]) + ' nxt: ' + adapt_state(s[0])]
#             Policy[s] = np.random.choice(list(row.keys()), p=list(row.values()))
#         except KeyError:
# #             print("Warning! State not found: assume random behavior. ", s[0])
#             Policy[s] = np.random.choice(actions[s])
#         # take the action with higher prob
#     return Policy

# human_policy = humanBehavior()

# %%
# class Opponent_model:

#     def __init__(self, human_policy, mirrored_policy, p):
#         # humen_policy is made from the data
#         # mirrored_policy is the old policy of Value Iteration based agent.
#         self.human_policy = human_policy
#         self.mirrored_policy = mirrored_policy
#         self.p = p

#     def updateMirroredPolicy(self, new_mirrored_policy):
#         self.mirrored_policy = new_mirrored_policy
        
#     def getAction(self, state):
#         human_action = self.human_policy[state]
#         mirrored_action = self.mirrored_policy[state]
#         return np.random.choice([human_action, mirrored_action], p=[self.p, 1-self.p])

#     def __str__(self):
#         return "human_policy:\n " + str(self.human_policy) + "\n" + str(self.mirrored_policy) + "\n p: " + str(self.p)

# %%
# V[((5,0),(-10,-10))]

# %%
# Policy[((5,0),(-10,-10))]

# %%
# optimal_policy_v3, optimal_V_v3 = convertStates()

# %%
# try:
#     db.child("valueIterationBasedBehavior_v3").set(optimal_policy_v3)
# except Exception as err:
#     print(err)
